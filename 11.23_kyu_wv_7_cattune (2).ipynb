# %% [markdown]
# # <font color='CC3D3D'>데이터 불러오기

# %%
import pandas as pd
import numpy as np
import missingno as msno
import klib
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rc('font',family='Malgun Gothic')
pd.set_option('display.max_columns', None)

from sklearn.decomposition import PCA

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# # 파일불러오기

# %%
train = pd.read_csv('L.POINT_train.csv', encoding='UTF-8')
test = pd.read_csv('L.POINT_test.csv', encoding='UTF-8')
y_train =  pd.read_csv('y_train.csv')

# %%
train['PD_BUY_AM']  = train['PD_BUY_AM'].map(lambda x: int(str(x).replace(',','')) )
train['PD_BUY_CT']  = train['PD_BUY_CT'].map(lambda x: int(str(x).replace(',','')) )
test['PD_BUY_AM']  = test['PD_BUY_AM'].map(lambda x: int(str(x).replace(',','')) )
test['PD_BUY_CT']  = test['PD_BUY_CT'].map(lambda x: int(str(x).replace(',','')) )

# %% [markdown]
# # <font color='CC3D3D'>Feature Making

# %%
data=pd.DataFrame()
data_te=pd.DataFrame()

# %%
train
# Out:
#          CLNT_ID  SESS_ID  HITS_SEQ    PD_C              PD_ADD_NM  \
# 0              0  6771240        63  578845                     1개
# 1              0  6771240        63  788068       선택:버닝 [베이지] / 1개
# 2              1  5762174       109  180447        사이즈:L(105) / 1개
# 3              1  5753875        94  731145                     1개
# 4              1  7417570       114  216947                     1개
# ...          ...      ...       ...     ...                    ...
# 1948681   263103  4792233        76  144818  색상:핑크(P)|사이즈:105 / 1개
# 1948682   263103  4792233        76  144818  색상:핑크(P)|사이즈:105 / 1개
# 1948683   263103  4792233        76  144818  색상:핑크(P)|사이즈:105 / 1개
# 1948684   263103  4792233        76  144818  색상:핑크(P)|사이즈:105 / 1개
# 1948685   263103  4792233       165  307369  색상:핑크(P)|사이즈:120 / 1개
#
#             PD_BRA_NM  PD_BUY_AM  PD_BUY_CT  SESS_SEQ   SESS_DT  \
# 0        필립스(PHILIPS)      81000          1        17  20180609
# 1                쁘리엘르       5500          1        17  20180609
# 2                 퀵실버      59000          1        12  20180626
# 3                  키엘      39000          1        13  20180626
# 4                  키엘      49000          1         2  20180529
# ...               ...        ...        ...       ...       ...
# 1948681         엠엘비키즈      79000          1       182  20180712
# 1948682         엠엘비키즈      79000          1       182  20180712
# 1948683         엠엘비키즈      79000          1       182  20180712
# 1948684         엠엘비키즈      79000          1       182  20180712
# 1948685         엠엘비키즈      69000          1       182  20180712
#
#          TOT_PAG_VIEW_CT TOT_SESS_HR_V DVC_CTG_NM       ZON_NM     CITY_NM  \
# 0                   59.0           922     mobile  Gyeonggi-do  Bucheon-si
# 1                   59.0           922     mobile  Gyeonggi-do  Bucheon-si
# 2                  161.0         1,661     mobile        Seoul       Seoul
# 3                  115.0           620     mobile        Seoul       Seoul
# 4                  122.0           860     mobile        Seoul       Seoul
# ...                  ...           ...        ...          ...         ...
# 1948681            271.0         2,627     mobile        Seoul       Seoul
# 1948682            271.0         2,627     mobile        Seoul       Seoul
# 1948683            271.0         2,627     mobile        Seoul       Seoul
# 1948684            271.0         2,627     mobile        Seoul       Seoul
# 1948685            271.0         2,627     mobile        Seoul       Seoul
#
#           KWD_NM  SEARCH_CNT                                        PD_NM  \
# 0         에어컨 커버           1                     아방세 프로믹스 핸드블렌더 HR1672/90
# 1         에어컨 커버           1  스판 벽걸이 에어컨커버(트라이앵글_82x27x26) 모음 - 블루가든 [블루]
# 2          바비브라운           1            퀵실버 남성 루즈핏 래쉬가드 QS579KMT - M(100)
# 3             키엘           2                   칼렌듈라 딥 클렌징 포밍 페이스 워시 230ml
# 4          키엘비타민           2                             키엘 자외선 차단제 점보 세트
# ...          ...         ...                                          ...
# 1948681     키즈샌들           1       돌핀 배색 올인원 수영복[71SW77831] - 핑크(P) / 110
# 1948682      갭키즈           1       돌핀 배색 올인원 수영복[71SW77831] - 핑크(P) / 110
# 1948683    팁토이조이           1       돌핀 배색 올인원 수영복[71SW77831] - 핑크(P) / 110
# 1948684  갭키즈 수영복           1       돌핀 배색 올인원 수영복[71SW77831] - 핑크(P) / 110
# 1948685   갭키즈 여아           1      여아 돌고래 배색 래쉬가드[71SW50831] - 핑크(P) / 105
#
#          CLAC1_NM CLAC2_NM CLAC3_NM
# 0         생활/주방가전     주방가전      블랜더
# 1           침구/수예     수예소품   거실수예소품
# 2           시즌스포츠   수영/물놀이    남성수영복
# 3        화장품/뷰티케어     스킨케어   페이셜클렌저
# 4        화장품/뷰티케어      선케어     선크림류
# ...           ...      ...      ...
# 1948681     시즌스포츠   수영/물놀이    아동수영복
# 1948682     시즌스포츠   수영/물놀이    아동수영복
# 1948683     시즌스포츠   수영/물놀이    아동수영복
# 1948684     시즌스포츠   수영/물놀이    아동수영복
# 1948685     시즌스포츠   수영/물놀이    아동수영복
#
# [1948686 rows x 21 columns]

# %% [markdown]
# **[총구매액, 구매건수, 평균구매액, 최대구매액]**

# %%
train['AMOUNT'] = train['PD_BUY_AM'] * train['PD_BUY_CT']
test['AMOUNT'] = test['PD_BUY_AM'] * test['PD_BUY_CT']

# %%
f = train.groupby('CLNT_ID')['AMOUNT'].agg([('총구매액', np.sum),
                                            ('평균구매액', lambda x : np.round(np.mean(x))),
                                            ('최대구매액', np.max)])
data=pd.concat([data,f],axis=1)

f_te = test.groupby('CLNT_ID')['AMOUNT'].agg([('총구매액', np.sum),
                                            ('평균구매액', lambda x : np.round(np.mean(x))),
                                            ('최대구매액', np.max)])
data_te = pd.concat([data_te,f_te],axis=1);data_te
# Out:
#            총구매액   평균구매액   최대구매액
# CLNT_ID
# 2        560000   50909   62100
# 3        851200  106400  110400
# 4        125200   20867   37000
# 5        380000   31667   42000
# 7        457900   28619   40000
# ...         ...     ...     ...
# 263097   753220   57940  105000
# 263098   601200  100200  100200
# 263099   973000    8688   22000
# 263100    22400   11200   12900
# 263101   135600   33900   33900
#
# [113104 rows x 3 columns]

# %% [markdown]
# **[최소구매액]**

# %%
f = train.groupby('CLNT_ID')['AMOUNT'].agg([('최소구매액', np.min)]) #최소구매액
data=pd.concat([data,f],axis=1)

f_te = test.groupby('CLNT_ID')['AMOUNT'].agg([('최소구매액', np.min)]) #최소구매액
data_te = pd.concat([data_te,f_te],axis=1);data_te
# Out:
#            총구매액   평균구매액   최대구매액   최소구매액
# CLNT_ID
# 2        560000   50909   62100   20000
# 3        851200  106400  110400  102400
# 4        125200   20867   37000   12800
# 5        380000   31667   42000   11000
# 7        457900   28619   40000   20600
# ...         ...     ...     ...     ...
# 263097   753220   57940  105000   25900
# 263098   601200  100200  100200  100200
# 263099   973000    8688   22000    7000
# 263100    22400   11200   12900    9500
# 263101   135600   33900   33900   33900
#
# [113104 rows x 4 columns]

# %% [markdown]
# **[주말방문비율]**

# %%
train['date'] = pd.to_datetime(train['SESS_DT'], format= '%Y%m%d')
test['date'] = pd.to_datetime(test['SESS_DT'], format= '%Y%m%d')

# %%
f = train.groupby('CLNT_ID')['date'].agg([('주말방문비율', lambda x: np.mean(x.dt.dayofweek>4))])
data=pd.concat([data,f],axis=1)

f_te = test.groupby('CLNT_ID')['date'].agg([('주말방문비율', lambda x: np.mean(x.dt.dayofweek>4))])
data_te=pd.concat([data_te,f_te],axis=1); data_te
# Out:
#            총구매액   평균구매액   최대구매액   최소구매액    주말방문비율
# CLNT_ID
# 2        560000   50909   62100   20000  0.000000
# 3        851200  106400  110400  102400  1.000000
# 4        125200   20867   37000   12800  0.333333
# 5        380000   31667   42000   11000  0.000000
# 7        457900   28619   40000   20600  0.312500
# ...         ...     ...     ...     ...       ...
# 263097   753220   57940  105000   25900  0.307692
# 263098   601200  100200  100200  100200  0.000000
# 263099   973000    8688   22000    7000  0.000000
# 263100    22400   11200   12900    9500  0.500000
# 263101   135600   33900   33900   33900  0.000000
#
# [113104 rows x 5 columns]

# %% [markdown]
# 고가상품구매율

# %%
# 상품중분류별 평균 판매단가에 대한 4분위수 계산 => 3Q 이상을 고가상품으로 설정

#train
price_4q = train.groupby('CLAC2_NM')['PD_BUY_AM'].mean().quantile([.25,.5,.75])
f = (train.groupby('CLNT_ID')['PD_BUY_AM'].agg([('고가상품구매율', lambda x: (x > price_4q.iloc[2]).mean().round(2))]))
data=pd.concat([data,f],axis=1)


#test
price_4q = test.groupby('CLAC2_NM')['PD_BUY_AM'].mean().quantile([.25,.5,.75])
f_te = (test.groupby('CLNT_ID')['PD_BUY_AM'].agg([('고가상품구매율', lambda x: (x > price_4q.iloc[2]).mean().round(2))]))
data_te=pd.concat([data_te,f_te],axis=1)

# %% [markdown]
# ### 내점일수

# %%
# train
f = train.groupby("CLNT_ID")['date'].agg([('내점일수',lambda x: x.nunique()),('구매주기', lambda x : int(((x.max() - x.min()).days) / x.nunique()))])
data=pd.concat([data,f],axis=1)


# test
f_te = test.groupby("CLNT_ID")['date'].agg([('내점일수',lambda x: x.nunique()),('구매주기', lambda x : int(((x.max() - x.min()).days) / x.nunique()))])
data_te=pd.concat([data_te,f_te],axis=1)

# %% [markdown]
# 구매빈도

# %%
# 최종 구매일 다음날을 기준으로 계산 
# 최종 구매일 + 1일 더하기

#train
now = train.date.max()+pd.DateOffset(days=1) #1은 하루전 구매 38은 38일전구매 (누가 가장 최근에 구매하는가)
f = train.groupby('CLNT_ID')['date'].agg(lambda x,y: (y - x).min().days, now)
data=pd.concat([data,f],axis=1)
data = data.rename(columns = {"date" : "recency"})
# test
now_te = test.date.max()+pd.DateOffset(days=1)
f_te = test.groupby('CLNT_ID')['date'].agg(lambda x,y: (y - x).min().days, now_te)
data_te=pd.concat([data_te,f_te],axis=1)
data_te = data_te.rename(columns = {"date" : "recency"})

# %% [markdown]
# 세션 접속 일수

# %%
#train
f = pd.DataFrame(train.groupby("CLNT_ID")["date"].nunique())
f = f.rename(columns = {"date" : "세션 접속 일수"})
data = pd.concat([data,f],axis=1)
#test
f_te = pd.DataFrame(test.groupby("CLNT_ID")["date"].nunique())
f_te = f_te.rename(columns = {"date" : "세션 접속 일수"})
data_te = pd.concat([data_te,f_te],axis=1)

# %% [markdown]
# 총 페이지 조회 건수

# %%
#train
df = train[['CLNT_ID','TOT_PAG_VIEW_CT']]

f = df.groupby(['CLNT_ID'])['TOT_PAG_VIEW_CT'].agg([('총페이지조회건수','sum')])
data = pd.concat([data,f],axis=1)

#test
df_te = test[['CLNT_ID','TOT_PAG_VIEW_CT']]

f_te = df_te.groupby(['CLNT_ID'])['TOT_PAG_VIEW_CT'].agg([('총페이지조회건수','sum')])
data_te = pd.concat([data_te,f_te],axis=1)

# %% [markdown]
# 상위 키워드 검색의 합

# %%
# 검색키워드명 KWD_NM (많이 나온 단어 검색 비율)
#train
df = train[['CLNT_ID','KWD_NM']]

len(train['KWD_NM'])
# 단어 언급 횟수
KWD = dict()
for i in train['KWD_NM'] :
    KWD[i] = KWD.get(i,0) +1
    
# 자주 언급되는 단어 Top20
a = sorted([(v,k) for k,v in KWD.items()], reverse=True)[:20]
#TOP20 이름
b=[]
for i in range(20):
    b.append(a[i][1])
    
# Top20 안에든 단어 검색하면 1, 아니면 0
def f_word(x):
    if x in b:
        return 1
    else:
        return 0

df['상위키워드검색여부']=df['KWD_NM'].apply(f_word)
#display(df)
f = df.groupby(['CLNT_ID'])['상위키워드검색여부'].agg([('상위키워드검색합','sum')])
data = pd.concat([data,f],axis=1)


# 검색키워드명 KWD_NM (많이 나온 단어 검색 비율)
#test
df_te = test[['CLNT_ID','KWD_NM']]

len(test['KWD_NM'])
# 단어 언급 횟수
KWD_te = dict()
for i in test['KWD_NM'] :
    KWD_te[i] = KWD_te.get(i,0) +1
    
# 자주 언급되는 단어 Top20
a_te = sorted([(v,k) for k,v in KWD_te.items()], reverse=True)[:20]
#TOP20 이름
b_te=[]
for i in range(20):
    b_te.append(a_te[i][1])
    
# Top20 안에든 단어 검색하면 1, 아니면 0
def f_te_word(x):
    if x in b:
        return 1
    else:
        return 0

df_te['상위키워드검색여부']=df_te['KWD_NM'].apply(f_te_word)
#display(df)
f_te = df_te.groupby(['CLNT_ID'])['상위키워드검색여부'].agg([('상위키워드검색합','sum')])
data_te = pd.concat([data_te,f_te],axis=1)

# %% [markdown]
# 총접속시간 대비 최소,최대,평균 접속시간

# %%
train['TOT_SESS_HR_V']  = train['TOT_SESS_HR_V'].map(lambda x: int(str(x).replace(',','')))
test['TOT_SESS_HR_V']  = test['TOT_SESS_HR_V'].map(lambda x: int(str(x).replace(',','')))

# %%
#train
f = train.groupby('CLNT_ID')['TOT_SESS_HR_V'].agg([('총접속시간', np.sum),
                                                   ('평균접속시간', lambda x : np.round(np.mean(x))),
                                                   ('최대접속시간', np.max),
                                                   ('최소접속시간', np.min)])

f['총접속시간 대비 평균접속시간'] = f['평균접속시간']/f['총접속시간']
f['총접속시간 대비 최대접속시간'] = f['최대접속시간']/f['총접속시간']
f['총접속시간 대비 최소접속시간'] = f['최소접속시간']/f['총접속시간']

data=pd.concat([data,f],axis=1)
#test
f_te = test.groupby('CLNT_ID')['TOT_SESS_HR_V'].agg([('총접속시간', np.sum),
                                                   ('평균접속시간', lambda x : np.round(np.mean(x))),
                                                   ('최대접속시간', np.max),
                                                   ('최소접속시간', np.min)])

f_te['총접속시간 대비 평균접속시간'] = f_te['평균접속시간']/f_te['총접속시간']
f_te['총접속시간 대비 최대접속시간'] = f_te['최대접속시간']/f_te['총접속시간']
f_te['총접속시간 대비 최소접속시간'] = f_te['최소접속시간']/f_te['총접속시간']

data_te=pd.concat([data_te,f_te],axis=1)

# %% [markdown]
# # power Transformation

# %%
data
# Out:
#             총구매액   평균구매액   최대구매액  최소구매액    주말방문비율  고가상품구매율  내점일수  구매주기  \
# CLNT_ID
# 0          86500   43250   81000   5500  1.000000     0.00     1     0
# 1        1276000   79750   99000  39000  0.125000     0.44     4     7
# 6         148900   21271   44900   8000  0.857143     0.00     2     8
# 9          42200   10550   12600   8500  1.000000     0.00     1     0
# 12        510180   15943   79000    990  0.250000     0.00     5    12
# ...          ...     ...     ...    ...       ...      ...   ...   ...
# 263094     10000   10000   10000  10000  0.000000     0.00     1     0
# 263095    511000  102200  155000  89000  0.000000     0.20     2    41
# 263096     85500   28500   47000  17000  0.000000     0.00     1     0
# 263102     59400    3960    9720   1080  0.000000     0.00     1     0
# 263103   2961200   61692   79000  35000  0.000000     0.00     3     9
#
#          recency  세션 접속 일수  총페이지조회건수  상위키워드검색합   총접속시간  평균접속시간  최대접속시간  \
# CLNT_ID
# 0            114         1     118.0         0    1844     922     922
# 1             96         4    2045.0         0   22160    1385    3063
# 6            128         2     144.0         6    1966     281     412
# 9            162         1     996.0         0   20196    5049    5049
# 12            18         5    4335.0         0  124592    3894    5435
# ...          ...       ...       ...       ...     ...     ...     ...
# 263094       130         1      66.0         0     513     513     513
# 263095        35         2    1383.0         0   10688    2138    2344
# 263096        88         1     768.0         0   12711    4237    4237
# 263102       144         1    2820.0         3   27180    1812    1812
# 263103        56         3   14997.0         1  170047    3543    5156
#
#          최소접속시간  총접속시간 대비 평균접속시간  총접속시간 대비 최대접속시간  총접속시간 대비 최소접속시간
# CLNT_ID
# 0           922         0.500000         0.500000         0.500000
# 1           620         0.062500         0.138222         0.027978
# 6           259         0.142930         0.209563         0.131740
# 9          5049         0.250000         0.250000         0.250000
# 12          735         0.031254         0.043622         0.005899
# ...         ...              ...              ...              ...
# 263094      513         1.000000         1.000000         1.000000
# 263095     1312         0.200037         0.219311         0.122754
# 263096     4237         0.333333         0.333333         0.333333
# 263102     1812         0.066667         0.066667         0.066667
# 263103      530         0.020835         0.030321         0.003117
#
# [150000 rows x 19 columns]

# %%
# making data more Gaussian-like
from sklearn.preprocessing import PowerTransformer

scaler = PowerTransformer(standardize=True)
data_sc = scaler.fit(data).transform(data)

# %%
data_te_sc = scaler.transform(data_te)

# %%
data_sc = pd.DataFrame(data_sc)
data_te_sc = pd.DataFrame(data_te_sc)

# %%
display(data_te_sc)
display(data_sc)
# Out:
#          0         1         2         3         4         5         6   \
# 0       0.0  0.352807  0.105847 -0.013397 -0.836109 -0.579314  0.516369
# 1       0.0  1.145305  0.663831  1.441632  1.488220  2.011584 -0.877109
# 2       0.0 -0.632115 -0.400375 -0.411404  0.686927 -0.579314  0.516369
# 3       0.0 -0.167887 -0.276109 -0.546597 -0.836109 -0.579314 -0.877109
# 4       0.0 -0.279939 -0.323915  0.012959  0.632533 -0.579314  1.511260
# ...     ...       ...       ...       ...       ...       ...       ...
# 113099  0.0  0.493283  0.615383  0.217072  0.619493  1.574110  0.516369
# 113100  0.0  1.081480  0.570147  1.422298 -0.836109  2.011584 -0.877109
# 113101  0.0 -1.628348 -0.912471 -0.949906 -0.836109 -0.579314 -0.877109
# 113102  0.0 -1.336632 -1.442362 -0.677394  1.023183 -0.579314  0.516369
# 113103  0.0 -0.092653 -0.486296  0.456984 -0.836109 -0.579314 -0.877109
#
#               7         8         9         10        11        12        13  \
# 0       1.525705 -0.929833  0.516369  0.933633  2.655081  1.005734  1.428969
# 1      -0.868404 -1.106506 -0.877109  0.175981 -0.378682  0.021185 -0.583829
# 2       1.581127 -0.368136  0.516369 -0.301400 -0.378682 -0.387792 -1.041173
# 3      -0.868404 -1.169798 -0.877109  0.059888 -0.378682  0.883057  0.930463
# 4       1.259175  0.373620  1.511260  1.162320  2.616895  1.219075  1.460232
# ...          ...       ...       ...       ...       ...       ...       ...
# 113099  1.401151  0.523213  0.516369  1.303488  2.654615  0.943817  0.977957
# 113100 -0.868404 -1.202435 -0.877109  0.230215 -0.378682 -0.081573 -0.450320
# 113101 -0.868404  0.390552 -0.877109  2.049846  2.655096  2.160766  1.232131
# 113102  1.154287  0.539463  0.516369 -0.617477 -0.378682 -0.599671 -0.167648
# 113103 -0.868404  1.209867 -0.877109 -0.355748  2.654978 -0.072843  0.086322
#
#               14        15        16        17        18
# 0       1.176994 -0.981699 -0.829548 -0.916489 -1.233363
# 1      -0.744515  0.090627 -0.592986 -0.747172 -0.335098
# 2      -1.031347 -0.653418 -0.335229 -0.376406 -0.349534
# 3       0.601992  1.343223 -0.885767 -1.027218 -0.612344
# 4       1.540134  0.122832 -1.047450 -1.018723 -1.164214
# ...          ...       ...       ...       ...       ...
# 113099  0.870975  0.806731 -0.934317 -0.977923 -0.891249
# 113100 -0.625935  0.210763 -0.335689 -0.497452 -0.094242
# 113101  0.870604  1.568232 -1.518368 -1.619319 -1.221746
# 113102  0.265314 -0.785054  0.927244  1.452614 -0.168080
# 113103 -0.149024  0.673120  0.092886 -0.072897  0.300530
#
# [113104 rows x 19 columns]
#          0         1         2         3         4         5         6   \
# 0       0.0  0.174909  0.364108 -1.165161  1.488220 -0.579314 -0.877109
# 1       0.0  0.837647  0.558494  0.581872 -0.055873  1.902729  1.348177
# 2       0.0 -0.610633 -0.210743 -0.830738  1.402939 -0.579314  0.516369
# 3       0.0 -1.405086 -1.465815 -0.776640  1.488220 -0.579314 -0.877109
# 4       0.0 -0.935075  0.339850 -2.696740  0.447186 -0.579314  1.511260
# ...     ...       ...       ...       ...       ...       ...       ...
# 149995  0.0 -1.466502 -1.696590 -0.631629 -0.836109 -0.579314 -0.877109
# 149996  0.0  1.102504  0.990699  1.316770 -0.836109  1.469915  0.516369
# 149997  0.0 -0.284560 -0.166030 -0.158315 -0.836109 -0.579314 -0.877109
# 149998  0.0 -2.546383 -1.725002 -2.619000 -0.836109 -0.579314 -0.877109
# 149999  0.0  0.561201  0.339850  0.485442 -0.836109 -0.579314  1.068525
#
#               7         8         9         10        11        12        13  \
# 0      -0.868404  0.759988 -0.877109 -0.998236 -0.378682 -0.885556 -0.736096
# 1       0.928553  0.474031  1.348177  0.746716 -0.378682  0.574985 -0.246839
# 2       0.987990  0.969011  0.516369 -0.862503  2.655081 -0.846266 -1.918855
# 3      -0.868404  1.438699 -0.877109  0.345786 -0.378682  0.522786  1.667196
# 4       1.154287 -1.235796  1.511260  1.139545 -0.378682  1.515006  1.233792
# ...          ...       ...       ...       ...       ...       ...       ...
# 149995 -0.868404  0.998042 -0.877109 -1.406368 -0.378682 -1.689067 -1.361967
# 149996  1.531602 -0.742968  0.516369  0.531830 -0.378682  0.160106  0.330672
# 149997 -0.868404  0.339508 -0.877109  0.194670 -0.378682  0.259726  1.371698
# 149998 -0.868404  1.196052 -0.877109  0.917875  2.654615  0.689224  0.103491
# 149999  1.038520 -0.261847  1.068525  1.734701  2.616895  1.678184  1.082750
#
#               14        15        16        17        18
# 0      -0.879718 -0.049104  0.927653  0.794093  1.041466
# 1       0.536213 -0.463875 -1.047457 -0.664860 -1.049618
# 2      -1.623201 -1.331684 -0.478255 -0.267623 -0.293840
# 3       1.258189  1.881053  0.092886 -0.072897  0.300530
# 4       1.372181 -0.287612 -1.311737 -1.326980 -1.250267
# ...          ...       ...       ...       ...       ...
# 149995 -1.435025 -0.657363  1.671374  1.638219  1.657185
# 149996  0.184150  0.330595 -0.151578 -0.218845 -0.349053
# 149997  0.994916  1.670034  0.432422  0.272421  0.606857
# 149998 -0.133758  0.687408 -1.014236 -1.148830 -0.734997
# 149999  1.290432 -0.624272 -1.406205 -1.435467 -1.276753
#
# [150000 rows x 19 columns]

# %% [markdown]
# # 범주형피쳐 (원핫인코딩)

# %% [markdown]
# 주구매경로

# %%
#train
f = train.groupby('CLNT_ID')["DVC_CTG_NM"].agg([("주구매경로",lambda x : x.value_counts().index[0])])
f = f.reset_index()
data_sc_oh = pd.concat([data_sc,f],axis=1)
data_sc_oh = pd.concat([data_sc_oh,pd.get_dummies(data_sc_oh.주구매경로)], axis = 1)

#test
f_te = test.groupby('CLNT_ID')["DVC_CTG_NM"].agg([("주구매경로",lambda x : x.value_counts().index[0])])
f_te = f_te.reset_index()
data_te_sc_oh = pd.concat([data_te_sc,f_te],axis=1)
data_te_sc_oh = pd.concat([data_te_sc_oh,pd.get_dummies(data_te_sc_oh.주구매경로)], axis = 1)

# %% [markdown]
# 구매지역

# %%
#train
f = train.groupby("CLNT_ID")["ZON_NM"].agg([('구매지역', lambda x : x.value_counts().index[0])])
f = f.reset_index()
data_sc_oh = pd.concat([data_sc_oh,f],axis=1)
data_sc_oh = pd.concat([data_sc_oh,pd.get_dummies(data_sc_oh.구매지역)], axis = 1)

#test
f_te = test.groupby("CLNT_ID")["ZON_NM"].agg([('구매지역', lambda x : x.value_counts().index[0])])
f_te = f_te.reset_index()
data_te_sc_oh = pd.concat([data_te_sc_oh,f_te],axis=1)
data_te_sc_oh = pd.concat([data_te_sc_oh,pd.get_dummies(data_te_sc_oh.구매지역)], axis = 1)

# %%
data_sc_oh=data_sc_oh.drop(columns = ["구매지역","주구매경로"])
data_te_sc_oh=data_te_sc_oh.drop(columns = ["구매지역","주구매경로"])

# %%
# for i in range(18):
#   data_sc_oh.columns.values[i] = "{}_0".format(i)
#   data_te_sc_oh.columns.values[i] = "{}_0".format(i)

# %% [markdown]
# ## 데이터 저장

# %%
import pickle
with open('data_1123_2.pkl', 'wb') as f:
    pickle.dump(data_sc_oh, f)

# %%
import pickle
with open('data_te_1123_2.pkl', 'wb') as f:
    pickle.dump(data_te_sc_oh, f)

# %% [markdown]
# ## 데이터 읽기

# %%
import pickle
with open('data_1123_2.pkl', 'rb') as f:  # cv.pkl이라는 파일을 바이너리 읽기(rb)모드로 열어서 f라 하고
    data_sc_oh = pickle.load(f)

# %%
import pickle
with open('data_te_1123_2.pkl', 'rb') as f:  # cv.pkl이라는 파일을 바이너리 읽기(rb)모드로 열어서 f라 하고
    data_te_sc_oh = pickle.load(f)

# %%
data_sc_oh.shape, data_te_sc_oh.shape
# Out:
# ((150000, 40), (113104, 40))

# %% [markdown]
# # W2V

# %%
train_data = list(train.groupby('CLNT_ID')['CLAC3_NM'].unique())
test_data = list(test.groupby('CLNT_ID')['CLAC3_NM'].unique())
train_data # 리스트 안의 단어들을 한 문장으로 생각 , 주변 단어를 보고 학습
# Out:
# [array(['블랜더', '거실수예소품'], dtype=object),
#  array(['남성수영복', '페이셜클렌저', '선크림류', '여성비치웨어', '홍삼액', 'BB/파운데이션/컴팩트류',
#         '에센스/세럼'], dtype=object),
#  array(['여성속옷세트', '브래지어', '여성팬티', '여성스포츠샌들/슬리퍼'], dtype=object),
#  array(['유아동팬티'], dtype=object),
#  array(['유아동일반양말', '여성샌들', '유아동타이즈', '주방칼/가위', '영유아점프수트/오버롤', '아동모',
#         '프라이팬'], dtype=object),
#  array(['롤티슈'], dtype=object),
#  array(['플라스틱서랍장'], dtype=object),
#  array(['유아용화장품', '일반형냉장고'], dtype=object),
#  array(['핸드로션/크림', '남성스포츠티셔츠', '페이셜클렌저', '크림/밤/오일', '골프공', '골프연습장비',
#         '립글로즈/틴트'], dtype=object),
#  array(['남성일반지갑'], dtype=object),
#  array(['남성런닝/트레이닝화', '애견주거/실내용품', '선크림류'], dtype=object),
#  array(['생수'], dtype=object),
#  array(['여성트레이닝복', '남성스포츠티셔츠'], dtype=object),
#  array(['여성런닝셔츠/캐미솔', '여성팬티'], dtype=object),
#  array(['채소즙'], dtype=object),
#  array(['남성용스킨케어류', '3단우산', '스포츠가방', '남성팬티'], dtype=object),
#  array(['여성남방셔츠', '여성원피스', '유아동이불/이불커버'], dtype=object),
#  array(['여성비치웨어'], dtype=object),
#  array(['BB/파운데이션/컴팩트류'], dtype=object),
#  array(['남성티셔츠', '남성캐주얼바지', '여성코트', '남성청바지'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['기타여성속옷', '기타냉방가전'], dtype=object),
#  array(['영유아티셔츠/탑', '여아티셔츠/탑', '생수'], dtype=object),
#  array(['생리대', '유아용기저귀', '유산균/프로바이오틱스'], dtype=object),
#  array(['김치류', '남성등산바지', '여성팬티', '유아동스포츠샌들/슬리퍼', '골프패션잡화', '염모제', '장우산',
#         '골프필드용품', '여성원피스', '텐트', '기타에어컨', '여성스니커즈', '남성정장셔츠', '여성샌들',
#         '토스터/제빵기', '선풍기', '유아동런닝셔츠', '배낭', '여성크로스백', '남성런닝셔츠', '유아동일반양말',
#         '남성남방셔츠'], dtype=object),
#  array(['여성스웨터/풀오버'], dtype=object),
#  array(['영유아스커트', '여성원피스', '여아가디건'], dtype=object),
#  array(['여성스포츠샌들/슬리퍼'], dtype=object),
#  array(['아동수영복'], dtype=object),
#  array(['미스트', '스킨/토너'], dtype=object),
#  array(['애견장난감/훈련', '고양이캣타워/실내용품'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['크림/밤/오일'], dtype=object),
#  array(['기타구강관리용품'], dtype=object),
#  array(['생리대', '남성등산티셔츠', '남성티셔츠', '유아용화장품', '남성점퍼', '여성팬티', '팬티라이너',
#         '여성로퍼', '홍삼액', '여성티셔츠/탑', '남성캐주얼바지', '페이셜클렌저', '김치류', '롤티슈',
#         '냉동국탕류', '여성원피스'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['서랍장/수납장', '책상의자'], dtype=object),
#  array(['스킨케어세트', '페이셜팩류', '에센스/세럼', '선크림류', '크림/밤/오일'], dtype=object),
#  array(['출산/신생아용품세트', '아기띠/캐리어'], dtype=object),
#  array(['BB/파운데이션/컴팩트류'], dtype=object),
#  array(['여성스포츠티셔츠/탑', '유아동스포츠샌들/슬리퍼', '유아동샌들'], dtype=object),
#  array(['여성팬티', '여성바지'], dtype=object),
#  array(['아동수영복'], dtype=object),
#  array(['여아티셔츠/탑', '영유아원피스', '여성스포츠티셔츠/탑'], dtype=object),
#  array(['브래지어'], dtype=object),
#  array(['남성캐주얼바지', '거실수예소품', '여성남방셔츠', '남성정장바지'], dtype=object),
#  array(['남성일반스포츠바지'], dtype=object),
#  array(['미술/창작완구'], dtype=object),
#  array(['기타요가/필라테스소품'], dtype=object),
#  array(['숟가락/젓가락'], dtype=object),
#  array(['아쿠아슈즈', '남성런닝/트레이닝화', '여성재킷', '여성원피스', '여성샌들'], dtype=object),
#  array(['영유아바지', '여아티셔츠/탑', '영유아스커트', '남성골프바지'], dtype=object),
#  array(['유아동이불/이불커버', '유아동침구세트'], dtype=object),
#  array(['생수'], dtype=object),
#  array(['유아/아동용치약'], dtype=object),
#  array(['스포츠모자'], dtype=object),
#  array(['아동수영복', '유아동슬리퍼'], dtype=object),
#  array(['남성등산티셔츠', '남성스포츠티셔츠'], dtype=object),
#  array(['페이셜팩류', '남성정장셔츠'], dtype=object),
#  array(['크림/밤/오일'], dtype=object),
#  array(['여성골프패딩'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['여성숄더백'], dtype=object),
#  array(['야구모자', '유아동스니커즈'], dtype=object),
#  array(['헤어에센스'], dtype=object),
#  array(['탁자'], dtype=object),
#  array(['여성티셔츠/탑', '여성원피스'], dtype=object),
#  array(['유아동샌들', '여아티셔츠/탑', '닭가슴살', '유아동내의', '남아티셔츠/탑', '오리발/스노클링', '남아잠옷',
#         '식탁의자', '유아용물티슈', '애견간식', '여성플랫', '애견사료'], dtype=object),
#  array(['반찬통/밀폐용기'], dtype=object),
#  array(['어린이홍삼', '스포츠시계'], dtype=object),
#  array(['고양이모래/배변용품', '남성스포츠샌들/슬리퍼'], dtype=object),
#  array(['생수'], dtype=object),
#  array(['혼합즙', '골프패션잡화'], dtype=object),
#  array(['페이셜클렌저'], dtype=object),
#  array(['에센스/세럼', '아이브로우', '아이케어'], dtype=object),
#  array(['영유아스커트', '유아동내의'], dtype=object),
#  array(['남성캐주얼바지'], dtype=object),
#  array(['바디워시', '유아용샴푸/바디워시', '여성팬티', '유아동팬티', '브래지어', '샴푸', '유아용화장품'],
#        dtype=object),
#  array(['남성캐주얼바지', '남성가디건', '립글로즈/틴트', '여성가디건', '캐리어'], dtype=object),
#  array(['한방음료'], dtype=object),
#  array(['영유아티셔츠/탑', '유아용물티슈', '아동용가방', '생수', '여성일반스포츠바지', '남성스포츠티셔츠'],
#        dtype=object),
#  array(['노트북', '메이크업세트'], dtype=object),
#  array(['여성임부속옷'], dtype=object),
#  array(['생수', '여성스웨터/풀오버', '접시', '여성가디건', '반상기세트/홈세트', '여성바지', '여성티셔츠/탑',
#         '여성남방셔츠'], dtype=object),
#  array(['장롱', '매트리스'], dtype=object),
#  array(['여성로퍼', '여성점퍼', '홈웨어세트', '남성등산티셔츠', '남성골프티셔츠', '여성스웨트셔츠/후드/집업',
#         '남성일반스포츠바지', '남성티셔츠'], dtype=object),
#  array(['에센스/세럼', '여성원피스', '미스트', '여성가디건'], dtype=object),
#  array(['남성비치웨어', '남성스포츠티셔츠'], dtype=object),
#  array(['기타모바일액세서리', '생리대', '남성청바지'], dtype=object),
#  array(['성인침구속통/솜'], dtype=object),
#  array(['바구니', '플라스틱서랍장'], dtype=object),
#  array(['아동모', '테이프', '칼/가위', '아동수영복', '수정용품', '유아동선글라스', '여성클러치백'],
#        dtype=object),
#  array(['유아용화장품', '선크림류'], dtype=object),
#  array(['남성정장셔츠'], dtype=object),
#  array(['남성스포츠티셔츠', '여성남방셔츠'], dtype=object),
#  array(['여성일반스포츠바지', '여성스포츠티셔츠/탑'], dtype=object),
#  array(['메이크업세트', '남성티셔츠', '선크림류'], dtype=object),
#  array(['영유아청바지', '여성바지'], dtype=object),
#  array(['여성남방셔츠', '유아동런닝셔츠'], dtype=object),
#  array(['여성스니커즈'], dtype=object),
#  array(['캠핑테이블/의자', '텐트'], dtype=object),
#  array(['여성크로스백', '남성티셔츠'], dtype=object),
#  array(['여아바지', '여아티셔츠/탑', '남아청바지'], dtype=object),
#  array(['고양이사료', '캐리어'], dtype=object),
#  array(['남성티셔츠', '여성티셔츠/탑'], dtype=object),
#  array(['커튼', '김치류'], dtype=object),
#  array(['여성속옷세트'], dtype=object),
#  array(['여성남방셔츠', '여성원피스', '스킨케어세트'], dtype=object),
#  array(['기타물놀이용품'], dtype=object),
#  array(['여성신발부속품'], dtype=object),
#  array(['노트북가방', '여성카드/명함지갑'], dtype=object),
#  array(['블랜더'], dtype=object),
#  array(['크림/밤/오일'], dtype=object),
#  array(['고양이사료'], dtype=object),
#  array(['여성속옷세트', '선크림류'], dtype=object),
#  array(['에센스/세럼'], dtype=object),
#  array(['여성원피스', '김치류', '책상', '여성스커트', '욕실발판'], dtype=object),
#  array(['여성스웨터/풀오버', '마스카라', '남성일반지갑'], dtype=object),
#  array(['남성티셔츠', '남성스포츠티셔츠', '남성남방셔츠', '남성런닝/트레이닝화', '남성시계', '남성패딩'],
#        dtype=object),
#  array(['식탁세트', '식탁의자'], dtype=object),
#  array(['기타모바일액세서리'], dtype=object),
#  array(['피규어', '영유아티셔츠/탑', '욕실소품', '롤플레잉완구', '기타캠핑용품', '분말표백제', '풀',
#         '한방음료'], dtype=object),
#  array(['종합영양제'], dtype=object),
#  array(['BB/파운데이션/컴팩트류', '영유아점프수트/오버롤', '남성비치웨어'], dtype=object),
#  array(['남성캐주얼바지', '스킨/토너', '남성스포츠티셔츠'], dtype=object),
#  array(['남성스포츠샌들/슬리퍼'], dtype=object),
#  array(['에센스/세럼'], dtype=object),
#  array(['피트니스용품', '스툴/리빙의자', '책장'], dtype=object),
#  array(['스킨케어세트', 'BB/파운데이션/컴팩트류', '칫솔', '수건'], dtype=object),
#  array(['크림/밤/오일'], dtype=object),
#  array(['유아동내의', '액상세탁세제', '남성용스킨케어류', '여성원피스', '유아동런닝셔츠', '영유아블라우스',
#         '아쿠아슈즈', '유아용샴푸/바디워시', '기타모바일액세서리', '유아/아동용치약', '영유아점프수트/오버롤',
#         '유아동스포츠샌들/슬리퍼', '남성티셔츠', '영유아티셔츠/탑', '남성남방셔츠', '남아바지'],
#        dtype=object),
#  array(['여성재킷', '여성바지'], dtype=object),
#  array(['헤어케어선물세트', '샴푸'], dtype=object),
#  array(['여성팬티', '여성런닝셔츠/캐미솔'], dtype=object),
#  array(['립글로즈/틴트'], dtype=object),
#  array(['여성속옷세트'], dtype=object),
#  array(['남성등산티셔츠', '여성등산티셔츠/탑', '남성베스트'], dtype=object),
#  array(['썬캡', '여성티셔츠/탑', '스카프', '남성캐주얼바지', '블러셔/쉐이딩/하이라이터', '여성원피스'],
#        dtype=object),
#  array(['여아레깅스', '남성스포츠샌들/슬리퍼', '유아동팬티'], dtype=object),
#  array(['주방칼/가위'], dtype=object),
#  array(['수건', '애견목욕/위생용품'], dtype=object),
#  array(['오리발/스노클링', 'BB/파운데이션/컴팩트류', '기타일반문구/사무용품', '선풍기', '린스/컨디셔너',
#         '페이셜클렌저', '골프필드용품', '선크림류', '샴푸/린스세트'], dtype=object),
#  array(['미용비누', '샴푸', '여성원피스', '기타일반문구/사무용품', '성인매트리스커버'], dtype=object),
#  array(['홍삼액', '남성티셔츠', '여성속옷세트', '영유아원피스', '스냅백', '기타컴퓨터액세서리'],
#        dtype=object),
#  array(['BB/파운데이션/컴팩트류'], dtype=object),
#  array(['유아동플랫', '기타영양제', '여아티셔츠/탑', '여성샌들', '여아바지', '여아남방셔츠', '남아의류세트',
#         '여성비치웨어'], dtype=object),
#  array(['탄산수'], dtype=object),
#  array(['유아동샌들', '김치류'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['홍삼액', '일반청소기'], dtype=object),
#  array(['스킨케어세트', '페이셜클렌저'], dtype=object),
#  array(['손싸개/발싸개'], dtype=object),
#  array(['여성속옷세트', '여성팬티'], dtype=object),
#  array(['유아동런닝/트레이닝화'], dtype=object),
#  array(['여성티셔츠/탑', '여성스포츠티셔츠/탑', '칫솔', '수정용품', '기타일반문구/사무용품', '여성토트백',
#         '남성팬티', '여성속옷세트', '남성일반지갑', '여성일반양말', '여성바지', '여성런닝/트레이닝화', '치약'],
#        dtype=object),
#  array(['남성캐주얼바지', '여성바지'], dtype=object),
#  array(['여성런닝/트레이닝화', '샤워/목욕도구/목욕헤어밴드'], dtype=object),
#  array(['남성정장셔츠'], dtype=object),
#  array(['스킨/토너', '선크림류'], dtype=object),
#  array(['봉제인형', '유아동베개/베개커버', '놀이방매트'], dtype=object),
#  array(['식음료모바일상품권'], dtype=object),
#  array(['접시'], dtype=object),
#  array(['여아베스트', '여성스니커즈'], dtype=object),
#  array(['성인베개/베개커버', '이유식용품'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['아쿠아슈즈', '스킨케어세트'], dtype=object),
#  array(['애견목욕/위생용품'], dtype=object),
#  array(['아이섀도우', '여성런닝/트레이닝화', '남성스포츠샌들/슬리퍼', '스킨케어세트', '남성샌들',
#         '여성스포츠티셔츠/탑', '남성런닝/트레이닝화', '린스/컨디셔너', '아이브로우', '여성스포츠샌들/슬리퍼',
#         '에센스/세럼', '기타이미용가전', '스포츠가방', '여성스니커즈'], dtype=object),
#  array(['여성티셔츠/탑', '블러셔/쉐이딩/하이라이터', '요가/필라테스복', '남성캐주얼바지'], dtype=object),
#  array(['여성향수', '여성크로스백', '아이섀도우'], dtype=object),
#  array(['골프연습장비', '골프필드용품', '블러셔/쉐이딩/하이라이터', '남성남방셔츠', '선크림류', '골프패션잡화',
#         'BB/파운데이션/컴팩트류', '페이셜클렌저', '유아용화장품', '에센스/세럼', '유아용물티슈', '여성티셔츠/탑',
#         '여성바지', '기타정리용품', '트리트먼트/팩', '욕실청소용품', '여성원피스', '기타주방정리용품/소모품'],
#        dtype=object),
#  array(['아쿠아슈즈', '플라스틱서랍장', '남성수영복'], dtype=object),
#  array(['BB/파운데이션/컴팩트류'], dtype=object),
#  array(['유아동스포츠샌들/슬리퍼', '여아바지', '남아티셔츠/탑', '여아티셔츠/탑', '여아청바지'],
#        dtype=object),
#  array(['블러셔/쉐이딩/하이라이터', '여성샌들', '여성티셔츠/탑', '기름종이', '여성바지',
#         'BB/파운데이션/컴팩트류', '아이라이너'], dtype=object),
#  array(['홍삼/인삼혼합세트'], dtype=object),
#  array(['핸드로션/크림', '유아용샴푸/바디워시', '생수', '여성속옷세트'], dtype=object),
#  array(['유아용화장품', '아이섀도우'], dtype=object),
#  array(['남성등산바지', '남성일반스포츠바지'], dtype=object),
#  array(['여성시계'], dtype=object),
#  array(['브래지어', '여성남방셔츠', '손수건', '여성재킷', '여성티셔츠/탑', '여성점퍼', '여성바지', '여성팬티',
#         '여성원피스'], dtype=object),
#  array(['남성티셔츠', '샴푸', '남성캐주얼바지', '블러셔/쉐이딩/하이라이터'], dtype=object),
#  array(['여성스포츠티셔츠/탑', '스포츠가방', '여성일반스포츠바지'], dtype=object),
#  array(['팔찌', '남성숄더/크로스백'], dtype=object),
#  array(['유아동베개/베개커버'], dtype=object),
#  array(['기타일반문구/사무용품', '기타모바일액세서리', '지퍼백/비닐백', '반찬통/밀폐용기'], dtype=object),
#  array(['여성원피스'], dtype=object),
#  array(['여성바지', '여성원피스', '여성티셔츠/탑', '여아바지', '여성스웨터/풀오버', '남성스포츠샌들/슬리퍼',
#         '성인패드/스프레드', '남성남방셔츠', '여성펌프스', '프라이팬', '여성남방셔츠', '기타구강관리용품',
#         '여성크로스백', '구강청정제', '남성티셔츠', '여아티셔츠/탑', '여성일반스포츠바지', '여아청바지',
#         '남성일반양말'], dtype=object),
#  array(['여성오픈토', '에센스/세럼', '공기청정기', '메이크업세트', '여성향수', '여성클러치백',
#         'BB/파운데이션/컴팩트류'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['여성등산바지', '커튼링/커튼봉/부속품', '여아티셔츠/탑', '메이크업베이스/프라이머',
#         'BB/파운데이션/컴팩트류', '여성등산티셔츠/탑'], dtype=object),
#  array(['여아점퍼', '남성등산점퍼/재킷'], dtype=object),
#  array(['영유아원피스', '유아동슬립온', '스포츠가방', '아동수영복', '아쿠아슈즈'], dtype=object),
#  array(['영유아바지', '여아티셔츠/탑', '영유아스커트'], dtype=object),
#  array(['페이셜클렌저'], dtype=object),
#  array(['인삼가공식품', '남성티셔츠', '남성캐주얼바지'], dtype=object),
#  array(['여성바지', '혼합즙'], dtype=object),
#  array(['여성덧신류'], dtype=object),
#  array(['남성티셔츠', '남성캐주얼바지', '야구모자', '스포츠모자'], dtype=object),
#  array(['헤어케어선물세트'], dtype=object),
#  array(['유아용화장품', '선크림류'], dtype=object),
#  array(['스킨케어세트', '냉동핫도그', '여성샌들'], dtype=object),
#  array(['에센스/세럼'], dtype=object),
#  array(['아동수영복'], dtype=object),
#  array(['애견사료'], dtype=object),
#  array(['기타영양제'], dtype=object),
#  array(['남성캐주얼바지', '여성블라우스', '여성바지', '에센스/세럼', '여성원피스', '남성티셔츠'],
#        dtype=object),
#  array(['식기건조대/수저통', '국자/뒤지개/주걱'], dtype=object),
#  array(['여성부츠', 'BB/파운데이션/컴팩트류', '여성코트', '여성스니커즈', '여성베스트', '여성재킷',
#         '에멀젼/로션', '여성스웨터/풀오버', '여성가디건', '여성티셔츠/탑', '기타조리도구', '성인침구속통/솜',
#         '바디보습', '여성원피스', '여성패딩', '성인이불/이불커버', '여성바지', '여성남방셔츠', '여성점퍼',
#         '거실수예소품', '솥', '남성티셔츠', '기타여성속옷', '핸드로션/크림', '골프연습장비'],
#        dtype=object),
#  array(['스킨케어세트'], dtype=object),
#  array(['남성캐주얼바지'], dtype=object),
#  array(['페이셜클렌저'], dtype=object),
#  array(['이불/옷압축팩', '섬유유연제/향기지속제'], dtype=object),
#  array(['남성티셔츠', 'BB/파운데이션/컴팩트류', '여성원피스', '여성런닝/트레이닝화', '기름종이'],
#        dtype=object),
#  array(['남성스포츠티셔츠', '여성속옷세트', '선크림류'], dtype=object),
#  array(['양산', '여성샌들'], dtype=object),
#  array(['여성티셔츠/탑', '여성원피스', '여성바지', '여성비치웨어'], dtype=object),
#  array(['성인매트리스커버'], dtype=object),
#  array(['여성원피스'], dtype=object),
#  array(['여성로퍼', '여성플랫', '기타정리용품'], dtype=object),
#  array(['남아티셔츠/탑', '여아티셔츠/탑'], dtype=object),
#  array(['여성수영복'], dtype=object),
#  array(['여성원피스', '여성점퍼'], dtype=object),
#  array(['여성팬티', '남성내의'], dtype=object),
#  array(['여성속옷세트', '여성팬티', '혼합즙', '출산/신생아용품세트', '주방칼/가위', '기타등산용품',
#         '유아용화장품', '스포츠모자', '여성바지', '여성티셔츠/탑', '스포츠가방'], dtype=object),
#  array(['유아용화장품', '이유식용품', '유아용세척용품', '봉제인형', '도마', '생활모바일상품권', '젖병/젖꼭지'],
#        dtype=object),
#  array(['페이셜클렌저', '아이라이너', '스킨케어세트', '에센스/세럼'], dtype=object),
#  array(['아동우산', '아이라이너', '남성런닝셔츠', '남성스포츠샌들/슬리퍼', '남성숄더/크로스백',
#         '블러셔/쉐이딩/하이라이터', '케이스/보호필름', '에멀젼/로션', '아이케어', '페이셜클렌저', '크림/밤/오일'],
#        dtype=object),
#  array(['여성플랫'], dtype=object),
#  array(['스킨/토너', '남성스킨케어세트', '크림/밤/오일'], dtype=object),
#  array(['여성베스트', '여성스웨터/풀오버', '여성남방셔츠', '여성백팩', '여아남방셔츠', '영유아원피스',
#         '성인패드/스프레드', '여성부츠', '기타일반문구/사무용품', '커피머신', '방석/방석커버',
#         '블러셔/쉐이딩/하이라이터'], dtype=object),
#  array(['커튼'], dtype=object),
#  array(['여성덧신류'], dtype=object),
#  array(['여성크로스백', '메이크업베이스/프라이머'], dtype=object),
#  array(['핸드로션/크림', '여성바지', '페이셜클렌저', '남성티셔츠', '프라이팬', '장식장/진열장', '여성속옷세트',
#         '다이어트보조식품', '여성남방셔츠', '남성캐주얼바지', '기타영양제', '남성스니커즈', '여성런닝/트레이닝화',
#         '여성원피스', '기타일반문구/사무용품', '생수', '일반청소기', '아이브로우', '바디워시', '남성용클렌저',
#         '여성오픈토', '반찬통/밀폐용기', '소품가방', '남성가디건', '식기건조대/수저통', '욕실소품',
#         '변기시트/커버', '여성스웨터/풀오버', '여성런닝셔츠/캐미솔', '여성토트백', '여성재킷', '헤드웨어',
#         '여행용소품', '목걸이', '남성정장셔츠', '미용보조식품', '여성샌들', '제빵용품', 'PC부품',
#         '여성티셔츠/탑', '등산화', '젤네일/케어류', '선크림류', '핸디형청소기', '주방선반/걸이대',
#         '남성스포츠티셔츠', '남성청바지', '옷걸이', '유아동침대', '애견간식', '로봇청소기'], dtype=object),
#  array(['여성런닝/트레이닝화'], dtype=object),
#  array(['여성바지', '헤어드라이어'], dtype=object),
#  array(['메이크업세트'], dtype=object),
#  array(['여성토트백'], dtype=object),
#  array(['남아티셔츠/탑', '남성티셔츠', '영유아티셔츠/탑', '유아동슬립온'], dtype=object),
#  array(['아동모', '아동수영복'], dtype=object),
#  array(['레저모바일상품권'], dtype=object),
#  array(['아이섀도우', '핸드로션/크림', 'BB/파운데이션/컴팩트류', '메이크업세트', '남성스포츠샌들/슬리퍼',
#         '여성스포츠샌들/슬리퍼'], dtype=object),
#  array(['유아동침구세트', '유아동팬티', '성인패드/스프레드', '액상세탁세제', '이유식용품', '유아동타이즈',
#         '유아동스포츠샌들/슬리퍼', '유아동스니커즈', '영유아티셔츠/탑', '유아동내의', '영유아바지'],
#        dtype=object),
#  array(['마스카라', '아이라이너', '스폰지/퍼프', '기타컴퓨터액세서리', '기타정리용품', '아이브로우'],
#        dtype=object),
#  array(['커피머신', '커피용품'], dtype=object),
#  array(['커피잔'], dtype=object),
#  array(['스폰지/퍼프', '여성티셔츠/탑', '블러셔/쉐이딩/하이라이터'], dtype=object),
#  array(['저장장치', '메이크업세트'], dtype=object),
#  array(['메이크업세트', '기타영양제', '기타모바일액세서리', '블러셔/쉐이딩/하이라이터'], dtype=object),
#  array(['여성런닝/트레이닝화', '남성숄더/크로스백'], dtype=object),
#  array(['여성시계', '유아동일반양말', '이유식용품', '여성원피스', '우주복', '여성남방셔츠'], dtype=object),
#  array(['블러셔/쉐이딩/하이라이터', '메이크업베이스/프라이머', '아이섀도우', '스킨케어세트', '스폰지/퍼프',
#         '롤티슈', 'BB/파운데이션/컴팩트류', '립스틱/립라이너'], dtype=object),
#  array(['남성캐주얼바지', '조립/프라모델', '블러셔/쉐이딩/하이라이터', '피규어', '저장장치', '스케이트보드/킥보드',
#         '여성향수', '남성로퍼'], dtype=object),
#  array(['장우산'], dtype=object),
#  array(['여성쪼리', '유아동샌들'], dtype=object),
#  array(['여성스포츠티셔츠/탑'], dtype=object),
#  array(['스폰지/퍼프'], dtype=object),
#  array(['영유아티셔츠/탑', '남아바지', '여성크로스백', '유아동내의'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['식음료모바일상품권'], dtype=object),
#  array(['여성트렌치코트', '남성청바지'], dtype=object),
#  array(['BB/파운데이션/컴팩트류', '남성일반스포츠바지', '여성스커트', '여성티셔츠/탑', '남성스포츠티셔츠',
#         '스포츠모자', '남성런닝/트레이닝화', '남성정장재킷', '남성티셔츠', '여성남방셔츠', '여성샌들', '골프화',
#         '남성캐주얼바지', '여성스웨터/풀오버', '여성크로스백'], dtype=object),
#  array(['여성샌들'], dtype=object),
#  array(['여성수영복', '남성수영복'], dtype=object),
#  array(['남성일반스포츠바지', '남성티셔츠', '남성런닝/트레이닝화'], dtype=object),
#  array(['여아남방셔츠', '영유아바지', '유아동슬립온', '여아티셔츠/탑'], dtype=object),
#  array(['남성트레이닝복'], dtype=object),
#  array(['생수'], dtype=object),
#  array(['여성샌들', '여성플랫', '여성로퍼'], dtype=object),
#  array(['여성덧신류', '김치류', '선풍기'], dtype=object),
#  array(['BB/파운데이션/컴팩트류'], dtype=object),
#  array(['남성남방셔츠'], dtype=object),
#  array(['남성정장셔츠'], dtype=object),
#  array(['남성캐주얼바지', '남성일반스포츠바지', '블러셔/쉐이딩/하이라이터'], dtype=object),
#  array(['BB/파운데이션/컴팩트류', '메이크업세트', '기름종이'], dtype=object),
#  array(['여성스웨터/풀오버', '남성티셔츠', '영유아바지', '여성가디건', '여성티셔츠/탑', '출산/신생아용품세트'],
#        dtype=object),
#  array(['욕실소품'], dtype=object),
#  array(['스폰지/퍼프'], dtype=object),
#  array(['전기찜기'], dtype=object),
#  array(['남성골프바지', '골프연습장비', '여성속옷세트', '에멀젼/로션', '메이크업세트', '아이케어'],
#        dtype=object),
#  array(['여성티셔츠/탑'], dtype=object),
#  array(['남성런닝/트레이닝화'], dtype=object),
#  array(['남성향수', '여성향수'], dtype=object),
#  array(['여성스포츠티셔츠/탑', '이불/옷압축팩', '여성샌들', '여성베스트', '일반비타민', '여성원피스',
#         '여성슬링백', '여성코트', '남성스포츠티셔츠'], dtype=object),
#  array(['기타일반문구/사무용품', '애견사료'], dtype=object),
#  array(['에센스/세럼'], dtype=object),
#  array(['남아티셔츠/탑'], dtype=object),
#  array(['브래지어'], dtype=object),
#  array(['치약'], dtype=object),
#  array(['기타모바일액세서리'], dtype=object),
#  array(['BB/파운데이션/컴팩트류', '스킨케어세트'], dtype=object),
#  array(['여성스커트', '남성스포츠샌들/슬리퍼', '여성남방셔츠', '아동수영복'], dtype=object),
#  array(['스킨/토너'], dtype=object),
#  array(['남성정장셔츠'], dtype=object),
#  array(['여성펌프스', '여성남방셔츠', '여성플랫'], dtype=object),
#  array(['기타일반문구/사무용품'], dtype=object),
#  array(['영유아바지'], dtype=object),
#  array(['여성스포츠티셔츠/탑'], dtype=object),
#  array(['아동수영복', '촉각놀이/오뚝이', '여성크로스백'], dtype=object),
#  array(['기타패션잡화', '노트북', '블러셔/쉐이딩/하이라이터'], dtype=object),
#  array(['성인이불/이불커버'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['골프필드용품', '남성티셔츠', '여성스니커즈', '여성샌들', '여성티셔츠/탑', '여성런닝/트레이닝화',
#         '남성런닝/트레이닝화'], dtype=object),
#  array(['남성정장셔츠', '유아동내의'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['스킨케어세트', '남성정장바지', '애견목욕/위생용품', '헤어케어선물세트', 'BB/파운데이션/컴팩트류'],
#        dtype=object),
#  array(['남성청바지', '애견목욕/위생용품'], dtype=object),
#  array(['남성용스킨케어류'], dtype=object),
#  array(['식음료모바일상품권'], dtype=object),
#  array(['영유아스커트', '데오도란트', '수영모자', '여성슬리퍼', '고무장갑', '기타일반문구/사무용품',
#         '서랍장/수납장', '남성티셔츠', '여성티셔츠/탑', '남성캐주얼바지', '여성팬티', '주방선반/걸이대',
#         '주방칼/가위', '여성스포츠샌들/슬리퍼', '일반두유', '속눈썹/쌍꺼풀', '물안경', '장우산', '여성쪼리',
#         '기타여행용가방', '반찬통/밀폐용기', '여성수영복', '기타정리용품', '여성런닝셔츠/캐미솔'],
#        dtype=object),
#  array(['일반두유', '여성런닝/트레이닝화', '여성티셔츠/탑', '유아동샌들', '여성샌들', '여성런닝셔츠/캐미솔'],
#        dtype=object),
#  array(['남성점퍼'], dtype=object),
#  array(['여성바지', '여성원피스', '여성티셔츠/탑', '영유아티셔츠/탑', '남성티셔츠', '여성남방셔츠'],
#        dtype=object),
#  array(['여성가디건'], dtype=object),
#  array(['남성트렌치코트'], dtype=object),
#  array(['여성원피스', '남성티셔츠', '여성티셔츠/탑', '영유아바지', '발찌', '여아티셔츠/탑', '여성베스트',
#         '여성재킷', '영유아청바지', '여성런닝/트레이닝화', '영유아원피스', '여아점퍼', '여성런닝셔츠/캐미솔',
#         '남성스웨터/풀오버', '호두'], dtype=object),
#  array(['일반두유', '메이크업세트'], dtype=object),
#  array(['캠핑침구', '고양이사료'], dtype=object),
#  array(['크림/밤/오일', 'BB/파운데이션/컴팩트류'], dtype=object),
#  array(['블러셔/쉐이딩/하이라이터', '여성티셔츠/탑'], dtype=object),
#  array(['스킨케어세트'], dtype=object),
#  array(['남성스포츠티셔츠', '여성런닝/트레이닝화', '여성티셔츠/탑'], dtype=object),
#  array(['여성원피스'], dtype=object),
#  array(['여성원피스', '여성비치웨어'], dtype=object),
#  array(['여성스포츠티셔츠/탑', '남성스포츠티셔츠', '이유식용품'], dtype=object),
#  array(['여성크로스백', '아동비치웨어', '기타컴퓨터액세서리'], dtype=object),
#  array(['여성팬티', '영유아티셔츠/탑', '바디보습', '유아동런닝/트레이닝화'], dtype=object),
#  array(['아동수영복'], dtype=object),
#  array(['유아동내의', '유아동일반양말'], dtype=object),
#  array(['남성캐주얼바지', '인삼가공식품'], dtype=object),
#  array(['애견의류/악세서리'], dtype=object),
#  array(['영유아원피스'], dtype=object),
#  array(['남성스포츠샌들/슬리퍼'], dtype=object),
#  array(['유아용화장품'], dtype=object),
#  array(['성인베개/베개커버', '성인침구세트', '샴푸', '립스틱/립라이너', '탁자', '바디워시'],
#        dtype=object),
#  array(['남성등산패딩'], dtype=object),
#  array(['여성펌프스', '미용비누'], dtype=object),
#  array(['립스틱/립라이너', '아이섀도우', '기타모바일액세서리', '여성펌프스'], dtype=object),
#  array(['냉동만두'], dtype=object),
#  array(['바구니', '기타조리도구', '바디보습'], dtype=object),
#  array(['유아용물티슈', '애견주거/실내용품'], dtype=object),
#  array(['유아동스니커즈', '등산화', '냄비', '유아동런닝/트레이닝화'], dtype=object),
#  array(['페이셜팩류'], dtype=object),
#  array(['유아동런닝/트레이닝화'], dtype=object),
#  array(['반찬통/밀폐용기'], dtype=object),
#  array(['샴푸', '기름종이'], dtype=object),
#  array(['아이섀도우'], dtype=object),
#  array(['여성트레이닝복', '남성정장셔츠', '영유아티셔츠/탑', '남성캐주얼재킷', '남성팬티', '스포츠모자',
#         '야구모자'], dtype=object),
#  array(['남성티셔츠', '승마운동기', '남성캐주얼바지', '여성숄더백', '여성트레이닝복', '남성숄더/크로스백',
#         '남성수영복'], dtype=object),
#  array(['생수'], dtype=object),
#  array(['여성원피스', '여성가디건'], dtype=object),
#  array(['홍삼액'], dtype=object),
#  array(['마스카라', '염모제', '기타컴퓨터액세서리', '바디케어세트', '솥', '헤어케어선물세트', '홍삼액', '샴푸',
#         '페이셜클렌저', 'BB/파운데이션/컴팩트류', '기름종이', '일반청소기'], dtype=object),
#  array(['여성속옷세트'], dtype=object),
#  array(['남성티셔츠', '남성남방셔츠'], dtype=object),
#  array(['여성속옷세트', '남성팬티', '여성원피스', '여성남방셔츠', '스킨/토너', '여성스웨터/풀오버', '남성티셔츠',
#         '거들'], dtype=object),
#  array(['에센스/세럼', '크림/밤/오일', '커피잔'], dtype=object),
#  array(['남성샌들', '여성쪼리'], dtype=object),
#  array(['립글로즈/틴트'], dtype=object),
#  array(['성인요/요커버', '에멀젼/로션', '헤어케어선물세트', '스킨케어세트', '유아동이불/이불커버', '기름종이',
#         'BB/파운데이션/컴팩트류', '액상세탁세제', '남성티셔츠', '여성점퍼', '여성내의', '성인베개/베개커버',
#         '루테인'], dtype=object),
#  array(['남성티셔츠', '여성팬티', '유아동내의', '유아동런닝셔츠', '애견간식', '남성캐주얼바지'],
#        dtype=object),
#  array(['블러셔/쉐이딩/하이라이터', '스킨케어세트'], dtype=object),
#  array(['여성원피스', '여성등산바지'], dtype=object),
#  array(['여성청바지', '커피잔', '여성원피스', '기타일반문구/사무용품', '남성티셔츠', '여성스커트', '남성샌들',
#         '남성남방셔츠', '여성티셔츠/탑', '여성샌들'], dtype=object),
#  array(['야구모자', '여성티셔츠/탑', '애견주거/실내용품'], dtype=object),
#  array(['영유아티셔츠/탑'], dtype=object),
#  array(['여성잠옷'], dtype=object),
#  array(['유아동내의', '여성트렌치코트'], dtype=object),
#  array(['크림/밤/오일', '바디보습', '페이셜클렌저'], dtype=object),
#  array(['성인침구속통/솜'], dtype=object),
#  array(['남성티셔츠', '남성가디건'], dtype=object),
#  array(['장우산'], dtype=object),
#  array(['남성스포츠샌들/슬리퍼'], dtype=object),
#  array(['인덕션/가스레인지', '캠핑취사'], dtype=object),
#  array(['텐트'], dtype=object),
#  array(['에센스/세럼', '메이크업세트', '선크림류', '남성스포츠샌들/슬리퍼', '바디워시', '커피용품'],
#        dtype=object),
#  array(['여성등산티셔츠/탑', '여성등산바지'], dtype=object),
#  array(['남성골프바지', '노트북가방', '마우스', '지퍼백/비닐백', '유아동슬립온', '남성등산점퍼/재킷',
#         '남성정장셔츠', '기타컴퓨터액세서리', '블랙박스', '노트북'], dtype=object),
#  array(['주방칼/가위', '남성런닝/트레이닝화', '포크/나이프', '접시', '숟가락/젓가락', '애견주거/실내용품',
#         '남성속옷세트', '남성정장바지', '남성남방셔츠', '애견장난감/훈련', '여성슬립온'], dtype=object),
#  array(['기타영양제'], dtype=object),
#  array(['영유아티셔츠/탑', '유아동스포츠샌들/슬리퍼'], dtype=object),
#  array(['여성티셔츠/탑', '기타물놀이용품', '여성잠옷', '오메가3/기타추출오일', '여성수영복', '헤어세팅기',
#         '남성점퍼', '메이크업세트', '여성팬티', '오리발/스노클링', '여성바지', '욕실소품', '선풍기', '키보드',
#         '모바일배터리/충전기', '수건'], dtype=object),
#  array(['남성비치웨어'], dtype=object),
#  array(['남성용스킨케어류'], dtype=object),
#  array(['남성티셔츠', '여성코트'], dtype=object),
#  array(['브래지어', '아쿠아슈즈', '여성잠옷', '여성일반스포츠바지', '여성팬티', '유아동샌들', '유아용화장품'],
#        dtype=object),
#  array(['여성남방셔츠'], dtype=object),
#  array(['남성일반스포츠바지', '여성스포츠티셔츠/탑', '아동수영복', '남성티셔츠', '여성일반스포츠바지'],
#        dtype=object),
#  array(['에멀젼/로션', '샴푸'], dtype=object),
#  array(['블러셔/쉐이딩/하이라이터'], dtype=object),
#  array(['여성스웨터/풀오버', '식기건조대/수저통', '남성티셔츠', '선크림류', '오메가3/기타추출오일', '페이셜클렌저',
#         '애견사료'], dtype=object),
#  array(['여성비치웨어', '남성비치웨어'], dtype=object),
#  array(['냉동만두'], dtype=object),
#  array(['남성스포츠티셔츠', '캐리어'], dtype=object),
#  array(['여성스커트'], dtype=object),
#  array(['남성트레이닝복'], dtype=object),
#  array(['고양이모래/배변용품'], dtype=object),
#  array(['남아바지', '남아티셔츠/탑', '남아청바지', '여아티셔츠/탑'], dtype=object),
#  array(['남아바지', '남아의류세트', '영유아티셔츠/탑', '크림/밤/오일', '애견주거/실내용품', '애견목욕/위생용품',
#         '애견사료', '채반/바구니/쟁반', '유아용물티슈', '남아티셔츠/탑', '섬유유연제/향기지속제', '여성로퍼',
#         '기타일반문구/사무용품', '애견간식'], dtype=object),
#  array(['아이섀도우'], dtype=object),
#  array(['여성원피스'], dtype=object),
#  array(['여성원피스'], dtype=object),
#  array(['여성가디건', '수건', '김치류', '선반장/행거', '매트리스', '이불/옷압축팩', '젤네일/케어류',
#         '남성정장바지', '안경테', '여성골프바지', '채소즙', '생수', '커피메이커/포트', '여성바지',
#         '기타모바일액세서리', '여성베스트', '기타영양제', '장롱', '옷걸이', '루테인'], dtype=object),
#  array(['남성스웨터/풀오버'], dtype=object),
#  array(['스킨/토너'], dtype=object),
#  array(['이유식용품'], dtype=object),
#  array(['남아의류세트', '유아동스포츠티셔츠/탑', '남아티셔츠/탑', '남아바지', '유아동스포츠스웨트셔츠/후드/집업'],
#        dtype=object),
#  array(['남성티셔츠', '남성캐주얼바지'], dtype=object),
#  array(['여아티셔츠/탑', '여성슬립온', '남아바지'], dtype=object),
#  array(['여성비치웨어'], dtype=object),
#  array(['성인요/요커버'], dtype=object),
#  array(['남성등산바지', '남성등산티셔츠'], dtype=object),
#  array(['남성스포츠샌들/슬리퍼', '스포츠가방'], dtype=object),
#  array(['여성스포츠티셔츠/탑'], dtype=object),
#  array(['BB/파운데이션/컴팩트류', '아동수영복'], dtype=object),
#  array(['여성팬티', '남성용스킨케어류'], dtype=object),
#  array(['여성토트백'], dtype=object),
#  array(['여성남방셔츠', '여성바지'], dtype=object),
#  array(['여성남방셔츠', '여성바지', '여성원피스', '여아티셔츠/탑'], dtype=object),
#  array(['고양이간식', '페이셜클렌저'], dtype=object),
#  array(['유아동스포츠샌들/슬리퍼', 'BB/파운데이션/컴팩트류', '여성샌들', '여성크로스백'], dtype=object),
#  array(['사무용/학생용가구세트'], dtype=object),
#  array(['유아동타이즈', '유아동일반양말'], dtype=object),
#  array(['벽걸이형에어컨', '오메가3/기타추출오일', '일반형냉장고'], dtype=object),
#  array(['BB/파운데이션/컴팩트류', '블러셔/쉐이딩/하이라이터'], dtype=object),
#  array(['유아동스포츠샌들/슬리퍼'], dtype=object),
#  array(['커튼링/커튼봉/부속품', '커튼'], dtype=object),
#  array(['여성등산점퍼/재킷', '생수', '스킨케어세트'], dtype=object),
#  array(['아동모'], dtype=object),
#  array(['홍삼정/분말/환', '성인패드/스프레드', '기타모바일액세서리', '여성속옷세트', '남성남방셔츠', '헤어에센스',
#         '홍삼액', '토마토'], dtype=object),
#  array(['미용보조식품'], dtype=object),
#  array(['영유아스커트', '여아레깅스'], dtype=object),
#  array(['블러셔/쉐이딩/하이라이터', '스킨케어디바이스', '립글로즈/틴트', '크림/밤/오일', '샴푸',
#         '입욕제/스파제품'], dtype=object),
#  array(['남성티셔츠', '남성정장셔츠'], dtype=object),
#  array(['생리대', '바디보습'], dtype=object),
#  array(['스카프', '어린이홍삼', '여성런닝/트레이닝화', '골프패션잡화'], dtype=object),
#  array(['아동수영복'], dtype=object),
#  array(['남성스포츠티셔츠'], dtype=object),
#  array(['여성티셔츠/탑', '남성남방셔츠', '여성슬립온'], dtype=object),
#  array(['블러셔/쉐이딩/하이라이터'], dtype=object),
#  array(['과일즙'], dtype=object),
#  array(['여아남방셔츠', '영유아스커트'], dtype=object),
#  array(['스폰지/퍼프', '기타모바일액세서리', '남성스킨케어세트', '아이섀도우'], dtype=object),
#  array(['전기튀김기', '성인패드/스프레드', '성인담요'], dtype=object),
#  array(['남아티셔츠/탑', '유아동스포츠스웨트셔츠/후드/집업'], dtype=object),
#  array(['남성가디건', '남성남방셔츠', '남성티셔츠'], dtype=object),
#  array(['여성남방셔츠', '여성코트'], dtype=object),
#  array(['목걸이', '귀걸이', '남성골프티셔츠', '여성런닝/트레이닝화'], dtype=object),
#  array(['요가/필라테스복', '물안경', '남성티셔츠', '여성수영복'], dtype=object),
#  array(['여성청바지'], dtype=object),
#  array(['여성티셔츠/탑', '립글로즈/틴트'], dtype=object),
#  array(['남성티셔츠', '남성베스트', '여성재킷', '여성원피스', '여성스커트', '과일즙'], dtype=object),
#  array(['남성캐주얼바지'], dtype=object),
#  array(['여성비치웨어'], dtype=object),
#  array(['스포츠모자', '프라이팬'], dtype=object),
#  array(['여성런닝/트레이닝화', '여성원피스'], dtype=object),
#  array(['양산', '분말표백제'], dtype=object),
#  array(['남성등산티셔츠', '남성캐주얼바지'], dtype=object),
#  array(['소파'], dtype=object),
#  array(['메이크업세트'], dtype=object),
#  array(['여성남방셔츠'], dtype=object),
#  array(['여성남방셔츠', '여성재킷', '여성바지', '에센스/세럼', '여성내의', '유아동팬티', '여성속옷세트',
#         '페이셜클렌저', '스킨/토너', '유아동샌들', '유아동내의'], dtype=object),
#  array(['팔찌'], dtype=object),
#  array(['크림/밤/오일', '스킨/토너', '행주'], dtype=object),
#  array(['롤티슈', '선크림류', '액상세탁세제', '일반청소기', '유아용화장품', '여성향수'], dtype=object),
#  array(['기타일반문구/사무용품'], dtype=object),
#  array(['기타패션잡화', '립글로즈/틴트'], dtype=object),
#  array(['여성덧신류'], dtype=object),
#  array(['여성토트백'], dtype=object),
#  array(['남성캐주얼바지', '남성팬티', '여아바지', '팔찌', '남성티셔츠', '여성펌프스', '여성숄더백',
#         '여성남방셔츠', '여성속옷세트', '여성티셔츠/탑', '여성스니커즈', '아동수영복', '여성골프남방셔츠',
#         '남성런닝/트레이닝화', '여성팬티', '영유아스커트', '영유아남방셔츠', '영유아바지', '여성수영복',
#         '남성수영복'], dtype=object),
#  array(['수건', '프라이팬', '유산균/프로바이오틱스', '스텝퍼/트위스트'], dtype=object),
#  array(['여성부츠', '여성등산패딩'], dtype=object),
#  array(['여성원피스', '여성베스트', '바구니', '성인패드/스프레드', '일반비타민', '스포츠가방', '메이크업세트',
#         '식탁'], dtype=object),
#  array(['생수', '스킨케어세트'], dtype=object),
#  array(['페이셜클렌저', '크림/밤/오일', '스킨케어세트', '여성원피스', '전기밥솥'], dtype=object),
#  array(['여성팬티', '기타영양제', '유아동스포츠샌들/슬리퍼', '대접/볼', '오메가3/기타추출오일', '여아남방셔츠',
#         '밥공기', '선크림류', '찬기/종지', '일반비타민', '여아티셔츠/탑', '남아의류세트',
#         '블러셔/쉐이딩/하이라이터'], dtype=object),
#  array(['남성일반스포츠바지'], dtype=object),
#  array(['남아의류세트', '남아바지', '남성티셔츠', '골프화', '남성스포츠티셔츠', '영유아점프수트/오버롤',
#         '영유아티셔츠/탑'], dtype=object),
#  array(['여성발가락양말'], dtype=object),
#  array(['남성스포츠샌들/슬리퍼', '섬유유연제/향기지속제'], dtype=object),
#  array(['역할놀이', '남아티셔츠/탑', '유아동베개/베개커버', '유아용카시트/매트'], dtype=object),
#  array(['수건', '유아동런닝셔츠', '유아용물티슈', '여아티셔츠/탑', '프라이팬', '한방음료', '영유아원피스'],
#        dtype=object),
#  array(['김치류'], dtype=object),
#  array(['남성스킨케어세트'], dtype=object),
#  array(['젖병소독/건조용품', '유아용기저귀'], dtype=object),
#  array(['남성티셔츠', '남성캐주얼바지', '남성등산티셔츠'], dtype=object),
#  array(['유아/아동용칫솔', '기타냉동간편식', '유아목욕용품', '유아용샴푸/바디워시', '유아용화장품', '기타냉방가전',
#         'BB/파운데이션/컴팩트류', '유아동스포츠샌들/슬리퍼'], dtype=object),
#  array(['선반장/행거'], dtype=object),
#  array(['여성속옷세트', '유아동내의', '여성스포츠티셔츠/탑', '영유아원피스', '유아동스니커즈', '아동수영복',
#         '유아동트레이닝복', '여성일반양말', '요가/필라테스복', '여성수영복', '수영모자', '유아동일반양말',
#         '헤어에센스', '페이셜팩류', '기타물놀이용품', '기타여성속옷', '케이스/보호필름', '유아동런닝셔츠',
#         '피규어', '기타일반문구/사무용품', '출산/신생아용품세트', '여아잠옷', '스킨케어세트'], dtype=object),
#  array(['여성바지', '일반두유', '남성정장바지'], dtype=object),
#  array(['여성코트', '여성스웨터/풀오버'], dtype=object),
#  array(['페이셜클렌저', '에센스/세럼'], dtype=object),
#  array(['여성비치웨어'], dtype=object),
#  array(['헤어드라이어', '스킨/토너', '에센스/세럼', '크림/밤/오일'], dtype=object),
#  array(['식음료모바일상품권'], dtype=object),
#  array(['아이섀도우'], dtype=object),
#  array(['유아동타이즈', '여아티셔츠/탑'], dtype=object),
#  array(['여성속옷세트', '선반/걸이', '선반장/행거'], dtype=object),
#  array(['립스틱/립라이너', '여성향수', '여성티셔츠/탑', '여성남방셔츠', '여성스커트', '유아용샴푸/바디워시',
#         '남성티셔츠'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['헤어에센스', '기타일반문구/사무용품', '여성양말선물세트', '스킨/토너', '우주복', '유아동내의'],
#        dtype=object),
#  array(['귀걸이', '남성캐주얼바지', '여성펌프스'], dtype=object),
#  array(['일반두유'], dtype=object),
#  array(['여성코트'], dtype=object),
#  array(['식음료모바일상품권', '물티슈', '플라스틱서랍장'], dtype=object),
#  array(['메이크업베이스/프라이머', '블러셔/쉐이딩/하이라이터', '남성티셔츠'], dtype=object),
#  array(['지퍼백/비닐백'], dtype=object),
#  array(['여성베스트', '스킨케어세트'], dtype=object),
#  array(['생수'], dtype=object),
#  array(['남성팬티'], dtype=object),
#  array(['남성코트', '스킨케어디바이스', '남성티셔츠'], dtype=object),
#  array(['메이크업세트'], dtype=object),
#  array(['액상세탁세제', '커피메이커/포트', '역할놀이', '분말세탁세제', '섬유유연제/향기지속제', '분말표백제'],
#        dtype=object),
#  array(['책상', '책상의자'], dtype=object),
#  array(['여성런닝/트레이닝화'], dtype=object),
#  array(['여성런닝/트레이닝화'], dtype=object),
#  array(['고양이간식', '고양이모래/배변용품'], dtype=object),
#  array(['남성티셔츠', '수유패드/보조용품', '이유식용품', '유아동의자'], dtype=object),
#  array(['골프필드용품', '남성골프티셔츠', '영유아원피스'], dtype=object),
#  array(['여성스커트'], dtype=object),
#  array(['아이섀도우', '남성스포츠샌들/슬리퍼', '기름종이', '아이라이너', '아이브로우', '남아바지', '남성티셔츠',
#         '여성티셔츠/탑'], dtype=object),
#  array(['남성남방셔츠', '남성캐주얼바지'], dtype=object),
#  array(['여성향수', '영유아점프수트/오버롤', '유아동스포츠샌들/슬리퍼', '영유아원피스', '남아바지', '메이크업세트',
#         '남성티셔츠', '영유아티셔츠/탑', '스킨케어세트', '남아의류세트', '학생용가방', '남성스포츠티셔츠'],
#        dtype=object),
#  array(['여성런닝/트레이닝화'], dtype=object),
#  array(['남성스포츠점퍼/재킷'], dtype=object),
#  array(['여성로퍼', '여성원피스'], dtype=object),
#  array(['기타일반문구/사무용품', '남성캐주얼바지', '이불/옷압축팩', '유아동샌들', '메이크업베이스/프라이머',
#         '유아공부상/디딤대'], dtype=object),
#  array(['생수'], dtype=object),
#  array(['유아동스니커즈'], dtype=object),
#  array(['에센스/세럼', '여성팬티', '잉크/토너'], dtype=object),
#  array(['여성향수세트', 'BB/파운데이션/컴팩트류'], dtype=object),
#  array(['여성스커트', '여성바지'], dtype=object),
#  array(['유아동일반양말', '이유식용품', '여성스웨터/풀오버', '여성바지', '여성비치웨어', '아동모', '여성재킷',
#         '남성수영복', '여성등산티셔츠/탑', '여성등산점퍼/재킷'], dtype=object),
#  array(['유아용기저귀', '여성잠옷', '젖병/젖꼭지'], dtype=object),
#  array(['여성남방셔츠', '여성티셔츠/탑', '유아동런닝/트레이닝화'], dtype=object),
#  array(['남성수영복', '남성스포츠샌들/슬리퍼'], dtype=object),
#  array(['목걸이', '여성티셔츠/탑', '펜던트', '기타패션잡화', '여성스커트', '여성원피스', '샴푸'],
#        dtype=object),
#  array(['여성일반지갑'], dtype=object),
#  array(['보드게임'], dtype=object),
#  array(['여성스포츠샌들/슬리퍼'], dtype=object),
#  array(['스킨/토너', '린스/컨디셔너', '헤어에센스', '블러셔/쉐이딩/하이라이터'], dtype=object),
#  array(['여성수영복'], dtype=object),
#  array(['레고'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['여성바지', '여성원피스'], dtype=object),
#  array(['남성비치웨어', '등산화', '남성티셔츠', '유아동스포츠티셔츠/탑', '유아동스포츠점퍼/재킷', '접시',
#         '남아티셔츠/탑', '썬캡'], dtype=object),
#  array(['메이크업세트', '여성샌들', '여성속옷세트', '고양이모래/배변용품'], dtype=object),
#  array(['유아목욕용품', '유아동샌들', '출산/신생아용품세트', '역할놀이', '다이어트보조식품'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['헤어케어선물세트', '메이크업세트'], dtype=object),
#  array(['선크림류', '기름종이'], dtype=object),
#  array(['커피메이커/포트'], dtype=object),
#  array(['기타냉동간편식', '여성바지'], dtype=object),
#  array(['남성정장셔츠', '남성남방셔츠', 'BB/파운데이션/컴팩트류', '남성정장바지'], dtype=object),
#  array(['여성티셔츠/탑'], dtype=object),
#  array(['남성티셔츠', '남성스포츠샌들/슬리퍼', '여성스웨터/풀오버', '여성티셔츠/탑', '유아동스포츠샌들/슬리퍼',
#         '영유아블라우스'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['유아용화장품', '유아동내의'], dtype=object),
#  array(['남성팬티', '헤어에센스', '스킨/토너', '샴푸/린스세트'], dtype=object),
#  array(['이유식용품'], dtype=object),
#  array(['여성바지'], dtype=object),
#  array(['여성등산패딩'], dtype=object),
#  array(['여성비치웨어', '성인베개/베개커버', '유아동트레이닝복', '유아동런닝/트레이닝화', '여성수영복',
#         '유아동스니커즈', '유아동베개/베개커버', '영유아티셔츠/탑', '유아동슬립온', '유아동런닝셔츠', '남아바지',
#         '프라이팬', '유아동팬티', '아동수영복', '여성향수'], dtype=object),
#  array(['여성펌프스', '남성정장바지', '남성티셔츠', '성인이불/이불커버', '성인패드/스프레드'], dtype=object),
#  array(['바디워시', '남성티셔츠', '남성캐주얼바지', '여성샌들', '헤어드라이어'], dtype=object),
#  array(['아이섀도우', '남성티셔츠', '남성스포츠티셔츠', '여성스포츠티셔츠/탑', '성인베개/베개커버', '스포츠가방',
#         '남성등산티셔츠', '브래지어', '여성남방셔츠', '여성등산점퍼/재킷', '남성런닝/트레이닝화', '스킨/토너',
#         '기타일반문구/사무용품', 'BB/파운데이션/컴팩트류', '에멀젼/로션', '스킨케어세트', '성인이불/이불커버',
#         '남성수영복', '여성티셔츠/탑', '오메가3/기타추출오일', '페이셜클렌저'], dtype=object),
#  array(['유아동런닝/트레이닝화'], dtype=object),
#  array(['여성로퍼'], dtype=object),
#  array(['립글로즈/틴트', '블러셔/쉐이딩/하이라이터', '아이섀도우', 'BB/파운데이션/컴팩트류'], dtype=object),
#  array(['남성등산패딩'], dtype=object),
#  array(['치약/칫솔세트', '기타구강관리용품', '섬유유연제/향기지속제'], dtype=object),
#  array(['페이셜팩류', '페이셜클렌저'], dtype=object),
#  array(['여성스커트', '여성티셔츠/탑'], dtype=object),
#  array(['블러셔/쉐이딩/하이라이터'], dtype=object),
#  array(['유아동런닝/트레이닝화'], dtype=object),
#  array(['여성스커트', '블랙박스'], dtype=object),
#  array(['헤어드라이어'], dtype=object),
#  array(['여성바지', '여성점퍼', '여성스커트', '남성티셔츠', '여성티셔츠/탑', '여성가디건',
#         'BB/파운데이션/컴팩트류', '기름종이', '스킨케어세트', '유아용화장품', '여성남방셔츠', '남성정장셔츠',
#         '여성원피스', '수영가방', '패션인형', '역할놀이', '귀걸이', '기타물놀이용품', '여성코트',
#         '유아목욕용품'], dtype=object),
#  array(['남성비치웨어', '여성비치웨어'], dtype=object),
#  array(['고무장갑', '남성티셔츠', '스킨/토너', '스포츠가방', '남성런닝셔츠', '여성티셔츠/탑'],
#        dtype=object),
#  array(['스킨/토너', '스킨케어세트'], dtype=object),
#  array(['생활모바일상품권', '여성티셔츠/탑'], dtype=object),
#  array(['유아동스니커즈'], dtype=object),
#  array(['여성티셔츠/탑', '여성바지', '남성티셔츠', '여성원피스', '브래지어', '귀걸이', '여성속옷세트',
#         '여성남방셔츠', '여성슬리퍼', '성인침구세트', '도시락/찬합'], dtype=object),
#  array(['립스틱/립라이너', '유아용화장품', '출산/신생아용품세트', '유아목욕용품', '크림/밤/오일', '고양이사료',
#         '페이셜클렌저', '기타냉동간편식', '블러셔/쉐이딩/하이라이터', '남성캐주얼바지', '립글로즈/틴트',
#         '유아용기저귀', '발효원액', '남성티셔츠', '유아동내의'], dtype=object),
#  array(['여성플랫'], dtype=object),
#  array(['남성남방셔츠', '여성향수', '남성베스트', '남성등산베스트', '여성선글라스', '남성티셔츠'],
#        dtype=object),
#  array(['여성런닝/트레이닝화', '남아티셔츠/탑'], dtype=object),
#  array(['남성티셔츠', '여성점프수트/오버롤', '여성원피스', '여성스커트'], dtype=object),
#  array(['이유식용품', '치아발육기/딸랑이'], dtype=object),
#  array(['여성원피스', '남성수영복', '귀걸이', '여성샌들', '남성카드/명함지갑'], dtype=object),
#  array(['남성런닝/트레이닝화'], dtype=object),
#  array(['남성런닝/트레이닝화', '남성스포츠샌들/슬리퍼'], dtype=object),
#  array(['아동수영복', '남아의류세트'], dtype=object),
#  array(['남아바지', '크림/밤/오일', '영유아티셔츠/탑', '남성용선크림/메이크업류', '스킨/토너'],
#        dtype=object),
#  array(['영유아티셔츠/탑', '영유아남방셔츠'], dtype=object),
#  array(['유아용화장품'], dtype=object),
#  array(['스킨/토너', '선크림류', '여성샌들', '에센스/세럼'], dtype=object),
#  array(['여성남방셔츠', '여성바지'], dtype=object),
#  array(['남성스포츠티셔츠'], dtype=object),
#  array(['여성비치웨어'], dtype=object),
#  array(['유아동슬립온', '여아티셔츠/탑', '영유아원피스', '영유아티셔츠/탑', '아동모'], dtype=object),
#  array(['여성원피스', '남성티셔츠', '메이크업세트', '여성스커트', '여성바지', '에센스/세럼', '혼합즙'],
#        dtype=object),
#  array(['수영가방', '아동수영복'], dtype=object),
#  array(['남성티셔츠', '여성팬티'], dtype=object),
#  array(['여성바지', '여성재킷', '남성골프점퍼/재킷', '여성골프티셔츠/탑', '여성티셔츠/탑', '여성남방셔츠',
#         '여성원피스'], dtype=object),
#  array(['BB/파운데이션/컴팩트류', '블러셔/쉐이딩/하이라이터'], dtype=object),
#  array(['아동수영복', '여성샌들', '남성수영복', '유아동샌들', '아동모', '아쿠아슈즈', '여성비치웨어'],
#        dtype=object),
#  array(['남성향수'], dtype=object),
#  array(['스킨케어세트', '선풍기'], dtype=object),
#  array(['남성티셔츠', '여성샌들', '브래지어', '기타국산과일류', 'BB/파운데이션/컴팩트류', '김치류',
#         '남성캐주얼바지', '여성속옷세트', '성인패드/스프레드', '영유아티셔츠/탑', '숟가락/젓가락', '여아스커트',
#         '건조기', '여성바지'], dtype=object),
#  array(['선크림류', '여성런닝셔츠/캐미솔', '스킨케어세트'], dtype=object),
#  array(['헤어에센스', '식음료모바일상품권'], dtype=object),
#  array(['기타요가/필라테스소품'], dtype=object),
#  array(['애견주거/실내용품', '여성티셔츠/탑', '여성스커트'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['여성덧신류', '여성샌들'], dtype=object),
#  array(['여성원피스', '여성카드/명함지갑'], dtype=object),
#  array(['다이어트보조식품', '채소즙', '생수'], dtype=object),
#  array(['브래지어'], dtype=object),
#  array(['스킨/토너', '에멀젼/로션', '메이크업세트', '바디케어세트', '스킨케어세트', 'BB/파운데이션/컴팩트류',
#         '여성티셔츠/탑'], dtype=object),
#  array(['린스/컨디셔너'], dtype=object),
#  array(['커피용품'], dtype=object),
#  array(['기타여성속옷'], dtype=object),
#  array(['기타구강관리용품', '칫솔', '여성일반양말', '남성용스킨케어류', '한방음료', '유아/아동용칫솔',
#         '유아용물티슈', '남성스킨케어세트', '남성티셔츠', '남성남방셔츠', '유아동일반양말'], dtype=object),
#  array(['유아동스포츠샌들/슬리퍼', '남성캐주얼바지'], dtype=object),
#  array(['팔찌', '여성슬리퍼'], dtype=object),
#  array(['남성티셔츠', '여성티셔츠/탑', '여성가디건'], dtype=object),
#  array(['메이크업세트', '페이셜클렌저'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['브래지어'], dtype=object),
#  array(['기타일반문구/사무용품', '유아동내의', '유아동일반양말', '성인베개/베개커버', '거실수예소품', '유아동팬티',
#         '남아티셔츠/탑', '기타기능성음료', '여아티셔츠/탑', '스피커', '얼음/빙수용품', '유아동타이즈'],
#        dtype=object),
#  array(['여성팬티'], dtype=object),
#  array(['영유아티셔츠/탑', '남아바지'], dtype=object),
#  array(['트리트먼트/팩', '샴푸'], dtype=object),
#  array(['남성스포츠샌들/슬리퍼'], dtype=object),
#  array(['액상세탁세제'], dtype=object),
#  array(['에센스/세럼', '페이셜팩류'], dtype=object),
#  array(['남성티셔츠', '남성스포츠티셔츠'], dtype=object),
#  array(['아쿠아슈즈', '생수'], dtype=object),
#  array(['남아의류세트'], dtype=object),
#  array(['여성일반스포츠바지', '블러셔/쉐이딩/하이라이터', '여성카드/명함지갑', '여성티셔츠/탑', '여성남방셔츠',
#         '남성가디건', '여성스웨터/풀오버'], dtype=object),
#  array(['남성용스킨케어류', '페이셜클렌저', '남성용클렌저', '아쿠아슈즈', '기타냉방가전'], dtype=object),
#  array(['남성가디건', '여성원피스'], dtype=object),
#  array(['여아티셔츠/탑', '스타킹', '커피잔', '스킨/토너', 'BB/파운데이션/컴팩트류', '유아동내의',
#         '남성티셔츠', '영유아바지'], dtype=object),
#  array(['남성일반양말', '보온병/텀블러'], dtype=object),
#  array(['전동칫솔/칫솔모', '여아티셔츠/탑'], dtype=object),
#  array(['남성수영복'], dtype=object),
#  array(['남성일반지갑'], dtype=object),
#  array(['여성남방셔츠'], dtype=object),
#  array(['남성수영복', '여성비치웨어', '남성캐주얼바지', '남성티셔츠'], dtype=object),
#  array(['여성플랫'], dtype=object),
#  array(['여성원피스', '등산화', '여성스포츠샌들/슬리퍼', '페이셜클렌저', '골프패션잡화', '여성샌들',
#         '에센스/세럼', '에멀젼/로션', '크림/밤/오일'], dtype=object),
#  array(['방석/방석커버'], dtype=object),
#  array(['여성남방셔츠', 'BB/파운데이션/컴팩트류', '스킨/토너', '스폰지/퍼프', '페이셜클렌저'],
#        dtype=object),
#  array(['영유아원피스', '여아티셔츠/탑'], dtype=object),
#  array(['유아동슬립온', '여아레깅스', '여아티셔츠/탑', '여아스웨트셔츠/후드/집업'], dtype=object),
#  array(['홍삼액', '생수'], dtype=object),
#  array(['헤어에센스'], dtype=object),
#  array(['에센스/세럼'], dtype=object),
#  array(['스포츠가방', '남성스킨케어세트', '양산', '여성가디건', '여성비치웨어', '여성바지', '여성원피스',
#         '유아용화장품'], dtype=object),
#  array(['에센스/세럼', '남성수영복', '남성런닝/트레이닝화', '남성스킨케어세트'], dtype=object),
#  array(['BB/파운데이션/컴팩트류'], dtype=object),
#  array(['아동수영복', '여성수영복'], dtype=object),
#  array(['유아동베개/베개커버', '유아동트레이닝복', '여성스커트', '여성원피스'], dtype=object),
#  array(['여성숄더백', '여성속옷세트'], dtype=object),
#  array(['혼합견과', '여성남방셔츠'], dtype=object),
#  array(['립스틱/립라이너'], dtype=object),
#  array(['여성스커트'], dtype=object),
#  array(['여성일반스포츠바지', '여성트레이닝복'], dtype=object),
#  array(['메이크업세트', '스킨케어세트', '남성스킨케어세트'], dtype=object),
#  array(['여아바지', '썬캡'], dtype=object),
#  array(['남성정장셔츠'], dtype=object),
#  array(['남성골프바지'], dtype=object),
#  array(['바디워시'], dtype=object),
#  array(['남성골프티셔츠', '남성트레이닝복', '여성트레이닝복', '남성등산바지', '남성캐주얼재킷'], dtype=object),
#  array(['아동수영복', '여성비치웨어', '장우산', '스킨케어세트', '크림/밤/오일'], dtype=object),
#  array(['남성런닝/트레이닝화', '남성캐주얼바지', '기타이미용가전'], dtype=object),
#  array(['남성비치웨어', '애견목욕/위생용품', '남성수영복'], dtype=object),
#  array(['영유아청바지', '조립/프라모델', '바디케어세트', '볼펜', '미술/창작완구', '필통', '샤프/샤프심',
#         '여아남방셔츠', '유아용물티슈', '기타일반문구/사무용품'], dtype=object),
#  array(['여성스포츠티셔츠/탑', '여성일반스포츠바지', '여성샌들'], dtype=object),
#  array(['스킨/토너', '선크림류', '바디케어세트'], dtype=object),
#  array(['유아동스니커즈'], dtype=object),
#  array(['여성향수', '메이크업세트', '블러셔/쉐이딩/하이라이터'], dtype=object),
#  array(['여성남방셔츠', '필기구세트', '남아의류세트', '남성티셔츠', '엽산/철분', '여아티셔츠/탑', '보드게임',
#         '볼펜', '영유아티셔츠/탑', '유아동트레이닝복', '유아패션잡화', '밥공기', '여아레깅스',
#         '남성카드/명함지갑', '여성런닝/트레이닝화', '레고'], dtype=object),
#  array(['휴대폰'], dtype=object),
#  array(['여성수영복'], dtype=object),
#  array(['여성비치웨어', '남성등산티셔츠', '등산화', '남성등산바지'], dtype=object),
#  array(['여성카드/명함지갑', '남성팬티', '남성일반스포츠바지'], dtype=object),
#  array(['입욕제/스파제품'], dtype=object),
#  array(['남아의류세트', '유아동스포츠티셔츠/탑', '남아티셔츠/탑', '남성스포츠점퍼/재킷', '유아동샌들',
#         '남성숄더/크로스백'], dtype=object),
#  array(['유아동런닝/트레이닝화', '남아의류세트', '유아동샌들', '아동수영복', '영유아티셔츠/탑'],
#        dtype=object),
#  array(['남성티셔츠', '여성골프티셔츠/탑', '남아바지'], dtype=object),
#  array(['남성티셔츠', '남성가디건', '야구모자', '남성일반스포츠바지', '여성토트백'], dtype=object),
#  array(['영유아청바지', '남성티셔츠', '여아바지', '여성청바지', '남성캐주얼바지'], dtype=object),
#  array(['블랜더'], dtype=object),
#  array(['일반비타민', '어린이홍삼'], dtype=object),
#  array(['여성남방셔츠'], dtype=object),
#  array(['귀걸이'], dtype=object),
#  array(['영유아바지', '여성스커트', '여아티셔츠/탑', '여성남방셔츠', '여성티셔츠/탑', '여성런닝셔츠/캐미솔'],
#        dtype=object),
#  array(['여성팬티', '여성런닝셔츠/캐미솔', '여성속옷세트', '여성오픈토', '여성플랫'], dtype=object),
#  array(['밥공기'], dtype=object),
#  array(['립글로즈/틴트', '기타조리도구', '안경테', '반찬통/밀폐용기', '여성슬립온', '다이어트보조식품',
#         '여성속옷세트', '3단우산', '장우산'], dtype=object),
#  array(['남성캐주얼바지'], dtype=object),
#  array(['기타물놀이용품', '아동수영복', '영유아바지', '아동비치웨어', '여아티셔츠/탑', '남성등산점퍼/재킷',
#         '여성등산점퍼/재킷'], dtype=object),
#  array(['여성일반지갑', '여성남방셔츠'], dtype=object),
#  array(['유아용화장품'], dtype=object),
#  array(['여성스커트'], dtype=object),
#  array(['페이셜클렌저', '다이어트보조식품', '페이셜팩류', '선크림류', '바디워시', '루테인', '스킨/토너',
#         '립스틱/립라이너', '에센스/세럼'], dtype=object),
#  array(['유아동내의', '출산/신생아용품세트'], dtype=object),
#  array(['칫솔'], dtype=object),
#  array(['생수', '각티슈/미용티슈'], dtype=object),
#  array(['스킨케어세트', '크림/밤/오일'], dtype=object),
#  array(['메이크업세트'], dtype=object),
#  array(['남성스포츠티셔츠', '골프가방', '남성스포츠점퍼/재킷'], dtype=object),
#  array(['여성원피스', '여성샌들', '여성트레이닝복', '여성재킷', '여성티셔츠/탑', '여성타이즈', '남성캐주얼바지',
#         '여성스포츠티셔츠/탑', '바디케어세트', '남성청바지', '여성청바지', '남성티셔츠', '혼합견과', '여성바지',
#         '여성가디건', '요가/스포츠매트', '여성펌프스', '여성남방셔츠', '페이셜팩류', '여성플랫',
#         '여성스웨트셔츠/후드/집업', '스카프', '3단우산', '여성일반스포츠바지', '커피잔', '장우산'],
#        dtype=object),
#  array(['유아동내의', '유아동슬립온'], dtype=object),
#  array(['남성캐주얼바지'], dtype=object),
#  array(['스포츠가방', '유아동스포츠티셔츠/탑', '영유아점프수트/오버롤', '영유아바지', '여아티셔츠/탑',
#         '여성골프티셔츠/탑', '유아동스포츠샌들/슬리퍼'], dtype=object),
#  array(['여성남방셔츠'], dtype=object),
#  array(['여성남방셔츠', '종합영양제'], dtype=object),
#  array(['유아용기저귀', '기타기능성음료'], dtype=object),
#  array(['에멀젼/로션', '유아용화장품'], dtype=object),
#  array(['남성캐주얼바지', '남성청바지', '바디워시'], dtype=object),
#  array(['엽산/철분', '영유아원피스'], dtype=object),
#  array(['스킨/토너', '페이셜클렌저', '스킨케어세트', '립글로즈/틴트'], dtype=object),
#  array(['유아용세척용품', '이유식용품'], dtype=object),
#  array(['여성스포츠티셔츠/탑', '여성런닝/트레이닝화'], dtype=object),
#  array(['식음료모바일상품권'], dtype=object),
#  array(['생리대', '여성원피스'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['이유식용품'], dtype=object),
#  array(['유아동내의', '유아동팬티'], dtype=object),
#  array(['야구모자', '여성골프스커트', '여성티셔츠/탑', '여성팬티', '여성타이즈', '골프필드용품', '여성남방셔츠',
#         '여성재킷', '기타일반문구/사무용품', '여성코트', '생수', '여성샌들', '여성청바지', '남성숄더/크로스백',
#         '골프장갑', '여성골프패딩', '남성스포츠티셔츠', '메이크업베이스/프라이머', '여성바지', '여성골프니트/가디건',
#         '아이브로우', '골프연습장비', '남성수영복', '아이섀도우', '페이셜클렌저', '여성스커트', '홍삼액',
#         '여성원피스', '여성골프베스트', '골프패션잡화', '블러셔/쉐이딩/하이라이터', '여성골프티셔츠/탑',
#         '메이크업세트', '여성토트백', '립글로즈/틴트'], dtype=object),
#  array(['남아잠옷', '영유아티셔츠/탑', '스타킹'], dtype=object),
#  array(['남성스킨케어세트'], dtype=object),
#  array(['닭가슴살'], dtype=object),
#  array(['아쿠아슈즈'], dtype=object),
#  array(['BB/파운데이션/컴팩트류', '크림/밤/오일'], dtype=object),
#  array(['유아동이불/이불커버'], dtype=object),
#  array(['페이셜클렌저', '여아티셔츠/탑', '남성티셔츠', '스폰지/퍼프'], dtype=object),
#  array(['유아동내의', '유아동팬티', '남성런닝/트레이닝화', '유아동런닝셔츠'], dtype=object),
#  array(['남성스포츠샌들/슬리퍼'], dtype=object),
#  array(['남성시계', '샴푸'], dtype=object),
#  array(['인삼가공식품', '남성스포츠샌들/슬리퍼', '여아레깅스'], dtype=object),
#  array(['영유아점퍼', '영유아티셔츠/탑', '남아바지', '남아청바지', '영유아가디건'], dtype=object),
#  array(['아동모'], dtype=object),
#  array(['영유아점프수트/오버롤', '남아의류세트', '영유아티셔츠/탑', '여아스웨트셔츠/후드/집업'], dtype=object),
#  array(['여성일반스포츠바지'], dtype=object),
#  array(['블러셔/쉐이딩/하이라이터'], dtype=object),
#  array(['영유아스커트'], dtype=object),
#  array(['여성등산점퍼/재킷'], dtype=object),
#  array(['여성속옷세트'], dtype=object),
#  array(['여성숄더백', '미용비누', '브래지어', '여성런닝/트레이닝화', '메이크업세트'], dtype=object),
#  array(['여성수영복', '물안경', '수영모자'], dtype=object),
#  array(['남성스웨터/풀오버', '여성스포츠티셔츠/탑', '스포츠가방', '여성샌들', '남성패딩', '남성티셔츠',
#         '여성바지', '여성일반스포츠바지', '여성티셔츠/탑'], dtype=object),
#  array(['여성티셔츠/탑', '섬유유연제/향기지속제', '여성원피스', '여성바지'], dtype=object),
#  array(['남성티셔츠', '핸드로션/크림', '남성스웨트셔츠/후드/집업'], dtype=object),
#  array(['아쿠아슈즈', 'BB/파운데이션/컴팩트류', '욕실소품'], dtype=object),
#  array(['여성재킷', '남성티셔츠', '여성향수', '여성바지', '남성향수', '사인펜', '여성향수세트', '볼펜'],
#        dtype=object),
#  array(['BB/파운데이션/컴팩트류', '남성선글라스', '헤어에센스', '기타패션잡화'], dtype=object),
#  array(['남성스포츠샌들/슬리퍼', '아기띠/캐리어', '남성스킨케어세트'], dtype=object),
#  array(['아동수영복'], dtype=object),
#  array(['남성티셔츠', '남성캐주얼바지', '남성남방셔츠', '남성시계', '남성스포츠티셔츠'], dtype=object),
#  array(['여성바지', '여성런닝/트레이닝화'], dtype=object),
#  array(['기타기능성음료'], dtype=object),
#  array(['영유아티셔츠/탑', '스킨/토너'], dtype=object),
#  array(['BB/파운데이션/컴팩트류'], dtype=object),
#  array(['반지'], dtype=object),
#  array(['여성플랫', '여성바지', '남성티셔츠', '여성카드/명함지갑', '남성정장바지'], dtype=object),
#  array(['여성스커트'], dtype=object),
#  array(['일반비타민', '남성팬티', '여성런닝/트레이닝화'], dtype=object),
#  array(['이어폰/헤드폰'], dtype=object),
#  array(['남성스포츠티셔츠'], dtype=object),
#  array(['여성원피스'], dtype=object),
#  array(['크림/밤/오일', '여성오픈토', '여성펌프스', '여성시계', '골프필드용품', '여성샌들', '여성티셔츠/탑',
#         'BB/파운데이션/컴팩트류', '아동우산', '여성스웨터/풀오버', '여성선글라스', '여성재킷', '남성용스킨케어류',
#         '여성바지', '여성크로스백', '샴푸', '여성부츠', '유아동플랫', '여성숄더백'], dtype=object),
#  array(['BB/파운데이션/컴팩트류', '유아패션잡화', '립글로즈/틴트', '유아동타이즈'], dtype=object),
#  array(['여성샌들', '여성남방셔츠', '남성트레이닝복', '여성티셔츠/탑', '숟가락/젓가락', '조리도구세트',
#         '여성일반지갑', '여성골프티셔츠/탑', '여성원피스', '여성스웨터/풀오버'], dtype=object),
#  array(['여성일반지갑'], dtype=object),
#  array(['출산/신생아용품세트', '유아동스포츠샌들/슬리퍼', '유아동샌들'], dtype=object),
#  array(['유아동슬립온', '여아티셔츠/탑', '영유아티셔츠/탑', '여아스커트'], dtype=object),
#  array(['남성런닝/트레이닝화'], dtype=object),
#  array(['패션인형'], dtype=object),
#  array(['조립/프라모델'], dtype=object),
#  array(['여성속옷세트'], dtype=object),
#  array(['남성티셔츠', '미용비누'], dtype=object),
#  array(['여성속옷세트', '여성임부속옷', '여성런닝/트레이닝화'], dtype=object),
#  array(['스킨/토너', '에멀젼/로션', '페이셜클렌저', '여성향수', '키친타올', '남성런닝셔츠', '남성팬티',
#         '바디워시'], dtype=object),
#  array(['남녀공용향수', '바디보습', '핸드로션/크림'], dtype=object),
#  array(['여성수영복', '유아동레인부츠/슈즈', '커피머신'], dtype=object),
#  array(['BB/파운데이션/컴팩트류'], dtype=object),
#  array(['기타냉동간편식'], dtype=object),
#  array(['일반두유'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['크림/밤/오일', '유아동런닝/트레이닝화', '여성샌들', '여성스웨터/풀오버', '여성원피스', '유아동샌들',
#         '여성스커트'], dtype=object),
#  array(['유아동스니커즈'], dtype=object),
#  array(['스킨/토너'], dtype=object),
#  array(['여성런닝/트레이닝화', '남성런닝/트레이닝화'], dtype=object),
#  array(['남성런닝/트레이닝화'], dtype=object),
#  array(['접시', '여성일반스포츠바지', '헤어드라이어', '남성티셔츠', '여성로퍼', '남녀공용향수', '남성정장바지',
#         '남성일반스포츠바지', '크림/밤/오일', '양산', '찬기/종지', '미용비누', '바디보습'],
#        dtype=object),
#  array(['골프연습장비'], dtype=object),
#  array(['여성바지', '남성용스킨케어류', '스킨케어세트'], dtype=object),
#  array(['여성팬티', '여성덧신류'], dtype=object),
#  array(['남성티셔츠', '블러셔/쉐이딩/하이라이터', '여성스커트', 'BB/파운데이션/컴팩트류'], dtype=object),
#  array(['여성스커트', '여성플랫'], dtype=object),
#  array(['크림/밤/오일'], dtype=object),
#  array(['여성런닝/트레이닝화', '여성덧신류'], dtype=object),
#  array(['골프패션잡화', '아쿠아슈즈', '남성일반스포츠바지', '젖병소독/건조용품', '골프필드용품'],
#        dtype=object),
#  array(['아동모'], dtype=object),
#  array(['유아동일반양말'], dtype=object),
#  array(['성인베개/베개커버'], dtype=object),
#  array(['여성티셔츠/탑', '크림/밤/오일'], dtype=object),
#  array(['등산화', '성인침구속통/솜', '여성남방셔츠'], dtype=object),
#  array(['여성원피스', '남성비치웨어', '여성비치웨어', '남성티셔츠', '남성정장셔츠'], dtype=object),
#  array(['스킨케어세트'], dtype=object),
#  array(['고양이간식'], dtype=object),
#  array(['여성남방셔츠'], dtype=object),
#  array(['남성티셔츠', '남성등산바지'], dtype=object),
#  array(['여성남방셔츠'], dtype=object),
#  array(['유아건강보조제'], dtype=object),
#  array(['김치류', '여성슬립온'], dtype=object),
#  array(['바디보습', '핸드로션/크림', '린스/컨디셔너', '샴푸', '헤어에센스'], dtype=object),
#  array(['여성로퍼'], dtype=object),
#  array(['생수', '여성런닝/트레이닝화', '블랜더', '남성팬티', '캠핑테이블/의자', '도시락/찬합', '유아용물티슈'],
#        dtype=object),
#  array(['유아패션잡화', '스킨케어세트', '여성가운'], dtype=object),
#  array(['여성스커트', '여성남방셔츠'], dtype=object),
#  array(['여성티셔츠/탑', '여성원피스'], dtype=object),
#  array(['남성점퍼', '남성티셔츠'], dtype=object),
#  array(['남성청바지', '남성캐주얼바지'], dtype=object),
#  array(['여성재킷'], dtype=object),
#  array(['여성스웨트셔츠/후드/집업', '홍삼액'], dtype=object),
#  array(['남성스포츠샌들/슬리퍼'], dtype=object),
#  array(['여성슬립온', '여성원피스', '여성샌들'], dtype=object),
#  array(['성인베개/베개커버', '남성캐주얼바지', '영유아바지', '롤플레잉완구', '남아바지', '바디워시',
#         '기타컴퓨터액세서리', '보온병/텀블러', '핸드로션/크림', '유아동슬리퍼', '남성일반양말', '유아동샌들'],
#        dtype=object),
#  array(['유아동팬티', '남성티셔츠', '남성등산티셔츠', '남성잠옷'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['영유아티셔츠/탑', '여성코트', '남아바지', '남성티셔츠', '여성샌들', '아동모', '남성런닝/트레이닝화',
#         '보온병/텀블러', '남아의류세트'], dtype=object),
#  array(['여성스니커즈'], dtype=object),
#  array(['바디케어세트'], dtype=object),
#  array(['아이섀도우', '메이크업세트', '아이브로우', '반찬통/밀폐용기', '여성덧신류', '스킨케어세트',
#         '입욕제/스파제품', 'PC부품', '아이라이너', '목걸이', '영유아가디건', '유아동일반양말', '바디케어세트'],
#        dtype=object),
#  array(['치약', '김치류', '남성캐주얼바지', '애견사료', '액상세탁세제'], dtype=object),
#  array(['아동수영복', '여아티셔츠/탑', '유아동내의', '물안경', '유아동샌들', '영유아스커트', '영유아청바지',
#         '여아남방셔츠', '여아스커트', '기타모바일액세서리', '여성티셔츠/탑', '영유아티셔츠/탑'],
#        dtype=object),
#  array(['생수', '기타모바일액세서리', '남성티셔츠', '기타일반문구/사무용품'], dtype=object),
#  array(['블러셔/쉐이딩/하이라이터'], dtype=object),
#  array(['남성비치웨어'], dtype=object),
#  array(['생수', '아기띠/캐리어', '스킨케어세트'], dtype=object),
#  array(['블러셔/쉐이딩/하이라이터', '미스트'], dtype=object),
#  array(['유아동내의', '샴푸', '유아동일반양말', '유아동런닝셔츠', '여성원피스', '스킨/토너'],
#        dtype=object),
#  array(['여성트레이닝복', '프라이팬'], dtype=object),
#  array(['영유아티셔츠/탑', '유아동일반양말', '남성남방셔츠', '여아티셔츠/탑'], dtype=object),
#  array(['기름종이', 'BB/파운데이션/컴팩트류'], dtype=object),
#  array(['남성티셔츠', '여성펌프스', '유아동스포츠패딩', '여성슬링백', '영유아바지', '여아패딩', '캠핑취사',
#         '기타캠핑용품', '영유아원피스', '유아동슬립온', '반찬통/밀폐용기', '여성바지'], dtype=object),
#  array(['스킨케어세트', '페이셜팩류', '립글로즈/틴트'], dtype=object),
#  array(['블러셔/쉐이딩/하이라이터'], dtype=object),
#  array(['블러셔/쉐이딩/하이라이터', '유아동스니커즈', '아이섀도우', '유아동런닝/트레이닝화', '전통/종교장신구',
#         '프라이팬'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['여성런닝/트레이닝화', '남아의류세트', '여성향수'], dtype=object),
#  array(['홍삼/인삼혼합세트'], dtype=object),
#  array(['여성바지'], dtype=object),
#  array(['여아티셔츠/탑', '남아티셔츠/탑'], dtype=object),
#  array(['남성점퍼'], dtype=object),
#  array(['여성덧신류'], dtype=object),
#  array(['여성샌들', '남성등산티셔츠', '키보드', '여아남방셔츠', '페이셜클렌저', '여성바지', '복근/벨트마사지기구',
#         '영유아바지', '에센스/세럼', '기타캠핑용품', '수건', '벙거지', '여성스웨터/풀오버', '여아청바지',
#         '영유아원피스', '여성토트백', '립글로즈/틴트', '여아티셔츠/탑', '일반비타민', '여아레깅스', '남아바지',
#         '유아동팬티', '브래지어', '유아동스포츠샌들/슬리퍼', '아이섀도우', '남성티셔츠', '영유아청바지', '슬립',
#         '스킨케어세트', '여성발가락양말'], dtype=object),
#  array(['남성남방셔츠'], dtype=object),
#  array(['브래지어', '여성팬티'], dtype=object),
#  array(['미스트', '여성트레이닝복'], dtype=object),
#  array(['여성트레이닝복', '샤워/목욕도구/목욕헤어밴드', '여성숄더백', '만년필'], dtype=object),
#  array(['남아바지', '기름종이', '여성스니커즈', '남아청바지', '영유아티셔츠/탑', '영유아바지', '남아티셔츠/탑'],
#        dtype=object),
#  array(['여성티셔츠/탑', 'BB/파운데이션/컴팩트류', '여성속옷세트', '블러셔/쉐이딩/하이라이터', '브래지어'],
#        dtype=object),
#  array(['분말표백제', '여성골프티셔츠/탑', '여성골프남방셔츠'], dtype=object),
#  array(['유아동스포츠샌들/슬리퍼'], dtype=object),
#  array(['여성스커트', '여성원피스'], dtype=object),
#  array(['페이셜팩류', '공병/모델링팩전용도구'], dtype=object),
#  array(['스킨케어세트', 'BB/파운데이션/컴팩트류', '샴푸'], dtype=object),
#  array(['메이크업베이스/프라이머'], dtype=object),
#  array(['크림/밤/오일', '에센스/세럼', '스킨케어세트', '여성원피스', '여성슬립온', '기름종이', '메이크업세트',
#         '여성등산티셔츠/탑', '스포츠모자', '여성남방셔츠'], dtype=object),
#  array(['아동용가방'], dtype=object),
#  array(['남성스포츠티셔츠', '스포츠가방'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['남성스포츠샌들/슬리퍼', '여성속옷세트'], dtype=object),
#  array(['여성남방셔츠', '여성스커트', '여성원피스'], dtype=object),
#  array(['반찬통/밀폐용기'], dtype=object),
#  array(['로봇청소기', '스킨케어세트', '여성스웨트셔츠/후드/집업', '여성등산바지'], dtype=object),
#  array(['화장대'], dtype=object),
#  array(['남성비치웨어'], dtype=object),
#  array(['기타일반문구/사무용품', '여성골프티셔츠/탑', '여성티셔츠/탑', '애견간식', '여성등산바지', '여성토트백',
#         '남성트레이닝복', '종합영양제', '여성일반스포츠바지', '애견사료', '남성일반스포츠바지', '남성비치웨어',
#         '남성등산바지', '여성비치웨어', '생수', '일반두유', '남성티셔츠', '여성샌들', '여성골프바지',
#         '애견목욕/위생용품'], dtype=object),
#  array(['영유아티셔츠/탑'], dtype=object),
#  array(['홍삼액'], dtype=object),
#  array(['핸드카트', '스킨케어세트', '여성런닝/트레이닝화', '홍삼정/분말/환', '플라스틱서랍장'],
#        dtype=object),
#  array(['BB/파운데이션/컴팩트류', '선크림류'], dtype=object),
#  array(['여성레인부츠/슈즈', '여성슬리퍼', '혼합견과'], dtype=object),
#  array(['여성일반스포츠바지'], dtype=object),
#  array(['남성런닝/트레이닝화'], dtype=object),
#  array(['남성티셔츠', '여성속옷세트'], dtype=object),
#  array(['스포츠가방', '기타패션잡화', '젖병/젖꼭지', '유아동스포츠샌들/슬리퍼', '유아용기저귀'],
#        dtype=object),
#  array(['여성향수'], dtype=object),
#  array(['남아바지', '여아패딩', '영유아티셔츠/탑', '영유아점퍼'], dtype=object),
#  array(['여성남방셔츠', '남성티셔츠', '남아티셔츠/탑', '여아스웨트셔츠/후드/집업', '여성티셔츠/탑', '여성가디건',
#         '여성청바지', '생수', '남아의류세트', '요가/필라테스복', '수영가방', '롤티슈', '남성런닝/트레이닝화',
#         '스포츠모자', '여성트레이닝복', '바디케어세트', '여성바지', '여성스포츠티셔츠/탑'], dtype=object),
#  array(['생수', '퍼즐'], dtype=object),
#  array(['블러셔/쉐이딩/하이라이터'], dtype=object),
#  array(['바디보습'], dtype=object),
#  array(['남성비치웨어', '남성스포츠티셔츠', '여성비치웨어'], dtype=object),
#  array(['영유아청바지', '여아티셔츠/탑'], dtype=object),
#  array(['남성런닝/트레이닝화', '여성런닝/트레이닝화'], dtype=object),
#  array(['여성수영복'], dtype=object),
#  array(['캐쥬얼크로스백'], dtype=object),
#  array(['남성티셔츠', '음악/악기완구', '아기체육관/러닝홈', '유아동타이즈', '남성정장바지', '핸드로션/크림',
#         '영유아티셔츠/탑', '면봉/화장솜', '기타캠핑용품', '아동모', '채반/바구니/쟁반', '소파',
#         '유아/아동용칫솔', '우주복'], dtype=object),
#  array(['귀걸이', '목걸이', '남아바지'], dtype=object),
#  array(['여성골프바지'], dtype=object),
#  array(['남성용스킨케어류'], dtype=object),
#  array(['크림/밤/오일'], dtype=object),
#  array(['BB/파운데이션/컴팩트류', '페이셜클렌저'], dtype=object),
#  array(['립글로즈/틴트'], dtype=object),
#  array(['남성비치웨어'], dtype=object),
#  array(['여성스웨터/풀오버'], dtype=object),
#  array(['홍삼액'], dtype=object),
#  array(['남성캐주얼바지'], dtype=object),
#  array(['스킨케어세트', '크림/밤/오일', '생수', '에센스/세럼'], dtype=object),
#  array(['반찬통/밀폐용기', '여성원피스', '아이브로우'], dtype=object),
#  array(['골프필드용품', '골프패션잡화', '남성향수', '남성골프바지', '골프화', '여성팬티', '남성골프남방셔츠',
#         '여성스포츠티셔츠/탑', '여성골프티셔츠/탑', '아동수영복', '여성스포츠샌들/슬리퍼'], dtype=object),
#  array(['BB/파운데이션/컴팩트류'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['크림/밤/오일'], dtype=object),
#  array(['BB/파운데이션/컴팩트류'], dtype=object),
#  array(['스킨케어세트', '립글로즈/틴트'], dtype=object),
#  array(['남성팬티', '메이크업세트', '영유아티셔츠/탑', '유아동스니커즈', '남아바지', '유아동일반양말'],
#        dtype=object),
#  array(['스킨케어세트'], dtype=object),
#  array(['유아/아동용치약', '유아/아동용칫솔', '여성남방셔츠', '액상세탁세제', '우주복', '유아동일반양말',
#         '오리발/스노클링', '여아티셔츠/탑', '여아레깅스', '아동모', '보드게임', '남성런닝셔츠', '유아동샌들'],
#        dtype=object),
#  array(['에멀젼/로션', '기타영양제'], dtype=object),
#  array(['남성스포츠티셔츠'], dtype=object),
#  array(['수예소품속통/솜', '쿠션/쿠션커버'], dtype=object),
#  array(['수영가방'], dtype=object),
#  array(['여성속옷세트'], dtype=object),
#  array(['유아동스니커즈', '여성펌프스', '남성등산티셔츠'], dtype=object),
#  array(['남성스포츠점퍼/재킷', '남성티셔츠', '남성시계', '양산'], dtype=object),
#  array(['여성남방셔츠', '남성남방셔츠', '스포츠모자'], dtype=object),
#  array(['여성골프티셔츠/탑', '여성스포츠티셔츠/탑', '유아용화장품', '붙박이장', '장롱', '기타견과류', '남성점퍼',
#         '아몬드', '종합영양제', '롤티슈', '여성타이즈', '브래지어', '여성팬티', '여성등산베스트',
#         '모바일배터리/충전기', '염모제', '여성바지'], dtype=object),
#  array(['여성잠옷', '이유식용품', '남성일반지갑', '남성티셔츠', '여성일반지갑', '블랜더', '여성원피스'],
#        dtype=object),
#  array(['영유아블라우스', '홍삼액', '입욕제/스파제품', '젤네일/케어류', '영유아레깅스', '목걸이', '반지'],
#        dtype=object),
#  array(['홍삼액', '유아동스포츠샌들/슬리퍼'], dtype=object),
#  array(['여성수영복', '여성일반스포츠바지'], dtype=object),
#  array(['남성티셔츠', '남성수영복'], dtype=object),
#  array(['기타일반문구/사무용품', '여성등산바지', '케이스/보호필름'], dtype=object),
#  array(['메이크업베이스/프라이머'], dtype=object),
#  array(['남성가디건'], dtype=object),
#  array(['여성런닝/트레이닝화'], dtype=object),
#  array(['치아발육기/딸랑이', '팬티라이너', '영유아티셔츠/탑', '이유식용품', '출산/신생아용품세트'],
#        dtype=object),
#  array(['기타모바일액세서리', 'BB/파운데이션/컴팩트류', '케이스/보호필름', '기름종이', '샴푸', '여성스커트',
#         '헤어케어선물세트', '메이크업베이스/프라이머', '블러셔/쉐이딩/하이라이터'], dtype=object),
#  array(['유아동스포츠샌들/슬리퍼', '아동모'], dtype=object),
#  array(['식음료모바일상품권'], dtype=object),
#  array(['여성원피스', '여성바지', '유아동스포츠샌들/슬리퍼'], dtype=object),
#  array(['남성스니커즈', '남아티셔츠/탑', '선크림류', '유아동내의', '남아의류세트'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['바디보습', '스킨케어세트'], dtype=object),
#  array(['스케이트보드/킥보드', '여성시계', '피규어', '음악/악기완구', '여성일반지갑', '전기튀김기',
#         '기타등산용품'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['샴푸'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['여성토트백', '여성일반지갑', '스포츠모자'], dtype=object),
#  array(['여성일반양말'], dtype=object),
#  array(['일반비타민', '스킨케어세트'], dtype=object),
#  array(['여성남방셔츠'], dtype=object),
#  array(['여성로퍼'], dtype=object),
#  array(['남성향수', '여성향수', '남녀공용향수'], dtype=object),
#  array(['유아동스포츠샌들/슬리퍼'], dtype=object),
#  array(['남성티셔츠', '남성용스킨케어류', '남성런닝/트레이닝화', '스킨/토너', '여성재킷', '여성컴포트화',
#         '페이셜클렌저'], dtype=object),
#  array(['여성티셔츠/탑'], dtype=object),
#  array(['메이크업세트', '남성정장화', '남성티셔츠', '유아동스포츠샌들/슬리퍼', '유아용화장품'], dtype=object),
#  array(['스킨케어세트', '남성스킨케어세트'], dtype=object),
#  array(['일반두유'], dtype=object),
#  array(['여성일반지갑', '여성숄더백'], dtype=object),
#  array(['여성바지'], dtype=object),
#  array(['아쿠아슈즈', '영유아티셔츠/탑', '남아바지'], dtype=object),
#  array(['남성스킨케어세트', '크림/밤/오일', '헤어에센스'], dtype=object),
#  array(['요가/필라테스복'], dtype=object),
#  array(['기타등산용품', '여성등산티셔츠/탑', '블라인드/버티컬', '등산화', '기타일반문구/사무용품', '남성팬티',
#         '스포츠두건/머플러/마스크'], dtype=object),
#  array(['스킨케어세트', '메이크업세트'], dtype=object),
#  array(['남성티셔츠', '기타모바일액세서리', '선풍기'], dtype=object),
#  array(['수건', '남성런닝셔츠', '선반/걸이', '일반청소기'], dtype=object),
#  array(['여성티셔츠/탑', '여성스니커즈', '페이셜클렌저', '프라이팬', '홍삼액', '여성가디건',
#         '여성런닝/트레이닝화'], dtype=object),
#  array(['거실수예소품', '여성속옷세트', '숟가락/젓가락', '바구니', '포크/나이프'], dtype=object),
#  array(['여성슬립온'], dtype=object),
#  array(['아동용가방', '영유아점퍼'], dtype=object),
#  array(['여성티셔츠/탑', '염모제', '액상세탁세제'], dtype=object),
#  array(['유아동내의', '이유식용품', '테이프'], dtype=object),
#  array(['남성골프티셔츠', '남성골프패딩', '남성골프바지'], dtype=object),
#  array(['스킨케어세트'], dtype=object),
#  array(['메이크업세트', '여성일반스포츠바지'], dtype=object),
#  array(['립글로즈/틴트', '유아동내의'], dtype=object),
#  array(['블러셔/쉐이딩/하이라이터', '여성잠옷'], dtype=object),
#  array(['헤어에센스', '일반두유'], dtype=object),
#  array(['남성남방셔츠'], dtype=object),
#  array(['구강청정제', '유아동선글라스'], dtype=object),
#  array(['여성원피스', '김치류', '남성티셔츠'], dtype=object),
#  array(['여성티셔츠/탑', '여성스커트'], dtype=object),
#  array(['남성티셔츠'], dtype=object),
#  array(['젖병/젖꼭지'], dtype=object),
#  array(['남성티셔츠', '여성숄더백', '남성스포츠티셔츠'], dtype=object),
#  ...]

# %%
train_data2 = list(train.groupby('CLNT_ID')['PD_ADD_NM'].unique())
test_data2 = list(test.groupby('CLNT_ID')['PD_ADD_NM'].unique())
train_data2 # 사이즈정보
# Out:
# [array(['1개', '선택:버닝 [베이지] / 1개'], dtype=object),
#  array(['사이즈:L(105) / 1개', '1개', '색상:NV|사이즈:90 / 1개',
#         '타입:톤업 쿠션 세트 (리필+케이스) / 1개'], dtype=object),
#  array(['상품명:05)CDABRM21SK/set|사이즈:80B/90 / 1개',
#         '상품명:04)CDABRM21DGY/set|사이즈:80B/90 / 1개',
#         '상품명:14)CCCBRM91DGR|사이즈:80A / 1개',
#         '상품명:14)CCCBPM91DGR|사이즈:90 / 1개', '상품명:01)CCBBPM51LGY|사이즈:90 / 1개',
#         '사이즈:M5W7 / 1개', '상품명:01)CCBBRM51LGY|사이즈:80A / 1개'], dtype=object),
#  array(['품명:첨이몬스터디노남삼각|사이즈:80(11-12세) / 1개', '사이즈:65(5-6세) / 1개'],
#        dtype=object),
#  array(['색상:베이지|사이즈:S / 1개', '모델명:01>MS4388아이보리|사이즈:39 / 1개',
#         '색상:크림|사이즈:S / 1개', '색상:브라운|사이즈:S(6~12m) / 1개',
#         '색상:핑크|사이즈:M(12~24m) / 1개', '색상:핑크|사이즈:S(6~12m) / 1개',
#         '색상:크림|사이즈:M(12~24m) / 1개', '색상:그린|사이즈:S(6~12m) / 1개', '1개',
#         '색상:BLUE|사이즈:85 / 1개', '사이즈:18M / 1개', '색상:크림|사이즈:48(6~12m) / 1개',
#         '색상:핑크|사이즈:48(6~12m) / 1개', '색상:화이트|사이즈:S(6~12m) / 1개',
#         '색상:코랄|사이즈:S(6~12m) / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:머스타드 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['1개', '모델:나이키 NSW 엠브로이드 반팔티|사이즈:827021-100_화이트 L(105) / 1개',
#         '품번:01.ADIDAS_S98742_|사이즈:M / 1개',
#         '품번:02.NIKE_804340_063_|사이즈:L / 1개',
#         '품번:01.NIKE_804340_010_|사이즈:XS / 1개'], dtype=object),
#  array(['색상:KHAKIE / 1개'], dtype=object),
#  array(['사이즈:270 / 1개', '색상:핑크 / 4개', '1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:BLACK(블랙)|사이즈:250 / 1개', '색상:BLUE(파랑)|사이즈:95(M) / 1개'],
#        dtype=object),
#  array(['상품명:인견베이직나시 블랙|사이즈:90 / 4개', '선택:요일팬티 블랙|사이즈:XXL(100) / 5개',
#         '사이즈:95 / 5개', '상품명:인견베이직나시 화이트|사이즈:90 / 2개'], dtype=object),
#  array(['선택:수세미 배도라지 / 1개'], dtype=object),
#  array(['1개', '상품타입:기라로쉬-SK0078-퍼플 / 1개', '색상:웜 패치워크 (W/PW) / 1개',
#         '상품명:면오렌지(5287)|사이즈:95 / 1개', '상품명:EHD5288|사이즈:95 / 1개'],
#        dtype=object),
#  array(['색상:아이보리|사이즈:F / 1개', 'color:블랙|size:프리 / 1개', '디자인선택:후프베어 / 1개'],
#        dtype=object),
#  array(['색상:G99 실키 베이직 브라탑세트 누드|사이즈:XL(66~77) / 1개', '색상:화이트|사이즈:100 / 1개'],
#        dtype=object),
#  array(['FM10:FM10 / 1개'], dtype=object),
#  array(['색상:05|사이즈:L / 2개', '색상:09|사이즈:32 / 1개', '색상:네이비|사이즈:55 / 1개',
#         '색상:선택06) 117942-03|사이즈:32 / 1개', '색상:08|사이즈:L / 1개'], dtype=object),
#  array(['색상:블랙|사이즈:M / 1개'], dtype=object),
#  array(['색상:블랙|사이즈:100 / 1개', '색상:베이지|사이즈:100 / 1개', '사이즈:더블 / 1개'],
#        dtype=object),
#  array(['색상:화이트(W)|사이즈:130 / 1개', '색상:핑크-PKOEURS34VP2|사이즈:9T / 1개',
#         '상품명:아이시스8.0 500ML*40펫 / 1개', '색상:핑크|사이즈:130 / 1개',
#         '색상:블루(U)|사이즈:130 / 1개', '1개', '구성:아이시스8.0 300mlx40펫 / 1개'],
#        dtype=object),
#  array(['상품선택:1.소형 16px5팩 +손거울5개 증정 / 1개',
#         '사이즈선택:밴드4단계 48매x3팩(7-13kg) / 1개', '1개'], dtype=object),
#  array(['1개', '컬러:그레이쉬베이지|사이즈:84 / 1개', '컬러:그레이쉬베이지|사이즈:88 / 1개',
#         '색상:블랙|사이즈:90 / 1개', '색상:1.NLM(네이비)|사이즈:200 / 1개',
#         '색상:3.RNV(레드)|사이즈:210 / 1개', '사이즈:FREE|색상:화이트 / 1개', '색상:오렌지 / 1개',
#         '색상:레드와인 / 1개', '타입:투명 / 1개', '색상:화이트|사이즈:FREE / 1개',
#         '색상:화이트|사이즈:090. / 1개', '색상:네이비(NA)|사이즈:55 / 1개',
#         '필수선택:볼주머니NBB18 / 1개', '컬러:화이트|사이즈:4/37(235-240mm) / 1개',
#         '색상:그레이|사이즈:100 / 1개', '상품명:LCWN725J27블랙|사이즈:240 / 1개',
#         '색상:화이트 / 1개', '옵션:VAHB-이중방풍우산 그린 / 1개',
#         '색상:백색|사이즈:80/11~12세 / 2개', '색상:카메오블루(CMB)|사이즈:ONE SIZE / 1개',
#         '상품타입:샌드박스-J1092-도티 / 1개', '사이즈:100 / 3개',
#         '색상:네이비(NAY)|사이즈:180 / 1개', '색상:HKSO8E201BK|사이즈:240 / 1개',
#         '선택:선택06|사이즈:100 / 1개', '색상:핑크 / 1개', '스타일:5051|사이즈:190 / 1개'],
#        dtype=object),
#  array(['색상:블랙|사이즈:FREE / 1개', '색상:핑크|사이즈:FREE / 1개'], dtype=object),
#  array(['색상:YELLOW|사이즈:120 / 1개', 'color:소라|size:FREE / 1개',
#         '색상:IVORY|사이즈:110 / 1개', '색상:IV|사이즈:110 / 1개'], dtype=object),
#  array(['색상:화이트|사이즈:250 / 1개'], dtype=object),
#  array(['색상/사이즈:블랙/11호 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:선택|사이즈:단일상품 / 1개', '색상:차콜그레이 / 1개'], dtype=object),
#  array(['색상:11(화이트3)|사이즈:L / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['1개', '상의색상:그레이(13)|상의사이즈:110 / 1개', '색상:19|사이즈:XL / 1개',
#         '색상:그레이|사이즈:M / 1개', '사이즈:95 / 1개', '색상:03|사이즈:XL / 1개',
#         '색상:BR323블랙|사이즈:240 / 1개', '색상:카키|사이즈:FREE / 1개',
#         '색상:CCH|사이즈:34(86) / 1개', '색상:07|사이즈:XL / 1개', '선택:포기김치10kg / 1개',
#         '번호:순백 27m *(24+6)롤(EC) *2팩(블루) / 1개', '색상:베이지|사이즈:110 / 1개',
#         '컬러:브라운|사이즈:FREE / 1개'], dtype=object),
#  array(['직접입력1:인디고블루|직접입력2:105 / 1개', '직접입력1:블루|직접입력2:105 / 1개',
#         '직접입력1:다크블루|직접입력2:105 / 1개'], dtype=object),
#  array(['1개', '색상:라이트그레이 / 1개'], dtype=object),
#  array(['1개', '선택:점보세트 / 1개'], dtype=object),
#  array(['색상:숲속 친구들(L) / 1개', '1개'], dtype=object),
#  array(['색상:#5 소프트 샌드 / 1개'], dtype=object),
#  array(['모델:CQ2632_WHITE|사이즈:285 / 1개', '신발색상:골드글리터|신발사이즈:170mm / 1개',
#         '색상:핑크_204536-6I2|사이즈:170 / 1개'], dtype=object),
#  array(['색상 선택:블루|사이즈 선택:100 / 2개', '색상:스킨|팬티사이즈:95 / 2개',
#         '색상-사이즈:백색-100 / 1개', '색상:블랙(BK)|사이즈:FREE(M) / 1개'], dtype=object),
#  array(['색상:NVY|사이즈:080 / 1개'], dtype=object),
#  array(['색상:라이트블루|사이즈:130 / 1개', '사이즈:130 / 1개', '색상:핑크|사이즈:120 / 1개',
#         '색상:밴딩네이비(7602WD21)|사이즈:250 / 1개',
#         '색상:클래식그레이(7601WD71)|사이즈:250 / 1개',
#         '색상:밴딩그레이(7602WD71)|사이즈:250 / 1개', '색상:아이보리|사이즈:130 / 1개',
#         '색상:블랙|사이즈:130 / 1개', '색상:아이보리|사이즈:120 / 1개'], dtype=object),
#  array(['color:BE|size:80A / 2개'], dtype=object),
#  array(['색상:92|사이즈:28 / 1개', '색상:그린_82x27x26 / 1개', '선택:40x33x190 / 1개',
#         '색상:블랙|사이즈:F / 1개', '색상:네이비|사이즈:F / 1개', '선택:하이 / 1개',
#         '색상:10베이지체크|사이즈:28 / 1개'], dtype=object),
#  array(['색상:BLK0_(BLK0)BLACK|사이즈:90 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:라텍스밴드-옐로우(120x15x0.3mm) / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:01_NAVY_PEPPER(Z4CC)|사이즈:M6W8(250) / 1개',
#         '색상:01_NAVY_PEPPER(Z4CC)|사이즈:M5W7(240) / 1개', '사이즈:275 / 1개',
#         '색상:네이비|사이즈:66 / 1개', '색상:베이지|사이즈:66 / 1개',
#         'COLOR-SIZE:베이지(beige)-FREE / 1개',
#         '색상:01_NAVY_PEPPER(Z4CC)|사이즈:M9W11(270) / 1개',
#         '색상:01_NAVY_PEPPER(Z4CC)|사이즈:M10W12(280) / 1개',
#         '색상:J7210_베이지|사이즈:240 / 1개'], dtype=object),
#  array(['사이즈:150 / 1개', '색상:검정색|Size:078 / 1개', '색상:흰색|Size:080 / 1개'],
#        dtype=object),
#  array(['디자인:로라 / 1개', '디자인선택:로라의 낭만여행 / 1개'], dtype=object),
#  array(['4개'], dtype=object),
#  array(['상품명:어린이치약 무불소 1P|향:딸기 / 1개'], dtype=object),
#  array(['색상:블랙|사이즈:M(58) / 1개'], dtype=object),
#  array(['옵션:[1051703763]블랙/155 / 1개', '색상:블랙|사이즈:270 / 1개',
#         '사이즈:블랙13호 / 1개'], dtype=object),
#  array(['색상:IVO(아이보리)|사이즈:95(M) / 1개', '직접입력1:WHT(화이트)|직접입력2:90(S) / 1개',
#         '색상:WHT(화이트)|사이즈:100(L) / 1개', '색상:MEG(멜란지 그레이)|사이즈:100(L) / 1개',
#         '색상:CHG(차콜그레이)|사이즈:100(L) / 1개', '색상:CHG(차콜그레이)|사이즈:L / 1개'],
#        dtype=object),
#  array(['1개', '상품번호:07번|사이즈:100 / 1개', '상품번호:03번|사이즈:100 / 1개'],
#        dtype=object),
#  array(['1개'], dtype=object),
#  array(['직접입력1:100 / 1개'], dtype=object),
#  array(['색상:선택01_블랙|사이즈:95 / 1개', '색상:선택01_블랙|사이즈:105 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:블랙|사이즈:FREE / 1개', '사이즈:260 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:오프화이트|사이즈:S / 1개', '색상:차콜|사이즈:S / 1개'], dtype=object),
#  array(['상품타입:쥬쥬-K0634|사이즈:170 / 1개', '색상/사이즈:레드/110 / 2개',
#         '상품선택:02_수비드 닭가슴살 갈릭허브 / 1개', '사이즈:120호(6세) / 1개',
#         '색상:블루|사이즈:L(130)[258320003] / 1개', '품명:오끼오플로랄7부세트|사이즈:65 / 1개',
#         '사이즈:120(5~6세) / 1개', '색상:03.방울방울잠옷세트|사이즈:아이보리130 / 1개',
#         '색상:02.쏘핫큐트실내복|사이즈:화이트130 / 1개', '색상사이즈:핑크 XS / 1개',
#         '상품명:1.CSC여3부파01|사이즈:65호 / 1개', '색상/사이즈:레드/110 / 1개',
#         '품명:오끼오아쿠아마린7부세트|사이즈:65 / 1개', '상품선택:09_갈릭스파이시 닭가슴살 / 1개',
#         '상품선택:05_맛있는 리얼갈릭 닭가슴살 / 1개', '상품선택:04_매콤훈제 슬라이스 닭가슴살 / 1개',
#         '상품선택:06_맛있는 청양고추 닭가슴살 / 1개', '상품선택:11_매콤 토마토 슬라이스 닭가슴살 / 1개',
#         '상품선택:08_훈제 닭가슴살 / 1개', '상품선택:10_담백한 오리지널 닭가슴살 / 1개',
#         '색상:01.스윗프릴잠옷세트|사이즈:옐로우130 / 1개', '옵션:A형 에스프레소(A) / 1개',
#         '모델명:100매 10팩 캡형 / 1개', '20개', '상품선택:03_부드러운 훈제 슬라이스 닭가슴살 / 1개',
#         '색상:핑크(P2)|사이즈:26(160-165) / 1개', '상품선택:01_수비드 닭가슴살 칠리페퍼 / 1개',
#         '1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['선택:정관장 아이키커 / 1개', '1개'], dtype=object),
#  array(['1개', 'SIZE:230 / 1개', '2개'], dtype=object),
#  array(['선택:스파클 생수 2리터×6병(6팩) - 총36병 / 2개'], dtype=object),
#  array(['1개', '선택:[892764-010] 블랙 / 1개'], dtype=object),
#  array(['필수선택:멀티 모공브러쉬 大 / 1개'], dtype=object),
#  array(['1개', '선택:EX-4 / 1개'], dtype=object),
#  array(['색상:레드|사이즈:110 / 1개', '모델명:18FW빨간망토30수9부상하|사이즈:100호(3~4세) / 1개',
#         '모델명:18FW핑크히어로30수9부상하|사이즈:100호(3~4세) / 1개',
#         '모델명:18FW핑크히어로30수9부상하|사이즈:120호(6세) / 1개'], dtype=object),
#  array(['색상:미디엄블루|사이즈:27 / 1개'], dtype=object),
#  array(['1개', '색상:피치|사이즈:M / 1개', '품명/사이즈:여드로즈/60호 / 1개',
#         '색상:화이트|사이즈:M / 1개', '색상:코코아|사이즈:75AB / 1개'], dtype=object),
#  array(['색상:BK|사이즈:86(34) / 1개', '색상:네이비(300)|사이즈:95(M) / 1개', '1개',
#         '색상:네이비(NV)|사이즈:F / 1개', '색상:DARK GREY / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:검정색|사이즈:130 / 1개', '색상:검정색|사이즈:120 / 1개',
#         '타입:화이트 캡형 74매X20팩 / 1개', '타입:화이트 캡형 74매X10팩 / 1개',
#         '컬러:남색|사이즈:F / 1개', '1개', '사이즈:070 / 1개', '사이즈:095 / 1개'],
#        dtype=object),
#  array(['1개', '색상:코랄크러쉬 / 1개'], dtype=object),
#  array(['색상:아이보리|사이즈:L / 1개'], dtype=object),
#  array(['제주 삼다수 500ml*20:제주 삼다수 500ml*20 / 1개',
#         '제주삼다수 2L:제주삼다수 2L*6EA / 2개', '색상:바이올렛|사이즈:FF / 1개', '1개',
#         '색상:아이보리|사이즈:FF / 1개', '색상:네이비|사이즈:FF / 1개', '색상:그린|사이즈:FF / 1개',
#         '색상:WHITE|사이즈:FREE / 1개', '2개', '색상/사이즈:카키/FF / 1개',
#         '색상:브릭|사이즈:FF / 1개', '제주 삼다수 500ml*20:제주 삼다수 500ml*20 / 2개',
#         '색상:브라운|사이즈:FF / 1개'], dtype=object),
#  array(['색상:화이트 / 1개', '색상:워시 / 1개'], dtype=object),
#  array(['색상:핑크|사이즈:225 / 1개', '색상:VIOLET|사이즈:55 / 1개', '색상/사이즈:핑크/55 / 1개',
#         '선택:MSWS315세트-오렌지FREE / 2개', '색상:블랙[BK]|사이즈:30 / 1개',
#         '색상:S93913 네이비|사이즈:M / 1개', '선택:MSWS312세트-블루FREE / 1개',
#         '색상/사이즈:화이트|WH|/FF|FREE| / 1개', '품번/사이즈:1313201-002_블랙 / LG / 1개',
#         '사이즈:095 / 1개'], dtype=object),
#  array(['기본:기본 / 1개', '색상:L/INDIGO|사이즈:L / 1개', '2개', '색상:네이비 / 1개'],
#        dtype=object),
#  array(['색상:04.LAWe0902_NV|사이즈:105 / 1개', '사이즈:XL / 1개'], dtype=object),
#  array(['상품명:갤럭시탭A 8.0 2017 에바폼케이스(+터치펜)|색상:그린 / 1개',
#         '선택:스키니 일반 라이너 20p x4팩 / 1개', '색상:CDBDP203M062|사이즈:028 / 1개'],
#        dtype=object),
#  array(['색상:화이트 / 1개'], dtype=object),
#  array(['컬러:그레이 / 1개', '1개', '컬러:다크블루 / 1개', '4개', '컬러:아이보리 / 2개'],
#        dtype=object),
#  array(['디자인:05.플랩캡_IVORY|사이즈:L / 1개', '4개', '1개', '색상:레드 / 1개', '5개',
#         '색상:네이비|사이즈:M(40cm) / 1개', '디자인:07.플라이어_BROWTT / 1개', '10개'],
#        dtype=object),
#  array(['색상사이즈:없음/20393120/ / 1개', '1개'], dtype=object),
#  array(['옵션:33|셔츠사이즈:105 / 1개', '옵션:27|셔츠사이즈:105 / 1개',
#         '옵션:38|셔츠사이즈:105 / 1개'], dtype=object),
#  array(['사이즈:S / 1개', '색상:(42)블루|사이즈:FF / 1개'], dtype=object),
#  array(['COLOR_SIZE:[OZMP-00106] 에어쿨링 블랙/2 (44 ~ 55) / 1개',
#         'COLOR/SIZE:[OMIT-00101] 화이트/F (Free) / 1개'], dtype=object),
#  array(['컬러:R210 / 1개', '사이즈:M(100) / 1개', '1개'], dtype=object),
#  array(['색상:라이트 인디고|사이즈:130 / 1개', '색상:블랙 Black|사이즈:F / 1개'], dtype=object),
#  array(['색상:IV|사이즈:100 / 1개', '상품명:9.CSC남런닝11|사이즈:90호 / 1개',
#         '상품명:4.CSC남런닝06|사이즈:90호 / 1개', '색상:그린|사이즈:100 / 1개',
#         '사이즈:90(15-16세) / 2개'], dtype=object),
#  array(['사이즈:260 / 1개', '사이즈:280 / 1개'], dtype=object),
#  array(['1개', '색상:그레이 / 1개'], dtype=object),
#  array(['옵션선택1:ONE SIZE / 1개', '색상:LT BLUE|사이즈:L / 1개',
#         '색상:ORNG|사이즈:L / 1개'], dtype=object),
#  array(['색상:KHAKI|사이즈:130 / 1개', '색상:PK(핑크)|사이즈:130 / 1개',
#         '색상:BLUE|사이즈:165 / 1개', '사이즈:130 / 1개'], dtype=object),
#  array(['1개', '색상:네이비 / 1개'], dtype=object),
#  array(['사이즈:110 / 1개', '색상:그린|사이즈:44(66) / 1개'], dtype=object),
#  array(['색상:핑크 / 1개', '상품명:문중 총각김치 5kg / 1개'], dtype=object),
#  array(['색상:핑크|브라사이즈:75A|팬티사이즈:85 / 1개'], dtype=object),
#  array(['색상:(41)스카이|사이즈:FF / 1개', '색상:56(네이비)|사이즈:100 / 1개', '2개'],
#        dtype=object),
#  array(['색상:레드 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['1개', '색상:WIHO7F009G2|사이즈:선택사항참조 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['상품명:06)EPB3643/set|사이즈:75B/90 / 1개',
#         '상품명:02)EPB3660/set|사이즈:75B/90 / 1개', '1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상/사이즈:옐로우/FREE / 1개', '1개', '색상/사이즈:블랙/FREE / 1개',
#         '색상/사이즈:네이비/FREE / 1개', '색상:네이비(NAVY)|사이즈:66 / 1개',
#         '색상:그레이 - L / 1개'], dtype=object),
#  array(['색상:GE-그린|사이즈:FREE / 1개', '선택:롱앤컬(K117ON) / 1개',
#         '색상:HJWA8E918BK|사이즈:선택사항참조 / 1개'], dtype=object),
#  array(['색상:01 블랙|사이즈:XL / 1개', '색상:11(화이트3)|사이즈:L / 1개', '사이즈:105 / 1개',
#         '색상:03콜그레이|사이즈:XL / 1개', '색상:08|사이즈:XL / 1개',
#         '모델명:05. MZ-K1GA180061-00|사이즈:260 / 1개', '색상:07헌터그린|사이즈:XL / 1개',
#         '1개', '색상:10 차콜|사이즈:L / 1개'], dtype=object),
#  array(['색상 선택:월넛 / 1개', '1개'], dtype=object),
#  array(['색상:화이트 / 1개', '색상:레드 / 1개', '색상:진인디고 / 1개', '색상:다크그레이 / 1개'],
#        dtype=object),
#  array(['1개', '색상:WHI|사이즈:155 / 1개', '색상:SBU|사이즈:155 / 1개',
#         '선택:(영실업) B-88(툴) 베이런처LR / 1개', '색상:CG(차콜그레이)|사이즈:155 / 1개',
#         '상품명:디자인방문모기장(시티라이프)100 / 1개', '색상:GY(그레이)|사이즈:155 / 1개',
#         '색상:멜란지|사이즈:155 / 1개', '선택:[3050181]단일상품 / 2개',
#         '홍백작:홍백작 (40mlx30포) / 2개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:B10 / 1개', '색상:레드(RE)|사이즈:130(6-7세) / 1개',
#         '색상:KVJ|사이즈:85(XS) / 1개'], dtype=object),
#  array(['색상:SNV|사이즈:74(28) / 1개', '1개', '사이즈:95 / 1개', '색상:TB|사이즈:28 / 1개'],
#        dtype=object),
#  array(['색상:블랙화이트|사이즈:230 / 1개', '사이즈:230 / 2개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:그레이 / 1개', '색상:아이보리 / 1개', '색상:화이트 / 1개'], dtype=object),
#  array(['1개', '색상:아이보리_611121304 / 1개', '색상:화이트 / 1개', '색상:먹색 / 1개',
#         '색상:보라 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['사이즈:75 / 1개', '타입:드럼 / 1개', '1개', '색상:BEIGE|사이즈:30 / 1개',
#         '사이즈:75(9-10세) / 1개', '사이즈:12M / 1개',
#         '사이즈:CRO-204361-488_230 / 1개', '품명:오끼오스피드클럽3부세트|사이즈:85 / 1개',
#         '모델명:(EP-TA12KWKUG) 화이트 / 1개', '필수선택:4단계-스타워즈 / 5개',
#         '사이즈:80(11-12세) / 1개', '직접입력1:흰색|직접입력2:80 / 1개', '사이즈:6M / 1개',
#         '색상:CM7639 블루|사이즈:230 / 1개', '색상:딥그레이|사이즈:7FM. / 1개',
#         '색상:화이트|사이즈:140 / 1개', '사이즈:105 / 1개', '색상:네이비|사이즈:150 / 1개'],
#        dtype=object),
#  array(['색상/사이즈:그레이/FREE / 1개', '색상/사이즈:블랙/L / 1개', '색상/사이즈:화이트/L / 1개'],
#        dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:마법보정팬티 블랙|사이즈:M / 1개', '색상:여신브라 블랙|사이즈:글램85(70E.75D) / 1개'],
#        dtype=object),
#  array(['색상:리미티드 립 컬렉션 / 1개'], dtype=object),
#  array(['상품명:01)CDABRM31SK/Set|사이즈:80B/95 / 1개',
#         '상품명:08)CDABRM21DGY/Set|사이즈:80A/95 / 1개',
#         '상품명:06)CDABRM21SB/Set|사이즈:80A/95 / 1개'], dtype=object),
#  array(['색상:베이지|사이즈:110 / 1개', '색상:그레이|사이즈:110 / 1개',
#         '색상:IVORY(아이보리)|사이즈:100 / 1개', '색상:BLACK(검정색)|사이즈:100 / 1개',
#         '색상:01_GFZG7305C30|사이즈:100 / 1개', '색상:라이트그레이(L/GY)|사이즈:110 / 1개'],
#        dtype=object),
#  array(['색상:흰색 / 1개', '색상_사이즈:아이보리Ivory_F / 1개', '색상:와인|사이즈:free / 1개',
#         '색상:화이트 White|사이즈:F / 1개', '색상_사이즈:화이트White_F / 1개',
#         '색상:블랙|사이즈:71 / 1개', '1개', '색상:검정 / 1개', '색상:그린하와이패턴|사이즈:F / 1개'],
#        dtype=object),
#  array(['색상:화이트|사이즈:13 / 1개', '색상:▶10126-200초콜렛|사이즈:M7/W9 / 1개',
#         '색상:메란지|사이즈:13 / 2개', '스타일:2.여)여아케미솔|사이즈:80 / 5개'], dtype=object),
#  array(['선택1:라이프 중식도 2종 세트(중식도+클리버) / 1개'], dtype=object),
#  array(['색상:카키 / 3개', '색상:밤색 / 3개', '종류:백모견용 / 2개'], dtype=object),
#  array(['모델명:BN-507 블루 / 1개', '색상:010 아이보리 (리필) / 1개', '색상:블랙 / 1개', '1개',
#         '2개', '색상:화이트|사이즈:M / 3개', '옵션:09 아몬드 영양 샴푸2개+컨디셔너500ml / 1개'],
#        dtype=object),
#  array(['색상:21호 일반피부 / 1개', '향기선택:01.베이비파우더 / 1개', '색상/사이즈:베이지/FREE / 1개',
#         '색상:무지개 / 1개', '1개'], dtype=object),
#  array(['모델:화애락진 / 1개', '사이즈:095 / 1개', '상품명:02)TWB0499|사이즈:75A/90 / 1개',
#         '색상:핑크(P)|사이즈:145 / 1개', '색상:핑크 / 1개', '제품선택:레티나15.4인치-그린 / 1개',
#         '색상:스카이블루 / 1개', '디자인선택:0467(아이보리)|브라 사이즈:80A|팬티 사이즈:90 / 1개',
#         '사이즈:90|브라사이즈:75A|모델명:2.TWB0465TWH0465NY / 1개'], dtype=object),
#  array(['옵션:인텐스 커버 21C / 1개'], dtype=object),
#  array(['옵션선택:190 / 1개', '2개', '옵션선택:XXL 13호 노랑 / 1개', '1개',
#         '사이즈:EU36(230mm) / 1개', '옵션선택:XL 13호 / 1개',
#         '색상:CG(차콜그레이)|사이즈:145 / 1개', '옵션선택:XL 13호 회색 / 1개',
#         '색상선택:단일색상|사이즈선택:Medium / 1개', '옵션선택:XL 13호 핑크 / 1개',
#         '색상:MG|사이즈:145 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:볼트그린_10190-395|사이즈:210 / 1개', '1개'], dtype=object),
#  array(['색상:09|사이즈:S / 1개', '색상:01|사이즈:S / 1개'], dtype=object),
#  array(['색상:644(핑크)|사이즈:S(003) / 1개', '색상:003(화이트)|사이즈:S(003) / 1개',
#         '색상:003(화이트)|사이즈:M(004) / 1개', '색상:640(핑크)|사이즈:S(003) / 1개'],
#        dtype=object),
#  array(['1개', '폐가전수거요청:없음 / 1개'], dtype=object),
#  array(['필수선택:02_허브 달팽이 로션 / 2개', '1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['번호/디자인:7.EPB2781(BK)|사이즈(브라/팬티):80A/95 / 1개',
#         '번호/디자인:8.EPB2784(OR)|사이즈(브라/팬티):80A/95 / 1개',
#         '번호/디자인:4.EPB2338(VI)|사이즈(브라/팬티):80A/95 / 1개',
#         '번호/디자인:3.EPB2360(BU)|사이즈(브라/팬티):80A/95 / 1개', '사이즈:95 / 1개'],
#        dtype=object),
#  array(['사이즈:130(111번) / 1개'], dtype=object),
#  array(['색상:아이보리|사이즈:FREE(44~66) / 1개',
#         '제품번호:CE5578(블랙+화이트)|상의사이즈:XS(085) / 1개', '사이즈:단품 / 1개',
#         '선택:[2304100]단품 / 1개', 'Color:Red / 1개',
#         '색상:아이보리|사이즈:Free (넓이43cm 높이40cm) / 1개', 'Color:Black / 1개',
#         '품번:7MYZSH04/00|사이즈:095 / 1개', '품명:03. WBW8E19_T|사이즈:70B(90) / 1개',
#         '색상사이즈:BLACK / Small [042] / 1개', '색상:화이트(N00)|사이즈:85 / 1개',
#         '상품명:08.도트래빗|색상:핑크 / 6개', '컬러:아이보리 / 1개', '색상:중청|사이즈:M / 1개',
#         '색상:화이트&블루&레드|사이즈:240 / 1개', '1개', '색상:아이보리|사이즈:M / 1개'],
#        dtype=object),
#  array(['색상:블루(21)|사이즈:71(28) / 1개', '색상:(69)오렌지|사이즈:66 / 1개',
#         '색상:핑크|사이즈:28 / 1개', '색상:민트|사이즈:28 / 1개', '색상:(47)네이비|사이즈:77 / 1개'],
#        dtype=object),
#  array(['색상:화이트|사이즈:280 / 1개', '상품명:질레트 프로쉴드기획세트 / 1개'], dtype=object),
#  array(['선택:선택18|사이즈:100 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['선택:아기양치치 / 1개', '사이즈:M사이즈(머리둘레 41Cm 이상)|색상:베이비카 / 1개',
#         '선택:브라운st(BS) / 1개', '선택:월드스타 특대형 160 (아이보리) / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['쉐입:03.스몰사각볼 8종 택1|패턴:03-07.그린클로버(161-25A) / 1개',
#         '쉐입:15.딥쉘로우볼|패턴:15-01.블루플라워/1385A / 1개',
#         '쉐입:06.샐러드플레이트 8종 택1|패턴:06-06.마리아/203A-165 / 1개',
#         '쉐입:16.공기|패턴:16-01.블루플라워/1836A / 1개',
#         '쉐입:04.스몰오발디시 3종 택1|패턴:04-02.블루벨(222-408) / 1개'], dtype=object),
#  array(['색상:PK|사이즈:120 / 1개', 'COLOR:White|SIZE:250 / 1개'], dtype=object),
#  array(['색상:다운필 블루라벨 베개 1+1(50x70) / 1개', '필수선택:[트라이탄 푸고]바디링(핑크) / 1개'],
#        dtype=object),
#  array(['사이즈:038 / 1개'], dtype=object),
#  array(['색상:02_BLACK(Z001)|사이즈:W7(240) / 1개', '옵션:없음 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['1개', '색상:FS1HTA1078X_BBK|사이즈:240 / 1개', '색상:그레이화이트|사이즈:255 / 1개',
#         '색상:FS1HTZ3077X_BLK|사이즈:260 / 1개', '색상:BK(블랙)|사이즈:043(280mm) / 1개',
#         '색상:FS1HTZ3075X_EPK|사이즈:250 / 1개', '사이즈:280 / 1개', '사이즈:245 / 1개',
#         '색상:03 (미디움) / 1개', '사이즈:275 / 1개', '사이즈:260 / 1개',
#         '색상:FS1HTZ3074X WPK|사이즈:245 / 1개', '색상:그린|사이즈:270 / 1개',
#         '품번/사이즈:B27998_민트 / 255 / 1개', '공용_A:255 / 1개', '사이즈:235 / 1개',
#         '사이즈:220 / 1개', '순서_품번_컬러:01_FS1HTA1078X_BBK|사이즈:260 / 1개',
#         '색상:BLK(블랙) / 1개', '사이즈:270 / 1개'], dtype=object),
#  array(['color:white|size:FREE / 1개', '색상:PK356 / 1개', '색상:PK376 / 1개',
#         'COLOR-SIZE:블랙(black)-FREE / 1개', '상품명:11_3부투라인레깅스|사이즈:블랙M / 1개',
#         'COLOR-SIZE:그레이(gray)-FREE / 1개', '상품명:07_라운드반팔티셔츠|사이즈:핑크M / 1개',
#         '상품명:13_9부레깅스|사이즈:그레이블랙M / 1개', '색상:화이트(00)|사이즈:27(68) / 1개'],
#        dtype=object),
#  array(['1개', '컬러:싱가포르 / 1개'], dtype=object),
#  array(['선택:롱6팩 / 1개', '색상:화이트-네이비|사이즈:18호[양손1세트] / 1개',
#         '색상:47 카민 태그 / 1개', '사이즈:034 / 1개', '1개', '색상:블랙(001) / 1개',
#         '색상 선택:10 / 1개', '색상:10 / 1개', '타입:페이셜 크림 150ml / 1개',
#         '색상:217 레드 스프레이 / 1개', '2개', '색상:블랙|사이즈:FREE / 1개',
#         '옵션:[1051432892]베이지/fr / 1개', '색상선택:그레이 / 1개', '색상:블랙|사이즈:66 / 1개',
#         '옵션:[1050576421]핑크/fr / 1개', '옵션:[1044778814]네이비/55 / 1개'],
#        dtype=object),
#  array(['옵션:선택13.피치(로즈핑크)|사이즈:230 / 1개', '색상:다크그레이 / 1개', '사이즈:85 / 1개'],
#        dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:화이트|사이즈:180 / 1개', '색상:핑크|사이즈:180 / 1개', '색상:화이트|사이즈:130 / 1개',
#         '모델명:LA 칠부 티셔츠|색상사이즈:블랙11호 / 1개', '색상:블랙|사이즈:130 / 1개',
#         '색상:레드|사이즈:9호 ◈85017824◈ / 1개', '색상:GD|사이즈:180 / 1개',
#         '색상:(17D2_18S0393) 네이비|사이즈:130 / 1개', '색상:블루|사이즈:130 / 1개'],
#        dtype=object),
#  array(['색상:418 로사 템페라 / 1개', '색상:브라운|사이즈:240 / 1개', '색상:베이지|사이즈:240 / 1개',
#         '직접입력1:U2(퍼플)|직접입력2:S(55) / 1개', '색상:E1(라이트그린)|사이즈:S(55) / 1개',
#         '1개', '색상:410 로쏘 폼페이아노 / 1개', '색상:415로쏘 파르테놉 / 1개',
#         '색상:블랙|사이즈:S(55) / 1개', '색상:010 아이보리 / 1개', '색상:091 매트 블랙 / 1개',
#         '색상:O2(오렌지)|사이즈:S(55) / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['선택1:허벌|선택2:Q10 / 1개', '1개', '선택:스파클 생수 2리터×6병(6팩) - 총36병 / 1개',
#         '사이즈:75A/90 / 1개'], dtype=object),
#  array(['1개', '선택사항:S101 비너스 / 1개'], dtype=object),
#  array(['색상:BLACK(16)|사이즈:070 / 1개', '색상:네이비|사이즈:85 / 1개',
#         '색상:네이비|사이즈:85 / 2개', '색상:블랙|사이즈:085 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:스킨|사이즈:80A / 1개', '색상:소프트브라운|사이즈:85A / 1개',
#         '색상:라이트블루|사이즈:55 / 1개', '색상:선택(07)_DKI1407 핑크(15) / 1개',
#         '색상:그레이|사이즈:55(90) / 1개', '색상:선택(10)_DET1103 핑크(15) / 1개',
#         '색상:화이트|사이즈:90 / 1개', '색상:블루|사이즈:90 / 1개',
#         '색상:23(오렌지)|사이즈:90 / 1개', '사이즈:55|색상:엘로 / 1개',
#         '색상:53(블루)|사이즈:73 / 1개', '색상:옐로우|사이즈:55 / 1개',
#         '색상:오렌지|사이즈:90 / 1개', '색상:스킨|사이즈:M / 3개', '색상:다크그레이|사이즈:66 / 1개',
#         '색상:네이비|사이즈:55(90) / 1개'], dtype=object),
#  array(['색상:03|사이즈:S / 1개', '1개', '색상:11 미드헤더그레이|사이즈:S / 1개',
#         '색상:핑크 클라우드 / 1개'], dtype=object),
#  array(['사이즈:090 / 1개', '색상:BA5527-010 블랙|사이즈:FREE / 1개', '사이즈:000 / 1개',
#         '색상:830587-010 블랙|사이즈:75L / 1개', '사이즈:85[70표기] / 1개',
#         '색상선택:레드(D11006) / 1개'], dtype=object),
#  array(['1개', '사이즈:블랙 / 1개'], dtype=object),
#  array(['디자인(솜포함):미니톰(호랑이)+마이크로실버솜 / 1개', '커버:알버트(악어)|솜:매쉬 베개솜 / 1개'],
#        dtype=object),
#  array(['줄길이 선택:일반접지_1.5M / 1개', '선택:MP-25 핑크 / 1개', '색상:화이트 / 1개',
#         '선택:MP-25 핑크 / 2개', '색상:네이비 / 1개', '1개'], dtype=object),
#  array(['색상:핑크|사이즈:66 / 1개', '색상:네이비프린트|사이즈:66 / 1개'], dtype=object),
#  array(['색상:블랙|사이즈:55 / 1개', '색상:아이보리(IV)|사이즈:55 / 1개',
#         '색상:화이트(WH)|사이즈:90 / 1개', '색상:베이지|사이즈:17호 / 1개',
#         '색상/사이즈:BK/85 / 1개', '상품선택:01.11016-001|사이즈:M5W7(240) / 1개',
#         '색상:블루|사이즈:55 / 1개', '필수옵션:쿨엠보 패드[SS]|컬러선택:CE08_스틸블루 / 1개',
#         '컬러선택:크로바-핑크 / 1개', '색상:아이보리(IV)|사이즈:FREE / 1개',
#         '컬러선택:크로바-퍼플그레이 / 1개', '필수옵션:쿨엠보 패드[SS]|컬러선택:CE03_라이트핑크 / 1개',
#         '사이즈:110 / 1개', '색상:다크네이비|사이즈:55 / 1개',
#         '상품명:01.Albino_JLMP003_Black_5|사이즈:230 / 1개', '1개',
#         '색상:아이보리|사이즈:55 / 1개', '선택:FREE / 1개', '색상:720(PINK)|사이즈:55 / 1개',
#         '5개', '색상:네이비-PKOEARL21UN8|사이즈:9T / 1개', '색상:크림|사이즈:55 / 1개',
#         '사이즈:55|색상:네이비 / 1개', '품번/사이즈:BI4526_검흰 / 090 / 1개',
#         '색상:네이비29|사이즈:165 / 1개', '색상:네이비29|사이즈:155 / 1개'], dtype=object),
#  array(['색상:White_10|사이즈:240 / 1개', '모델명:80018821 / 1개', '1개',
#         '색상:1W1 본 / 1개', '색상:멀티네이비(B87)|사이즈:FREE / 1개', '5개',
#         '색상:B20 아이보리 / 1개'], dtype=object),
#  array(['색상:옐로우|사이즈:95(M) / 1개', '색상:화이트|사이즈:110(XXL) / 1개',
#         '색상:화이트|사이즈:95(M) / 1개', '색상:블랙|사이즈:105(XL) / 1개',
#         '색상:옐로우|사이즈:100(L) / 1개'], dtype=object),
#  array(['색상:블랙|사이즈:34 / 1개', '1개', '색상/사이즈:NAVY/110 / 1개',
#         '옵션:인텐스 커버 21 / 1개', '색상:블랙|사이즈:95(L)[77] / 1개',
#         '색상:네이비|사이즈:32 / 1개'], dtype=object),
#  array(['색상:RED|사이즈:145 / 1개', '색상:OJ213(남.화이트)|사이즈:M(95) / 1개',
#         '색상:카키색|사이즈:95 / 1개'], dtype=object),
#  array(['색상:네이비|사이즈:145 / 1개', '색상/사이즈:핑크 210@9 / 1개', '사이즈:MISC / 1개',
#         '사이즈:FREE / 1개', '사이즈:70 / 1개',
#         '품번:04.CROCS_10126_001_|사이즈:230 / 1개'], dtype=object),
#  array(['색상:베이지|사이즈:110 / 1개', '색상/사이즈:인핑크/110 / 1개',
#         '색상/사이즈:pink/110 / 1개', '색상:그레이|사이즈:5YR / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['1개', '색상:BK(블랙)|사이즈:85 / 1개', '색상:OWT(오프화이트)|사이즈:85 / 1개',
#         '색상:CH(차콜)|사이즈:85 / 1개', '하의색상:IVP|하의사이즈:67(26) / 1개',
#         '색상:선택02_LKH(라이트카키)|사이즈:85 / 1개', '색상:MKH(카키)|사이즈:85 / 1개',
#         '하의색상:NVP|하의사이즈:67(26) / 1개'], dtype=object),
#  array(['COLOR:화이트|SIZE:S / 1개', '상품명:유기농 타히티 노니주스 946ml×2병 / 1개'],
#        dtype=object),
#  array(['색상:(남)그레이(3족) / 1개'], dtype=object),
#  array(['SIZE:S / 1개', '색상:분홍색|Size:080 / 1개',
#         '색상:화이트|사이즈:FREE(55~61) / 1개', '사이즈:FREE / 1개'], dtype=object),
#  array(['선택:세트 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['1개', '2개', '타입:세트 / 2개', '색상:골드|사이즈:235 / 1개', '사이즈:235 / 1개'],
#        dtype=object),
#  array(['1개'], dtype=object),
#  array(['사이즈:5 / 1개', '사이즈:4 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['상품명:뉴케어 미니 구수한맛 아셉틱 / 1개'], dtype=object),
#  array(['색상:OL2|사이즈:65(S) / 1개', '색상:스카이(SKY)|사이즈:FREE / 1개',
#         '색상:핑크|사이즈:28 / 1개', '1개', '색상:핑크|사이즈:34 / 1개', '색상:그린|사이즈:F / 1개',
#         '색상:MI2|사이즈:FREE / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:블랙|사이즈:7 / 1개', '색상:블랙|사이즈:8 / 1개', '색상:라이트 네이비|사이즈:7 / 1개',
#         '색상:시크릿키 타투 커버 쿠션 [핑크에디션]/23호 내추럴베이지 / 1개',
#         '색상:NA(네이비)|사이즈:77 / 1개', '색상:블랙|사이즈:245 / 1개',
#         '색상:57 (블랙)|사이즈:245 (4½) / 1개', '선택:단일품목|사이즈:38 / 1개',
#         '색상:BR(브라운)|사이즈:66 / 1개', '색상:카멜|사이즈:8 / 1개',
#         '색상:GRAY|사이즈:L ◈79715417◈ / 1개', '1개',
#         '사이즈:1(FREE)|색상:블랙(BK) / 1개', '색상:블루|사이즈:66 ◈56303515◈ / 1개',
#         '색상:민트|사이즈:66 / 1개', '색상:4호 그린베이지 / 1개', '색상/사이즈:블랙/FREE / 1개',
#         '모델명:그릴구이팬s3 / 1개', '사이즈:38 / 1개', '색상:네이비|사이즈:77 ◈63156003◈ / 1개',
#         '색상:066(네이비)|사이즈:M(66) / 1개', '색상:다크그린(DN)|사이즈:1(FREE) / 1개',
#         '색상:블루|사이즈:F / 1개', '색상/사이즈:네이비/FREE / 1개',
#         '색상:그레이|사이즈:FREE ◈88375738◈ / 1개',
#         '색상:그레이|사이즈:FREE ◈88377465◈ / 1개',
#         '색상:챠콜|사이즈:FREE ◈88375893◈ / 1개', '색상:블랙|사이즈:66 / 1개',
#         '색상:블랙|사이즈:FREE / 1개', '색상:그레이(14)|사이즈:FREE / 1개',
#         '색상:블랙(11)|사이즈:FREE / 1개', '색상:그레이(13)|사이즈:FREE / 1개',
#         '색상:네이비솔리드 / 1개', '컬러:블랙|사이즈:Size2 / 1개', '선택:얼굴코르셋 / 1개', '5개',
#         '색상:베이지|사이즈:66 ◈55136431◈ / 1개', '색상:블랙|사이즈:250 / 1개',
#         '색상:(45)네이비|사이즈:FFF / 1개', '색상:BLCK_BLACK|사이즈:FR / 1개'],
#        dtype=object),
#  array(['타입:세트. / 1개', '타입:세트 / 1개'], dtype=object),
#  array(['색상:94|사이즈:필수선택 ◈84720675◈ / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['3개', '상품명:스너글고농축_블루스파클4.96L x1개 / 1개'], dtype=object),
#  array(['사이즈:100 / 1개', '색상:02호 아이보리 / 1개',
#         '색상:선1)166(네이비)|사이즈:038(100) / 1개', '사이즈:240 / 1개', '1개'],
#        dtype=object),
#  array(['상품명:CW2336(화이트)|사이즈:S / 1개', '모델명:AFYBFH11|사이즈:75A / 1개', '1개',
#         '색상:NBNE721013-10화이트|사이즈:90 / 1개',
#         '색상:BLK0_(BLK0)BLACK|사이즈:85 / 1개'], dtype=object),
#  array(['색상:네이비 / 1개', '색상:블루|사이즈:240 / 1개'], dtype=object),
#  array(['color:네이비 / 1개', 'color:핑크|size:FREE / 1개',
#         'color:블랙|size:FREE / 1개', 'color:네이비|size:FREE / 1개',
#         'color1:네이비|color2:차콜 / 1개', 'color:청록|size:FREE / 1개',
#         '색상:MG|사이즈:95 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:화이트스트라이프|사이즈:M ◈88584676◈ / 1개'], dtype=object),
#  array(['색상:블랙/2cm|사이즈:240 / 1개', '색상:브라운|사이즈:240 / 1개', '색상선택:그레이 / 1개'],
#        dtype=object),
#  array(['색상:OR|사이즈:120[9817993-2] / 1개', '색상:BL|사이즈:120[9709962-2] / 1개'],
#        dtype=object),
#  array(['사이즈:30_NESS805767830 / 1개'], dtype=object),
#  array(['색상:네이비|사이즈:프리 / 1개', '색상:블루|사이즈:프리 / 1개'], dtype=object),
#  array(['사이즈:S / 1개', '색상:324 BU|사이즈:100(L) / 1개'], dtype=object),
#  array(['색상:01.(RSET774)라이트브라운|사이즈:80A-95 / 1개',
#         '색상:02.(SKPTE112H)라이트브라운|사이즈:90 / 1개', '1개',
#         '색상:NAVY|사이즈:FREE / 1개', '단일상품:단일상품 / 1개', '사이즈:240 / 1개',
#         '사이즈:FREE / 1개', '색상:04.(RSET699)쉘핑크|사이즈:80A-90 / 1개',
#         '색상:베이지|사이즈:FREE / 1개', 'COLOR-SIZE:화이트(white)-Free / 1개',
#         '첫번째색상:베이지|두번째색상:차콜|사이즈:M27~28인치) / 1개', '색상:BLK(블랙)|사이즈:ONE / 1개'],
#        dtype=object),
#  array(['1개', '필수선택:그로미미 빨대솔 / 1개', '색상:블루그레이+인디핑크 / 1개',
#         'PPSU빨대컵 300ml:스카이블루 + 보틀커버(L) / 1개',
#         '필수선택:그로미미 PPSU 빨대컵 200ml(스카이블루)+필터폼브러쉬증정 / 1개'], dtype=object),
#  array(['1개', '색상:블랙 초콜릿 / 1개'], dtype=object),
#  array(['상품타입:마블-L0399-블랙 / 1개', '색상:마호가니 / 1개', '사이즈:100 / 8개',
#         '사이즈:230 / 1개', '1개', '색상:워터멜론 / 1개', '색상:레드=GP-G950ICCPHAC / 1개',
#         '스타일번호:819352-001|사이즈:240 / 1개'], dtype=object),
#  array(['색상:핑크(P1)|사이즈:22(125-130) / 1개',
#         '색상:핫핑크(P3)|사이즈:22(125-130) / 1개'], dtype=object),
#  array(['1개', '타입:하이드레이팅 젤 / 1개', '기본:기본 / 1개'], dtype=object),
#  array(['사이즈:095 / 1개', '색상:09 BLACK|사이즈:FREE(프리) / 1개',
#         '색상:레드|사이즈:FREE / 1개', '1개', '사이즈:150 / 1개', '사이즈:130 / 1개',
#         '색상:07.네이비|사이즈:Q / 1개', '모델:CH1001(블랙)|사이즈:240(7M) / 1개',
#         '선택하기:룽고 대용량 팩 / 1개', '필수선택:테마/로지핑크/방석(솜포함) / 1개',
#         '필수선택:테마/모카/방석(솜포함) / 1개', '색상:24 레어 로즈 / 1개',
#         '색상:11 앰비규어스 베이지 / 1개'], dtype=object),
#  array(['색상:플라워화이트 / 1개'], dtype=object),
#  array(['색상:(남)블랙(3족) / 1개', '색상:(남)네이비(3족) / 1개'], dtype=object),
#  array(['색상:뉴트럴|사이즈:FREE / 1개', '1개'], dtype=object),
#  array(['2개', '색상:50(워시드카키)|사이즈:S / 1개', '1개', '사이즈:100 / 1개',
#         '사이즈:85B(L)|색상:네이비 / 1개', '색상:sky blue|사이즈:FREE / 1개',
#         '색상:BE2|사이즈:65(S) / 1개', '색상:AFHG18S0260블루|사이즈:240 / 1개',
#         '옵션:818381-100|사이즈:250/7Y / 1개', '색상:라이트 블루|사이즈:FREE / 1개',
#         '색상선택:로즈골드 / 1개', '번호:풀무원 샘물 500mL x 40병 / 2개',
#         '색상선택:2) ILVH-4000W(화이트필터) / 1개', '색상:D/INDIGO|사이즈:30 / 1개',
#         '색상:블랙|사이즈:240|굽높이:6cm / 1개', '색상:Black|사이즈:Free / 1개',
#         '색상/사이즈:화이트/6FS. / 1개', '881104 100:245 / 1개',
#         '색상:Beige|사이즈:Free / 1개', '색상:여신브라 레드|사이즈:95(80B.80C.85A) / 1개',
#         '색상:아이보리|사이즈:F / 1개', '색상:Pink|사이즈:Free / 1개',
#         '색상:그린_EFZGFH18/55|사이즈:0000 / 1개', 'color:pink|size:FREE / 1개',
#         '디자인:라이언 / 1개', '색상:아이보리|사이즈:FREE / 1개', '색상:로즈골드|사이즈:기성 / 1개',
#         '색상:화이트|사이즈:L / 1개', '색상:진청 Dark blue|사이즈:L / 1개', '선택:레드 자몽 / 1개',
#         '스타일/색상:29-502_캐미숄/베이지|사이즈:L / 1개',
#         '상품명:01.투톤브라|색상사이즈:블랙95(66사이즈) / 1개', '색상:실버|사이즈:235_240(M) / 1개',
#         '선택:플럼 / 1개', '색상:베이지|사이즈:F / 1개',
#         '상품명:02.마법보정브라|색상사이즈:블랙95(66사이즈) / 1개', '색상:BK2|사이즈:65(S) / 1개',
#         '상품명:[10팩] 복숭아맛 / 3개', '사이즈:85B(L)|색상:다크그린 / 1개',
#         '사이즈:85B(L)|상품명:40.브리제 / 1개', '사이즈:85B(L)|상품명:35.브로닌 / 1개',
#         '색상:오프화이트(01)|사이즈:L / 1개', '색상:AFHG18S0503그레이|사이즈:240 / 1개',
#         'color:navy|size:FREE / 1개', '색상:B7(블루)|직접입력2:260 / 1개',
#         '스타일/색상:29-503_탱크탑/블랙|사이즈:L / 1개', '색상:핑크|사이즈:F / 1개',
#         '색상:다크그레이|사이즈:95 / 1개', '색상:블랙|사이즈:30(L) / 1개', '색상:그레이 / 1개',
#         '색상:화이트_착불6만원 / 1개', '더원 :닭고기치킨연어포300g / 3개',
#         '더원 :닭고기DHA사사미300g / 3개', '사이즈:240 / 1개', '색상:BE4|사이즈:85(S) / 1개',
#         '종류 선택:01. 디베아 무선청소기 / 1개', '선택:레드 그레이프 / 1개',
#         '색상:옐로우|사이즈:FREE / 1개', '더원 :닭고기습식슬라이스300g / 3개',
#         '더원 :오리사사미300g / 3개', '더원 :오리사사미300g / 2개'], dtype=object),
#  array(['상품명:단비 3|사이즈:235 / 1개'], dtype=object),
#  array(['color:black|size:M / 1개', '색상_사이즈:블랙Black_M / 1개', '1개'],
#        dtype=object),
#  array(['컬러1:진저|컬러2:코냑 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:YE|사이즈:130 / 1개', '사이즈:095 / 1개', '색상:블루|사이즈:90 / 1개',
#         '색상:D-GRAY|사이즈:90 / 1개', 'SIZE:190 / 1개'], dtype=object),
#  array(['디자인:01.플랩캡_BLUE|사이즈:M / 1개', '색상:01_UR72SL491_네이비|사이즈:120 / 1개'],
#        dtype=object),
#  array(['2개'], dtype=object),
#  array(['색상:바나나 / 1개', '상품명:이솝 레저렉션 아로마틱 핸드 밤 75 / 1개', '1개',
#         '타입:래쉬 파워 렝쓰닝 마스카라 / 1개', 'SIZE:240 / 1개', '사이즈:240 / 1개'],
#        dtype=object),
#  array(['1개', 'CFBABFAS01:검정(02)|사이즈:80/11~12세 / 2개',
#         'CFBABFAS01:그레이(01)|사이즈:80/11~12세 / 2개', '색상:핑크 / 1개',
#         '디자인선택:빨간망토로라 / 1개',
#         '세탁세제 2개:수딩카모마일|섬유유연제 2개:수딩카모마일|젖병세정제 2개:시트러스 제스트 / 1개',
#         '필수선택:프리미엄 푸고 빨대컵(베이지) / 1개', '사이즈:100 / 1개', '사이즈:230 / 1개',
#         '사이즈:140 / 1개', '색상:화이트(BY9937)|사이즈:140mm / 1개',
#         '색상:MINT|사이즈:100 / 1개', '필수선택:[프리미엄 푸고]텀블러 유니트(핑크) / 1개',
#         '색상:네이비|사이즈:100 / 1개', '색상:IVORY|사이즈:100 / 1개',
#         '색상:GREEN|사이즈:100 / 1개', '색상:WHITE|사이즈:12 / 1개',
#         '색상:PURPLE|사이즈:100 / 1개', '필수선택:[프리미엄 푸고]텀블러 유니트(옐로) / 1개'],
#        dtype=object),
#  array(['1개', '선택:잉크브라운 / 1개', '색상:퍼플 / 1개', '색상:핑크 / 1개',
#         '선택:02호-브라운라인 / 1개', '색상:아이보리 / 1개'], dtype=object),
#  array(['색상:미니미 [블랙] / 1개', '선택:아메리카노 / 2개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['1개', '색상:그레이|사이즈:90 / 1개', '색상:12 코랄 아크리릭 / 1개'], dtype=object),
#  array(['1개', '색상:1N0 포슬린 / 1개'], dtype=object),
#  array(['색상:3호 민트 / 1개', '상품명:트리플러스 / 1개', '색상:러블리 핑크 / 1개',
#         '상품명:트리플러스 / 2개', '컬러:블러드플라워 / 1개'], dtype=object),
#  array(['사이즈:240 / 1개', '사이즈:235 / 1개', '사이즈:블랙 / 1개'], dtype=object),
#  array(['색상:OTW115423APP|사이즈:FREE / 1개', '색상:인디핑크|사이즈:M(12~24m) / 1개',
#         '색상:웨일 / 1개', '색상:연블루|사이즈:S(6~12m) / 1개', '색상:베이비 / 1개',
#         '색상:022(아이보리)|사이즈:M(004) / 1개', '색상:화이트|사이즈:M(12~24m) / 1개',
#         '품명색상:달퐁여우2긴팔우주복 80 / 1개', '색상:레드|사이즈:77 / 1개',
#         '색상:오렌지|사이즈:M(12~24m) / 1개', '색상:그레이|사이즈:M(12~24m) / 1개'],
#        dtype=object),
#  array(['색상:테라코타 / 1개', '1개', '컬러:베인 / 1개', '컬러:플레이펜 / 1개', '컬러:싱가포르 / 1개',
#         '색상:오 / 1개', '컬러:모하비 / 1개', '번호:순백 27m *(24+6)롤(EC) *1팩(블루) / 1개',
#         '색상:A-블러쉬 30호 발레리나 코랄 / 1개', '색상:A-블러쉬 50호 발레리나 핑크 / 1개',
#         '색상:엔젤 / 1개', '색상:405 페퍼 / 1개', '컬러:Y235 / 1개', '선택:315 / 1개',
#         '컬러:300 파우더리 코랄 / 1개', '색상:러브 유어셀프 / 1개', '색상:프로세코 / 1개',
#         '컬러:피치 / 1개', '컬러:진저 / 1개', '색상:몰튼 브론즈 / 1개',
#         '색상:낫 어프레이드 투 스파클 / 1개', '컬러:언드레스드 리퀴드 립 세트 I / 1개',
#         '컬러:레드 디스트릭트 / 1개', '색상:005 상하이 브랙퍼스트 / 1개',
#         '색상:G041806 344 SEXY CORAL / 1개', '색상:딥 쓰로트 / 1개', '컬러:소월 / 1개',
#         '색상:001 라스트 엠퍼러 / 1개', '색상:오르가즘 / 1개', '색상:언로플 / 1개', '색상:2호 / 1개',
#         '색상:몰리 와우 / 1개'], dtype=object),
#  array(['색상:NV|사이즈:31(80) / 1개', '1개', '색상:16누드 엠블럼 / 1개', '색상:블루블랙 / 1개',
#         '색상:곤색|사이즈:255 ◈88086539◈ / 1개'], dtype=object),
#  array(['색상:레드(13) / 2개'], dtype=object),
#  array(['색상:BLACK(K222001KB)|직접입력2:240 / 1개',
#         '색상:네이비_204537-485|사이즈:180 / 1개'], dtype=object),
#  array(['색상:그레이(020)|사이즈:LG / 1개', '색상:001|사이즈:XL / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:NY|사이즈:145 / 1개', '색상:NAVY|사이즈:155 / 1개', '색상:BL|사이즈:155 / 1개',
#         '색상:BLUE|사이즈:FREE / 1개', '색상:MG|사이즈:145 / 1개'], dtype=object),
#  array(['색상:선택06) 028250-70|사이즈:L / 1개', '색상:선택09) 028250-76|사이즈:L / 1개',
#         '색상:블랙(N90)|사이즈:XL / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['선택:블랙(BK)-55 / 1개', '색상:02워시드블루|사이즈:25 / 1개'], dtype=object),
#  array(['상품명:No.13 APRICOT(아프리콧) / 1개', '색상:차콜그레이|바지사이즈:95 / 1개',
#         '색상:블랙|사이즈:FREE / 1개', '색상:그레이|사이즈:F / 1개',
#         '색상:11.TR255(MH)|사이즈:100(L) / 1개', '1개', '사이즈:240 / 1개',
#         '색상:블랙|바지사이즈:95 / 1개', '사이즈:110|칼라:네이비(NV)-82 / 1개',
#         '색상:레드(R57)|사이즈:M / 1개', '색상:아이보리(IV)|사이즈:66 / 1개',
#         '상품명:02.LCWN813J97화이트|사이즈:245 / 1개', '선택:[844551] 화이트 275 / 1개',
#         '색상:(062)블루|사이즈:30 / 1개', '색상:화이트|사이즈:F / 1개',
#         '옵션선택1:ONE SIZE / 1개', '색상:아이보리|사이즈:FREE / 1개'], dtype=object),
#  array(['색상:블랙(CH3707)|사이즈:5.5M(225) / 1개'], dtype=object),
#  array(['사이즈:34_NESS804661434 / 1개', '사이즈:30_NESS804400130 / 1개'],
#        dtype=object),
#  array(['색상:차콜그레이|사이즈:80 / 1개', '번호:11|셔츠사이즈:M(100) / 1개',
#         '스타일:블랙|사이즈:250 / 1개'], dtype=object),
#  array(['사이즈:130 / 1개', '색상:GY|사이즈:130 / 1개', '색상:IV|사이즈:210 / 1개',
#         '색상:IV|사이즈:130 / 1개'], dtype=object),
#  array(['사이즈:BI4509 블랙/L / 1개'], dtype=object),
#  array(['번호:강원 평창수 2.0L x 6병 / 1개', '상품명:남양 천연수 2L x 6펫 / 1개', '1개'],
#        dtype=object),
#  array(['색상:심플 화이트|사이즈:245 / 1개', '색상:핑크7cm|사이즈:245 / 1개',
#         '색상/사이즈:그레이/245mm / 1개', '색상:블랙|사이즈:245 / 1개'], dtype=object),
#  array(['색상:(남)스킨 / 10개', '색상:(남)화이트 / 8개', '2개', '1개',
#         '상품명:전라도 포기김치 / 1개'], dtype=object),
#  array(['색상:21호 / 2개'], dtype=object),
#  array(['옵션선택:선택 07 핑크|사이즈:110 / 1개', '옵션선택:선택 05 네이비|사이즈:110 / 1개'],
#        dtype=object),
#  array(['상품번호:20번|사이즈:100 / 1개', '상품번호:01번|사이즈:100 / 1개'], dtype=object),
#  array(['색상:MI2|사이즈:70(M) / 1개', '색상:BE2|사이즈:70(M) / 1개',
#         '색상:블랙|사이즈:95(XXL) / 1개', '색상:그레이|사이즈:85(L) / 2개', '1개',
#         '컬러:카날 카네이션 / 1개'], dtype=object),
#  array(['색상:320 / 1개', '스타일:320(+310호증정) / 1개', '1개'], dtype=object),
#  array(['색상:(39)Ivory|사이즈:095 / 1개', '색상:블랙(100)|사이즈:95(M) / 1개',
#         '색상/사이즈:블랙/18M / 1개', '색상:버건디|사이즈:66 / 1개', '색상/사이즈:차콜그레이/2T / 1개',
#         '색상:다크그린|사이즈:66 / 2개', '색상:브라운|사이즈:66 / 1개',
#         '상품선택1/상품선택2:티셔츠_와인 2T/레깅스_와인 2T / 1개'], dtype=object),
#  array(['선택:글라스터 훅세트 / 2개', '선택:글라스터보조패드(소) / 2개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['사이즈:082 / 1개', '색상:파랑 / 1개', '사이즈:75A/90 / 1개', '1개',
#         '색상:23호 트루베이지 / 1개', '색상:21호 / 1개', '구 성:자마골프 바람개비 스윙연습기 / 1개'],
#        dtype=object),
#  array(['옵션1:핑크|옵션2:F / 1개', '옵션1:블랙|옵션2:1번 / 1개', '옵션1:아이보리|옵션2:F / 1개'],
#        dtype=object),
#  array(['사이즈:260 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['사이즈:230 / 1개', '색상:블루 / 1개', '제품선택:코코로미들 블랙 230 / 1개',
#         '색상:블랙(6776NP11)|사이즈:230 / 1개', '색상:012(화이트)|사이즈:M(66) / 1개',
#         '상품명:멀티비타민&미네랄 올앤원 틴즈 (90정) / 1개', '색상:멜란지그레이|사이즈:77 / 1개',
#         '색상:블랙|사이즈:230 / 1개', '색상:핑크|사이즈:FREE / 1개', '선택:095호 / 1개'],
#        dtype=object),
#  array(['1개', '사은품선택:선택사은품2번 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:화이트(CE1070)|사이즈:150cm / 1개'], dtype=object),
#  array(['색상:SKIN+RED|사이즈:FREE / 1개', '색상:BLACK+PALE BLUE|사이즈:FREE / 1개'],
#        dtype=object),
#  array(['선택:캐비티5개+후레쉬5개(180ml샴푸) / 1개', '상품명:오리지날6개 / 1개'], dtype=object),
#  array(['색상:블랙 / 1개'], dtype=object),
#  array(['색상:쿨본 / 1개', '2개'], dtype=object),
#  array(['색상:NA(네이비)|사이즈:66 / 1개', '색상:204774-060 블랙|사이즈:W6 / 1개',
#         '색상:네이비|사이즈:66 / 1개', '사이즈:230 / 1개', '색상:아이보리 / 1개',
#         '색상:LB(라이트베이지)|사이즈:M(66) / 1개', '색상:블랙 / 1개', '색상:블루|사이즈:130 / 1개'],
#        dtype=object),
#  array(['1개'], dtype=object),
#  array(['옵션:옵션28|상의사이즈:95 / 5개'], dtype=object),
#  array(['색상:블랙|사이즈:255 / 1개', '색상:화이트|사이즈:F / 1개',
#         '색상:오렌지브라운|사이즈:255 / 1개'], dtype=object),
#  array(['성명서체:블랙 / 1개'], dtype=object),
#  array(['색상:블랙|사이즈:145 / 1개'], dtype=object),
#  array(['사이즈:S / 1개'], dtype=object),
#  array(['색상:NA|사이즈:110[9608087-1] / 1개', '1개', '색상:초코브라운 / 1개'],
#        dtype=object),
#  array(['색상:와인 / 1개', '색상:X542UA-DM892 (화이트) / 1개', '색상:CR344 / 1개'],
#        dtype=object),
#  array(['색상:별 75*100cm_민트블루 / 1개'], dtype=object),
#  array(['사이즈:105 / 1개'], dtype=object),
#  array(['색상:블랙 / 1개', '색상:선택03_블랙|사이즈:XL(남) / 1개', '사이즈:W8_250 / 1개',
#         '사이즈:250 / 1개', '제품:09_해외 10001411 블루|사이즈:250mm(8) / 1개',
#         '색상:아이보리|사이즈:FREE / 1개', '색상:2.네이비(NVY)|사이즈:250 / 1개',
#         '색상:아이보리|사이즈:XL / 1개', '사이즈:250mm / 1개', '색상:블랙|사이즈:250 / 1개'],
#        dtype=object),
#  array(['모델명:옵션24번|셔츠사이즈:105 / 1개', '모델명:옵션25번|셔츠사이즈:105 / 1개',
#         '사이즈:120 / 1개'], dtype=object),
#  array(['색상:03|사이즈:L / 1개', '색상:131(베이지)|사이즈:S(003) / 1개',
#         '색상:521(핑크)|사이즈:M(004) / 1개', '색상:79|사이즈:L / 1개',
#         '색상:131(베이지)|사이즈:M(004) / 1개', '색상:521(핑크)|사이즈:S(003) / 1개'],
#        dtype=object),
#  array(['옵션 선택:레드-애디션 2종세트 2개 +증정 / 2개', '색상:검정|사이즈:28 / 1개', '4개', '1개',
#         '옵션 선택:레드-애디션 2종세트 2개 +증정 / 1개', '옵션:21호 커버 바닐라 / 5개'],
#        dtype=object),
#  array(['색상:BLACK(06)|사이즈:072 / 1개', '색상선택:다크블랙 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상/사이즈:ONECOLOR/17호 / 1개', '2개', '타입:하드타입 / 1개',
#         '색상:HN그린중블랙|신발사이즈:240 / 1개', '1개', '품목:그린(10365789) / 10개',
#         '색상:블랙|사이즈:FREE / 1개', '색상:PINK|사이즈:M / 1개',
#         '색상:NVY|사이즈:스판수모 / 1개', '디자인선택:089-ME-0031/그레잇스마일 / 1개',
#         '디자인:089-MS-14/굿별 / 1개', '색상:라이트블루|사이즈:27 / 1개', '사이즈:100 / 1개',
#         '3개', '색상:화이트|사이즈:85 / 1개', '색상:NAV(네이비)|사이즈:240 / 1개',
#         '상품명:소이밀크 플러스 약콩두유 190ml×24팩. / 1개', '색상:블랙 / 1개',
#         '색상:그린|사이즈:FREE / 1개', '색상:와인|사이즈:FREE / 1개',
#         '색상:M/그레이|사이즈:FREE / 1개', '색상:그레이(03) / 1개',
#         '사이즈:235|색상:브라운(KV21) / 1개', '컬러선택:그레이 / 1개', '색상:BK|사이즈:105 / 1개',
#         '색상:화이트(반투명) / 1개', '색상:여신브라 블랙|사이즈:100(85B.85C.90A) / 2개'],
#        dtype=object),
#  array(['1개', '상품명:소이밀크 플러스 약콩두유 190ml×72팩 / 1개', '색상:화이트블랙|사이즈:240 / 1개',
#         '사이즈:27인치 / 1개', '색상:블랙|사이즈:240 / 1개', 'COLOR:COBALT|SIZE:37 / 1개',
#         'color:WH|size:free / 2개'], dtype=object),
#  array(['색상:카키(397)|사이즈:S(003) / 1개'], dtype=object),
#  array(['선택:베이지(BE)-55 / 1개', '색상:블랙|사이즈:F / 1개', '색상:옐로우|사이즈:55 / 1개',
#         '색상:화이트(W)|사이즈:155 / 1개', '색상:화이트(WH)|사이즈:F / 1개',
#         '색상:U-블루|사이즈:105-XL / 1개', '품번:02_TSMSPH60030|색상사이즈:라이트블루_66 / 1개',
#         '색상:U-블루|사이즈:85-XS / 1개'], dtype=object),
#  array(['색상:032(베이지)|사이즈:FREE / 1개'], dtype=object),
#  array(['색상:그레이|사이즈:110 / 1개', '색상:블랙|사이즈:110 / 1개'], dtype=object),
#  array(['색상:베이지|사이즈:FF / 1개', '색상:02|사이즈:S / 1개',
#         '색상:아이보리|사이즈:FREE ◈90073738◈ / 1개', '사이즈:150 / 1개',
#         '모델명:선택01) 0967mpbrP+한정사은품 / 1개',
#         'COLOR-SIZE:아이보리(ivory)-FREE / 1개', '색상:네이비|사이즈:L / 1개',
#         '색상:브라운|사이즈:S / 1개', '색상:그린|사이즈:S / 1개', '모델:CQ3104|사이즈:225 / 1개',
#         '색상/사이즈:블랙/FREE / 1개', '색상:네이비|사이즈:S / 1개',
#         '색상:화이트(001)|사이즈:FREE(000) / 1개', '색상:오렌지|사이즈:95 / 1개',
#         '사이즈:90|색상:블랙(BK) / 1개', '색상:오프화이트|사이즈:S / 1개', '1개',
#         '색상:라이트그레이|사이즈:S / 1개', '색상:라이트그레이|사이즈:L / 1개'], dtype=object),
#  array(['상품명:매일두유 99.89 190ml 24팩+바비다 2포 / 1개', '상품명:뼈칼두유 190ml 24팩 / 1개',
#         '색상:C21호 핑크바닐라커버 / 2개'], dtype=object),
#  array(['히프노스침낭:어덜트네이비 / 1개', '1개'], dtype=object),
#  array(['상품:BS121 / 1개', '본품:본품 / 1개', '세트:비비+안티다크커버 / 1개'], dtype=object),
#  array(['직접입력1:KRHMK0393B 단델리온 트윙클 하이라이터 BOX / 1개', '사이즈:27인치 / 1개'],
#        dtype=object),
#  array(['타입:세트 / 1개', '1개'], dtype=object),
#  array(['색상:블랙|사이즈:S / 1개', '사이즈:230 / 1개', '색상:WH(화이트)|사이즈:44(66) / 1개'],
#        dtype=object),
#  array(['색상:네이비(NA)|사이즈:S(55) / 1개'], dtype=object),
#  array(['색상:B60|사이즈:06 / 1개', '사이즈:95 / 1개'], dtype=object),
#  array(['사이즈:38 / 1개', '사이즈:L / 1개', '필수선택:그로미미 교체용 빨대세트(2개입)_(1단계) / 1개',
#         '필수선택:그로미미 교체용 빨대세트(2개입)_(2단계) / 1개'], dtype=object),
#  array(['사이즈:S / 1개', '색상1:민트그레이|색상2:오렌지핑크 / 1개', '색상:화이트 / 1개'],
#        dtype=object),
#  array(['사이즈:95 / 1개', '색상:블랙(L)|사이즈:155 / 1개', '품번:S556|사이즈:90 / 1개',
#         '1개', '사이즈:220 / 1개'], dtype=object),
#  array(['색상:01.컬러플래쉬가드3SET|사이즈:핑크150 / 1개', '색상:핑크|사이즈:S / 1개'],
#        dtype=object),
#  array(['품목:남아스니커즈01|사이즈:5호 / 1개', '품목:남아스니커즈07|사이즈:5호 / 1개',
#         '품목:남아스니커즈05|사이즈:5호 / 1개', '품목:남아스니커즈12|사이즈:5호 / 1개',
#         '상품타입:다이노코어-K0139-랜덤-5 / 1개'], dtype=object),
#  array(['색상:B60(네이비)|사이즈:34 / 1개', '1개'], dtype=object),
#  array(['상품선택:XL / 1개'], dtype=object),
#  array(['색상:그린|사이즈:110 / 1개'], dtype=object),
#  array(['색상:BLK0_(BLK0)BLACK|사이즈:260 / 1개'], dtype=object),
#  array(['색상사이즈:없음/12240824/ / 2개'], dtype=object),
#  array(['3개', '선택:핑크 / 1개', '2개', '색상:쏘 쇼드 / 1개', '색상:스시 키스 / 1개',
#         '제품 선택:화이트 프레임 (무료배송) / 1개', '1개'], dtype=object),
#  array(['색상:블랙( Z1)|사이즈:85 / 1개'], dtype=object),
#  array(['색상:BLACK|사이즈:240 / 1개', '단일상품:단일상품 / 1개'], dtype=object),
#  array(['색상:스터디드 키스 / 1개', '색상:코르크 / 1개', '색상:화이트 / 1개',
#         '색상:블랙|사이즈:240 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:색상랜덤 / 1개', '1개'], dtype=object),
#  array(['베베숲 아기물티슈:B13-제로 캡10팩+휴대 리필 2팩 / 1개', '색상선택:화이트 / 1개'],
#        dtype=object),
#  array(['색상:BK|사이즈:210mm / 1개', '색상:BK|사이즈:190mm / 1개',
#         '색상:NS98J08BBLK|사이즈:260MM / 1개', '1개',
#         '색상:454500_101|사이즈:220/3Y / 1개', '색상:블루|사이즈:255 / 1개'],
#        dtype=object),
#  array(['1개'], dtype=object),
#  array(['상품명:BZ0418(화이트)|사이즈:130 / 1개', '상품명:BZ0418(화이트)|사이즈:160 / 2개'],
#        dtype=object),
#  array(['필수선택:보르미올리 피도2L_화이트탑[2개] / 2개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['타입:올 나이터 / 1개'], dtype=object),
#  array(['모델명:01_4217GF113_|사이즈:80 / 1개', '모델:01-01|셔츠사이즈:100 / 1개',
#         '사이즈:100 / 1개', '모델명:옵션28번|셔츠사이즈:100 / 1개',
#         '모델명:03_4217GF213_|사이즈:80 / 1개', '색상:네이비|사이즈:100 / 1개',
#         '품번|색상:7635PK(핑크)|사이즈:100 / 1개', '색상:그레이[GR]|사이즈:M[58] / 1개',
#         '색상:50N|사이즈:61CM / 1개', '상품명:선택3.EHX7890|사이즈:100 / 1개'],
#        dtype=object),
#  array(['색상:베이지|사이즈:100 / 1개', '상의색상:CH|상의사이즈:90 / 1개',
#         '색상:핑크|사이즈:100 / 1개', '상의색상:BE|상의사이즈:100 / 1개', '색상:티탄실버 / 1개',
#         '색상:화이트|사이즈:100 / 1개', '색상:DNV|사이즈:76(30) / 1개', '사이즈:더스티핑크 / 1개',
#         '색상:선택02_MGR|사이즈:FREE / 1개', '모델명:01_4217GF153_|사이즈:85 / 1개',
#         '색상:멜란지그레이|사이즈:100 / 1개', '색상:그린|사이즈:100 / 1개',
#         '상의색상:선택01_XPK|상의사이즈:100 / 1개', '색상:아이보리/AG14FIV / 1개',
#         '색상:화이트 / 1개', '상의색상:XDK|상의사이즈:95 / 1개', '색상:BK|사이즈:76(30) / 1개',
#         '상의색상:MGR|상의사이즈:100 / 1개', '색상:CH(차콜)|사이즈:76 (30) / 1개'],
#        dtype=object),
#  array(['구성:아이시스8.0 300mlx40펫 / 1개', '구성:아이시스8.0 300mlx40펫 / 2개'],
#        dtype=object),
#  array(['색상:베이지|사이즈:FREE / 1개', '사이즈:FREE|색상:KK(카키) / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['선택:아이래쉬세럼 (K321A) / 1개', '2개', '1개', '색상:레드 / 1개',
#         '상품명:화애락진 / 1개', '선택사항:23호 / 1개', '색상:핑크베이지 / 1개'], dtype=object),
#  array(['색상:US14(GR)|사이즈:80A90 / 1개', '색상:US17(NB)|사이즈:80A90 / 1개',
#         '색상:US11(BK)|사이즈:80A90 / 1개', '색상:US18(DG)|사이즈:80A90 / 1개'],
#        dtype=object),
#  array(['색상:MG|사이즈:100 / 5개', '색상:13_FBRK5541D20|사이즈:100 / 1개',
#         '색상:12_FBRK5525DD0|사이즈:100 / 1개', '색상:20_FBZK5521C40|사이즈:100 / 1개',
#         '색상:01_FBRK5522DD0|사이즈:100 / 1개', '색상:05_FBAG5824D30|사이즈:90 / 1개',
#         '색상:38_FCRG5834E30|사이즈:90 / 1개', '색상:17_FBRK5544D20|사이즈:100 / 1개'],
#        dtype=object),
#  array(['번호/디자인:3.베이비핑크(3727)|브라/팬티(사이즈):75A/90 / 1개',
#         '상품명:003)EHD5670|사이즈:105 / 1개', '색상:네이비|사이즈:S / 1개',
#         '색상:L/BEIGE|사이즈:S / 1개', '색상:화이트|사이즈:F / 1개', '1개',
#         '색상:베이지|사이즈:FF / 1개', '색상:핑크|사이즈:FF / 1개', '사이즈:110 / 1개',
#         '색상:베이지 / 1개', '브라:75A|팬티:90 / 1개', '색상:옐로우|사이즈:F / 1개',
#         '색상:네이비|사이즈:XL(105~110) / 1개'], dtype=object),
#  array(['1개', '색상:옐로우 / 1개', '색상:그린 / 1개', '색상:라일락 / 1개', '색상:오렌지 / 1개'],
#        dtype=object),
#  array(['색상:FFSO7FA03BK|사이즈:030 / 1개', '색상:G3(퓨터)|사이즈:40(240) / 1개'],
#        dtype=object),
#  array(['3개'], dtype=object),
#  array(['색상:핑크|사이즈:S / 1개', '1개', '타입:세트 / 1개', '색상:베이지 / 1개',
#         '색상:010 / 1개', '필수 선택:01) 일반용 / 1개', '색상:WWG|사이즈:105(XL) / 1개',
#         'Size:095 / 1개', '색상:스킨|사이즈:85 / 1개', '색상:스킨|사이즈:85 / 2개',
#         '색상:베이직_네이비2장 / 1개', '색상:1호 / 1개', '2개', '선택1:메이트_네이비 / 1개'],
#        dtype=object),
#  array(['색상:엘로우(413)|사이즈:13호 / 1개', '색상:베이지(BE)|사이즈:95 / 3개',
#         '색상:블루네이비(247)|사이즈:13호 / 1개', '품목:남아스니커즈11|사이즈:6호 / 1개',
#         '품목:남아스니커즈03|사이즈:6호 / 1개', '품목:남아스니커즈13|사이즈:6호 / 1개',
#         '품목:남아스니커즈12|사이즈:6호 / 1개', '색상:핑크(VP)|사이즈:95 / 2개',
#         '품목:남아스니커즈04|사이즈:6호 / 1개', '품목:남아목양말05|사이즈:6호 / 1개',
#         '품목:남아목양말04|사이즈:6호 / 1개', '품목:남아목양말09|사이즈:6호 / 1개', '1개',
#         '품목:남아목양말10|사이즈:6호 / 1개', '색상:네이비(269)|사이즈:13호 / 1개',
#         '품목:남아목양말06|사이즈:6호 / 1개', '색상:블랙(100)|사이즈:13호 / 1개',
#         '품목:남아목양말02|사이즈:6호 / 1개'], dtype=object),
#  array(['색상:보스 핑크 (3) / 1개', '1개'], dtype=object),
#  array(['색상:네이비(275)|사이즈:S(003) / 1개', '하의색상:네이비|하의사이즈:067 / 1개',
#         '바지사이즈:070 (27) / 1개'], dtype=object),
#  array(['색상_사이즈:블루Blue_F / 1개', '색상:데님 블루 / 2개', '색상:인디고|사이즈:S / 1개',
#         '색상/사이즈:그레이/XL / 1개', '색상:그레이(N36)|사이즈:M / 1개',
#         '색상:블루|사이즈:100 / 1개', '색상:멜란지그레이|사이즈:FREE / 1개',
#         '품번:02.FITFLOPL05_167_|사이즈:280 / 1개',
#         '색상:아이보리|사이즈:WM ◈67414969◈ / 1개', '색상:화이트 / 1개',
#         '색상_사이즈:아이보리Ivory_F / 1개', '색상:네이비|사이즈:SM / 1개',
#         '색상:화이트|사이즈:S / 1개', '색상:네이비|사이즈:37(235~240) / 1개'], dtype=object),
#  array(['색상:50L(블랙)|사이즈:FREE(55~61) / 1개', '색상:화이트|사이즈:0F(FREE) / 1개',
#         '색상:블랙|사이즈:0F(FREE) / 1개', '색상:그레이 / 1개'], dtype=object),
#  array(['색상:그레이|사이즈:L / 1개', '색상:GN|사이즈:155 / 1개', '사이즈:L / 1개'],
#        dtype=object),
#  array(['상의 사이즈-하의 사이즈:S-S / 1개'], dtype=object),
#  array(['색상:BL|사이즈:110 / 1개', '색상:TFMR1JHE08A0W10|사이즈:04 / 1개'],
#        dtype=object),
#  array(['1개', '단품:오일스무딩 로션 350ml / 1개', '2개'], dtype=object),
#  array(['2개'], dtype=object),
#  array(['색상:05|사이즈:M / 1개', '색상:02|사이즈:L / 1개'], dtype=object),
#  array(['스타일:낭만고양이 / 1개', '스타일:애니멀파크 / 1개'], dtype=object),
#  array(['색상:BLK0_(BLK0)BLACK|사이즈:280 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:올리브그린 / 1개'], dtype=object),
#  array(['1개', '선택:360 수지로즈(Matte) / 1개', '타입:마린 더블 프로텍션 선스틱 / 1개',
#         '사이즈:01-CRO-204950-060_230 / 1개',
#         '선택:[네소호환by이태리캡슐] 버라이어티 10팩(100알)+2팩(20알) / 1개',
#         '선택:373 수지코랄(Cream) / 2개'], dtype=object),
# ...
#         '색상:멜란지|사이즈:110 / 1개', '사이즈:260 / 1개', '색상:IVORY|사이즈:110 / 1개',
#         '색상:GR|사이즈:110 / 1개', '색상:BLACK(블랙)|사이즈:240MM / 1개'], dtype=object),
#  array(['color:아이보리 / 1개', '색상:커스터드 / 1개', '색상:블랙|브라사이즈:80A|팬티사이즈:95 / 1개',
#         '색상:09 / 1개', '사이즈:80A / 1개'], dtype=object),
#  array(['1개', '사이즈:095 / 1개', '사이즈:090 / 1개', '색상:NAVY_NAVY|사이즈:L / 1개'],
#        dtype=object),
#  array(['색상:CG3777(블랙)|사이즈:160 / 1개'], dtype=object),
#  array(['색상:BK(블랙)|사이즈:M(66) / 1개', '색상:GE(그레이)|사이즈:S(55) / 1개'],
#        dtype=object),
#  array(['제품선택:콜라겐 1kg / 1개', '1개'], dtype=object),
#  array(['1개', '색상:4호 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['1개', '색상:블랙(BK)|사이즈:FREE / 1개',
#         '제품번호/색상:8CKQM21_SH3_블랙|사이즈:230 / 1개', '2개', '옵션:없음 / 1개',
#         '색상:화이트[WH]|사이즈:90 / 1개', '색상:그레이쉬베이지|사이즈:S(57) / 1개',
#         '색상:화이트|사이즈:85 / 1개', '색상:화이트01|사이즈:55 / 1개'], dtype=object),
#  array(['색상:래빗-퍼플옐로우 / 1개', '상품명:핑크 / 1개'], dtype=object),
#  array(['색상:LML(라이트멜란지)|사이즈:105 / 1개', '색상:BLK(블랙) / 1개'], dtype=object),
#  array(['색상:LKP|사이즈:95 / 1개'], dtype=object),
#  array(['사이즈:270(42) / 1개', '색상:04.(RSET695)쉘핑크|사이즈:75A-95 / 1개'],
#        dtype=object),
#  array(['색상:아이보리|사이즈:FREE / 1개', 'color:블랙s / 1개',
#         '색상:인디언핑크|사이즈:FREE / 1개', '색상:베이지|사이즈:55 / 1개', 'color:아이보리 / 1개',
#         'color:베이지 / 1개'], dtype=object),
#  array(['1개', '필수선택:보르미올리 스윙 유리병 1L_사각[2개] / 1개'], dtype=object),
#  array(['색상:블랙 / 1개', '타입:세트. / 1개', '옵션:셋트 / 1개',
#         'color:purple|size:FREE / 1개', 'color:beige|size:L / 1개',
#         '테라 반바지레깅스:블랙31 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:멜란지그레이(MG)|사이즈:105 / 1개'], dtype=object),
#  array(['1개', '품번:NFKUSH20/01|사이즈:105 / 1개', '색상:화이트(WH)|사이즈:FREE / 1개',
#         '색상:화이트(WH)|사이즈:FF / 1개', '색상:99(블랙)|사이즈:FREE / 1개',
#         '색상:NS6NJ31ABLK|사이즈:80(XL) / 1개', '색상:DBBA8E806BK|사이즈:선택사항참조 / 1개',
#         '색상:그린(GR)|사이즈:FREE / 1개', '사이즈:100 / 1개',
#         '색상:블랙|사이즈:Free(넓이43cm 높이40cm) / 1개', '색상:BLK|사이즈:여80(77반) / 1개',
#         '2개', '컬러:네이비(NA)|사이즈:66 / 1개', '컬러:핑크(PK)|사이즈:66 / 2개',
#         '직접입력1:725931-010_블랙 / 095(XL) / 1개', '색상:블랙|사이즈:100(XL)[88] / 1개',
#         '색상:BLK(블랙)|사이즈:86 / 1개', '사이즈:L_NESS8278001L / 1개',
#         '사이즈:M_NESS8291001M / 1개', '색상:딥그린(367)|사이즈:FREE(000) / 1개',
#         '사이즈:EU39(250mm) / 1개', '품번:NFKLSH23/69|사이즈:105 / 1개',
#         '색상:블랙|사이즈:90 / 1개', '3개', '색상:블랙|사이즈:F / 1개', '사이즈:10 / 1개',
#         '사이즈:12 / 1개'], dtype=object),
#  array(['사이즈:110 / 1개'], dtype=object),
#  array(['2개'], dtype=object),
#  array(['모델명:플랫폼핸드카트브레이크형 / 1개', '1개', '사이즈:250 / 1개',
#         '모델명:접이식스마트박스퍼플 / 1개'], dtype=object),
#  array(['색상:포슬린(0) / 1개', '1개'], dtype=object),
#  array(['색상:블랙|사이즈:37 / 1개', '색상:그레이|사이즈:37 / 1개', '선택:M브런치크랜베리100낱봉 / 1개'],
#        dtype=object),
#  array(['사이즈:090 / 1개', '사이즈:070 / 1개'], dtype=object),
#  array(['사이즈:블랙 남성-260 / 1개'], dtype=object),
#  array(['색상:BE|사이즈:105(XL) / 2개', '색상:BE|사이즈:100(L) / 2개',
#         '색상:SK|사이즈:100(L) / 1개', '색상:SK|사이즈:105(XL) / 2개',
#         '색상:PGN|사이즈:95(M) / 1개', '색상:네이비(NV)|사이즈:110(XXL) / 1개',
#         '색상:SK|사이즈:95(M) / 1개', '색상:71헌터그린|사이즈:M / 1개',
#         '색상:71헌터그린|사이즈:XL / 3개', '색상:DGN|사이즈:110(XXL) / 1개',
#         '색상:BK|사이즈:1(FREE) / 1개', '색상:선택01_BL|사이즈:110(XXL) / 1개',
#         '색상:화이트|브라사이즈:75A|팬티사이즈:95 / 1개'], dtype=object),
#  array(['사이즈:FREE / 1개', '사이즈:0TU / 1개', '사이즈:0TU / 2개', '1개',
#         '사이즈:220 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:네이비(B60)|사이즈:10(140) / 1개', '색상:PK|사이즈:130 / 1개',
#         '사이즈:150 / 1개', '색상:PK|사이즈:140 / 1개'], dtype=object),
#  array(['색상:블루|사이즈:FREE / 1개', '색상:네이비(277)|사이즈:L(005) / 1개',
#         '색상:블루(246)|사이즈:L(005) / 1개', '색상/사이즈:Navy/130 / 1개',
#         '색상/사이즈:Melange Grey/130 / 1개', '색상/사이즈:Black/140 / 1개',
#         'color:그린|size:FREE / 1개', '색상/사이즈:베이지/FF / 1개',
#         '번호:01 마법 ver.102-연청-L / 1개', '2개', '색상:076(블랙)|사이즈:M(004) / 1개',
#         'color:블랙|size:FREE / 1개', '색상:M그레이|사이즈:150 / 1개',
#         '색상:네이비|사이즈:150 / 1개',
#         'COLOR/SIZE:[FST-05106] 블랙/6 (66반 ~ 77) / 1개',
#         'COLOR/SIZE:[ADCP-02906] 블랙/6 (66반 ~ 77) / 2개',
#         '색상:네이비(275)|사이즈:L(005) / 1개', '색상:핑크|사이즈:FREE / 1개',
#         '색상:247(네이비)|사이즈:M(004) / 1개', '색상/사이즈:Dark Blue/130 / 1개',
#         '색상:네이비(275)|사이즈:M(004) / 1개', '플랩캡/색상_사이즈:PCC_103/팝바우_코발트 / 1개',
#         '색상:옐로우(YE)|사이즈:F / 1개', '색상:화이트|사이즈:F / 1개', '1개',
#         '품번:04.SUPE_S000010_933_|사이즈:270 / 1개',
#         '색상:(E1)L/Beige|사이즈:56(S) / 1개', '색상:911(BUX)|직접입력2:245 / 1개',
#         '색상:236(블루)|사이즈:M(004) / 1개', 'COLOR-SIZE:소라(sky blue)-FREE / 1개',
#         '색상:화이트(001)|사이즈:M(004) / 1개', '상품선택:N-바디 에멀젼 310ml x2개 / 1개',
#         '색상:그린|사이즈:FREE / 1개', '색상:300(WHITE)|사이즈:66 / 1개',
#         'COLOR-SIZE:옐로우(Yellow)-FREE / 1개', '색상:COS|사이즈_사이즈:66 / 1개',
#         '색상:(64)옐로우|사이즈:FF / 1개',
#         'COLOR/SIZE:[OFST-06712] 핑크/6 (66반 ~ 77) / 1개', '색상:카키|사이즈:F / 1개',
#         '색상:블랙|사이즈:F / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:400 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상선택:네이비|사이즈선택:2XL / 1개', '색상:GRE(그린)|사이즈:110(XXL) / 1개',
#         '색상:LB|사이즈:95 / 1개', '색상:BK|사이즈:100 / 1개'], dtype=object),
#  array(['사이즈:150 / 1개'], dtype=object),
#  array(['사이즈:250 / 1개'], dtype=object),
#  array(['사이즈:26_TFSS008244026 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:화이트|사이즈:105 / 1개', '1개', '필수선택사항:피셔 클래식 러닝홈_W4713 / 1개',
#         '색상:블루|사이즈:105 / 1개', '색상:화이트|사이즈:S(1~12m) / 1개',
#         '색상:MGR(멜라지그레이)|사이즈:88(35) / 1개', '2개', '선택:(코니스) 에듀테이블 / 1개',
#         '색상:아이보리|사이즈:S(6~12m) / 1개', '품목:블루(1552139) / 1개',
#         '색상:베이지|사이즈:48(6~12m) / 1개', '옵션:정쟁반(소) / 2개', '색상:초코 / 1개',
#         '필수선택:(DR)손가락 실리콘 칫솔 / 1개', '색상:핑크베이지|사이즈:S(6~12m) / 1개'],
#        dtype=object),
#  array(['1개', '색상/사이즈:블랙/15호 / 1개'], dtype=object),
#  array(['색상:49네이비|사이즈:073 / 1개', '색상:39블랙|사이즈:073 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:20 / 1개', '1개'], dtype=object),
#  array(['색상:프리저빙 패션 / 2개', '색상:프리저빙 패션 / 1개'], dtype=object),
#  array(['색상선택:화이트|사이즈선택:Medium / 1개', '색상선택:단일색상|사이즈선택:Small / 1개'],
#        dtype=object),
#  array(['사이즈:085 / 1개'], dtype=object),
#  array(['3개', '2개', '1개'], dtype=object),
#  array(['색상:85|사이즈:M / 1개', '색상:04|사이즈:M / 1개', '색상:01|사이즈:M / 1개',
#         '색상:11|사이즈:L / 1개', '색상:09|사이즈:L / 1개', '색상:10|사이즈:L / 1개',
#         '색상:02|사이즈:M / 1개'], dtype=object),
#  array(['타입:세트 / 1개', '1개', '제주 삼다수 500ml*20:제주 삼다수 500ml*20 / 2개'],
#        dtype=object),
#  array(['2개', '색상/사이즈:블루/FREE / 1개', '직접입력1:BM24_06 딥 / 1개'], dtype=object),
#  array(['색상:CBKG_Carbon-Black|사이즈:FR / 1개',
#         '색상:RRDG_Racing-Red|사이즈:FR / 1개', '상품명:E_에센셜 오드트왈렛 30ML / 1개',
#         '색상:MKBG_Mykonos-Blue|사이즈:092 / 1개',
#         '색상:CBKG_Carbon-Black|사이즈:265 / 1개', '선택사항:22호 / 4개',
#         '색상:블랙5|사이즈:100 / 1개', '색상:화이트 M/L_TH8FTMSK / 1개',
#         '색상:WHTE_white|사이즈:56 / 1개', '색상:SWTG_STAR-WHITE|사이즈:105 / 1개',
#         '사이즈:092 / 1개', '사이즈:L(LARGE) / 1개', '선택:그레이 / 1개',
#         '색상:MKBL_Milty-Blue|사이즈:L / 1개', '색상:PINK|사이즈:145 / 1개',
#         '품번:599-012|사이즈:240(UK5) / 1개'], dtype=object),
#  array(['컬러:세인트모리츠 / 1개', '컬러:핀란드 / 1개'], dtype=object),
#  array(['색상:03|사이즈:S / 1개'], dtype=object),
#  array(['선택:그린티 / 1개', '선택:샌달우드앤자스민 / 1개'], dtype=object),
#  array(['기본:기본 / 1개', '타입:톤업 쿠션 세트 (리필+케이스) / 1개'], dtype=object),
#  array(['타입:오리지널 / 1개', '1개'], dtype=object),
#  array(['상품명:TT32_비버리힐즈폴로클럽0174트렁크|사이즈:105 / 1개',
#         '선택1:340 핫 루머-엣지 크림|선택2:310 바 레드-울트라 매트 / 1개',
#         '사이즈:M(145)|색상:레드 / 1개', '색상:NA|사이즈:210mm / 1개',
#         '색상:INA(네이비)|사이즈:130 / 1개', '사이즈:145(L) / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['1개', '색상:블랙|사이즈:66 / 1개', '타입:일반 / 1개', '사이즈:90 / 1개',
#         '상품타입:장안사-H0268-아이보리-3 / 1개', '색상:YEL|사이즈:36-37(230-235mm) / 1개',
#         '상품타입:장안사-H0266-아이보리-3 / 1개', '색상/사이즈:화이트/120호 / 1개',
#         '사이즈:130호 / 1개', '사이즈:46(46cm) / 1개', '사이즈:100 / 3개',
#         '색상:핑크|사이즈:180 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:MGR0_(MGR0)H.-GREY|사이즈:95 / 1개', '색상:50_블루|사이즈:95M / 1개'],
#        dtype=object),
#  array(['사이즈:45x45 / 2개', '타입(커버만):A타입 / 1개', '타입(커버만):B타입 / 1개'],
#        dtype=object),
#  array(['상품명:PCC_004|색상_사이즈:팝덕_네이비 / 1개'], dtype=object),
#  array(['색상:06.(RSET661)브라운|사이즈:75A-90 / 1개',
#         '색상:03.(RSET637)라이트브라운|사이즈:75A-90 / 1개',
#         '상품명:선택02)프라미스 3차 패키지|사이즈:75A/90 / 1개'], dtype=object),
#  array(['색상:BLACK|사이즈:200mm / 1개', '색상:BLACK|사이즈:210mm / 1개',
#         '색상:PINK|사이즈:210mm / 1개', '색상:09)LS7051아이보리|사이즈:235 / 1개',
#         '색상:08)LS7036네이비|사이즈:235 / 1개', '색상:NT227(남.네이비)|사이즈:L(100) / 1개',
#         '색상:NT228(남.블랙)|사이즈:M(95) / 1개', '색상:06)LS7024베이지|사이즈:235 / 1개'],
#        dtype=object),
#  array(['색상/사이즈:사이즈/M / 1개', '사이즈:095 / 1개', '사이즈:110 / 1개',
#         '색상:남색|사이즈:95 / 1개', '1개', '색상:핑크 / 1개'], dtype=object),
#  array(['SIZE:95(66) / 1개', '색상:검정색|Size:105 / 1개',
#         'COLOR:네이비|SIZE:58 / 1개'], dtype=object),
#  array(['색상/사이즈:64|로얄블루|/95 / 1개', '색상:차콜그레이|사이즈:95 / 1개',
#         '색상/사이즈:10|화이트|/100 / 1개', '상품선택:보니비노 70파이 극세사 면분첩 / 8개', '1개',
#         '색상:A형/ 화이트도어+화이트손잡이+화이트몸통(A) / 1개', '선택:브라질너트(페루산)500g*3봉 / 1개',
#         '색상:다크블루(DBL)|사이즈:95 / 1개', '선택:브라질너트(페루산)500gx2봉 / 2개',
#         '선택:그루 프리미엄 화이트 27M 30롤x3 / 1개', '색상:KA4W0WKX050610|사이즈:FREE / 2개',
#         '색상:03.(1DH5362)아네타|사이즈:85A / 2개',
#         '색상:04.(1DH5363)아네타|사이즈:85A / 2개', '색상:10.아이보리|사이즈:95(XL) / 6개',
#         '색상:화이트(100)|사이즈:95 / 1개', '색상:화이트|사이즈:95 / 1개',
#         '선택하세요:구운아몬드 400g+400g 총800g / 1개', '옵션:02 5BR 딥보르도로즈 2개 / 2개',
#         '색상:56(네이비)|사이즈:73 / 1개'], dtype=object),
#  array(['상품명:반팔원피스_B02_FREE / 1개',
#         '스푸니:오렌지&블루|턱받이1P:피치1P|어도러볼:피치|프리저포드:피치 / 1개',
#         '상품명:반팔원피스_B07_FREE / 1개', '1개', '상품명:반팔원피스_B03_FREE / 1개',
#         '상품명:반팔원피스_B04_FREE / 1개', '사이즈:100 / 1개', '2개',
#         '모델명:BLSTMM-BRD-071 / 1개', '색상:네이비|사이즈:105(88) / 1개'], dtype=object),
#  array(['사이즈:18M(90) / 1개', '1개', '2개', '색상:02.Bubble Bath-연핑크 / 1개',
#         '색상:PK|사이즈:90 / 1개', '색상:데님(블루)|사이즈:120 / 1개', '선택사항:각인_영문 / 1개'],
#        dtype=object),
#  array(['1개', '색상:01.실버|사이즈:EU21(134mm) / 1개'], dtype=object),
#  array(['색상:DGY(다크그레이)|사이즈:085 / 1개', '색상:그레이|사이즈:70(M) / 1개'],
#        dtype=object),
#  array(['품번/컬러:MI2K9407 WHT|사이즈:L / 1개',
#         '옵션1:팬츠-LDU7MRP951NG|상하 사이즈:L-L / 1개',
#         '품번 컬러:YI2K9407 BLK|사이즈:S / 1개'], dtype=object),
#  array(['1개', '색상:흰색|Size:064 / 1개'], dtype=object),
#  array(['모델명:올나이터 / 1개'], dtype=object),
#  array(['색상:LI8SCA04.그레이|사이즈:L / 1개'], dtype=object),
#  array(['사이즈:220 / 1개'], dtype=object),
#  array(['1개', '선택:노랑 S / 1개', '선택:단일품목 / 1개', '품명색상:스퀘어동물나염손수건_10매입 / 2개',
#         '품명색상:달퐁패밀리엠보손수건_10매입 블루 / 1개', '옵션선택:빅베어SET / 1개'], dtype=object),
#  array(['색상:블랙 / 1개', '1개', '상품명:하이스카이 스마트폰 암밴드/블랙 / 1개',
#         '타입:톤업 쿠션 세트 (리필+케이스) / 1개', '색상:크림|사이즈:66 / 1개', '색상:라이트 / 1개',
#         '색상1:베어 팝시클|색상2:베어 핑크 / 1개', '색상:웜 포슬린(0.5) / 1개'], dtype=object),
#  array(['색상:블랙|사이즈:190 / 1개', '색상:블루|사이즈:220 / 1개',
#         '색상:COBALT BLUE|사이즈:056 / 1개', '색상:COBALT BLUE|사이즈:054 / 1개'],
#        dtype=object),
#  array(['1개'], dtype=object),
#  array(['COLOR:화이트|SIZE:FREE / 1개', 'COLOR:블랙|SIZE:S / 1개',
#         'COLOR:블랙|SIZE:FREE / 1개', '옵션:386521-608|사이즈:(150/9C) / 1개'],
#        dtype=object),
#  array(['색상:BLACK|사이즈:275 / 1개', '색상:멜란지(MG)|사이즈:17(175) / 1개', '1개',
#         '사이즈:80 / 1개', '색상:핑크|사이즈:80 / 1개',
#         '사이즈:17(175)|직접입력1:스카이블루(SB) / 1개'], dtype=object),
#  array(['색상:001(블루)|사이즈:L(005) / 1개', '색상:선택11_BLK|사이즈:L(M) / 1개',
#         '색상:선택08_BLK|사이즈:L(M) / 1개', '색상:022(그레이|사이즈:L(005) / 1개'],
#        dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:화이트 / 1개', '색상:그레이_GR_SG / 1개', '종류선택:타이니소어_카르노 / 1개', '2개',
#         '품번:GAXP112_46|사이즈:001 / 1개', '종류선택:타이니소어_아노말로 / 1개', '1개'],
#        dtype=object),
#  array(['사이즈:100 / 1개'], dtype=object),
#  array(['향기:02.클린솝 / 1개'], dtype=object),
#  array(['색상:화이트/XL|사이즈:필수선택 ◈86650965◈ / 1개', '사이즈:105 / 1개'], dtype=object),
#  array(['색상:분홍베이지색 / 1개', '색상:네이비 / 1개', '색상:네이비(NY) / 1개'], dtype=object),
#  array(['직접입력1:02.18334 면스판 단목 아가일 신사양말 2족세트 / 1개'], dtype=object),
#  array(['1개', '선택:비타민c1000 180정 / 1개'], dtype=object),
#  array(['색상:NY(네이비)|사이즈:FREE / 1개', '색상:네이비(NY)|사이즈:FREE / 1개'],
#        dtype=object),
#  array(['size:6.5 / 1개', 'size:6 / 1개'], dtype=object),
#  array(['(not set)', '상품선택/ETC:버버리 위크앤드 포맨 100ml/ETC'], dtype=object),
#  array(['색상:BLU|사이즈:180 / 1개'], dtype=object),
#  array(['색상:네이비|사이즈:M / 1개', '1개', '모델명:BB8694|사이즈:230 / 1개',
#         '색상:브라운(BR)|사이즈:55 / 1개', '스타일:95053_브라운|사이즈:M(230-235) / 1개'],
#        dtype=object),
#  array(['색상:카키|사이즈:T4 / 1개'], dtype=object),
#  array(['색상:17호 커버 / 2개', '컬러:11.AJM853FG10_NAVY|사이즈:270 / 1개',
#         '사이즈:100 / 1개', '상품명:AC8148 블루|사이즈:160 / 1개',
#         '타입:페이셜 크림 150ml / 1개'], dtype=object),
#  array(['옵션 선택:레드-애디션 2종 세트 3개 +수분크림3개 +증정 / 1개',
#         '옵션 선택:레드-애디션 2종 세트 1개 +증정 / 2개', '2개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['색상:네이비|사이즈:70(66) / 1개'], dtype=object),
#  array(['품번:02.CROCS_11016_07W_|사이즈:240 / 1개', '사이즈:150 / 1개',
#         '색상:네이비|사이즈:155 / 1개'], dtype=object),
#  array(['색상:1호 내추럴 베이지 / 1개', '색상:CC CREAM 10 베쥬 / 1개',
#         '옵션:01 퍼펙트세럼 1+1(증정) / 1개'], dtype=object),
#  array(['사이즈:S (44-55) / 1개'], dtype=object),
#  array(['색상:PALE PINK|사이즈:00M / 1개', '색상:BLACK|사이즈:230 / 2개',
#         '색상:L.PINK|사이즈:105 / 1개', '상품명:셀프 1+1 화이트 240 / 1개',
#         '색상:BLACK|사이즈:230 / 1개', '제품:셀프 190 2장 / 2개',
#         '색상:BLUE|사이즈:00M / 1개', '색상:BLACK|사이즈:00M / 1개',
#         '색상:AQUA|사이즈:280 / 1개', '색상:블루|사이즈:L / 1개', '1개',
#         '색상:NAVY|사이즈:230 / 2개', '색상:NAVY|사이즈:230 / 4개',
#         '색상:BLACK|사이즈:280 / 1개', '색상:OFF WHITE|사이즈:230 / 5개',
#         '색상:GREEN|사이즈:105 / 1개', '색상:CHARCOAL.GREY|사이즈:230 / 5개',
#         '색상:SKYBLUE|사이즈:230 / 1개', '색상:블랙|사이즈:L / 1개',
#         '색상:CHARCOAL.GREY|사이즈:260 / 10개', '색상:그레이|사이즈:L / 1개',
#         '색상:NAVY|사이즈:260 / 5개', '색상:블랙|사이즈:L / 2개',
#         '색상:WHITE|사이즈:260 / 20개', '색상:세피아|사이즈:110. / 4개',
#         '색상:블루|사이즈:L / 2개', '색상:BLACK|사이즈:00S / 1개',
#         '색상:NAVY|사이즈:000 / 1개'], dtype=object),
#  array(['타입:세트 / 1개', '색상:15호 / 1개'], dtype=object),
#  array(['색상:04 TRS058 블랙|사이즈:XL / 1개', '색상:04 TRS058 화이트|사이즈:XL / 1개',
#         '색상:화이트 / 4개', '1개', '색상:BLACK|사이즈:M ◈71239707◈ / 1개',
#         '색상:04 TRS058 화이트|사이즈:L / 1개'], dtype=object),
#  array(['색상:헤링본 발매트_블루그레이 / 1개', '사이즈:100 / 1개', '1개'], dtype=object),
#  array(['색상:네이비|사이즈:95(77) / 1개', '색상:SV(실버)|사이즈:30(230) / 1개', '1개',
#         '색상:I2(아이보리)|사이즈:30(230) / 1개', '상품명:화애락진 / 1개',
#         '색상:네이비46|사이즈:FREE / 1개', '사이즈:230 / 1개'], dtype=object),
#  array(['1개', '색상:스킨|브라사이즈:85B|팬티사이즈:100 / 1개', '옵션:DT-1087GP-DF / 4개',
#         '옵션:DT-1087GP-DK / 4개', '옵션:디너스푼 핑크골드 / 4개'], dtype=object),
#  array(['색상:MU(머스타드)|사이즈:235 / 1개', '색상:BK|사이즈:235 / 1개'], dtype=object),
#  array(['색상:핫핑크옵티컬 / 2개', '사이즈:130|아이템:BS16JP01PK(핑크) / 1개'], dtype=object),
#  array(['옵션1:블루|옵션2:F(55~88) / 1개', '옵션:08 6N 초코브라운 x2 / 1개',
#         '제품선택:핑크로즈 2Lx3개 / 1개'], dtype=object),
#  array(['사이즈:100 / 1개', '뽀로로/패티 입체 스텐젓가락:패티 입체 스텐젓가락 / 1개',
#         '그로미미:교체용 빨대리필(2단계) / 1개', '기본선택:프렌즈양손빨대컵투[토끼] / 1개',
#         '선택:550 12x30M / 2개', '색상:810R-3 12mm알뜰팩 / 1개'], dtype=object),
#  array(['모델:01_AB7DMTS356_그레이|사이즈:100 / 2개',
#         '모델:01_AB7DMJP807_브라운|사이즈:100 / 1개',
#         '모델명:01_AB6DMPT604_NA|사이즈:100 / 1개'], dtype=object),
#  array(['선택:건성 / 1개'], dtype=object),
#  array(['1개', '제품번호:DH4422(네이비)|사이즈:L(100) / 1개'], dtype=object),
#  array(['1개', '상품명:16FC총여아양면내의01|사이즈:80호 / 1개', '사이즈:80호 / 1개'],
#        dtype=object),
#  array(['1개', '스타일및 사이즈:여성TWJSC11(핑크)-95 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['사이즈:036 / 1개'], dtype=object),
#  array(['2개', '옵션:브라운탠 / 1개'], dtype=object),
#  array(['품번:01.FAEI2607_네이비|색상_사이즈:FREE / 1개', '단품:8kg / 1개',
#         '색상:스카이블루(211)|사이즈:M / 1개'], dtype=object),
#  array(['색상:블랙(BK)|사이즈:FREE / 1개', '색상:베이지|사이즈:66 / 1개'], dtype=object),
#  array(['색상:45_FCRG5840F10|사이즈:85 / 1개', '색상:24_FCAG5831E10|사이즈:85 / 1개',
#         '색상:NAVY|사이즈:85 / 1개', '색상:MGREY|사이즈:85 / 1개'], dtype=object),
#  array(['1개'], dtype=object),
#  array(['사이즈:100 / 1개', '색상:블랙|사이즈:FREE(18*31) / 1개',
#         '색상:블랙(BK)|사이즈:100(L) / 1개'], dtype=object),
#  ...]

# %%
train_data3 = list(train.groupby('CLNT_ID')['PD_BRA_NM'].unique())
test_data3 = list(test.groupby('CLNT_ID')['PD_BRA_NM'].unique())
train_data3 # 브랜드
# Out:
# [array(['필립스(PHILIPS)', '쁘리엘르'], dtype=object),
#  array(['퀵실버', '키엘', '레노마수영복', '정관장', '바비브라운'], dtype=object),
#  array(['코데즈컴바인 이너웨어', '크록스'], dtype=object),
#  array(['첨이첨이'], dtype=object),
#  array(['해피프린스', '클립', '테팔', '베베드피노', '갭 키즈'], dtype=object),
#  array(['코디'], dtype=object),
#  array(['올리빙'], dtype=object),
#  array(['아토팜', 'LG전자'], dtype=object),
#  array(['록시땅', '나이키(의류)', '에스티 로더', '오리진스', '아디다스(의류)', '볼빅', '챔프', '나스'],
#        dtype=object),
#  array(['루이까또즈'], dtype=object),
#  array(['아디다스(슈즈)', '마이독스', '한율'], dtype=object),
#  array(['웅진식품'], dtype=object),
#  array(['다이나핏(스포츠)'], dtype=object),
#  array(['러브필', '이반', '트라이'], dtype=object),
#  array(['굿베이스'], dtype=object),
#  array(['엠도씨', '기라로쉬(우양산)', '키플링', '엘르이너웨어'], dtype=object),
#  array(['랩(LAP)', '모니카룸', '도노도노'], dtype=object),
#  array(['헤링본', '디스커버리'], dtype=object),
#  array(['닥터자르트'], dtype=object),
#  array(['지오다노', '블루페페'], dtype=object),
#  array(['앨빈클로'], dtype=object),
#  array(['고아라', '한솔라이프'], dtype=object),
#  array(['엠엘비키즈', '팬콧(키즈)', '롯데칠성', '뉴발란스(키즈)', '롯데칠성몰'], dtype=object),
#  array(['예지미인', '킨도', '드시모네'], dtype=object),
#  array(['종가집', '노스페이스', '에블린', '휠라 슈즈', '체스골프', '에스페소 플러스', '무민(우양산)',
#         '보디가드', '쉬즈미스', '콜맨', '신일', '바로스포츠', '락피쉬(구두)', '에스티듀퐁(셔츠)', '엘칸토',
#         '테팔', '가이타이너', '볼빅', '첨이첨이', '오키즈', '엘르이너웨어', '휠라 키즈', '헤지스(슈즈)',
#         '닥스(셔츠)', '레꼴뜨'], dtype=object),
#  array(['블루종'], dtype=object),
#  array(['밍크뮤', '모니카룸', '블루독'], dtype=object),
#  array(['라코스테스포츠'], dtype=object),
#  array(['행텐주니어'], dtype=object),
#  array(['이니스프리'], dtype=object),
#  array(['까르페티앙', '고공캣'], dtype=object),
#  array(['지오다노'], dtype=object),
#  array(['이니스프리'], dtype=object),
#  array(['리스테린'], dtype=object),
#  array(['화이트', '밀레(ML)', '지오다노', '핀덴', '모니즈', '비너스 자스민', '크리스제이', '정관장',
#         '커스텀에이블', '폴햄', '뉴트로지나', '김나운의 더 키친', '바이빠세', '깨끗한나라', '인디안',
#         '목우촌', '어반프랑'], dtype=object),
#  array(['흄'], dtype=object),
#  array(['세인트블레스', '시디즈'], dtype=object),
#  array(['빌리프', '키엘'], dtype=object),
#  array(['안나앤이브', '포그내'], dtype=object),
#  array(['바비브라운'], dtype=object),
#  array(['아디다스 오리지널', '토박스', '크록스키즈'], dtype=object),
#  array(['트라이엄프', '트라이', '에이비에프지'], dtype=object),
#  array(['아레나(수영복)'], dtype=object),
#  array(['로엠걸즈(아동)', '레노마키즈', '스코노', '오즈키즈(아동)'], dtype=object),
#  array(['고아라'], dtype=object),
#  array(['지오다노', '쁘리엘르', '지지피엑스', '숲'], dtype=object),
#  array(['데상트'], dtype=object),
#  array(['하마'], dtype=object),
#  array(['에코요기'], dtype=object),
#  array(['제이손'], dtype=object),
#  array(['크록스', '나이키', '보니알렉스', '난닝구', '잭앤질'], dtype=object),
#  array(['닥스 키즈', '닥스키즈', '빈폴골프'], dtype=object),
#  array(['밀로앤개비'], dtype=object),
#  array(['웅진식품'], dtype=object),
#  array(['자일로스'], dtype=object),
#  array(['케이투'], dtype=object),
#  array(['에어워크 주니어', '트렉스타', '엠제이키즈'], dtype=object),
#  array(['노스페이스', '노스페이스영', '노스페이스화이트라벨(프리미엄)'], dtype=object),
#  array(['메디힐', '에스티듀퐁(셔츠)'], dtype=object),
#  array(['바이오더마'], dtype=object),
#  array(['엘피지에이'], dtype=object),
#  array(['엠엘비'], dtype=object),
#  array(['ALPHARD'], dtype=object),
#  array(['햇츠온', '아디다스'], dtype=object),
#  array(['아베다'], dtype=object),
#  array(['끌레오'], dtype=object),
#  array(['써스데이아일랜드', '써스데이아일랜드 VIP'], dtype=object),
#  array(['오키즈', '헌트키즈', '아임닭', '유니프랜드', '베베쥬샵', '오끼오', '동물원', '쁘띠뮤', '더나이스',
#         '첨이첨이', '한샘', '도담이', '엔터펫', '앳코너', '퓨리나'], dtype=object),
#  array(['글라스락'], dtype=object),
#  array(['정관장.', '프레드릭콘스탄트(시계)'], dtype=object),
#  array(['매직카펫', '나이키(슈즈)'], dtype=object),
#  array(['스파클'], dtype=object),
#  array(['즙쟁이', '나이키골프'], dtype=object),
#  array(['스와니코코'], dtype=object),
#  array(['크리니크', '케이트', '오리진스'], dtype=object),
#  array(['리틀 그라운드', '유니프랜드'], dtype=object),
#  array(['게스(진)'], dtype=object),
#  array(['스킨푸드', '아토팜', '노블리제', '삐삐롱', '메이비바니', '존슨즈베이비'], dtype=object),
#  array(['폴햄', '행텐', '디올', '이앤씨', '아메리칸투어리스터'], dtype=object),
#  array(['정관장'], dtype=object),
#  array(['빈폴키즈', '앙블랑', '롯데칠성', '나이키'], dtype=object),
#  array(['LG전자', '스틸라'], dtype=object),
#  array(['마더스베이비'], dtype=object),
#  array(['쥬맥스', '매그제이(MAGJAY)', '니코트', '삼다수', '오버톤'], dtype=object),
#  array(['라자가구'], dtype=object),
#  array(['잭앤질', '예스비', '리스트', '모스트', '디스커버리', '아디다스골프', '꾸띠', '언더아머(스포츠)',
#         '헤지스남성'], dtype=object),
#  array(['빌리프', '미쏘', '아벤느', '아티젠'], dtype=object),
#  array(['에어워크', '나이키(의류)'], dtype=object),
#  array(['오젬', '예지미인', '클라이드'], dtype=object),
#  array(['세사'], dtype=object),
#  array(['락앤락'], dtype=object),
#  array(['베이비반즈', '오피스디포', '디즈니', '103886', '비치붐', '104704'], dtype=object),
#  array(['궁중비책', '키엘', '아토팜'], dtype=object),
#  array(['예작(셔츠)'], dtype=object),
#  array(['아디다스(의류)', '제이제이 지고트'], dtype=object),
#  array(['안다르(스포츠)'], dtype=object),
#  array(['메이크업포에버', '프레드페리', '설화수'], dtype=object),
#  array(['로엠걸즈(아동)', '핑크시슬리'], dtype=object),
#  array(['크로커다일 레이디', '첨이첨이'], dtype=object),
#  array(['나이키'], dtype=object),
#  array(['로티캠프', '패스트캠프'], dtype=object),
#  array(['토리버치', '아메리칸이글(진)'], dtype=object),
#  array(['블루독', '빈', '티파니'], dtype=object),
#  array(['로얄캐닌', '미치코런던'], dtype=object),
#  array(['헤지스남성', '베네통'], dtype=object),
#  array(['쉬즈홈', '문중김치'], dtype=object),
#  array(['에블린'], dtype=object),
#  array(['제이제이 지고트', '올리비아로렌', '프리메라'], dtype=object),
#  array(['아레나(수영복)'], dtype=object),
#  array(['슈미즈'], dtype=object),
#  array(['키플링', '헤지스'], dtype=object),
#  array(['엔유씨'], dtype=object),
#  array(['한율'], dtype=object),
#  array(['고내추럴'], dtype=object),
#  array(['엘르이너웨어', '닥터자르트'], dtype=object),
#  array(['차앤박'], dtype=object),
#  array(['비엘르', '씨제이프레시웨이', '이케아', '에이비에프지', '히로'], dtype=object),
#  array(['이앤씨', '키스미', '헤지스'], dtype=object),
#  array(['지오다노', '나이키', '헤지스남성', '미즈노', '세이코(시계)'], dtype=object),
#  array(['헤이미쉬홈', '베스트리빙'], dtype=object),
#  array(['엘라고'], dtype=object),
#  array(['영실업', '휠라 키즈', '샤워플러스', '빈', '트로비스', '소다스쿨', '베네통키즈', '아모스',
#         '정관장'], dtype=object),
#  array(['센트룸(식품)'], dtype=object),
#  array(['입생로랑', '플레이키즈프로', '록시'], dtype=object),
#  array(['폴햄', '오리진스', '휠라', '베이직하우스'], dtype=object),
#  array(['나이키(슈즈)'], dtype=object),
#  array(['프로레나타'], dtype=object),
#  array(['아디다스', '아람', '가구느낌'], dtype=object),
#  array(['슈에무라', '에스쁘아', '오랄비', '무한타올'], dtype=object),
#  array(['키엘'], dtype=object),
#  array(['파코라반 베이비', '헨켈', '헤라', '미쏘', '첨이첨이', '갭 키즈', '크록스', '오끼오', '사노산',
#         '삼성전자', '오랄비', '아디다스(슈즈)', '스파오', '크록스(키즈)', '헤지스남성', '오후(아동)'],
#        dtype=object),
#  array(['톰앤래빗'], dtype=object),
#  array(['록시땅'], dtype=object),
#  array(['컴포트랩'], dtype=object),
#  array(['폴앤조(명품화장품)'], dtype=object),
#  array(['코데즈컴바인 이너웨어'], dtype=object),
#  array(['살레와(아웃도어)', '블랙야크', '체이스컬트', '흄'], dtype=object),
#  array(['제이제이나인', '핑크시슬리', '쿠키세븐', '티비제이', '베네피트'], dtype=object),
#  array(['제이알주니어', '크록스', '트라이'], dtype=object),
#  array(['헹켈'], dtype=object),
#  array(['무한타올', '램버트케이(애완)'], dtype=object),
#  array(['비앤드', '디올', '바보사랑', '윈트라', '로레알(백)', '센카', '제이디엑스', '마몽드', '프레시팝'],
#        dtype=object),
#  array(['HONG SHOT', '쿤달', '22XX', '플라잉타이거코펜하겐', '세이프레스트'], dtype=object),
#  array(['정관장', '헤지스남성', '트라이엄프', '엠엘비키즈', '라파클럽', '바투카'], dtype=object),
#  array(['아이오페'], dtype=object),
#  array(['마이메리키즈', '듀오락', '캠퍼(슈즈)', '빈', '배럴', '알로봇'], dtype=object),
#  array(['롯데칠성몰'], dtype=object),
#  array(['크록스키즈', '이정섭본가김치'], dtype=object),
#  array(['지오다노'], dtype=object),
#  array(['에이치커넥트'], dtype=object),
#  array(['정관장', 'LG전자'], dtype=object),
#  array(['스와니코코', '아이소이'], dtype=object),
#  array(['메르베'], dtype=object),
#  array(['엘르이너웨어'], dtype=object),
#  array(['스케쳐스'], dtype=object),
#  array(['탐나나', '아디다스 오리지널', '라인프렌즈', '화랑고무', '바보사랑', '리바이스', '아디다스(퍼포먼스)',
#         '원더브라', '포에버21', '타미진', '제이핑크', '스튜디오화이트', '피그먼트', '오니츠카타이거(J)',
#         '덴티스테'], dtype=object),
#  array(['티비제이', '제이제이 지고트', '테이트'], dtype=object),
#  array(['엑셀시오르(스포츠)', '질레트'], dtype=object),
#  array(['밴브루'], dtype=object),
#  array(['키엘'], dtype=object),
#  array(['블레스네이처', '지오필로우', '꿈비'], dtype=object),
#  array(['배스킨라빈스31'], dtype=object),
#  array(['비자', '자크라디'], dtype=object),
#  array(['블루독', '렉켄'], dtype=object),
#  array(['헬렌스타인', '푸고'], dtype=object),
#  array(['라코스테(의류)'], dtype=object),
#  array(['크록스', '헤라'], dtype=object),
#  array(['로렌스'], dtype=object),
#  array(['나스', '휠라(프리미엄)', '아디다스(슈즈)', '설화수', '버켄스탁', '나이키', '나이키(슈즈)',
#         '투쿨포스쿨', '베네피트', '리복', '반스', '아디다스 오리지널', '마티덤', '바나브', '휠라 슈즈'],
#        dtype=object),
#  array(['피핀', '시크폭스', '슈에무라', '난닝구', '마요', '버커루'], dtype=object),
#  array(['조 말론 런던(Jo MaloneLondon)', '코치(잡화)', '나스'], dtype=object),
#  array(['XEEON', '캘러웨이', '입생로랑', '라코스테(의류)', 'AHC', '언더아머(스포츠)', '더말로지카',
#         '피지오겔', '키엘', '도담이', '안지크', '메종블랑쉬', '토마톰스', '메디플라워', '미스터펑',
#         '텐바이텐'], dtype=object),
#  array(['스위스런', '올리빙', '레노마수영복'], dtype=object),
#  array(['SK-II'], dtype=object),
#  array(['셀덴(아동)', '치크(키즈)', '폴앤폴리', '플레이몰', '유라비', '순천모다', '아이빈', '트윈키즈',
#         '밤비노'], dtype=object),
#  array(['샤넬', '비클리프', '쿠키세븐', '앳코너', '디올'], dtype=object),
#  array(['정관장'], dtype=object),
#  array(['카밀', '닥터아토', '스파클', '스킨핏'], dtype=object),
#  array(['피지오겔', 'VDL'], dtype=object),
#  array(['밀레', '르까프', '헤드'], dtype=object),
#  array(['몬데인(시계)'], dtype=object),
#  array(['럭센스', '비비안 블루비비', '피에르가르뎅(여성)', '닥스(손수건)', '엠씨', '올리비아로렌',
#         '레노마레이디스', '노블리제', '리스트'], dtype=object),
#  array(['지오다노', '르네휘테르', '바비브라운'], dtype=object),
#  array(['나이키', '아디다스', '나이키(의류)'], dtype=object),
#  array(['메트로시티(주얼리)', '캉골'], dtype=object),
#  array(['밀로앤개비'], dtype=object),
#  array(['솔로몬샵', '락앤락', '글라스락'], dtype=object),
#  array(['케네스레이디'], dtype=object),
#  array(['쉬즈미스', '미니멈', '쥬시쥬디', '엠제이키즈', '비키', '크록스', '리스트', '엠케이데코',
#         '에고이스트', '헤지스남성', '지니킴(슈즈)', '테팔', '지컷', '리스테린', '세인트스코트',
#         '제이제이지고트', '팬콧(키즈)', '잇미샤', '나이스클랍', '아디다스(의류)', '메종피치', '엘르(양말)'],
#        dtype=object),
#  array(['지니킴(슈즈)', '클라란스', 'LG전자', '에스티 로더', '페라가모(향수)', '타미진', '입생로랑'],
#        dtype=object),
#  array(['게스(진유니)', '게스(진)'], dtype=object),
#  array(['웨스트우드', '자유공간', '리바이스키즈', '에뛰드하우스', '아이오페', '노스페이스(TNF)'],
#        dtype=object),
#  array(['블랙야크(키즈)', '머렐(레저)', '마모트'], dtype=object),
#  array(['베네통키즈', '휠라 키즈', '나이키', '쿠기(수영복)', '크록스'], dtype=object),
#  array(['프랜치캣', '헬로키티', '보리보리', '갭 키즈'], dtype=object),
#  array(['DHC'], dtype=object),
#  array(['정관장', '탑텐'], dtype=object),
#  array(['임블리(imvely)', '데일리원'], dtype=object),
#  array(['올삭스'], dtype=object),
#  array(['세인트제임스', '빈폴', '엠엘비', '나이키'], dtype=object),
#  array(['록시땅'], dtype=object),
#  array(['닥터아토', '싸이닉'], dtype=object),
#  array(['SK-II', '풀무원', '설화수', '잭앤질', '바바라(슈즈)'], dtype=object),
#  array(['키엘'], dtype=object),
#  array(['퀵실버'], dtype=object),
#  array(['에이엔에프(펫)'], dtype=object),
#  array(['대상웰라이프'], dtype=object),
#  array(['써스데이아일랜드', '하루메이비', '잠뱅이', '이아소', '레코브(여성의류)', '엘록'], dtype=object),
#  array(['코렐코디네이츠'], dtype=object),
#  array(['UGG', '시크릿키', '씨', '고세', '가버(구두)', '스텔라 맥카트니', '뮤즈바이로즈', '바이오더마',
#         '시에로', '도호(여성의류)', '비키', '제니코코', '러비더빅', '렌지메이트', '라셀렌',
#         '이자벨마랑(패션잡화)', '안지크', '온더바디', '클래식패브릭', '지지피엑스', '이앤씨', '1861891',
#         '1870615', '1862300', '보니스팍스', '와이케이편집샵', '보웰', '벨라로사', '고스트리퍼블릭',
#         '보슈아', '꼬달리', '잭앤질', '비지트인뉴욕', '먼싱웨어'], dtype=object),
#  array(['설화수'], dtype=object),
#  array(['코모도스퀘어'], dtype=object),
#  array(['시루콧토'], dtype=object),
#  array(['락앤락', '스너글'], dtype=object),
#  array(['헤지스남성', '투쿨포스쿨', '라코스테(여성)', '리복'], dtype=object),
#  array(['아디다스 오리지날', '푸마 바디웨어', '오휘', '뉴발란스(의류)', '데상트'], dtype=object),
#  array(['메트로시티 우양산', '바이네르(여성화)'], dtype=object),
#  array(['모니카룸', '레노마수영복'], dtype=object),
#  array(['세이프레스트'], dtype=object),
#  array(['alaroo'], dtype=object),
#  array(['로레타', '스퍼', '아이홈'], dtype=object),
#  array(['컬리수'], dtype=object),
#  array(['나이키수영복'], dtype=object),
#  array(['르니앤맥코이(여성)'], dtype=object),
#  array(['캘빈클라인언더웨어', '리바이스(바디웨어)'], dtype=object),
#  array(['비너스 아르보', '비타민뱅크', '블루독베이비', '휘슬러', '라푸마', '보타니컬테라피', '나이키',
#         '올리비에스클로젯', '난닝구', '토마토팩토리', '노스페이스영'], dtype=object),
#  array(['보타니컬테라피', '리첼', '그로미미', '블레스네이처', '도블레', '지에스25'], dtype=object),
#  array(['슈에무라', '바비브라운', '랑콤'], dtype=object),
#  array(['오키즈', '바비브라운', '트라이', '버켄스탁', '투미(가방)', '아베다', '키엘', '나이키(슈즈)'],
#        dtype=object),
#  array(['앳코너'], dtype=object),
#  array(['빌리프', '랩시리즈'], dtype=object),
#  array(['닥스레이디스', '멜본', '앳코너', '캐스키드슨(잡화)', '레노마키즈', '아이닉스', '락포트(여성화)',
#         '바보사랑', '돌체구스토', '아이르', '입생로랑'], dtype=object),
#  array(['박홍근'], dtype=object),
#  array(['올삭스'], dtype=object),
#  array(['리뽀(가방)', '메이크업포에버'], dtype=object),
#  array(['마리끌레르', '지오다노', '스킨푸드', '헤지스남성', '키친아트', '리바트 이즈마인', '글램공감',
#         '네이처드림', '데이앤', '체리코코', '써스데이아일랜드', '글램디', '슈펜', '나이키(슈즈)',
#         '스킨푸드(명품화장품)', '솔로이스트', '바보사랑', '풀무원', '이나프', '스킨푸드(화장품)', '미쏘',
#         '엘리자벳', '스텐피아', '스위브', '스파오', '디어제인', '스토피아', '닥터크리너', '샤바스',
#         '샤워플러스', '컴포트랩', '지지피엑스', '엘르', '스타일티바', '이니스프리', '까사미아',
#         '카카오 프렌즈', '탑온탑', '오에스티', '질바이질스튜어트(셔츠)', '핑크시슬리', '벨리불리', '모노토노',
#         '분홍코끼리', '오조크', '순수식품', '실리만', '버커루', '아이정', '피핀', '아이더', '닥터지',
#         '니코', '창신리빙', '헤드', '피턴진', '스토브몬', '가쯔', '에보니아', '피플펫', '디베아',
#         '토마톰스', '컬쳐스타'], dtype=object),
#  array(['프로스펙스'], dtype=object),
#  array(['컨택유', '핑크시슬리', '필립스(PHILIPS)'], dtype=object),
#  array(['로라메르시에'], dtype=object),
#  array(['닥스ACC'], dtype=object),
#  array(['헤지스 키즈', '헤지스남성', '유지아이지', '블루독베이비', '나이키 키즈'], dtype=object),
#  array(['베이비반즈', '유라비'], dtype=object),
#  array(['롯데월드'], dtype=object),
#  array(['바비브라운', '이솝', '로라 메르시에', '크리니크', '나이키(슈즈)', '나이키'], dtype=object),
#  array(['밀로앤개비', '첨이첨이', '이브자리', '에티튜드', '푸고', '밍크뮤', '나이키', '아디다스키즈(아동)'],
#        dtype=object),
#  array(['홀리카홀리카', '카시오', '가쯔'], dtype=object),
#  array(['돌체구스토'], dtype=object),
#  array(['로얄알버트'], dtype=object),
#  array(['맥', '올리비아로렌', '입생로랑'], dtype=object),
#  array(['삼성전자', '에스티 로더'], dtype=object),
#  array(['헤라', '세노비스', '엘라고', '나스'], dtype=object),
#  array(['케즈', '캉골'], dtype=object),
#  array(['오에스티', '해피프린스', '코니테일', '에이치커넥트', '달퐁', '로엠'], dtype=object),
#  array(['알엠케이', '입생로랑', '나스', '맥', '프리메라', '깨끗한나라', '조르지오 아르마니', '디올',
#         '바비브라운', '메이크업포에버', '랑콤', '로라 메르시에', '어딕션(화장품)', '겔랑'],
#        dtype=object),
#  array(['폴햄', '가이아', '입생로랑', '가이아코퍼레이션(유아)', '삼성전자', '스쿳앤라이드', '랑방', '미소페'],
#        dtype=object),
#  array(['질스튜어트(우양산)'], dtype=object),
#  array(['베어파우(슈즈)', '크록스키즈'], dtype=object),
#  array(['언더아머(백)'], dtype=object),
#  array(['맥'], dtype=object),
#  array(['블루독'], dtype=object),
#  array(['지오다노', '타미진'], dtype=object),
#  array(['리버사이드호텔'], dtype=object),
#  array(['리스트', '지오다노'], dtype=object),
#  array(['더뷰티갤러리', '르까프', '파파야', '랩', '케이스위스', '아디다스', '아디다스(슈즈)',
#         '까르뜨블랑슈남성', '타미진', '쉬즈미스', '엘칸토', '나이키골프', '클라이드', '스테파넬',
#         '코치(잡화)', '프룹스'], dtype=object),
#  array(['락포트(여성화)'], dtype=object),
#  array(['나이키수영복'], dtype=object),
#  array(['르까프', '질바이질스튜어트(셔츠)', '스케쳐스'], dtype=object),
#  array(['레노마키즈', '헤지스키즈', '블루독'], dtype=object),
#  array(['아디다스(의류)'], dtype=object),
#  array(['해태음료', '남양유업', '풀무원', '웅진식품'], dtype=object),
#  array(['아미마켓', '고세', '데일리슈', '비클리프'], dtype=object),
#  array(['올삭스', '이종임 김치', '풀무원', '스타일리스'], dtype=object),
#  array(['설화수'], dtype=object),
#  array(['코디갤러리 바이 에스티코'], dtype=object),
#  array(['에스티듀퐁(셔츠)'], dtype=object),
#  array(['써스데이아일랜드', '케이스위스', '나스'], dtype=object),
#  array(['SK-II'], dtype=object),
#  array(['로엠', '행텐', '엔젤비닷'], dtype=object),
#  array(['글라스터'], dtype=object),
#  array(['에스쁘아'], dtype=object),
#  array(['한경희생활과학'], dtype=object),
#  array(['까스텔바작골프', '피스탑', '비비안 로즈버드', '이자녹스(화장품)', '헤라', '수려한',
#         'JM스포츠/자마골프'], dtype=object),
#  array(['로로텐'], dtype=object),
#  array(['나이키'], dtype=object),
#  array(['불가리', '불가리 향수'], dtype=object),
#  array(['스코노', '비즈제이', '스포디노', '지지피엑스', '비타민뱅크', '케네스 레이디', '스퍼', '디데무',
#         '아디다스(의류)'], dtype=object),
#  array(['바보사랑', '네추럴코어'], dtype=object),
#  array(['엘리자베스아덴'], dtype=object),
#  array(['아디다스키즈(아동)'], dtype=object),
#  array(['세컨스킨'], dtype=object),
#  array(['애경'], dtype=object),
#  array(['엘라고'], dtype=object),
#  array(['에스티 로더', '프리메라'], dtype=object),
#  array(['씨', '크록스', '린(의류)', '톰앤래빗', '플라스틱아일랜드스토리', '크록스(키즈)'],
#        dtype=object),
#  array(['롭스'], dtype=object),
#  array(['레노마(셔츠)'], dtype=object),
#  array(['스퍼', '레코브(여성의류)'], dtype=object),
#  array(['바보사랑'], dtype=object),
#  array(['뉴발란스(키즈)'], dtype=object),
#  array(['아디다스 오리지널'], dtype=object),
#  array(['컬리수', '타요더리틀버스(아동)', '맥끌라니'], dtype=object),
#  array(['에트로', '아수스', '슈에무라'], dtype=object),
#  array(['스코홈'], dtype=object),
#  array(['헤지스남성'], dtype=object),
#  array(['나이키골프', '게스(진유니)', '탐스', '포커스', '반스', '나이키(슈즈)', '안나루스'],
#        dtype=object),
#  array(['레노마(셔츠)', '꼬지비', '삐삐롱'], dtype=object),
#  array(['지오다노', '에이치커넥트'], dtype=object),
#  array(['참존', '에드윈', '버디', '엘지생활건강', '베리떼'], dtype=object),
#  array(['니', '토마고'], dtype=object),
#  array(['아이오페'], dtype=object),
#  array(['스타벅스'], dtype=object),
#  array(['보리보리', '니베아', '피닉스', '크리스제이', '쓰리엠', '바보사랑', '아트박스', '에프알제이',
#         '미쏘', '아레나(수영복)', '게스(진유니)', '댑 코리아', '창신리빙', '홈스웰', '노스페이스영',
#         '밥스누', '에뛰드하우스', '피에르가르뎅(여성)', '닥스(우양산)', '닥스(여성화)', '텐바이텐', '은성',
#         '레노마수영복', '한샘', '컴포트랩'], dtype=object),
#  array(['밥스누', '스케쳐스', '샤트렌', '팬콧(키즈)', '나귀사', '크리비아'], dtype=object),
#  array(['에이치커넥트'], dtype=object),
#  array(['리스트', '매긴', '엠엘비키즈', '플라스틱아일랜드스토리', '엠엘비'], dtype=object),
#  array(['지지피엑스'], dtype=object),
#  array(['아이엠지프리미엄(남성)'], dtype=object),
#  array(['매그제이(MAGJAY)', '지오다노', '엘케이트', '페리미츠', '메트로시티(주얼리)', '난닝구', '스위브',
#         '이앤씨', '아디다스', '올리비에스클로젯', '꼬망스(아동)', '에이치커넥트', '뱅뱅', '예스', '빨강호두'],
#        dtype=object),
#  array(['매일', '헤라'], dtype=object),
#  array(['피레스트', '로얄캐닌'], dtype=object),
#  array(['닥터자르트'], dtype=object),
#  array(['베네피트', '샤트렌'], dtype=object),
#  array(['설화수'], dtype=object),
#  array(['챔피언', '컨버스', '시슬리'], dtype=object),
#  array(['랩'], dtype=object),
#  array(['타미힐피거여성', '레노마수영복'], dtype=object),
#  array(['아디다스(의류)', '그로미미'], dtype=object),
#  array(['까스텔바작', '빅토리아앤프렌즈', '코시'], dtype=object),
#  array(['예스', '엠엘비키즈', '비욘드', '뉴발란스(슈즈)'], dtype=object),
#  array(['쁘띠뮤', '에스티홀리데이'], dtype=object),
#  array(['첨이첨이', '오키즈'], dtype=object),
#  array(['타미힐피거', '정관장'], dtype=object),
#  array(['퍼피짱'], dtype=object),
#  array(['로엠걸즈(아동)'], dtype=object),
#  array(['르꼬끄'], dtype=object),
#  array(['궁중비책'], dtype=object),
#  array(['아망떼', '쁘리엘르', '피지오겔', '맥', '상도가구', '더바디샵'], dtype=object),
#  array(['케이투(의류)'], dtype=object),
#  array(['금강제화(여성)', '퍼스트랩'], dtype=object),
#  array(['맥', '엘라고', '소보제화'], dtype=object),
#  array(['씨제이제일제당'], dtype=object),
#  array(['한미', '비스비바', '더바디샵'], dtype=object),
#  array(['베베숲', '펫츠맘마'], dtype=object),
#  array(['블랙야크(키즈)', '노스페이스', '벨라홈', '나이키(슈즈)', '네파'], dtype=object),
#  array(['메디힐'], dtype=object),
#  array(['아디다스 오리지날'], dtype=object),
#  array(['보르미올리'], dtype=object),
#  array(['아베다'], dtype=object),
#  array(['어반디케이'], dtype=object),
#  array(['케이스위스', '레노마(셔츠)', '꼬망스(아동)', '헨리코튼', '엘르이너웨어', '디스커버리', '엠엘비'],
#        dtype=object),
#  array(['테이트', '탑텐', '이화에스엠피', '캉골', '케이스위스', '에이지그레이', '내셔널지오그래픽(남성)'],
#        dtype=object),
#  array(['롯데칠성'], dtype=object),
#  array(['코벳블랑', '르샵'], dtype=object),
#  array(['정관장'], dtype=object),
#  array(['키스미', '리엔', '애플', '뉴트로지나', '키친플라워', '아베다', '정관장', '네이처리퍼블릭',
#         '아로마티카', '입큰', '플러스마이너스제로(가전)'], dtype=object),
#  array(['섹시쿠키'], dtype=object),
#  array(['베이직하우스', '체이스컬트'], dtype=object),
#  array(['엘르이너웨어', '나인(NAIN)', '미쏘', '오조크', '러쉬', '매그제이(MAGJAY)', '헤지스남성',
#         '보슈아', '코인코즈', '조군샵'], dtype=object),
#  array(['키엘', '휘슬러'], dtype=object),
#  array(['핏플랍'], dtype=object),
#  array(['디올'], dtype=object),
#  array(['이브자리', '설화수', '아모레퍼시픽', '쉬즈홈', '슈에무라', '디올', '엘지생활건강', '폴햄',
#         '빈폴레이디스', '비너스', '비비안', '안국건강'], dtype=object),
#  array(['행텐', '보엠', '첨이첨이', '더독'], dtype=object),
#  array(['바비브라운', '랑콤'], dtype=object),
#  array(['에이치커넥트', '빈폴아웃도어'], dtype=object),
#  array(['핑크시슬리', '코스타노바', '써스데이아일랜드', '바보사랑', '타미진(VIP)', '헨리코튼', '지프',
#         '핏플랍', '타미힐피거슈즈(백)'], dtype=object),
#  array(['엠엘비', '탑걸', '리진'], dtype=object),
#  array(['갭 키즈', '블루독'], dtype=object),
#  array(['게스(언더웨어)'], dtype=object),
#  array(['블루독베이비', '타미힐피거여성'], dtype=object),
#  array(['투마루', '일리윤', '스킨푸드'], dtype=object),
#  array(['헬렌스타인'], dtype=object),
#  array(['지오다노'], dtype=object),
#  array(['보그'], dtype=object),
#  array(['데상트'], dtype=object),
#  array(['지라프'], dtype=object),
#  array(['패스트캠프'], dtype=object),
#  array(['리리코스', '랑콤', '크록스', '러쉬', '카피탈리'], dtype=object),
#  array(['디스커버리'], dtype=object),
#  array(['마스터베어', '타거스', '맥컬리', '키친아트', '바바', '에코로바', '에이치옴므', '엑토', '유라이브',
#         '레노버'], dtype=object),
#  array(['헹켈', '나이키(슈즈)', '토마톰스', '데코원', '에덴블리스', '쁘띠쁘랑', '지이크', '아이홈',
#         '팀버랜드(남성)'], dtype=object),
#  array(['세노비스'], dtype=object),
#  array(['리바이스(키즈)', '뉴발란스(키즈)'], dtype=object),
#  array(['라코스테(여성)', '케이에스몰', '로리돌스', '세노비스', '엘르 수영복', '유닉스', '스위브',
#         '크리니크', '엘르이너웨어', '에어워크', '빈폴레이디스', '소프롱', '한경희생활과학', '로지텍', '벨킨',
#         '테리파머'], dtype=object),
#  array(['노스페이스', '노스페이스(TNF)'], dtype=object),
#  array(['비오템', '랩시리즈'], dtype=object),
#  array(['게스(진)', '엠폴햄', '러브앤쇼'], dtype=object),
#  array(['판도라 바이 비비안', '오즈키즈', '모스트', '아디다스 오리지널', '제이코튼', '크리비아', '크록스키즈',
#         '아토팜'], dtype=object),
#  array(['헤지스레이디스'], dtype=object),
#  array(['나이키(의류)', '아디다스(의류)', '나이키수영복', '헤지스남성'], dtype=object),
#  array(['참존', '엘라스틴'], dtype=object),
#  array(['조르지오 아르마니'], dtype=object),
#  array(['시슬리', '데일리라이크', '에프알제이', '이니스프리', '내츄럴어스', '로얄캐닌'], dtype=object),
#  array(['아레나', '레노마수영복'], dtype=object),
#  array(['올가홀푸드'], dtype=object),
#  array(['노스페이스영', '나이키', '아디다스(의류)', '아메리칸투어리스터'], dtype=object),
#  array(['에잇세컨즈'], dtype=object),
#  array(['아디다스(의류)'], dtype=object),
#  array(['리터로봇'], dtype=object),
#  array(['헌트키즈(아동)', '꼬망스(아동)', '보리보리', '아워큐주니어', '모데쯔'], dtype=object),
#  array(['아디다스 키즈', '블루독', '뉴트로지나', '스토어봄', '토마고', '에이엔에프', '깨끗하개', '포트메리온',
#         '데일리케어', '샤프란', '슈쁨', '화신', '리바이스키즈', '콜라겐 홀릭'], dtype=object),
#  array(['맥'], dtype=object),
#  array(['예스비', '제이제이 지고트'], dtype=object),
#  array(['반에이크'], dtype=object),
#  array(['지고트', '송월타올', '종가집', '왕자행거', '시몬스', '락앤락', '네이처리퍼블릭', '파파브로',
#         '타투(선글라스)', '올포유', '김재식 헬스푸드', '롯데칠성몰', '키친플라워', '로티니(LOTINI)',
#         '신일', '리안뉴욕', '일양약품', '한샘', '가쯔', '베스띠벨리', '네이처스 비타민샵', '키친아트',
#         '안국건강'], dtype=object),
#  array(['타미힐피거.'], dtype=object),
#  array(['유리아쥬'], dtype=object),
#  array(['그로미미'], dtype=object),
#  array(['노스페이스키즈(아동)', '네파키즈', '블랙야크(키즈)', '플레이키즈프로'], dtype=object),
#  array(['지오다노'], dtype=object),
#  array(['애플핑크', '소보제화', '빈'], dtype=object),
#  array(['마모트'], dtype=object),
#  array(['올리비아데코'], dtype=object),
#  array(['디스커버리'], dtype=object),
#  array(['아디다스(슈즈)', '아디다스'], dtype=object),
#  array(['스케쳐스'], dtype=object),
#  array(['나스', '알로봇'], dtype=object),
#  array(['로즈버드 바이 비비안', '비오템'], dtype=object),
#  array(['오야니(가방)'], dtype=object),
#  array(['빈폴레이디스', '세컨플로어'], dtype=object),
#  array(['보니알렉스', '컨택유', '타미진', '타미힐피거 칠드런'], dtype=object),
#  array(['이나바', '랑콤'], dtype=object),
#  array(['크록스', '디에스비', '스티유', '코치(잡화)'], dtype=object),
#  array(['한샘'], dtype=object),
#  array(['해피프린스'], dtype=object),
#  array(['캐리어', '뉴트라라이프', '딤채'], dtype=object),
#  array(['조르지오 아르마니', '메이크업포에버', '로라메르시에'], dtype=object),
#  array(['크록스', '휠라 키즈'], dtype=object),
#  array(['러빈코티지'], dtype=object),
#  array(['노스페이스', '쥬맥스', '네파', '설화수'], dtype=object),
#  array(['베이비반즈'], dtype=object),
#  array(['정관장', '보몽드', '엘라고', '비너스', '닥스(셔츠)', '인디안', '청훈', '우리토마토농장'],
#        dtype=object),
#  array(['하나마이'], dtype=object),
#  array(['밀크마일'], dtype=object),
#  array(['나스', '네이처리퍼블릭', '르샤트라1802', '러쉬', '유노하나'], dtype=object),
#  array(['레노마(셔츠)', '카운테스마라(셔츠)'], dtype=object),
#  array(['오드리선', '로라메르시에'], dtype=object),
#  array(['루이까또즈 스카프', '마이카인드', '언더아머(백)', '나이키골프'], dtype=object),
#  array(['킨더스펠'], dtype=object),
#  array(['노스페이스영'], dtype=object),
#  array(['모슬린', '닥스맨', '마담4060', '블랙마틴싯봉'], dtype=object),
#  array(['디올'], dtype=object),
#  array(['자연의품격'], dtype=object),
#  array(['프랜치캣'], dtype=object),
#  array(['스킨푸드', '벨킨', '비오템', '로라 메르시에'], dtype=object),
#  array(['필립스(PHILIPS)', '플로라', '까르뜨블랑슈'], dtype=object),
#  array(['네파키즈', '노스페이스키즈(아동)', '타미힐피거 칠드런'], dtype=object),
#  array(['행텐', '베이직하우스'], dtype=object),
#  array(['밸리걸', '에이비에프지', '보니알렉스'], dtype=object),
#  array(['도로시(쥬얼리)', '나이키골프', '나이키'], dtype=object),
#  array(['트로비스', '아레나(수영복)', '지오다노', '리바디', '후그'], dtype=object),
#  array(['르틸다'], dtype=object),
#  array(['룸나인(여성)', '톰보이', '크로커다일 레이디', '이니스프리'], dtype=object),
#  array(['게스(진)', '라코스테(의류)', '나이스클랍', '숲', '산지애'], dtype=object),
#  array(['에이치커넥트', '스파오', '지오다노'], dtype=object),
#  array(['아레나'], dtype=object),
#  array(['나이키', '키친아트'], dtype=object),
#  array(['케즈', '에이치커넥트'], dtype=object),
#  array(['기라로쉬(우양산)', '엘지생활건강'], dtype=object),
#  array(['디스커버리', '탑텐'], dtype=object),
#  array(['보니타빈백'], dtype=object),
#  array(['슈에무라'], dtype=object),
#  array(['제이제이 지고트'], dtype=object),
#  array(['라인', '꼬달리', '엘르이너웨어', '오가닉맘', '라인어디션', '매그제이(MAGJAY)', '미니멜리사'],
#        dtype=object),
#  array(['그레이스켈리'], dtype=object),
#  array(['에뛰드하우스', '크린랩'], dtype=object),
#  array(['깨끗한나라', '아이오페', '엘지생활건강', 'LG전자', '세타필', '불가리 향수', '모나리자'],
#        dtype=object),
#  array(['플라잉 타이거 코펜하겐'], dtype=object),
#  array(['라코스테(의류)', '디올'], dtype=object),
#  array(['올삭스'], dtype=object),
#  array(['지방시'], dtype=object),
#  array(['폴햄', '캘빈클라인언더웨어', '로엠걸즈(아동)', '판도라', '클라이드', '락포트(여성화)', '헤지스ACC',
#         '빈폴레이디스', '캘빈클라인 진', '마인드브릿지', '비비안', '헤지스 레이디스', '게스(구두)', '아레나',
#         '르꼬끄 골프', '엠폴햄', '아디다스(슈즈)', '빈폴키즈', '나이키(슈즈)', '헤지스 키즈', '에잇세컨즈',
#         '아레나(수영복)', '플루크'], dtype=object),
#  array(['테리파머', '퀸센스', '솔가', '이고진'], dtype=object),
#  array(['더콕', '아이더'], dtype=object),
#  array(['지지피엑스', '비키', '리벤스', '아망떼', '크로커다일레이디', '#텐텐', '푸마', '에고이스트',
#         '나이키', '스틸라', '룸앤홈'], dtype=object),
#  array(['풀무원', '비오템'], dtype=object),
#  array(['크리니크', '바비브라운', '패션풀', '써스데이아일랜드', '쿠쿠'], dtype=object),
#  array(['판도라 바이 비비안', '세노비스', '리복', '오덴세', '스위트박스', '빌리프', '플레이키즈프로',
#         '입생로랑'], dtype=object),
#  array(['나이키'], dtype=object),
#  array(['뉴발란스(키즈)', '버커루', '풋조이', '라코스테(슈즈)', '라코스테(의류)', '블랙야크(키즈)'],
#        dtype=object),
#  array(['케이에스몰'], dtype=object),
#  array(['크록스', '헨켈'], dtype=object),
#  array(['영실업', '래핑차일드', '밀로앤개비', '다이치'], dtype=object),
#  array(['닥스타올', '무냐무냐', '깨끗한나라', '페리미츠', '해피콜', '정관장'], dtype=object),
#  array(['홍진경의 더김치'], dtype=object),
#  array(['헤라'], dtype=object),
#  array(['유팡', '밤부베베'], dtype=object),
#  array(['플루크', '티비제이', '코오롱스포츠(의류)'], dtype=object),
#  array(['벨레다', '아임웰', '벨리니천연해면', '에티튜드', '래디어스', '보타니컬테라피', '리브맘', '바비브라운',
#         '엠엘비키즈'], dtype=object),
#  array(['왕자행거'], dtype=object),
#  array(['트라이엄프', '오가닉맘', '나이키(의류)', '베네통키즈', '나이키 키즈', '레노마수영복', '아디다스',
#         '올삭스', '안다르', '아레나(수영복)', '케이키드', '아베다', '빌리프', '나이키', '디노바시',
#         '크레앙', '첨이첨이', '아레나', '손오공', '아트박스', '블루독베이비', '랑콤'], dtype=object),
#  array(['마담4060', '매일', '프랑코페라로'], dtype=object),
#  array(['나이스클랍', '유닛'], dtype=object),
#  array(['산수시'], dtype=object),
#  array(['배럴'], dtype=object),
#  array(['유닉스', '빌리프'], dtype=object),
#  array(['스타벅스'], dtype=object),
#  array(['나스'], dtype=object),
#  array(['로엠걸즈(아동)'], dtype=object),
#  array(['아네타', '왕자행거'], dtype=object),
#  array(['에뛰드하우스', '장아떼', '오드', '스타일베리', '아토팜', '아이잗컬렉션', '헨어스'],
#        dtype=object),
#  array(['탑텐'], dtype=object),
#  array(['청훈', '아트박스', '푸마', '마몽드', '달퐁', '메르베'], dtype=object),
#  array(['판도라(주얼리)', '마운틴 벨리', '트리샤', '니나스파리'], dtype=object),
#  array(['매일'], dtype=object),
#  array(['나이스클랍'], dtype=object),
#  array(['배스킨라빈스31', '데일리워터', '가쯔'], dtype=object),
#  array(['베네피트', '지오다노'], dtype=object),
#  array(['지퍼락'], dtype=object),
#  array(['난닝구', '랑콤'], dtype=object),
#  array(['롯데칠성몰', '웅진식품'], dtype=object),
#  array(['엘르이너웨어'], dtype=object),
#  array(['타미진(브이아이피)', '클라리소닉.', '에잇세컨즈'], dtype=object),
#  array(['메이크업포에버'], dtype=object),
#  array(['토루토루', '라이온코리아', '컨센서스', '일렉트로룩스', '팀슨', '넬리세제', '퍼실', '헨켈', '테크',
#         '넬리', '애경', '엘지생활건강', '소다스쿨', '다우니'], dtype=object),
#  array(['두닷', '에넥스'], dtype=object),
#  array(['푸마 셀렉트'], dtype=object),
#  array(['케즈'], dtype=object),
#  array(['이나바', '엘지생활건강'], dtype=object),
#  array(['지오다노', '한스펌킨', '그로미미', '야마토야'], dtype=object),
#  array(['닥스골프', '헤지스키즈'], dtype=object),
#  array(['피그먼트'], dtype=object),
#  array(['바비브라운', '크록스', '시세이도', '블루독', '타미진', '베네통(여성의류)'], dtype=object),
#  array(['ANDEW', '티비제이'], dtype=object),
#  array(['랑콤', '치크(키즈)', '블랙야크(키즈)', '프랜치캣', '노스페이스키즈(아동)', '블루독', '토박스',
#         '뉴발란스(키즈)', '지오다노', '헤지스남성', '르꼬끄'], dtype=object),
#  array(['아디다스'], dtype=object),
#  array(['나이키'], dtype=object),
#  array(['세인트디보스', '아미마켓'], dtype=object),
#  array(['아트박스', '에이치커넥트', '리벤스', '크록스키즈', '라네즈', '일룸'], dtype=object),
#  array(['스파클'], dtype=object),
#  array(['블랙야크(키즈)'], dtype=object),
#  array(['비욘드', '비너스 아르보', '엡손'], dtype=object),
#  array(['헤라', '나스'], dtype=object),
#  array(['앳코너', '더틸버리'], dtype=object),
#  array(['해피프린스', '비박스', '제이제이지고트', '지고트', '레노마수영복', '케이투', '플라이워크'],
#        dtype=object),
#  array(['보솜이', '오르시떼', '더블하트'], dtype=object),
#  array(['코인코즈', '이앤씨', '나이키(슈즈)'], dtype=object),
#  array(['에어워크', '아디다스(슈즈)'], dtype=object),
#  array(['오에스티', '엠블러', '파파야', '에르게', '미니아트', '클루', '플라스틱아일랜드', '로렌즈앤',
#         '미쟝센', '이프네'], dtype=object),
#  array(['러브캣'], dtype=object),
#  array(['행복한바오밥'], dtype=object),
#  array(['나이키'], dtype=object),
#  array(['숨37˚', '키엘', '입생로랑'], dtype=object),
#  array(['이라인'], dtype=object),
#  array(['플레이모빌'], dtype=object),
#  array(['지오다노'], dtype=object),
#  array(['엘프색'], dtype=object),
#  array(['배럴', '아이더', '타미힐피거', '디스커버리', '르크루제', '빈폴', '타미힐피거 칠드런', '베이비반즈'],
#        dtype=object),
#  array(['크리니크', '바바라(슈즈)', '엘르이너웨어', '엔터펫'], dtype=object),
#  array(['플레이비츠', '크록스키즈', '영실업', '테일러'], dtype=object),
#  array(['게스(진유니)'], dtype=object),
#  array(['아베다', '부르조아'], dtype=object),
#  array(['차앤박', '바비브라운'], dtype=object),
#  array(['발뮤다'], dtype=object),
#  array(['청정원', '데드라'], dtype=object),
#  array(['루이까또즈(셔츠)', '코디갤러리 바이 에스티코', '차앤박', '리빌모아'], dtype=object),
#  array(['코인코즈', '이앤씨'], dtype=object),
#  array(['에프알제이', '크록스', '쉬즈미스', '피핀', '토박스', '파코라반 베이비'], dtype=object),
#  array(['타미힐피거'], dtype=object),
#  array(['닥터아토', '아토팜', '오가닉맘'], dtype=object),
#  array(['캘빈클라인언더웨어', '아베다', '더바디샵', '댕기머리'], dtype=object),
#  array(['드링크인더박스'], dtype=object),
#  array(['플라스틱아일랜드', '플라스틱아일랜드스토리'], dtype=object),
#  array(['빈폴아웃도어'], dtype=object),
#  array(['데상트', '리브맘', '업타운홀릭', '엠엘비키즈', '밀로앤개비', '빈폴키즈', '페이퍼플레인키즈', '블루독',
#         '테팔', '알로봇', '더바디샵', '안나수이(향수)'], dtype=object),
#  array(['소보제화', '까르뜨블랑슈남성', '올젠', '지오다노', '까사미아까사온', '코너샵'], dtype=object),
#  array(['비욘드', '게스(진)', '버커루', '고세', '버커루 브이아이피', '테팔'], dtype=object),
#  array(['맥', '지오다노', '아디다스', '르까프', '바자르', '아디다스 오리지널', '빈폴아웃도어', '럭센스',
#         '안지크', '아디다스(슈즈)', '카파(잠실)', '설화수', '바보사랑', '코리아나', '랑콤', '노스페이스영',
#         '마담4060', '핑크시슬리', '솔가'], dtype=object),
#  array(['아디다스(슈즈)'], dtype=object),
#  array(['스티유'], dtype=object),
#  array(['조르지오 아르마니', '입생로랑', '디올', '어반디케이', '맥'], dtype=object),
#  array(['케이투'], dtype=object),
#  array(['오랄비', '리스테린', '샤프란'], dtype=object),
#  array(['롭스', '티스'], dtype=object),
#  array(['우바', '코인코즈'], dtype=object),
#  array(['나스'], dtype=object),
#  array(['나이키', '나이키(슈즈)'], dtype=object),
#  array(['라인', '파인뷰'], dtype=object),
#  array(['다이슨'], dtype=object),
#  array(['탑걸', '쥬시쥬디', '클라이드', '플라스틱아일랜드스토리', '지지피엑스', '올리브데올리브', '비오템',
#         '더바디샵', '설화수', '아토팜', '예작(셔츠)', '비지트인뉴욕', '씨씨콜렉트', '게스(VIP)',
#         '에스티홀리데이', '영실업', '랩', '엑스웨이브', '꾸즈', '뽀로로'], dtype=object),
#  array(['레노마수영복'], dtype=object),
#  array(['쓰리엠', '탑텐', '키엘', '이스트팩(스포츠)', '트라이', '오조크'], dtype=object),
#  array(['SK-II'], dtype=object),
#  array(['세븐일레븐', '샤샤'], dtype=object),
#  array(['나이키 키즈', '트래드후스'], dtype=object),
#  array(['탑이슈', '로즈맘', '탑텐', '피핀', '예스', '캐스키드슨(잡화)', '이앤씨', '이프네',
#         '레코브(여성의류)', '조이너스', '에이치커넥트', '웨스트에비뉴', '아망떼', '보몽드', '비키', '락앤락'],
#        dtype=object),
#  array(['나스', '아토팜', '플레이비츠', '키엘', '내추럴발란스', '맥', '롭스', '마이닭',
#         '조르지오 아르마니', '갭', '보솜이', '올즙', '갭 키즈'], dtype=object),
#  array(['바바라(슈즈)'], dtype=object),
#  array(['헨리코튼', '페라가모(향수)', '올젠', '페라가모', '몽벨', '헤지스남성', '텐바이텐', '흄'],
#        dtype=object),
#  array(['케즈', '갭 키즈'], dtype=object),
#  array(['에이치커넥트', '쥬시쥬디'], dtype=object),
#  array(['베이비앤아이'], dtype=object),
#  array(['핑크시슬리', '레이지비', '러브캣비쥬(주얼리)', '코스(KHOS)', '지방시'], dtype=object),
#  array(['아디다스(슈즈)'], dtype=object),
#  array(['아디다스(슈즈)'], dtype=object),
#  array(['아이더', '트윈키즈'], dtype=object),
#  array(['휠라 키즈', '키엘', '아디다스(키즈)'], dtype=object),
#  array(['블루독', '닥스 키즈'], dtype=object),
#  array(['보타니컬테라피'], dtype=object),
#  array(['미샤', '분홍코끼리', '에끌라두플러스'], dtype=object),
#  array(['윈'], dtype=object),
#  array(['헤드'], dtype=object),
#  array(['레이지비(레저)'], dtype=object),
#  array(['페이퍼플레인키즈', '빈', '레노마키즈', '페리미츠', '티파니', '뉴발란스(키즈)', '썬글레이드'],
#        dtype=object),
#  array(['타미힐피거여성', '써스데이아일랜드', '헤라', '글로리룩', '씨위', '헤지스 레이디스', '달팡',
#         '메이크업포에버', '데일리원'], dtype=object),
#  array(['레노마수영복'], dtype=object),
#  array(['헤지스남성', '비너스 아르보'], dtype=object),
#  array(['리스트 레드라벨', '쉬즈미스', '푸마', '리스트', '더아이잗(여성)'], dtype=object),
#  array(['조르지오 아르마니', '크리니크', '로라 메르시에'], dtype=object),
#  array(['셀덴(아동)', '피프틴미닛', '헤링본', '에어워크', '베이비(아동)', '빅토리아앤프렌즈', '크록스',
#         '에스티엘', '레이지비', '블루독'], dtype=object),
#  array(['불가리 향수'], dtype=object),
#  array(['시슬리(화장품)', '한일'], dtype=object),
#  array(['에드윈', '코스(KHOS)', '비비안', '프리미엘', 'SK-II', '예소담', '에이치커넥트', '베딩나라',
#         '빈폴키즈', '헨어스', '골든벨', '헌트키즈(아동)', '지오다노', 'LG전자', '티비제이'],
#        dtype=object),
#  array(['키엘', '트라이.', '랑콤'], dtype=object),
#  array(['KLORANE', '투썸플레이스'], dtype=object),
#  array(['코어바디'], dtype=object),
#  array(['네이쳐리빙', '플라스틱아일랜드스토리', '제이케이'], dtype=object),
#  array(['탑텐'], dtype=object),
#  array(['올삭스', '클립'], dtype=object),
#  array(['코벳블랑', '피에르가르뎅_핸드백'], dtype=object),
#  array(['자연의품격', '스파클'], dtype=object),
#  array(['메이비바니'], dtype=object),
#  array(['비오템', '슈에무라', '더바디샵', '랑콤', '베네피트', '빈폴레이디스'], dtype=object),
#  array(['아베다'], dtype=object),
#  array(['돌체구스토'], dtype=object),
#  array(['이브스', '돈앤돈스'], dtype=object),
#  array(['라이온코리아', '메디메이트/NTB', '안스엉클(양말)', '헤라', '정관장', '버키비버', '브라운 물티슈',
#         '빈폴', '헤지스남성', '아놀드파마(양말)'], dtype=object),
#  array(['아디다스(슈즈)', '리바이스'], dtype=object),
#  array(['메트로시티(주얼리)', '소보제화'], dtype=object),
#  array(['클라이드', '폴앤폴', '22XX', '마이수야'], dtype=object),
#  array(['에스티 로더'], dtype=object),
#  array(['내셔널지오그래픽(남성)'], dtype=object),
#  array(['노블리제', '비너스'], dtype=object),
#  array(['하이모리', '오르시떼', '케이키드', '헬렌스타인', '텐바이텐', '첨이첨이', '플레이키즈프로', '씨제이',
#         '리바이스(키즈)', '제이코튼', '오키즈', '삼성전자', '코멕스'], dtype=object),
#  array(['예스'], dtype=object),
#  array(['뉴발란스(키즈)', '엠엘비키즈'], dtype=object),
#  array(['엘라스틴'], dtype=object),
#  array(['언더아머(스포츠)'], dtype=object),
#  array(['에티튜드'], dtype=object),
#  array(['네이처리퍼블릭', '메디힐'], dtype=object),
#  array(['엠엘비', '게스(VIP)', '아디다스(의류)'], dtype=object),
#  array(['크록스', '롯데칠성몰'], dtype=object),
#  array(['플레이키즈프로'], dtype=object),
#  array(['카파(스포츠)', '입생로랑', '헤지스ACC', '업타운홀릭', '에잇세컨즈'], dtype=object),
#  array(['에끌라두플러스', '키엘', '헤라', '크록스', '리브맘'], dtype=object),
#  array(['에이치커넥트'], dtype=object),
#  array(['프랜치캣', '비너스(스타킹)', '로얄알버트', '마몽드', '아이오페', '무냐무냐', '클라이드'],
#        dtype=object),
#  array(['질스튜어트', '써모스'], dtype=object),
#  array(['오랄비', '모노블랙'], dtype=object),
#  array(['에어워크'], dtype=object),
#  array(['루이까또즈'], dtype=object),
#  array(['르오트'], dtype=object),
#  array(['지오다노', '헤링본'], dtype=object),
#  array(['바바라(슈즈)'], dtype=object),
#  array(['쉬즈미스', '케이투', '크록스', '센카', '아리체', '잭앤질', '빌리프'], dtype=object),
#  array(['베네폼'], dtype=object),
#  array(['비씨비지', '이니스프리'], dtype=object),
#  array(['프랜치캣'], dtype=object),
#  array(['빅토리아', '밀크마일', '래핑차일드', '블루독베이비'], dtype=object),
#  array(['정관장', '웅진식품'], dtype=object),
#  array(['아모스프로페셔널'], dtype=object),
#  array(['롭스'], dtype=object),
#  array(['뉴발란스', '헤라', '레노마(우양산)', '시크폭스', '배럴', '난닝구', '아토팜', '디어제인',
#         '업타운홀릭', '아디다스(의류)'], dtype=object),
#  array(['비오템', '아레나(수영복)', '아디다스(슈즈)', '오휘'], dtype=object),
#  array(['나스'], dtype=object),
#  array(['스키즈', '아레나(수영복)'], dtype=object),
#  array(['밀로앤개비', '크록스', '라인어디션', '써스데이아일랜드'], dtype=object),
#  array(['코치', '로즈버드 바이 비비안', '닥스'], dtype=object),
#  array(['그린너트', '머스트비'], dtype=object),
#  array(['맥'], dtype=object),
#  array(['화이트폭스'], dtype=object),
#  array(['헤드'], dtype=object),
#  array(['헤라', '설화수'], dtype=object),
#  array(['애스크 주니어', '레노마(모자)'], dtype=object),
#  array(['레노마(셔츠)', '헤르본'], dtype=object),
#  array(['커터앤벅'], dtype=object),
#  array(['크리노미'], dtype=object),
#  array(['디즈니골프', '휠라', '머렐(레저)', '레노마캐주얼'], dtype=object),
#  array(['아이스샌드(아동)', '레노마수영복', '카카오 프렌즈', '랑콤', '오휘'], dtype=object),
#  array(['아식스', '엠폴햄', '신신'], dtype=object),
#  array(['레노마수영복', '펫토리아', '엔터펫'], dtype=object),
#  array(['로엠걸즈(아동)', '영실업', '더바디샵', '솔로몬샵', '보아스린', '바보사랑', '제브라', '페리미츠',
#         '베베숲'], dtype=object),
#  array(['안다르(스포츠)', '엘칸토'], dtype=object),
#  array(['빌리프', '아모레퍼시픽', '클라란스'], dtype=object),
#  array(['아디다스키즈(아동)'], dtype=object),
#  array(['씨이오퍼퓸(화장품)', '랑콤', '입생로랑'], dtype=object),
#  array(['온앤온', '아트박스', '빈', '지오다노', '블랙야크(키즈)', '함소아', '래핑차일드', '행복한바오밥',
#         '517681', '뉴발란스(키즈)', '네파키즈', '발레키즈', '도기야', '루이루다', '리치파우치',
#         '뉴발란스', '레고'], dtype=object),
#  array(['애플'], dtype=object),
#  array(['아레나(수영복)'], dtype=object),
#  array(['아레나', '노스페이스', '트렉스타', '네파'], dtype=object),
#  array(['헤지스ACC', '이반', '아디다스 오리지널'], dtype=object),
#  array(['러쉬'], dtype=object),
#  array(['노스페이스키즈(아동)', '노스페이스', '아디다스(키즈)', 'CE5578', '나이키 키즈', '캉골'],
#        dtype=object),
#  array(['아디다스(슈즈)', '아디다스 키즈', '나이키 키즈', '크록스(키즈)', '게스(키즈)'], dtype=object),
#  array(['엠엘비', '클리브랜드', '엠엘비키즈'], dtype=object),
#  array(['리바이스', '디키즈', '엠엘비', '아디다스 오리지날', '아디다스(의류)', '빈폴ACC'],
#        dtype=object),
#  array(['애스크 주니어', '게스(진)'], dtype=object),
#  array(['브라운'], dtype=object),
#  array(['뉴트리코어', '센트럴팜'], dtype=object),
#  array(['스튜디오화이트', '플라스틱아일랜드스토리'], dtype=object),
#  array(['도로시(쥬얼리)'], dtype=object),
#  array(['헌트키즈(아동)', '파파야', '로엠걸즈(아동)', '로티니', '보니알렉스', '헌트이너웨어', '셀덴(아동)',
#         '레노마키즈', '휠라키즈'], dtype=object),
#  array(['코데즈컴바인 이너웨어', '게스(언더웨어)', '트라이엄프', '엠 미소페', '소보제화'], dtype=object),
#  array(['덴비'], dtype=object),
#  array(['마몽드', '한미', '니콜', '락앤락', '분홍코끼리', '테일러', '오모떼', '기라로쉬(우양산)',
#         '스텐피아', '기라로쉬'], dtype=object),
#  array(['지오다노'], dtype=object),
#  array(['아레나(수영복)', '바비|', '아이스샌드(아동)', '오즈키즈', '꼬망스(아동)', '게스(키즈)',
#         '빈폴아웃도어'], dtype=object),
#  array(['쿠론', '빈폴레이디스'], dtype=object),
#  array(['아토팜'], dtype=object),
#  array(['빈폴레이디스'], dtype=object),
#  array(['해피바스', '나캇타코토니', '일리', '에스쁘아', '세노비스', '라네즈'], dtype=object),
#  array(['릴헤븐'], dtype=object),
#  array(['오랄비'], dtype=object),
#  array(['웅진식품', '깨끗한나라'], dtype=object),
#  array(['설화수', '클라란스'], dtype=object),
#  array(['랑콤'], dtype=object),
#  array(['아디다스(의류)', '피알지알', '아디다스'], dtype=object),
#  array(['로제', '미쏘', '아디다스(의류)', '지지피엑스', '쉬즈미스', '코인코즈', '테이트', '에이치커넥트',
#         '플라스틱아일랜드', '안다르(스포츠)', '애스크', '바디판타지 (화장품)', '클라이드', '잭앤질', '탑텐',
#         '넛츠팜', '밸리걸', '멜킨', '고세', '리스트', '모델리스트', '스파오', '클라비스', '앤섬',
#         '에고', '리스트 레드라벨', '네이처리퍼블릭', '지니킴(슈즈)', '시슬리', '탠디', '나이키(의류)',
#         '키친아트'], dtype=object),
#  array(['유니프랜드', '아이빈'], dtype=object),
#  array(['지오다노'], dtype=object),
#  array(['키플링', '블랙야크(키즈)', '게스(키즈)', '프랜치캣', '아리체', '케이스위스'], dtype=object),
#  array(['제이스타일'], dtype=object),
#  array(['리스트', '이경제'], dtype=object),
#  array(['군', '삼다수'], dtype=object),
#  array(['피지오겔'], dtype=object),
#  array(['지오다노', '플루'], dtype=object),
#  array(['솔가', '페리미츠', '꼬망스(아동)'], dtype=object),
#  array(['키엘', '숨37˚', '디올'], dtype=object),
#  array(['그로미미', '푸고'], dtype=object),
#  array(['라코스테(슈즈)', '플랫폼'], dtype=object),
#  array(['파리바게뜨'], dtype=object),
#  array(['나트라케어', '플라스틱아일랜드스토리'], dtype=object),
#  array(['체이스컬트'], dtype=object),
#  array(['툼툼'], dtype=object),
#  array(['꼬지비', '삐삐롱', '첨이첨이'], dtype=object),
#  array(['뉴에라', '르꼬끄 골프', '피핀', '예스', '비와이씨', '데상트(골프)', '시크폭스', '랩',
#         '바보사랑', '클루드클레어', '롯데칠성몰', '클립', '제이엘프', '캉골', '스타일온미', '먼싱웨어',
#         '엄브로', '쥬맥스', 'AHC', '엔비룩', '키스미', '보이스캐디', '레이지비', '바비브라운',
#         '토니모리', '제이스타일', '에고이스트', '정관장', '와이드앵글', '모니카룸', '랑콤', '까스텔바작골프',
#         '로라 메르시에', '타미진'], dtype=object),
#  array(['첨이첨이', '빈', '판도라'], dtype=object),
#  array(['오딧세이'], dtype=object),
#  array(['아임닭'], dtype=object),
#  array(['크록스'], dtype=object),
#  array(['에스티 로더', '키엘'], dtype=object),
#  array(['티피'], dtype=object),
#  array(['시루콧토', '트윈키즈', '지오다노', '베네툴'], dtype=object),
#  array(['첨이첨이', '나이키'], dtype=object),
#  array(['아디다스(슈즈)'], dtype=object),
#  array(['카시오', '아도르'], dtype=object),
#  array(['정관장', '아디다스(슈즈)', '아디다스키즈(아동)'], dtype=object),
#  array(['페리미츠', '꼬망스(아동)'], dtype=object),
#  array(['엠엘비키즈'], dtype=object),
#  array(['뉴발란스(키즈)', '플레이키즈프로'], dtype=object),
#  array(['나이키(의류)'], dtype=object),
#  array(['조르지오 아르마니'], dtype=object),
#  array(['꼬망스(아동)'], dtype=object),
#  array(['네파'], dtype=object),
#  array(['플레이텍스'], dtype=object),
#  array(['아가타', '김정문알로에', '피트인', '왓코(스포츠)', '에스티 로더'], dtype=object),
#  array(['나이키수영복'], dtype=object),
#  array(['게스(진)', '언더아머(스포츠)', '뉴발란스', '발렌티노', '지오다노', '라코스테(의류)', '빈폴레이디스',
#         '라코스테스포츠', '타미힐피거여성', '베트멍'], dtype=object),
#  array(['쥬시쥬디', '다우니'], dtype=object),
#  array(['타미힐피거', '록시땅', '타미진'], dtype=object),
#  array(['오키즈', '입생로랑', '샤바스'], dtype=object),
#  array(['쉬즈미스', '게스(진유니)', '캘빈클라인(향수)', '제이제이 지고트', '불가리 향수', '동아',
#         '씨이오퍼퓸(화장품)', '게스(진)', '솔로몬샵', '헤지스 레이디스'], dtype=object),
#  array(['하나모리', '코리아나', '쟈딕앤 볼테르(선글라스)', '로레알 파리', '엘르(선글라스)'],
#        dtype=object),
#  array(['나이키(슈즈)', '에르고베이비', '랩시리즈'], dtype=object),
#  array(['스테판조셉'], dtype=object),
#  array(['지오다노', '컨셉원', '크리스크리스티리얼맨', '슈퍼스타아이', '옷타쿠', '르젠옴므', '자스페로(시계)',
#         '닥터마틴'], dtype=object),
#  array(['포커스', '스코노'], dtype=object),
#  array(['농심'], dtype=object),
#  array(['베베드피노', '오휘'], dtype=object),
#  array(['아이오페', '한율'], dtype=object),
#  array(['판도라(주얼리)'], dtype=object),
#  array(['탠디(여성화)', '쉬즈미스', '지오다노', '헤지스', '올젠'], dtype=object),
#  array(['에잇세컨즈'], dtype=object),
#  array(['종근당 건강', '코데즈컴바인 이너웨어', '오니츠카타이거(J)'], dtype=object),
#  array(['삼성전자'], dtype=object),
#  array(['뉴발란스(의류)'], dtype=object),
#  array(['에고이스트'], dtype=object),
#  array(['록시땅', '엠 미소페', '구희', '게스(시계)', '제이크로우', '분홍코끼리', '화이트폭스', '나스',
#         '디즈니', '라코스테(여성)', '입생로랑', '게스(선글라스)', '톰앤래빗', '비오템', '패션풀',
#         '드릴리스', '르네 휘테르', '핑크체리 슈즈', '핑크체리', '스타일베리'], dtype=object),
#  array(['클리오', '발레키즈', '포베네'], dtype=object),
#  array(['엘칸토', '지컷', '아디다스(의류)', '지지피엑스', '르샵', '골든벨', '제이에스티나 핸드백',
#         '휠라 골프', '쉬즈미스', '랩'], dtype=object),
#  array(['코치(잡화)'], dtype=object),
#  array(['밀크마일', '아디다스(키즈)', '나라라키즈', '래핑차일드'], dtype=object),
#  array(['토박스', '컬리수'], dtype=object),
#  array(['아디다스(슈즈)'], dtype=object),
#  array(['영실업'], dtype=object),
#  array(['반다이'], dtype=object),
#  array(['코데즈컴바인 이너웨어'], dtype=object),
#  array(['헤지스남성', 'HONG SHOT'], dtype=object),
#  array(['비너스 아르보', '엘르이너웨어', '비너스 자스민', '나이키', '캘빈클라인언더웨어'], dtype=object),
#  array(['오휘', '바이오더마', '엘리자베스아덴', '미래생활', '트라이', '이반', '스킨푸드', '제임스딘',
#         '존슨즈베이비', '보디가드', '비와이씨'], dtype=object),
#  array(['더바디샵'], dtype=object),
#  array(['화이트폭스', '토박스', '네스프레소'], dtype=object),
#  array(['아이오페'], dtype=object),
#  array(['요리하다'], dtype=object),
#  array(['매일'], dtype=object),
#  array(['타미진'], dtype=object),
#  array(['프레쉬', '아디다스(슈즈)', '비비안웨스트우드', '체리코코', '랩', '크록스키즈', '톰앤래빗', '난닝구'],
#        dtype=object),
#  array(['나이키 키즈'], dtype=object),
#  array(['코즈니'], dtype=object),
#  array(['나이키'], dtype=object),
#  array(['나이키'], dtype=object),
#  array(['포트메리온', '아디다스(의류)', '다이슨', '올젠', '락포트(여성화)', '러쉬', '나이키(의류)',
#         '키엘', '루이까또즈(우양산)', '데상트', '알라피아'], dtype=object),
#  array(['XEEON'], dtype=object),
#  array(['나이스클랍', '헤라'], dtype=object),
#  array(['비너스 아르보', '올삭스'], dtype=object),
#  array(['에이치커넥트', '베네피트', '아이오페'], dtype=object),
#  array(['로엠', '스퍼'], dtype=object),
#  array(['닥터지'], dtype=object),
#  array(['케즈', '아날도바시니'], dtype=object),
#  array(['잭니클라우스', '크록스', '데상트 스포츠', '유팡'], dtype=object),
#  array(['해피프린스'], dtype=object),
#  array(['오키즈'], dtype=object),
#  array(['헬렌스타인'], dtype=object),
#  array(['크로커다일 레이디', '아이오페'], dtype=object),
#  array(['머렐(레저)', '세사', '모슬린'], dtype=object),
#  array(['모리스커밍홈', '아놀드파마(수영)', '레노마수영복', '헤링본', '올젠', '예작(셔츠)', '탑텐'],
#        dtype=object),
#  array(['크리니크'], dtype=object),
#  array(['이나바'], dtype=object),
#  array(['쉬즈미스'], dtype=object),
#  array(['캘빈클라인 진', '게스(진)', '네파', '머렐(레저)', '아이더'], dtype=object),
#  array(['베스띠벨리'], dtype=object),
#  array(['파스퇴르'], dtype=object),
#  array(['김나운의 더 키친', '엘리자벳', '홍진경의 더김치'], dtype=object),
#  array(['더바디샵', '록시땅'], dtype=object),
#  array(['잭앤질'], dtype=object),
#  array(['쥬맥스', '스파클', '르까프', '브라운', '캘빈클라인언더웨어', '벅703', '알럽하우스', '도담이'],
#        dtype=object),
#  array(['한예빔', '랑콤', '비너스'], dtype=object),
#  array(['에이비에프지', '숲'], dtype=object),
#  array(['임블리(imvely)'], dtype=object),
#  array(['지오다노', '탑텐'], dtype=object),
#  array(['게스', '올젠'], dtype=object),
#  array(['모드아이'], dtype=object),
#  array(['난닝구', '정관장'], dtype=object),
#  array(['뉴발란스(슈즈)'], dtype=object),
#  array(['블랙마틴싯봉', '더아이잗(여성)', '타미진', '핏플랍'], dtype=object),
#  array(['라셀렌', '니', '젤리스푼', '세주(완구)', '래핑차일드', '메소드', '엑토', '키친아트',
#         '레노마키즈', '테이트', '해피바스', '샌드박스', '아놀드파마(양말)', '오키즈'], dtype=object),
#  array(['오가닉맘', '타미힐피거', '헤지스남성', '버커루 브이아이피', '노스페이스', '비너스 솔브'],
#        dtype=object),
#  array(['내셔널지오그래픽(남성)'], dtype=object),
#  array(['휠라 키즈', '나이스클랍', '스테파넬', '예작(셔츠)', '세라블라썸', '엠엘비키즈', '오니츠카타이거',
#         '써모스', '노스페이스키즈(아동)', '스퍼'], dtype=object),
#  array(['골든구스'], dtype=object),
#  array(['더바디샵'], dtype=object),
#  array(['바비브라운', '헤라', '케이트', '락앤락', '올삭스', '설화수', '러쉬', '안나수이', '아이피타임',
#         '엣지스쿨', '애스크 주니어', '첨이첨이', '더바디샵'], dtype=object),
#  array(['파인프라', '종가집', '티비제이', '엠폴햄', '질경이', '헨켈'], dtype=object),
#  array(['레노마수영복', '블루테일', '첨이첨이', '아레나(수영복)', '루루슈', '엠엘비키즈', '주니걸즈',
#         '오가닉맘', '아레나', '세마', '빈폴레이디스'], dtype=object),
#  array(['삼다수', '카카오프렌즈', '지오다노', '바보사랑'], dtype=object),
#  array(['입생로랑'], dtype=object),
#  array(['아레나'], dtype=object),
#  array(['풀무원', '에르고베이비', '설화수'], dtype=object),
#  array(['베네피트', '맥'], dtype=object),
#  array(['오가닉맘', 'KLORANE', '에이지도르', '키엘', '르네 휘테르'], dtype=object),
#  array(['나이키', '테팔'], dtype=object),
#  array(['빈', '빈폴'], dtype=object),
#  array(['메이크업포에버'], dtype=object),
#  array(['탑텐', '고세', '아이더', '세라블라썸', '래핑차일드', '베네통키즈', '코베아', '제드', '레노마키즈',
#         '게스(구두)', '보그스', '락앤락', '아이빈', '르샵'], dtype=object),
#  array(['프리메라', '멕리듬', '디올'], dtype=object),
#  array(['조르지오 아르마니'], dtype=object),
#  array(['입생로랑', '휠라키즈', '나이키', '박씨상방', '해피콜'], dtype=object),
#  array(['타미진'], dtype=object),
#  array(['리복(프리미엄)', '플레이키즈프로', '조말론런던'], dtype=object),
#  array(['정관장.'], dtype=object),
#  array(['나인(NAIN)'], dtype=object),
#  array(['밤비노', '래핑차일드', '페리미츠'], dtype=object),
#  array(['르젠옴므'], dtype=object),
#  array(['부자양말'], dtype=object),
#  array(['베어파우(슈즈)', '파타고니아', '엑토', '드팜', '라네즈', '보니알렉스', '루데아', '로엠걸즈(아동)',
#         '나와니스', '송월타올', '랩', '업타운홀릭', '래핑차일드', '타미진', '이니스프리', '애스크 주니어',
#         '지앤씨', '트라이', '컴포트랩', '크록스', '에잇세컨즈', '크리비아', '헤라', '케이에스몰'],
#        dtype=object),
#  array(['헤지스남성', '빈폴'], dtype=object),
#  array(['비너스'], dtype=object),
#  array(['록시땅', '데상트 스포츠'], dtype=object),
#  array(['케이스위스', '한율', '로키', '라미'], dtype=object),
#  array(['알로봇', '앤블리', '노스페이스영', '레노마키즈', '빈', '래핑차일드', '베네통키즈', '나이키'],
#        dtype=object),
#  array(['업타운홀릭', '나스', '리바이스(바디웨어)', '입생로랑'], dtype=object),
#  array(['소다스쿨', '까스텔바작골프', '헤지스골프', '르꼬끄골프'], dtype=object),
#  array(['아디다스(키즈)'], dtype=object),
#  array(['플라스틱아일랜드', '플라스틱아일랜드스토리'], dtype=object),
#  array(['메디플라워'], dtype=object),
#  array(['숨37˚', '조르지오 아르마니', '아베다'], dtype=object),
#  array(['VDL'], dtype=object),
#  array(['키엘', '아이소이', '랩', '코스(KHOS)', '토니모리', '헤라', '디스커버리', '노스페이스',
#         '쥬시쥬디', '보브(의류)'], dtype=object),
#  array(['빅토리아앤프렌즈', '윙하우스'], dtype=object),
#  array(['휠라(프리미엄)'], dtype=object),
#  array(['탑텐'], dtype=object),
#  array(['버켄스탁', '비너스 아르보'], dtype=object),
#  array(['포커스', '업타운홀릭', '윈'], dtype=object),
#  array(['네이쳐리빙', '보르미올리'], dtype=object),
#  array(['싹스', '설화수', '피핀', '허그코리아'], dtype=object),
#  array(['데코라인'], dtype=object),
#  array(['디스커버리'], dtype=object),
#  array(['바보사랑', '푸마골프', '랩', '톰보이', '더독', '노스페이스', '닥스', '아디다스(의류)', '센트룸',
#         '리바이스', '카파(잠실)', '보니알렉스', '나이키(의류)', '코오롱스포츠', '나이키수영복', '삼다수',
#         '삼육', '에이치커넥트', '캠퍼(슈즈)', '유지아이지'], dtype=object),
#  array(['페리미츠', '레노마키즈'], dtype=object),
#  array(['정관장'], dtype=object),
#  array(['로티홈시스', '에스티 로더', '나이키', '정관장'], dtype=object),
#  array(['바비브라운', '셀퓨전씨'], dtype=object),
#  array(['락피쉬(구두)', '산과들에'], dtype=object),
#  array(['아디다스(의류)', '나이키'], dtype=object),
#  array(['나이키(슈즈)'], dtype=object),
#  array(['엠폴햄', '폴햄', '지오다노', '에블린'], dtype=object),
#  array(['나이키', '라코스테(의류)', '아벤트', '나이키키즈', '네이쳐러브메레'], dtype=object),
#  array(['불가리 향수'], dtype=object),
#  array(['타미힐피거 칠드런', '닥스키즈'], dtype=object),
#  array(['이프네', '에이치커넥트', '아워큐주니어', '모니카룸', '플래퍼', '나인스텝', '루미씨', '스파클',
#         '월튼키즈', '안다르', '반에이크', '팬콧(키즈)', '보니알렉스', '르샵', '홈스웰', '수페르가(스포츠)',
#         '아이더', '헤드 슈즈(HEAD SHOES)', '난닝구', '뉴트로지나', '쿠기', '제이제이지고트', '씨',
#         '제이제이 지고트', '안다르(스포츠)', '지지피엑스'], dtype=object),
#  array(['동원', '맥포머스'], dtype=object),
#  array(['조르지오 아르마니'], dtype=object),
#  array(['러쉬'], dtype=object),
#  array(['배럴', '노스페이스영', '레노마수영복'], dtype=object),
#  array(['레노마키즈'], dtype=object),
#  array(['나이키'], dtype=object),
#  array(['나이키수영복'], dtype=object),
#  array(['아메리칸투어리스터'], dtype=object),
#  array(['앤듀', '브이텍', '마텔', '해피프린스', '올젠', '카밀', '코니스', '이니스프리', '아트박스',
#         '데코원', '에보니아', '닥터브라운'], dtype=object),
#  array(['스톤헨지(주얼리)', '에꼴리에'], dtype=object),
#  array(['임페리얼'], dtype=object),
#  array(['아이오페'], dtype=object),
#  array(['닥터자르트'], dtype=object),
#  array(['입생로랑', '디올'], dtype=object),
#  array(['맥'], dtype=object),
#  array(['배럴'], dtype=object),
#  array(['헤지스 레이디스'], dtype=object),
#  array(['정관장.'], dtype=object),
#  array(['지오다노'], dtype=object),
#  array(['설화수', '크리니크', '쥬맥스', '더바디샵'], dtype=object),
#  array(['볼 메이슨', '미닛플러스', '베네피트'], dtype=object),
#  array(['데상트(골프)', '폴스미스(향수)', '베티나르디', '판도라 바이 비비안', '타이틀리스트', '르꼬끄 골프',
#         '까스텔바작골프', '엘비엘스포츠', '나이키골프', '블루독', '레어택(스포츠)'], dtype=object),
#  array(['나스'], dtype=object),
#  array(['지오다노'], dtype=object),
#  array(['닥터브로너스'], dtype=object),
#  array(['오휘', '바비브라운'], dtype=object),
#  array(['설화수', '디올'], dtype=object),
#  array(['비버리힐스폴로클럽', '에스티 로더', '리바이스키즈', '블랙야크(키즈)', '휠라키즈', '헤지스키즈'],
#        dtype=object),
#  array(['SK-II'], dtype=object),
#  array(['벨레다', '쉬즈미스', '헨켈', '밍크뮤', '오키즈', '아레나(수영복)', '릴리푸리', '성광교역',
#         '트라이(속옷)', '디즈니'], dtype=object),
#  array(['아벤느', '스테비아'], dtype=object),
#  array(['데상트', '뉴발란스(의류)'], dtype=object),
#  array(['올리버하우스', '상상후'], dtype=object),
#  array(['팬콧'], dtype=object),
#  array(['비너스 아르보', '프라미스'], dtype=object),
#  array(['블랙야크(키즈)', '스퍼', '머렐(레저)'], dtype=object),
#  array(['아디다스', '헤지스남성', '빈폴', '파슬(시계)', '아가타(우산)'], dtype=object),
#  array(['빈폴레이디스', '빈폴', '라푸마브이아이피'], dtype=object),
#  array(['마코', '르까프', '보니비노', '한샘', '산과들에', '올젠', '그린너트', '자연의품격', '삼정펄프',
#         '테이트', '비너스 아네타', '이반', '네파', '스마스토어', '미쟝센', '앤섬'], dtype=object),
#  array(['언더러브', '세이지 스푼풀', '닥스ACC', '헤지스남성', '오스터', '크로커다일 레이디'],
#        dtype=object),
#  array(['에뜨와', '정관장', '러쉬', '오피아이', '블루독베이비', '오즈키즈', '제이에스티나(주얼리)',
#         '한국금거래소'], dtype=object),
#  array(['정관장', '트래드후스'], dtype=object),
#  array(['엘르 수영복', '카파(스포츠)'], dtype=object),
#  array(['게스', '레이지비'], dtype=object),
#  array(['바보사랑', '빈폴아웃도어', '텐바이텐'], dtype=object),
#  array(['어반디케이'], dtype=object),
#  array(['프랭키뉴욕'], dtype=object),
#  array(['리복'], dtype=object),
#  array(['KD Toys', '바디피트', '베이비맥스', '율그란', '큐트베이비', '달퐁', '도노도노'],
#        dtype=object),
#  array(['엘라고', '맥', '오젬', '시세이도', '르네 휘테르', '바비브라운', '잇미샤', '아베다'],
#        dtype=object),
#  array(['블랙야크(키즈)'], dtype=object),
#  array(['해비치호텔앤드리조트'], dtype=object),
#  array(['임블리(imvely)', '나이키(슈즈)'], dtype=object),
#  array(['보닌(신발)', '애스크 주니어', '닥터지', '압소바', '파코라반 베이비'], dtype=object),
#  array(['에이치커넥트', '게스(진유니)'], dtype=object),
#  array(['키엘'], dtype=object),
#  array(['더블에이', '블랙마틴싯봉', '손오공', '티블루', '휴도라', '필립스(PHILIPS)', '사츠'],
#        dtype=object),
#  array(['헤지스남성'], dtype=object),
#  array(['쿤달'], dtype=object),
#  array(['엔비에이', '헤지스남성'], dtype=object),
#  array(['프라다', '마리끌레르', '뉴발란스'], dtype=object),
#  array(['닥스(양말)'], dtype=object),
#  array(['고려은단', '오리진스', '프리메라'], dtype=object),
#  array(['르샵'], dtype=object),
#  array(['알도'], dtype=object),
#  array(['[벤츠]', '[돌체앤가바나(향수)]', '[모스키노]', '[불가리(향수)]', '[불가리]', '[랑방]',
#         '[크리스아담스]', '[이세이 미야케(향수)]', '[마크제이콥스(잡화)]', '[캘빈클라인(향수)]',
#         '[안나수이(향수)]', '[롭스]', '[몽블랑(향수)]', '[페라가모]', '[파코라반(향수)]',
#         '[쥬시꾸뛰르.]', '[베르사체]', '[버버리]', '[니나리치(향수)]', '[메르세데스벤츠(향수)]',
#         '[클린]', '[랑방(향수)]'], dtype=object),
#  array(['노스페이스키즈(아동)'], dtype=object),
#  array(['엘라모', '아이오페', '아디다스(슈즈)', '클린앤클리어', '나이스클랍', '팬지'], dtype=object),
#  array(['엘리든플레이'], dtype=object),
#  array(['헤라', '소다', '헤지스남성', '아디다스(슈즈)', '피지오겔'], dtype=object),
#  array(['참존', '오딧세이'], dtype=object),
#  array(['이롬'], dtype=object),
#  array(['캐스키드슨'], dtype=object),
#  array(['헤지스 레이디스'], dtype=object),
#  array(['크록스', '닥스 키즈', '뉴발란스(키즈)'], dtype=object),
#  array(['헤라', '샤넬', '미쟝센'], dtype=object),
#  array(['메디테이션'], dtype=object),
#  array(['이젠벅', '코지샵', '마모트', '바보사랑', '보디가드'], dtype=object),
#  array(['설화수'], dtype=object),
#  array(['크루클린', '에스케이네트웍스', '퀸센스', '상상'], dtype=object),
#  array(['소프트터치', '트라이', '아이홈', 'LG전자'], dtype=object),
#  array(['헤지스 레이디스', '핏플랍', '키엘', '해피콜', '정관장', '보브(의류)', '나이키'],
#        dtype=object),
#  array(['하우밍', '트라이엄프', '코즈니', '락앤락'], dtype=object),
#  array(['탑텐'], dtype=object),
#  array(['빅토리아앤프렌즈', '빈'], dtype=object),
#  array(['임부복닷컴', '미쟝센', '라이온코리아'], dtype=object),
#  array(['오가닉맘', '에디슨', '그로미미', '솔로몬샵'], dtype=object),
#  array(['앙드레김골프'], dtype=object),
#  array(['비오템'], dtype=object),
#  array(['스틸라', '아디다스 오리지널'], dtype=object),
#  array(['키엘', '첨이첨이'], dtype=object),
#  array(['베네피트', '트라이(속옷)'], dtype=object),
#  array(['아베다', '이롬'], dtype=object),
#  array(['라코스테(의류)'], dtype=object),
#  array(['동아제약', '베이비반즈'], dtype=object),
#  array(['솔로이스트', '종가집', '행텐'], dtype=object),
#  array(['랩', '잇미샤'], dtype=object),
#  array(['체이스컬트'], dtype=object),
#  array(['마더케이'], dtype=object),
#  array(['헤지스남성', '엔비에이', '뉴발란스'], dtype=object),
#  ...]

# %%
train_data4 = list(train.groupby('CLNT_ID')['KWD_NM'].unique())
test_data4 = list(test.groupby('CLNT_ID')['KWD_NM'].unique())
train_data4
# Out:
# [array(['에어컨 커버'], dtype=object),
#  array(['바비브라운', '키엘', '키엘비타민', '여자 래쉬가드', '정관장 홍삼정', '키엘선크림', '에브리타임',
#         '록시 모자', '서프캡'], dtype=object),
#  array(['타미힐피거여성', '크록스바야밴드클로그'], dtype=object),
#  array(['첨이첨이 남아팬티', '첨이첨이 파자마'], dtype=object),
#  array(['밍크뮤', '빈폴아웃도어', '해피프린스 양말', '해피프린스', '뚜아후아', '뚜아후아 귀걸이',
#         '베베드피노 레깅스', '베베드피노 양말', '갭베이비 여아', '베베드피노 오버롤', '빈폴남성', '코치'],
#        dtype=object),
#  array(['화장지'], dtype=object),
#  array(['계란', '리빙박스'], dtype=object),
#  array(['아토팜', '베이비로션', '냉장고'], dtype=object),
#  array(['록시땅 핸드크림', '록시땅 시어버터', '아디다스 맨투맨', '언더아머', '나이키 후드', '에스티로더',
#         '브이넥니트', '오리진스', '나이키 맨투맨', '원더브라 브라팬티세트', '오리진스 크림', '마크앤로나',
#         '디올 립밤'], dtype=object),
#  array(['남성지갑', '닥스지갑'], dtype=object),
#  array(['아디다스', '한율', '한율 선크림', '울타리', '아디다스 운동화 남성'], dtype=object),
#  array(['풀무원생수'], dtype=object),
#  array(['살레와', '살레와바지', '스파이더반팔티'], dtype=object),
#  array(['여성펌프스', '여성팬티', '브라런닝', '락포트여성화'], dtype=object),
#  array(['헤지스티셔츠', '헤지스남성', '굿베이스'], dtype=object),
#  array(['남자스킨', '양산', '면드로즈'], dtype=object),
#  array(['원피스'], dtype=object),
#  array(['디스커버리 브라탑', '레쉬가드 바지'], dtype=object),
#  array(['bb 크림'], dtype=object),
#  array(['남자청바지', '트렌치코트', '바바리', '블루투스 마이크', '반팔티', '지오다노반팔티'],
#        dtype=object),
#  array(['후드나시'], dtype=object),
#  array(['속바지', '속치마', '무료배송', '프릴 원피스', '인견 속바지'], dtype=object),
#  array(['무료배송', '뉴발란스키즈 티셔츠', '아이시스8.0', '팬콧 키즈 티셔츠', '삼다수500ML', '생수 500',
#         '기프티콘', '삼다수500', '루즈핏티셔츠', '생수', '스타벅스 기프티콘'], dtype=object),
#  array(['예지미인', '킨도', '드시모네'], dtype=object),
#  array(['종가집총각김치', '종가집김치', '남성기능성반바지', '면원피스', '남아 양말', '아동샌들', '투명우산',
#         '얼음주머니', '열무김치', '총각김치', '냉풍기', '골프마스크', '먼싱웨어모자', '점프슈트 여성',
#         '엘리든플레이 원피스', '골프볼주머니', '락피쉬', '빈폴남성반팔셔츠', '닥스남성반팔셔츠', '토스터기',
#         '엘르런닝', '어린이 크로스백', '남성반팔와이셔츠', '에스티듀퐁 넥타이', '빈폴남성반팔', '텐디여성화',
#         '네파양말', '필라양말', '여성양말'], dtype=object),
#  array(['여성롱티', '블루종', '블루독'], dtype=object),
#  array(['블루독 샌들', 'yk원피스'], dtype=object),
#  array(['라코스테 슬리퍼'], dtype=object),
#  array(['남아수영복', '스윔팬츠'], dtype=object),
#  array(['차앤박', '이니스프리 선크림', '이니스프리 스킨', '이니스프리'], dtype=object),
#  array(['노즈워크', '캣모나이트'], dtype=object),
#  array(['지오다노면티', '지오다노 반팔티', '지오다노 면티'], dtype=object),
#  array(['넥크림'], dtype=object),
#  array(['샘플링', '샘플', '체험 kit', '배송비체험'], dtype=object),
#  array(['화이트생리대', '남성 반팔 티셔츠', '지오다노 반팔티', '견미리', '정관장 에브리타임', '후드집업',
#         '견미리팩트홈쇼핑', '견미리팩트시즌10', '엘레강스신발', '여성 면팬티', '바이빠세', '소고기', '떡',
#         '면티', '여름 슬립온', '지오다노 면티', '폴햄 반바지', '여성 반팔니트', '뉴트로지나 클렌징오일',
#         '배추김치', '화장지', '웰메이드', '웰메이드남성', '갈비탕', '플리츠 원피스', '편강'],
#        dtype=object),
#  array(['흄 셔츠', '더셔츠스튜디오', '셔츠', '남성 점퍼'], dtype=object),
#  array(['세인트블레스', '시디즈의자 T50'], dtype=object),
#  array(['키엘', '빌리프', '빌리프에센스', '빌리프 에센스'], dtype=object),
#  array(['스와들스트랩', '포그내'], dtype=object),
#  array(['바비브라운', '바비브라운파우더'], dtype=object),
#  array(['베네통키즈 원피스', '미니로디니', '미니멜리사', '보보쇼즈', '프랜치캣원피스', '나이키스니커즈',
#         '크록스 키즈 이사벨라', '유아샌들', '크록스 키즈 샌들', '아디다스 스니커즈'], dtype=object),
#  array(['여성팬티'], dtype=object),
#  array(['아레나 여성수영복'], dtype=object),
#  array(['셀덴', '치크', '치크 여아', '헤지스키즈', '리바이스키즈', '스코노', '게스키즈'],
#        dtype=object),
#  array(['아이엘드 우양산', '3단우양산'], dtype=object),
#  array(['니트원피스 롱', '타임', '쁘리엘르', '에어컨커버 스탠드', '파슨스', '블라우스', '로엠', '잇미샤',
#         'it michaa', '바네사브루노', '베네통', '니트원피스'], dtype=object),
#  array(['데상트 반바지'], dtype=object),
#  array(['샌드위치메이커', '아디다스키즈'], dtype=object),
#  array(['밴드', '파우치', 's8 필름', '팬티', '팩', '면봉', '핀', '삔', '덧신'],
#        dtype=object),
#  array(['우동스푼'], dtype=object),
#  array(['크록스 남성 슬리퍼', '크록스 슬리퍼', '나이키운동화', '나이키에어', '여성구두', '슬립', '인견속치마'],
#        dtype=object),
#  array(['닥스키즈 여아 티셔츠', '닥스키즈티셔츠', '닥스키즈원피스', '닥스키즈바지', '닥스키즈 여아',
#         '빈폴골프남성바지', '빈폴골프남성티셔츠', '빈폴골프남성'], dtype=object),
#  array(['쿠폰'], dtype=object),
#  array(['생수 2L'], dtype=object),
#  array(['어린이 치약'], dtype=object),
#  array(['케이투모자'], dtype=object),
#  array(['아쿠아슈즈', '여성 래쉬가드'], dtype=object),
#  array(['노스페이스', '노스페이스 티셔츠 남성', '젠틀몬스터', '선글라스', '크리스크리스티'], dtype=object),
#  array(['메디힐 마스크팩', '반팔 와이셔츠'], dtype=object),
#  array(['바이오더마'], dtype=object),
#  array(['노스페이스 백팩', 'lpga여성골프웨어', '여성배낭'], dtype=object),
#  array(['남여커플티'], dtype=object),
#  array(['크로스백', '알파드', '숄더백'], dtype=object),
#  array(['팬콧모자', '팬콧', '햇츠온모자', '슈퍼스타 파운데이션'], dtype=object),
#  array(['멜킨'], dtype=object),
#  array(['한일카페트'], dtype=object),
#  array(['썰스데이아일랜드 티셔츠'], dtype=object),
#  array(['유아 아쿠아 슈즈', '대자리', '휴지', '위닉스타워', '유아내의', '공기청정기', '쁘띠뮤',
#         '유아여름내의', '닭가슴살', '칠부내의', '린스', '식탁의자', '벤치의자', '물티슈', '한샘식탁의자',
#         '강아지간식', '앳코너 작시', '작시', 'zaxy', '작시샌들', '알포'], dtype=object),
#  array(['글라스락'], dtype=object),
#  array(['아이키커', '빌리프', '남자시계', '여행', '콘스탄틴', '빌리프 베이비'], dtype=object),
#  array(['매직카펫', '나이키 베네시 듀오', '아메리칸솔루션'], dtype=object),
#  array(['물'], dtype=object),
#  array(['노니', '나이키모자'], dtype=object),
#  array(['모공브러쉬'], dtype=object),
#  array(['귀걸이'], dtype=object),
#  array(['리틀그라운드', '유아내의', '유아내복'], dtype=object),
#  array(['게스진 여성청바지'], dtype=object),
#  array(['샴퓨', '아토팜 워시', '여성브라', '바디워시', '심리스브라', '유아바디워시', '화이트닝 에센스',
#         '노와이어브라', '유아내의', '유아샴푸', '아토팜'], dtype=object),
#  array(['헤지스면티', '크리스피롤', '여름자켓', '칠부소매', '썸머자켓', '디올어딕트립글로우', '여성가디건',
#         '파인애플', '디올어딕트립글로우 라즈베리'], dtype=object),
#  array(['정관장 아이패스h', '정관장 아이패스m'], dtype=object),
#  array(['시트세제', '앙블랑', '모자', '빈폴키즈', '핸드폰가방', '아이시스 200', '앙블랑물티슈', '휠라',
#         '나이키', '아디다스'], dtype=object),
#  array(['엘지 그램', '스틸라'], dtype=object),
#  array(['마더스베이비'], dtype=object),
#  array(['크리니크', '매그제이', '니코트', '제주삼다수', '쥬맥스', '버버리스카프', '매그제이 팬츠',
#         '매그제이 니트', '에가와리', '여성샌들'], dtype=object),
#  array(['소형세탁기', '대우세탁기', '세탁기', '장롱'], dtype=object),
#  array(['블로퍼', '여성 실내복', '여성 나시티', '헤어밴드', '여성실내복세트', '여름자켓', '여성 여름 점퍼',
#         '여성실내복', '남성 리바이스 청바지'], dtype=object),
#  array(['빌리프 뉴메로', '랩 로브', '아벤느', '미쏘'], dtype=object),
#  array(['나이키 나시', '남성 비치 반바지'], dtype=object),
#  array(['삼성충전기', '보조배터리', '비너스 잠옷', '충전기', '성인용품', '파자마', '라면', '팬티',
#         '예스 파자마', '생리대', '마우스패드', '청소기', '배터리', '남자 팬티', '제모크림', '클라이드 데님'],
#        dtype=object),
#  array(['쥬시쥬디'], dtype=object),
#  array(['락앤락', '락앤락 트롤리'], dtype=object),
#  array(['아동수영모자', '수정테이프', '가위'], dtype=object),
#  array(['유아 선크림', '키엘', '유아 청바지', '프리메라 선쿠션', '빌리프', '베이비보', '스티커북',
#         '프리메라', '콩순이 선쿠션', '소피루비'], dtype=object),
#  array(['예작 반팔셔츠'], dtype=object),
#  array(['jj지코트', '아디다스 티셔츠 남성', '로엠블라우스', '투미 블라우스', '린 블라우스', '올리비아로렌',
#         '로엠', '나이키 기능성'], dtype=object),
#  array(['안다르 에어쿨링'], dtype=object),
#  array(['메이크업포에버 파우더', '이니스프리', '나인', '설화수 옴므'], dtype=object),
#  array(['여아 청바지', '배럴 래쉬가드 남성'], dtype=object),
#  array(['올리비아하슬러 블라우스', '크로커다일 레이디 블라우스', '샤트렌 블라우스', '올리비아로렌블라우스',
#         '첨이첨이 런닝'], dtype=object),
#  array(['나이키 축구화', '나이키 축구화 hg'], dtype=object),
#  array(['로티캠프', '패스트캠프메가스위트'], dtype=object),
#  array(['토리버치', '토리버치가방 크로스백', '세노비스 오메가3'], dtype=object),
#  array(['프랜치캣', '블루독'], dtype=object),
#  array(['수저케이스', '수저세트', '캐리어', '수저통'], dtype=object),
#  array(['로사케이 미니', '써스데이 아일랜드 티셔츠', '써스데이'], dtype=object),
#  array(['암막커텐', '총각김치', '암막커튼'], dtype=object),
#  array(['에블린', '에블린 브라'], dtype=object),
#  array(['스커트', '베스트', '린넨베스트', '원피스', '블라우스'], dtype=object),
#  array(['수영가방'], dtype=object),
#  array(['구두주걱', '여아샌들'], dtype=object),
#  array(['키플링백팩', '만다리나덕백팩', '카드지갑'], dtype=object),
#  array(['엔유씨'], dtype=object),
#  array(['라메르', '조개'], dtype=object),
#  array(['츄르', '닭가슴살'], dtype=object),
#  array(['엘르언더웨어 여성', '엘르언더웨어', '닥터자르트 선크림'], dtype=object),
#  array(['차앤박 블랙헤드'], dtype=object),
#  array(['여성티셔츠', '투피스세트', '맛김치', '게스여성티셔츠', '다리미판', '게스여성', '청치마',
#         '디젤 티셔츠', '리바이스 티셔츠', '사이드테이블', '욕실매트', '주방매트'], dtype=object),
#  array(['투명마스카라', '마스카라', '헤지스지갑', '남자헤지스지갑'], dtype=object),
#  array(['웨스트우드', '지오다노 후드티', '지오다노 기본티', '지오다노 맨투맨', '나이키후드티', '군화',
#         '지오다노 티', '지오다노 흰티', '지오다노 경량'], dtype=object),
#  array(['식탁의자'], dtype=object),
#  array(['검은콩두유', '일회용카메라'], dtype=object),
#  array(['제트아킬레스', '휠라키즈 티셔츠', '샤워기헤드', '위닝 발키리', '베이런처LR', '남아민소매', '모기장',
#         '과탄산소다', '빈 남아 티셔츠', '남아 민소매', '물풀', 'BEEN', '현관모기장', '홍백작',
#         '남아나시티', '민소매', '아모스 물풀'], dtype=object),
#  array(['유산균', '센트롬 멀티비타민', '멀티비타민'], dtype=object),
#  array(['록시'], dtype=object),
#  array(['휠라 반팔티', '캘빈클라인 티셔츠', '면반바지', '르꼬끄 반팔'], dtype=object),
#  array(['아디다스슬리퍼', '주니어슬리퍼', '나이키슬리퍼'], dtype=object),
#  array(['프로레나타'], dtype=object),
#  array(['이노크아든', '휴대용 선풍기', '비스비바'], dtype=object),
#  array(['랑콤 로션', '에스쁘아', '랑콤 스킨', '슈에무라클렌징오일', '랑콤토너', '랑콤'], dtype=object),
#  array(['키엘'], dtype=object),
#  array(['갭베이비여아', '남아바지', '크록스 키즈 샌들', '한샘도마', '갭 베이비', '빈백쇼파',
#         '리바이스키즈티셔츠', '파코라반베이비', '크록스 여성 샌들', '오끼오', '크록스키즈', '블루독베이비',
#         '빌리프 선크림', '크록스키즈티셔츠', '리스트코트', '오랄비어린이칫솔', '세레스', '베어파우 샌들',
#         '스파오 티셔츠', '헤지스남성바지', '헤지스남성셔츠', '아디다스 주니어 샌들'], dtype=object),
#  array(['톰앤래빗', '스위브', '레깅스', '디스커버리', '톰앤래빗 팬츠', '헬스복 티셔츠', '디스커버리 레깅스',
#         '푸마', '라코스테'], dtype=object),
#  array(['루이까스텔', '테리파머'], dtype=object),
#  array(['컴포트랩'], dtype=object),
#  array(['폴앤조'], dtype=object),
#  array(['헤지스가방', '헤지스', '라코스테 여성 티셔츠', '헤지스레이디스', '라코스떼'], dtype=object),
#  array(['패딩조끼'], dtype=object),
#  array(['영캐주얼', '브이넥 반팔', '여성반바지', '베네피트', '베네피트 차차'], dtype=object),
#  array(['더 샘', '크록스 바야', '립스틱', '크록스'], dtype=object),
#  array(['헹켈중식도'], dtype=object),
#  array(['헬렌스타인 베개커버', '헬렌스타인', '커튼', '스타벅스컵', '반바지', '스타벅스', '티셔츠',
#         '스타벅스원두', '삼다수', '머그컵', '고데기', '입생로랑 립스틱', '물'], dtype=object),
#  array(['썬크림', '스노쿨링', '제이디엑스', '풀무원', '클렌징', 'jdx 남성골프웨어', '우비', '괌',
#         '해외여행', 'TV', '암밴드', '대싱디바', '스노쿨링마스크', '팔토시', '아쿠아', '디올 팩트',
#         '여행', '아쿠아삭', '신일선풍기', '팔토시쿨토시', '체인백'], dtype=object),
#  array(['쥬시쥬디', '엠엘비키즈', '홍샷', '아이라이너 붓펜', '오가게원피스', '오버핏', '오가게 블라우스',
#         '토모톰스', '업타운홀릭', '원피스', 'ㅇ', '약파우치', '플라잉타이거코펜하겐', '비비도', '토퍼'],
#        dtype=object),
#  array(['빌리프 선스크린', '노트북파우치 15인치', '트라이엄프', '밸롭', '여성샌들', '핏플랍 여성샌들',
#         '빈폴키즈', '유아캡모자', 'AHC 선스틱', '아동선캡', '여성 슬리퍼', '화애락큐', '바투카', '빌리프',
#         '빌리프 선쿠션'], dtype=object),
#  array(['클렌징크림'], dtype=object),
#  array(['마이메리키즈 원피스', '듀오락', '캠퍼', '마이메리키즈', '배럴 래쉬가드 여성', '캠퍼여성샌들',
#         '남자바지', '남자 반팔티', '베럴 래쉬가드'], dtype=object),
#  array(['트레비', '삼다수2L'], dtype=object),
#  array(['crocs', '김치'], dtype=object),
#  array(['여자 반팔티'], dtype=object),
#  array(['헹텐'], dtype=object),
#  array(['여행용캐리어', '코드제로a9', '에브리타임 홍삼정', '산타마리아노벨라', '핏플랍'], dtype=object),
#  array(['차앤박 선크림', '아이소이 클렌징'], dtype=object),
#  array(['손싸개 발싸개'], dtype=object),
#  array(['엘르 여성 팬티', '엘르 면팬티'], dtype=object),
#  array(['머렐', '스케쳐스 트윙클'], dtype=object),
#  array(['크롭티', '속옷', '에코백', '아디다스 원피스', '원더브라', '나시', '소원팔찌', '폭스타일',
#         '아디다스 클라이마', '벨트', '스마트픽', '오프숄더 티셔츠', '발목양말', '양말', '아디다스',
#         '노스페이스'], dtype=object),
#  array(['스케쳐스', 'jj지고트 바지', '반바지', '스케쳐스 여성'], dtype=object),
#  array(['면도기', '리복크로스핏', '질레트', '에어팟', '엑셀시오르', '애플 에어팟'], dtype=object),
#  array(['빈폴셔츠', '밴브루셔츠', '빈폴셔츠남성'], dtype=object),
#  array(['키엘 선크림'], dtype=object),
#  array(['하기스', '초당옥수수', '탱글티저', '맘엔맘엔', '아너스', '오가닉', '미구하라', '시세이도 뷰러',
#         '니노필로우', '꿈비 월드스타', '오가닉 인형', '지오필로우'], dtype=object),
#  array(['베스킨라빈스'], dtype=object),
#  array(['덴비'], dtype=object),
#  array(['알퐁소 여아', '렉켄', '알퐁소', '블루독 점퍼'], dtype=object),
#  array(['트윙클토', '푸고', '헬렌스타인 베개'], dtype=object),
#  array(['라코스테 원피스'], dtype=object),
#  array(['크록스', '크록스 샌들', '헤라 아쿠아볼릭'], dtype=object),
#  array(['리케이'], dtype=object),
#  array(['나스 듀오', '디스럽터', '버켄스탁 피사', '설화수크림', '나이키 맥스', '나이키 인비고',
#         '885105-001', '투포스쿨', '베네피트 아이브로우', '875695-101', '정샘물 쿠션', '주방집게',
#         'TS샴푸', 'AC8583', '마티덤', '나이키 조던', '휠라 뮬', '반스 뮬', '바나브', '설화수',
#         '유세린', '구찌가방', '라로슈포제', '블로퍼'], dtype=object),
#  array(['여성블랙티셔츠', '슈에무라 립스틱'], dtype=object),
#  array(['조말론', '코치 로그', '코치 딩키', '나스'], dtype=object),
#  array(['뚫어뻥', '파리게이츠모자', '판도라팔찌', '여성골프모자', '라코스떼', '타이틀리스트여성모자',
#         '까스텔바작골프웨어 여성', '데상트골프모자', '피지오겔크림', '더말로지카', '언더아머모자', '라코스테 린넨',
#         '입생로랑 쿠션', '입생로랑', '도담이', '메종블랑쉬', '타미힐피거여성', '과일칩', '제이에스티나귀걸이',
#         '비치백'], dtype=object),
#  array(['아쿠아슈즈', '올리빙 리빙박스', '올리빙', '비치 모자'], dtype=object),
#  array(['쿠키'], dtype=object),
#  array(['꼬망스', '아이빈구두', '앤디애플', '밤비노', '아이빈 샌들', '여아 샌들', '밤비니 샌들',
#         '아동 칠부티셔츠', '월튼키즈', '여아동 티셔츠', '에꼴리에', '맘스메이드', '일로딜로', '유솔'],
#        dtype=object),
#  array(['슈에무라 미스트', '원피스', '여성샌들', '롱셔츠원피스', '엘리자벳 샌들', '앳코너후드', '샤넬립스틱',
#         '롱원피스', '셔츠원피스', '샤넬섀도우', '제시인뉴욕', '웨지힐'], dtype=object),
#  array(['활기력'], dtype=object),
#  array(['핸드크림', '닥터아토', '스파클', '비비안스킨핏'], dtype=object),
#  array(['피지오겔', '황지수', 'vdl', '코치'], dtype=object),
#  array(['7부', '남자반바지 7부'], dtype=object),
#  array(['몬데인'], dtype=object),
#  array(['럭센스', '브라', '스포츠 브라', '레노마양산', '모드아이', '엠씨원피스', '리본 자켓', '아니베에프',
#         '여성 크로스백', '올리비아로렌티셔츠', '베스띠벨리', '크록스', '크록스 여성', '꼼빠니아자켓',
#         '조이너스 자켓', '리본 원피스', '레노마레이디스', '엠씨 여성', '엠씨 블라우스', '리스트팬츠'],
#        dtype=object),
#  array(['르네휘테르 샴푸', '지오다노후드티', '천연샴푸', '바비브라운 립스틱'], dtype=object),
#  array(['뉴발 트레이닝', '여자운동가방', '아디다스 티셔츠 여성', '운동가방', '나이키'], dtype=object),
#  array(['메트로시티 팔찌', '메트로시티', '캉골'], dtype=object),
#  array(['밀로앤개비'], dtype=object),
#  array(['멀티탭', '전선', '글라스락'], dtype=object),
#  array(['나이키 운동화 여성', '스프리스', '나이키 슬립온'], dtype=object),
#  array(['레노마키즈 여아', '여아 래쉬가드 바지', '크록스 샌들', '컬리수 래쉬가드', '에고이스트 와이드팬츠',
#         '모다까리나', '아동 운동화', '크록스', '침대 패드', '아망떼 패드', '온앤온 니트',
#         '시리즈 series 티셔츠', '잇미샤 니트', '헤지스남성티셔츠', '나이스클랍', '에고이스트 청바지',
#         '프레드페리', '테팔 볶음팬', '남성 스니커즈', '솔제니', '크록스 성인', '주니어 블라우스',
#         '버커루 티셔츠 여성', '잇미샤 팬츠', '게스티셔츠 여성', '게스 티셔츠', '제이제이지고트 블라우스',
#         '팬콧키즈 티셔츠', '세인트스코트 버킷백', '주니어 민소매', '제이제이지고트 팬츠', '제이제이지고트 원피스',
#         '율무가루', '테팔웍', '에고이스트니트', '컬리수 수영복', '쌀 10KG', '남자 스니커즈', '테팔궁중팬',
#         '네파 래쉬가드', '아디다스 여성반팔', '아디다스 반바지 여성', '니모주니어', '스케쳐스 남성 운동화',
#         '엘칸토 남성로퍼', '래핑차일드 여아', '엘르 양말', '스케쳐스', '주니어 치마바지', '남성 운동화'],
#        dtype=object),
#  array(['여름샌들', '메이크업포에버', 'LG', '입생로랑 컨실러', 'lg퓨리케어공기청정기', '미니클러치',
#         '샤넬향수', '랑방향수', '에스티로더', '입생로랑 파운데이션', '지니킴 샌들', '지니킴', '입생로랑'],
#        dtype=object),
#  array(['게스남성', '게스'], dtype=object),
#  array(['돌돌이 모자', '바디워시', '리바이스키즈', '프라이머', '썬캡', '커튼봉'], dtype=object),
#  array(['남성 바람막이 자켓', '아동바람막이점퍼', '아이더 남성 바람막이', '남성 바람막이'], dtype=object),
#  array(['로엠걸즈 원피스', '여아원피스', '여아샌들', '발레복', '아식스운동화', '휠라슈즈', '여아운동화',
#         '베네통키즈 원피스', '나이키백', '웨이스트백', '휠라운동화', '나이키가방', '크록스', '엘르여아수영복',
#         '여아슬리퍼', '수영복', '여아수영복', '바나나팜스', '베네통키즈'], dtype=object),
#  array(['샤원피스', '공주원피스'], dtype=object),
#  array(['dhc'], dtype=object),
#  array(['정관장 홍삼톤마일드', '탑텐'], dtype=object),
#  array(['임블리', '노니주스'], dtype=object),
#  array(['우산', '가그린', '매직블럭', '고무장갑', '청소', '리빙박스', '리스테린', '칫솔', '페이크삭스',
#         '아기물티슈', '생수'], dtype=object),
#  array(['빈폴 남성 반바지', '빈폴 남성', '세인트 제임스', '엠엘비모자', '챙모자', '나이키 코리아'],
#        dtype=object),
#  array(['록시땅 샴푸'], dtype=object),
#  array(['베이비파우더', '썬스틱'], dtype=object),
#  array(['비비고', '잭앤질 샌들', '에스케이투', '바바라샌들'], dtype=object),
#  array(['키엘에센스', '오휘'], dtype=object),
#  array(['록시키즈', '퀵실버키즈', '아동 워터레깅스'], dtype=object),
#  array(['anf 6free'], dtype=object),
#  array(['올리브오일'], dtype=object),
#  array(['라피아햇', '톰슨', '여성 반바지', 'sj sj 원피스', '헬렌카민스키', '숲 티셔츠',
#         '여름 티셔츠 여성', '톰슨 에어프라이어', '반팔원피스', '이엔씨티셔츠', '레코브 티셔츠', '여성 썬캡',
#         '레코브 원피스', '써스데이아일랜드티셔츠', '여성 반팔원피스', '여름 가디건', '베네통 여성 티셔츠'],
#        dtype=object),
#  array(['코렐코디네이츠'], dtype=object),
#  array(['어그부츠', 'UGG', '투쿨포스쿨', '온더바디', '잉가', '러비더빅', '바비브라운 컨실러', '부티',
#         'ugg', '이자벨마랑', '투쿨포스쿨 쿠션', '빌리', '바비브라운', '양모코트', '오버핏 블라우스',
#         '도호', '나크21', '도호여성의류', '오버핏 가디건', '테팔', '전자렌지 용기', '테팔 볶음팬',
#         '클래식패브릭', '라셀렌', '머스크렛', '크라운구스', 'H라인', '랄프로렌 남성', '소프라움 구스',
#         '소프라움', '폭스 코트', 'H라인 원피스', '보니스팍스', '커버업', '남성 폴로티', 'yk편집샵',
#         '남성 폴로', 'POLO', '꼬달리'], dtype=object),
#  array(['설화수 세트'], dtype=object),
#  array(['코모도스퀘어'], dtype=object),
#  array(['화장솜', '화장품정리함'], dtype=object),
#  array(['압축팩', '스너글', '투썸플레이스'], dtype=object),
#  array(['지오다노 반팔티', '화장솜', '헤지스남성티셔츠', '지오다노 티셔츠'], dtype=object),
#  array(['아디다스반바지', '멸균우유', '오휘 선크림', '나이키 반팔', '뉴발란스 반팔', '데상트 반팔',
#         '아디다스 반팔'], dtype=object),
#  array(['화분받침대', '메트로시티 양산', '바이네르 샌들', '여름모자'], dtype=object),
#  array(['롱티', '루즈핏티셔츠', '모니카룸', '레쉬가드'], dtype=object),
#  array(['세이프레스트'], dtype=object),
#  array(['아이잗바바', '엘라루원피스'], dtype=object),
#  array(['구찌 블로퍼', '블로퍼', '전신거울 화장대'], dtype=object),
#  array(['컬리수'], dtype=object),
#  array(['패스트백'], dtype=object),
#  array(['르니앤맥코이'], dtype=object),
#  array(['엘르 잠옷', '남자 파자마', '리바이스 바디웨어 남성', '나이키 남자 반바지', '리바이스 바디웨어 여성',
#         '여성팬티세트', '여성 홈웨어', '팬티세트', '여성 잠옷', '남자 반바지', '캘빈클라인언더웨어',
#         '리바이스 바디웨어', '캘빈클라인언더웨어 팬티 여성', '트라이엄프 잠옷', '여성 슬립', '비너스 잠옷',
#         '여성 사각팬티'], dtype=object),
#  array(['수분크림', '유기농노니주스', '비타민뱅크', '스테파넬', '냄비세트', '겉싸개', '골프양말',
#         '휘슬러압력솥', '선스틱', '유기농노니', '나이키모자', '린넨셔츠', '블라우스', '노니주스', '청바지',
#         '린넨 원피스', '여성 린넨 팬츠', '랩', '린넨팬츠'], dtype=object),
#  array(['수딩젤', '이유식스푼', '그로미미', '밀키웨이', '도블레도마', '기프티콘', '몽디에스', '샘플체험',
#         '샘플키트', '체험팩'], dtype=object),
#  array(['슈에무라클렌징오일', '랑콤', '시세이도 샴푸', '제니피끄', '슈에무라', '바비브라운 아이라이너'],
#        dtype=object),
#  array(['마블 선풍기', '마블 게이밍', '키엘 토너', '마블 티셔츠', '런닝', '나이키운동화', '버켄스탁 지제',
#         '마블우산', '버켄스탁', '나이키슬리퍼 여성', '빨래건조대', '나이키 힙색', '투미가방', '키엘 클렌저',
#         '키엘수분크림', '아디다스키즈 티셔츠', '아디다스키즈', '아디다스 슬리퍼', '투미', '나이키슬리퍼',
#         '투미 크로스백', '남성가방', '투미 백팩', '바비브라운', '키엘 수분크림', '나이키에어맥스97'],
#        dtype=object),
#  array(['스크래치초특가', '작시', '스크래치특가'], dtype=object),
#  array(['프리메라 토너', '수분크림', '빌리프 토너', '빌리프 모이스춰라이징밤', '빌리프 수분크림',
#         '프리메라 수분크림', '토너', '빌리프 크림', '랩시리즈 올인원', '양산'], dtype=object),
#  array(['여성베스트', '가을원피스', '닉스여성청바지', '여성시계', '캐스키드슨백팩', '버커루여성청바지',
#         '레노마키즈 여아', '지오다노여성청바지', '여성청바지', '레노마키즈 남아', '빈', '레스포삭 백팩',
#         '파우치백', '여성백팩', '빈남아', '면패드', '락포트여성화', '캐스키드슨', '여성맨투맨', '엠엘비맨투맨',
#         '망고여성', '케이트스페이드가방', '롱샴백팩', '롱샴가방', '레스포삭 크로스백', '리바이스여성청바지',
#         '슬랙스', '돌체구스토 캡슐', '드립커피', '닥스스카프', '여성장갑'], dtype=object),
#  array(['풍기인견이불'], dtype=object),
#  array(['발목양말', '덧신'], dtype=object),
#  array(['리뽀 에코백', '명품화장품', '메이크업포에버', '메이크업포에버 파우더'], dtype=object),
#  array(['핸드크림', '오야니 가방', '스킨푸드', '빨래건조대', '뷔스티에 원피스', '인덕션 후라이팬', '셔츠',
#         '카페의자', '모던하우스가구', '버블', '강아지간식', '네이처드림', '메이크업', '자이언트', '블라우스',
#         '코인코즈', '식탁매트', '곤약젤리', '펌프스', '탑', '스파오', '슈펜', '스니커즈', '마크앤로나',
#         '제임스딘브라', '샌들', '크록스', '샤워', '스킨푸드 블랙슈가', '거실장세트', '홀하우스키즈',
#         '스테인레스 밀폐용기', 's8 케이스', '생수', '김치냉장고', '낙지젓갈', '무선청소기', '핸드폰케이스',
#         '나이키운동화', '나이키', '나이키여성운동화', '변기커버', 's8', '갤럭시S8 케이스', '씨씨크림',
#         '메리야스', '식기건조', '식기', '분홍코끼리', '토니모리', '여성메리야스', '여성블라우스', '젓갈',
#         '랩', '린넨자켓', '마자켓', '아이리무버', '거실장', '에보니아소파', '파우치', '벙커침대',
#         '김나운더키친', 'ost 목걸이', 'OST', '남성남방', '청반바지', '헤이올리', '마크',
#         '좋은사람들속옷', '데님팬츠', '디스커버리슬리퍼', '데님쇼츠', '팬티', '빵틀', '생연어',
#         '버커루티셔츠 반팔', '전선', '티셔츠', '하다라보 고쿠쥰 스킨로션', '닥터자르트 선크림', '하다라보',
#         'bbia', '삐아', '페인트', '버커루티셔츠', '질바이스튜어트', '논슬립옷걸이', '여성티셔츠', '전기',
#         '코드'], dtype=object),
#  array(['여성슬립온', '프로스펙스 여성'], dtype=object),
#  array(['스커트', '윈', '마인', '니플패치', '닉스 남성', '여성구두', '여성청바지'], dtype=object),
#  array(['스마트픽 본점'], dtype=object),
#  array(['페라가모', '여자명품지갑', '명품 여성 가방', '코치 크로스백', '코치 숄더백', '여성지갑',
#         '페라가모지갑', '여성장지갑', '페라가모 지갑', '닥스가방', '숄더백', '명품지갑', '토트백',
#         '코치 미니 크로스백', '프라다', '코치 가방', '여성가방', '코치 여성 가방', '닥스레이디스', '코치가방'],
#        dtype=object),
#  array(['알로봇바지'], dtype=object),
#  array(['아동썬햇'], dtype=object),
#  array(['롯데월드'], dtype=object),
#  array(['시세이도 뷰러', '시세이도 마끼아쥬', '이솝 핸드', '바비브라운 섀도우', '로라메르시에 파우더',
#         '크리니크 래쉬파워', '나이키 탄준샌들'], dtype=object),
#  array(['스텝케어', '밍크뮤', '속바지', '여아속바지', '알레르망', '알레르망 패드', '미니멜리사 샌들',
#         '에티튜드', '푸고 빨대컵', '푸고', '유아 덧신', '유아 실내화', '보브', '유아 트레이닝'],
#        dtype=object),
#  array(['투명마스카라', '마스카라', '반지', '아이라이너', '메이블린', 'cc크림', '세제통'],
#        dtype=object),
#  array(['일리커피머신', '캡슐커피머신', '네스프레소 커피머신', '커피머신'], dtype=object),
#  array(['컵'], dtype=object),
#  array(['맥 브러쉬', '립스틱', '올리비아로렌 티셔츠', '클렌징폼', '이사베이 블라우스', '비키티셔츠',
#         '입생로랑 틴트', '나이스클랍'], dtype=object),
#  array(['MLB 모자', '한화', '마이크로sd카드', '한화이글스', '에스티로더 파운데이션 더블웨어',
#         '에스티로더 파운데이션', '파운데이션', '에스티로더 더블웨어', '기계식키보드'], dtype=object),
#  array(['매직스타터', '세노비스트리플러스', '프로바이오틱스', '세노비스', '에어팟', '비타민', '나스'],
#        dtype=object),
#  array(['sjyp', '케즈', '케즈 킥스타트', '캉골 토트백'], dtype=object),
#  array(['로엠 원피스', '아기양말', '코니테일', '에이치커넥트 원피스', '에이치커넥트 블라우스', '로엠 블라우스',
#         '셔츠원피스', '로엠 스커트', '달퐁 우주복', '톰보이 원피스', '오가닉맘 우주복'], dtype=object),
#  array(['rmk', '에스쁘아', '뚜쉬에끌라', '나스', '디올', '입생로랑', '프리메라', '어딕션', '산양분유',
#         '에르뎀', '휴지', '네오누드', '조르지오아르마니', '조르지오 아르마니', '크리니크', '랑콤',
#         '메이크업포에버', '로라메르시에', '바비브라운', '겔랑'], dtype=object),
#  array(['남성 슬랙스', '유아선물', '틴트', '헤라썬크림', '빈폴가방', '미니특공대', '남자셔츠',
#         '외장하드 1tb', '공룡메카드', '외장하드', '킥보드', '랑방', '나이키운동화', '텐디스니커즈',
#         '미소페스니커즈'], dtype=object),
#  array(['질스튜어트 우산'], dtype=object),
#  array(['베어파우 슬리퍼', '타카타카', '크록스키즈'], dtype=object),
#  array(['언더아머 레깅스', '언더아머 레깅스 여성'], dtype=object),
#  array(['맥'], dtype=object),
#  array(['버켄스탁 샌들', '버켄스탁 슬리퍼'], dtype=object),
#  array(['뱅뱅여름청바지', '청바지'], dtype=object),
#  array(['리버사이드호텔뷔페'], dtype=object),
#  array(['리스트', '코데즈컴바인 원피스', '지오다노 여성 팬츠'], dtype=object),
#  array(['파우더', '남성 츄리닝 바지', '주름치마', '남성츄리닝세트', '여름청바지여성', '캔버스운동화', '쉬즈미즈',
#         '나이키골프화 남성', '아디다스골프모자', '아디다스골프화 남성', '남성 린넨자켓', '올젠 자켓', '남성자켓',
#         '여성청반바지', '여성티셔츠', '코치 가방'], dtype=object),
#  array(['락포트샌들'], dtype=object),
#  array(['나이키 수영복'], dtype=object),
#  array(['남성츄리닝바지', '남성남방셔츠', '스케쳐스 슬립온'], dtype=object),
#  array(['본 셔츠', '남성셔츠', '여아치마바지', '뉴발란스 여성', '블루독신발', '뉴발란스키즈 운동화',
#         '노스페이스 래쉬가드', '뉴발란스키즈', '알로봇신발', '닥스키즈운동화', '여아스니커즈'], dtype=object),
#  array(['bi4509'], dtype=object),
#  array(['생수 무료배송', '생수2l', '생수2리터', '생수', '레미떼'], dtype=object),
#  array(['여름 롱원피스', '블루테일', '분홍코끼리 샌들', '블루페페원피스', '블루페페 팬츠', '블루페페',
#         '스커트 여성'], dtype=object),
#  array(['디저트', '디저트포크', '남자양말', '여행가방캐리어', '풀무원김치', '이종임김치', '달팡',
#         '샤오미 선풍기', '신일선풍기'], dtype=object),
#  array(['설화수 쿠션 리필'], dtype=object),
#  array(['코디갤러리'], dtype=object),
#  array(['듀퐁셔츠'], dtype=object),
#  array(['아르마니 언더웨어', 'MLB', 'nll', '케이스위스', '나스 에르뎀', '나스 립스틱', '나스'],
#        dtype=object),
#  array(['SK-II'], dtype=object),
#  array(['면가디건', '엔젤비닷'], dtype=object),
#  array(['미장센 헤어에센스', '제니튼치약', '수반', '티스푼포크세트'], dtype=object),
#  array(['브러시', '브러쉬 클리너', '벙거지', '아모레', '브러쉬', '챙모자', '퍼프', '모자',
#         '브러쉬 클렌저', '아이리무버'], dtype=object),
#  array(['죽제조기'], dtype=object),
#  array(['까스텔바작골프웨어 여성 티셔츠', '골프용품', '수려한', '헤라화장품', '까스텔바작골프웨어 남성'],
#        dtype=object),
#  array(['원피스잠옷', '여성롱티', '롱티'], dtype=object),
#  array(['아디다스 슈퍼스타'], dtype=object),
#  array(['톰보이', '씨씨콜렉트', '보니 알렉스', '불가리 향수'], dtype=object),
#  array(['스코노', '이불정리함', '쇼파커버', '여성 샌들 통굽', '스코노 키높이', '쥬니어샌들', '아이스팬츠',
#         '종합비타민', '원피스 쉬폰', '스타카토', '남성샌들'], dtype=object),
#  array(['네츄럴코어'], dtype=object),
#  array(['엘리자베스아덴'], dtype=object),
#  array(['아디다스키즈 티셔츠', '아디다스키즈', '아디다스 남성'], dtype=object),
#  array(['세컨스킨', '세컨스킨 팬티'], dtype=object),
#  array(['치약'], dtype=object),
#  array(['에어팟', '아이폰6s 케이스'], dtype=object),
#  array(['에스티로더 쿠션', '프리메라 클렌징폼', '프리메라'], dtype=object),
#  array(['로엠 치마바지', '레시가드 키즈', '톰앤래빗 블라우스', '레쉬가드', '뱅뱅 여성', '뱅뱅 여성청바지',
#         '크록스 여성', '니', '치마바지', '에르고 아기띠', '크록스 래쉬가드'], dtype=object),
#  array(['싸이닉', '싸이닉퍼스트에센스', '아기 우비'], dtype=object),
#  array(['닥스키즈', '레노마 와이셔츠'], dtype=object),
#  array(['스퍼'], dtype=object),
#  array(['케이크토퍼', '비키니수영복'], dtype=object),
#  array(['여아사파리', '베네통키즈'], dtype=object),
#  array(['아디다스 반팔'], dtype=object),
#  array(['남아 래쉬가드 세트', '남아 래쉬가드', '시크릿쥬쥬 셀카폰', '여성가방', '여성가방 크로스백',
#         '게스 반팔티', '시크릿쥬쥬 티아라폰', '유아 래쉬가드', '타요긴급출동센터', '맥끌라니 가방', '게스티셔츠'],
#        dtype=object),
#  array(['에트로 집게핀', '에트로 헤어핀', '슈에무라 파우더'], dtype=object),
#  array(['여름이불'], dtype=object),
#  array(['아몬드', '견과류'], dtype=object),
#  array(['나이키 레거시91', '폴로', '폴로모자', '샌들', '폴로랄프로렌 셔츠', '모자', '여성샌들', '야구모자',
#         '탐스', '씨즈캔디', '나이키운동화', '볼캡모자', '캡모자', '탐스슈즈', '폴로랄프로렌', '반팔',
#         '여성야구모자'], dtype=object),
#  array(['아동내의', '셔츠'], dtype=object),
#  array(['지오다노', '에이치커넥트'], dtype=object),
#  array(['LG생활건강', '애견패드'], dtype=object),
#  array(['가죽바지', '애견바리깡', '애견이발기', '코팅진'], dtype=object),
#  array(['에잇세컨즈 에코백', '에코백'], dtype=object),
#  array(['스타벅스 기프티콘'], dtype=object),
#  array(['비치원피스', '데님 숏팬츠', '실리콘 브라', '흄여성', '점프슈트 원피스', '르샵', '나시블라우스',
#         '방향제', '헤지스블라우스', '수모', '만년도장', '니모주니어', '약콩두유', '나이스클랍원피스',
#         '점프슈트 여성', '피그먼트', '칸막이', '컴포트랩', '행운목', '케네스레이디블라우스',
#         '크로커다일레이디 티셔츠', '빈폴블라우스', '보냉백', '노스페이스슬리퍼', '자갈', '슬리퍼'],
#        dtype=object),
#  array(['약콩두유', '스케쳐스', '홈쇼핑', '롯데홈쇼핑', '크리비아', '여아브라런닝', '브라런닝', '속바지',
#         '크리비아 브라런닝', '나귀사'], dtype=object),
#  array(['h connect 여성', 'h connect'], dtype=object),
#  array(['블랙야크키즈', '매긴티셔츠', '코코블랙', '키즈상하', 'MLB 반팔티셔츠', 'MLB 반팔',
#         '플라스틱아일랜드티셔츠', 'MLB 후드', '리바이스키즈', 'MLB 티셔츠', '오조크', 'MLB 반팔 티셔츠',
#         '휠라키즈', '키즈크로스백', '리스트'], dtype=object),
#  array(['니트가디건', '니트가디건여성'], dtype=object),
#  array(['디스퀘어드2남성청바지', 'CP컴퍼니 바지', 'CP컴퍼니'], dtype=object),
#  array(['이앤씨', '여성맨투맨', '여성니트티', '스위브', '실버팔찌', '클라이드', '지지피엑스', '펜콧',
#         '페르미츠 여아', '체크자켓', '헤지스레이디스', '맨투맨 여성', '실버목걸이', '니트원피스', '르샵',
#         '휠라슬립온', '빈폴레이디스', '탑걸', '체크치마', '니트나시', '스퍼 펌프스', '푸마슬립온',
#         '아디다스 슬립온', '나이키 슬립온', '데상트슬립온', '아메리칸이글여성', '끈나시', '롱끈나시', '여성슬립',
#         '콜롬비아 여성', '망고여성', '디스커버리 여성', '빈폴아웃도어여성', '르샵 원피스', '망고스틴',
#         '뉴발란스맨투맨', '뉴발란스 여성', '빈폴골프여성 티셔츠', '여성바지', '빨강호두', '닥스여성티셔츠',
#         '여성골프웨어', '콜롬비아 티셔츠', '스퍼'], dtype=object),
#  array(['매일 두유', '서리태97', '헤라 쿠션', '두유'], dtype=object),
#  array(['침낭', '여성샌들'], dtype=object),
#  array(['닥터자르트비비', '닥터자르트'], dtype=object),
#  array(['베네피트', '덱케', '베네피트 단델리온', '빈폴레이디스 원피스', '써스데이아일랜드원피스',
#         '헤지스 레이디스 원피스', '샤트렌 바지'], dtype=object),
#  array(['윤조에센스', '설화수'], dtype=object),
#  array(['꼼데가르송 여성', '시스템 여성', '보스 이어폰', '레터링 여성티셔츠', '나이키 운동복 여성', '맨투맨',
#         '시슬리 치마', '나이키 바람막이 여성', '반팔티', '챔피온 티셔츠', '나이키운동화', 'system 의류',
#         '시슬리', '로엠', '나이키 점퍼', 'sj sj', '에스제이와이피', '톰보이 원피스', '시슬리 티셔츠',
#         '시스템 니트', '온앤온', '럭키슈에트', '골든구스 여성', '컨버스', '럭키슈에뜨', 'SYSTEM',
#         '베네통', '꼼데가르송', '챔피온 반팔티', '시스템'], dtype=object),
#  array(['뉴발란스 여성'], dtype=object),
#  array(['롱셔츠원피스', '레노마 여성 수영복'], dtype=object),
#  array(['아디다스 여성 티셔츠', '그로미미 빨대리필'], dtype=object),
#  array(['까스텔바작가방', '골든구스', '빅토리아앤프렌즈', '마크제이콥스 가방'], dtype=object),
#  array(['예스속옷', '엠엘비키즈', '바디로션', '뉴발란스키즈 운동화'], dtype=object),
#  array(['헐리키즈주니어', '아르마니주니어', '아동 바지', '주니어', '티파니주니어'], dtype=object),
#  array(['남아양말'], dtype=object),
#  array(['타미힐피거남성 반바지', '레노마 반바지', '타미힐피거남성', '빈폴', '홍이장군2단계', '비지트'],
#        dtype=object),
#  array(['애견옷'], dtype=object),
#  array(['치크', '어깨트임 원피스'], dtype=object),
#  array(['르꼬끄 슬리퍼'], dtype=object),
#  array(['궁중비책'], dtype=object),
#  array(['이유리 쿠션', '차렵이불', '핑크쿠션', '맥립스틱', '사이드테이블', '경추베게', '데코르테', '보이로'],
#        dtype=object),
#  array(['여성레깅스', '뉴발란스 여성레깅스', '데쌍트트레이닝복', '롱패딩', '아디다스 여성레깅스', '데쌍트레깅스'],
#        dtype=object),
#  array(['금강제화여성', '구찌키홀더', '롯데닷컴 루이비통', '락포트여성화', '루이비통', '에스콰이어여성구두',
#         '버버리 가방', '악녀일기 블라우스', 'MCM아울렛가방', '여성바지', '레노마여성구두', '블라우스여성'],
#        dtype=object),
#  array(['맥 섀도우', '마드모아젤', '맥 립스틱', '에어팟 케이스', '입생로랑', '키링'], dtype=object),
#  array(['세탁세제', '비비고만두'], dtype=object),
#  array(['청소포', '바구니', '빨래바구니', '포스트잇', '원목책장', '목욕바구니', '바디샵 바디버터'],
#        dtype=object),
#  array(['베베숲 물티슈', '지갑', '베베숲', '강아지 계단'], dtype=object),
#  array(['블랙야크키즈'], dtype=object),
#  array(['메디힐'], dtype=object),
#  array(['bz0418'], dtype=object),
#  array(['호피스커트', '밀폐용기 유리'], dtype=object),
#  array(['몰튼브라운'], dtype=object),
#  array(['어반디케이 픽서', '어반디케이'], dtype=object),
#  array(['여름 긴팔 남성', '등산모자', '트렁크팬티'], dtype=object),
#  array(['남성 팬티', '테이트', '탑텐', '테이트여성', '탑텐 티셔츠', '탑텐 여성', '여성칠부티셔츠',
#         '탑텐 래쉬가드', '헬스자전거', '테이트티셔츠', '에코백', '카파반바지레깅스', '여성반바지레깅스',
#         '네셔널지오그래픽에코백'], dtype=object),
#  array(['바오바오백', '아이시스 300', '어린이수영복', '아이시스8.0', '키즈여아수영복'], dtype=object),
#  array(['코벳블랑 원피스', '코벳블랑', '플라스틱아일랜드티셔츠', '베네통 여성 티셔츠', '시에로티셔츠', '지컷티셔츠'],
#        dtype=object),
#  array(['정관장홍삼정'], dtype=object),
#  array(['클렌징티슈', '뉴트로지나 바디로션', '매직마우스', '플러스마이너스제로청소기', '실리콘 찜기', '아베다 샴푸',
#         '아베다 펌프', '화애락진', '아벤느', '두피', '로션', '케라스타즈', '멜킨 요가매트', '브러쉬',
#         '샴푸', '선블럭', '선파우더'], dtype=object),
#  array(['섹시쿠키브라세트'], dtype=object),
#  array(['남성 남방', '남성 반팔셔츠', '남성 셔츠', '체이스컬트 원피스', '남성 반팔남방', '반팔 면티',
#         '남성 체크남방'], dtype=object),
#  array(['속치마', '원피스속치마', '미쏘', '버켄스탁', '스퍼', '슬랙스', '조군샵', '타미힐피거', '니트',
#         '러쉬 마스크', '린넨바지', '스퍼 슬링백'], dtype=object),
#  array(['키엘 울트라훼이셜크림', '키엘 오일', '레오나르도'], dtype=object),
#  array(['피플랍슬리퍼'], dtype=object),
#  array(['디올어딕트립글로우'], dtype=object),
#  array(['발', '설화수 자음유액', '요커버 s', '헤지스레이디스', '더바디샵 샤워젤', '요커버', '크린랩 고무장갑',
#         '설화수 클렌징 폼', '낮잠이불', '슈에무라 스펀지', '디올', '메이크업 스펀지', '디올 컴팩트',
#         '이불커버', '한입세제', '면티', '설화수자음2종기초세트', '클렌징 폼', '안나수이 립', '안나수이',
#         '설화수 2종', '베개', '낮잠패드', '쉬즈홈', '설화수 로션', '비너스 위생팬티', '설화수 상백크림',
#         '비너스 팬티', '루테인', '설화수 선크림', '비비안 위생팬티', '설화수 수율', '베게커버'],
#        dtype=object),
#  array(['남아상하', '여성팬티', '남아트레이닝', '첨이첨이양말', '첨이첨이 양말', '아동양말', '아동양말 남아',
#         '남아상하복', '마이도기'], dtype=object),
#  array(['바비브라운', '바비브라운 립스틱'], dtype=object),
#  array(['H커넥트', '빈폴아웃도어', '빈폴아웃도어여성', '빈폴아웃도어여성반바지'], dtype=object),
#  array(['멜빵팬츠', '핑크시슬리 티셔츠', '코스타노바 머그', '제시뉴욕', '써스데이 아일랜드 티셔츠',
#         '타미힐피거 원피스', '타미힐피거데님원피스', '타미진', '헨리코튼 티셔츠', '타미힐피거남성셔츠', '지프',
#         '트레이닝복세트', '타미힐피거남성', '피플랍', '지프원피스', '써스데이원피스', '핑크시슬리',
#         '써스데이아일랜드', '핏플랍남성'], dtype=object),
#  array(['펌프스', '여성구두', '매그제이블라우스', '여성펌프스', '여성구두5cm', '스트랩', '애견계단',
#         '스트랩힐'], dtype=object),
#  array(['갭키즈 남아', '블루독키즈'], dtype=object),
#  array(['게스이너웨어', '게스 브라', '유니클로', '게스언더웨어 여성세트', '헹거'], dtype=object),
#  array(['밍크뮤 내의', '유아크로스백', '블루독내의', '밍크뮤'], dtype=object),
#  array(['일리윤', '스킨푸드', '세인트이브스'], dtype=object),
#  array(['코튼렛', '베개커버', '헬렌스타인', '베개커버 50x70'], dtype=object),
#  array(['지오다노'], dtype=object),
#  array(['5단우양산', '우양산'], dtype=object),
#  array(['데상트슬리퍼'], dtype=object),
#  array(['지라프', '휴대용 가스렌지'], dtype=object),
#  array(['패스트캠프메가스위트'], dtype=object),
#  array(['리리코스', '선물', '크록스 웨지힐', '러쉬', '네스프레소 캡슐', '러쉬 엔젤스'], dtype=object),
#  array(['디스커버리 여성', '디스커버리남성티셔츠', '버버리 신발 여성', '디스커버리', '데상트여성바지', '데상트',
#         '디스커버리 반팔티', '디스커버리 여성 팬츠', '닥스여성의류', '데상트여성 티셔츠', '디스커버리신발',
#         '데상트여성', '데상트여성트레이닝복', '데상트운동화 여성'], dtype=object),
#  array(['남성바지', '무선마우스', '노트북가방', '아이스팩', '여행욕실 파우치', '비옷', '블랙박스', '방수자켓',
#         '마우스패드', '여행파우치', '세면도구세트', '노트북', '세면파우치'], dtype=object),
#  array(['블루투스스피커', '삼성 프린터', '전동킥보드', '전동킥보드악세사리', '무릎담요', '차이슨', '지이크',
#         '투미', '지이크 바지', '지이크 셔츠', '담요', '지이크 정장', '차이슨 드라이기'], dtype=object),
#  array(['써큘레이터', '신일서큘레이터'], dtype=object),
#  array(['리바이스키즈', 'MLB키즈', '뉴발란스키즈', '키즈 티셔츠', '뉴발란스키즈 티셔츠', 'MLB키즈 티셔츠',
#         '블루독키즈'], dtype=object),
#  array(['반팔티', '튜브', '비치볼', '여성잠옷', '레이지비 래쉬가드 세트', '잠옷', '세노비스 루테인',
#         '미니고데기', '아노락', '볼터치', '여성팬티', '빈폴레이디스', '캐주얼원피스', '샤워기헤드',
#         '아디다스 아노락', '소프롱', '선풍기', '아레나 여성 래쉬가드', '티셔츠', '키보드', '아이폰 충전기',
#         '수건'], dtype=object),
#  array(['에스티로더', '조르지오 아르마니'], dtype=object),
#  array(['비오템옴므', '랩 LAP', '비오템', '랩시리즈', '랩'], dtype=object),
#  array(['게스', '게스진', '엠폴햄', '러브앤쇼', '나무그림'], dtype=object),
#  array(['주니어1단계', '유아슬리퍼', '냉장고티셔츠', '크록스 키즈', '아디다스 레깅스', '여성팬티',
#         '잭앤질 샌들', '아토팜 수딩젤'], dtype=object),
#  array(['헤지스골프 티셔츠', '실리트', '깨갈이'], dtype=object),
#  array(['아디다스빅트레포일', '쥬니어래쉬가드', '빈'], dtype=object),
#  array(['슬랙스', '아디다스슈퍼스타'], dtype=object),
#  array(['조르지오 아르마니'], dtype=object),
#  array(['시슬리 니트', '시스루블라우스', '집게핀', '시슬리 블라우스', '에고이스트', '데일리라이크', '흄반바지',
#         '에잇세컨즈', '이니스프리 썬크림', '달맞이꽃종자유', '지유샵', 'frj 남성', '흄 팬츠', '클렌징오일',
#         '디너포크', 'FRJ 티셔츠', '지고트 스커트', '개사료', '로얄캐닌'], dtype=object),
#  array(['워터레깅스', '래쉬가드 바지', '여성 워터레깅스', '래쉬가드 여성', '남성 워터레깅스', '여성 래쉬가드'],
#        dtype=object),
#  array(['올가홀푸드'], dtype=object),
#  array(['캐리어', '스포츠 브라', '타미힐피거'], dtype=object),
#  array(['미디스커트'], dtype=object),
#  array(['아디다스 트레이닝복', '아디다스 트레이닝복 세트'], dtype=object),
#  array(['리터로봇'], dtype=object),
#  array(['아동 청바지', '노리개', '아동 바람막이점퍼', '남아 긴팔티셔츠'], dtype=object),
#  array(['앤디애플', '아동바지', '리바이스키즈', '블루독트레이닝', '니베아', '댄트롤', '푸마키즈', '비듬샴푸',
#         '스테판플라스트', '레노마키즈', '아동후드집업', '레모나', '내츄럴코어', 'anf', '송월타올',
#         '아디다스키즈바지', '메쎄샌들', '블루독키즈', '꽃담초섬유유연제', '소보제화', '켄넬', '노즈워크',
#         '이동장', '물티슈', '개껌', '아동양말', '토미힐피거키즈', '플레이키즈프로', '핸드크림세트', '더그린',
#         '블루독', '블루독맨투맨', '강아지이동가방', 'ANF', '블로퍼', '깨소금', '아동양말세트'],
#        dtype=object),
#  array(['입생로랑 틴트', '조말론향수', '맥 섀도우', '맥', '메이크업브러쉬'], dtype=object),
#  array(['써스데이아일랜드 가디건', '예스비 원피스', '빈폴', '플러스 마이너스 제로', '온앤온 원피스',
#         '나이스클랍원피스', '빈폴 가디건', '스커트 여성', '스커트', '헤지스레이디스', '앤클라인 원피스',
#         '써스데이아일랜드'], dtype=object),
#  array(['셔링 원피스'], dtype=object),
#  array(['몽타규', '송월타올', '종가집김치', '옷행거', '남성 바지', '옷걸이행거', '옷장',
#         '시몬스 매트리스 슈퍼싱글', '왕자행거', '한샘옷장', '바바패션', '리빙박스', '리바트옷장', '요하넥스',
#         '리무버', '몽타규니트', '네일리무버', '락앤락 리빙박스', '여성안경테', '베스띠벨리', '양배추브로콜리즙',
#         '명품 안경테', '블랙보리', '안국 루테인', '손선풍기', '리안 뉴욕', '코엔자임큐텐', '듀오백의자',
#         '논슬립옷걸이', '티포트'], dtype=object),
#  array(['남성 니트'], dtype=object),
#  array(['유리아쥬'], dtype=object),
#  array(['테아', '그로미미 빨대컵'], dtype=object),
#  array(['바람막이 여성', '래쉬가드', '크록스래쉬가드', '주니어래쉬가드'], dtype=object),
#  array(['지오다노 롱셔츠', '유니클로 여성'], dtype=object),
#  array(['아식스 스니커즈', '여성 슬립온', '휠라 여성 운동화', '여성 스니커즈', '남아 운동화'],
#        dtype=object),
#  array(['마모트'], dtype=object),
#  array(['덕케가방'], dtype=object),
#  array(['블랙야크', '디스커버리', 'K2', '반바지'], dtype=object),
#  array(['아디다스 슬리퍼', '아벤느', '슬리퍼'], dtype=object),
#  array(['브라탑', 'stl 여성래쉬가드'], dtype=object),
#  array(['나스', '알로봇래쉬가드'], dtype=object),
#  array(['클리오 아이라이너', '여성블라우스', '비오템옴므', '햄팬티', '아이라이너', '클리오'],
#        dtype=object),
#  array(['오야니 가방'], dtype=object),
#  array(['오즈세컨 니트', '빈폴레이디스점퍼'], dtype=object),
#  array(['원피스', '헤지스원피스', '타미원피스', '흰운동화'], dtype=object),
#  array(['파운데이션', '헤라 파운데이션', '랑콤 리무버'], dtype=object),
#  array(['롱샴르플리아쥬네오', '에이치커넥트', '파우더팩트', '스티유 샌들', '코치 라일라', '코치 이슬라'],
#        dtype=object),
#  array(['한샘책상세트'], dtype=object),
#  array(['해피프린스', '해피프린스 양말', '해피프린스 레깅스', '해피프린스 우주복'], dtype=object),
#  array(['벽걸이에어컨', '뉴트라라이프', '삼성김치냉장고', '김치냉장고', '딤채소형김치냉장고', '삼성김치냉장고뚜껑'],
#        dtype=object),
#  array(['조르지오아르마니', '로라메르시에', '케라스타즈', '입생로랑', '바비브라운', '메이크업포에버'],
#        dtype=object),
#  array(['아동샌들'], dtype=object),
#  array(['텐바이텐', '러빈코티지', '가리개 커튼'], dtype=object),
#  array(['디스커버리 바람막이', '여성바람막이', '바람막이', '생수', '설화수자음수', '설화수'],
#        dtype=object),
#  array(['배럴', '아쿠아슈즈 유아'], dtype=object),
#  array(['황진단', '파란자차', '노트북거치대', '신영와코루 아네타', '정관장황진단', '인디안남성셔츠',
#         '남성반팔남방', '정관장', '토마토', '대저토마토'], dtype=object),
#  array(['에르메스', '여성로퍼'], dtype=object),
#  array(['유아 바람막이', '밀리밤원피스', '오즈키즈 구두', '여아 바람막이', '셀덴', '로엠걸즈', '아니베에프',
#         '로엠걸즈 가디건', '여아 가디건', '밀리밤', '오후'], dtype=object),
#  array(['클라란스', '화장솜', '수분크림', '르샤트라1802', '수려한', '러쉬 샴푸', '유노하나입욕제',
#         '비욘드'], dtype=object),
#  array(['손가방', '여성손가방'], dtype=object),
#  array(['런드레스', '딥티크', '소프시스', '바이레도', '오드리선'], dtype=object),
#  array(['스카프', '임부속옷', '트윌리 스카프', '여름모자', '나이키모자', '임산부속옷'], dtype=object),
#  array(['킨더스펠'], dtype=object),
#  array(['노스페이스 폴로', '노스페이스'], dtype=object),
#  array(['모슬린', '닥스남방', '마담', '리본', '블랙마틴싯봉'], dtype=object),
#  array(['디올'], dtype=object),
#  array(['사과즙', '닭가슴살'], dtype=object),
#  array(['프렌치캣 스커트'], dtype=object),
#  array(['스킨푸드 웨지퍼프', '벨킨 케이블', '비오템옴므', '스냅백', '로라메르시에 진저'], dtype=object),
#  array(['에어프라이어', '극세사담요'], dtype=object),
#  array(['아동 티셔츠', '아동반바지'], dtype=object),
#  array(['후드집업', '후드티', '남방'], dtype=object),
#  array(['밸리걸 블라우스', '폴햄키즈', '홑겹트렌치', '밸리걸'], dtype=object),
#  array(['여성티셔츠 긴팔', '나이키 모자', '넥타이핀', '나이키운동화', '나이키 골프 남성 티셔츠'],
#        dtype=object),
#  array(['후그여자수영복', '지오다노 반팔티', '수경', '리바디레깅스'], dtype=object),
#  array(['여성 와이드팬츠', '여성 와이드데님'], dtype=object),
#  array(['시에로', '써스데이아일랜드'], dtype=object),
#  array(['게스나시', '라코스테조끼', '트위드', '쉬폰원피스', '숲원피스', '시에로', '티렌', '시슬리 원피스',
#         '시슬리', '사과즙'], dtype=object),
#  array(['에이치커넥트여성', '지오다노 슬랙스'], dtype=object),
#  array(['비치웨어', '래쉬가드 하의', '비치 커버업', '집업래쉬가드', '스윔팬츠', '수영복 팬츠'],
#        dtype=object),
#  array(['나이키모자', '후라이팬'], dtype=object),
#  array(['케즈', '에이치커넥트', '에이치커넥트 로브'], dtype=object),
#  array(['오휘', '탑텐'], dtype=object),
#  array(['여성청반바지', '여성반바지', '디스커버리', '르꼬끄', '리바이스키즈', '디스커버리 티셔츠 여성',
#         'MLB맨투맨티셔츠', 'MLB', '리바이스', '데쌍트', '디스커버리반바지'], dtype=object),
#  array(['보니타빈백'], dtype=object),
#  array(['슈에무라 번트로즈'], dtype=object),
#  array(['jj지코트'], dtype=object),
#  array(['케네스레이디 원피스', '나이스크랍 자켓', '트위드자켓', '케네스레이디 팬츠', '꼬달리', '닥스여성가방',
#         '엘르이너웨어', '잇미샤 원피스', '제이제이지고트원피스', '라인 원피스', '케네스레이디 자켓', '라인원피스',
#         '라인 자켓', '라인자켓', '미니멜리사', '라인팬츠', '라인 니트', '제이제이지고트', '라인 팬츠'],
#        dtype=object),
#  array(['원석팔찌', '여성가죽팔찌', '여성 팔찌'], dtype=object),
#  array(['고무장갑', '달팡 인트랄'], dtype=object),
#  array(['깨끗한나라 화장지', '이자녹스 선크림', '더페이스샵 선크림', '이자녹스 선스틱', '아이오페선스틱',
#         '한입세제', '선크림', '닥터지선스틱', '선스틱', '화장지', 'LG청소기', '세타필크림', '불가리 향수',
#         '쌀 20kg'], dtype=object),
#  array(['기획전', '플라잉타이거'], dtype=object),
#  array(['라코스테 양말', '디올어딕트립글로우', '샤넬립스틱'], dtype=object),
#  array(['호킨스', '남자 구두'], dtype=object),
#  array(['지방시 판도라'], dtype=object),
#  array(['티비제이반바지', '폴햄반바지', '심리스', '빈폴레이디스스커트', '태그호이어여성시계', '태그호이어시계',
#         '판도라뱅글', '클라이드 여성', '빈폴레이디스', '빈폴레이디스자켓', '빈폴레이디스티셔츠', '판도라 반지',
#         '흄 여성', '빈폴레이디스 셔츠', '닥스키즈여아', '브루노말리', '빈폴레이디스가디건', '헤지스레이디스가디건',
#         '어스앤뎀 남성 티셔츠', '에잇세컨즈 여성 티셔츠', '빈폴레이디스스카프', '판도라팔찌', '판도라귀걸이',
#         '빈폴레이디스블라우스', '오베이', '빈폴레이디스팬츠', '빈폴레이디스원피스', '닥스키즈블라우스',
#         '빈폴레이디스청바지', '락포트샌들', '게스슈즈', '빈폴슈즈', '금강구두', '게스구두', '락포트',
#         '에잇세컨즈', '에잇세컨즈청바지', '캘빈클라인진 여성', '어스앤뎀 여성', '아레나아동수영복', '여아레쉬가드',
#         '아레나 여성수영복', '여아수영복', '펠틱스', '버커루', '빈폴아웃도어', '아레나 여아 수영복',
#         '탑텐반바지', '반팔티', '헤지스레이디스티셔츠 반팔', '헤지스레이디스블라우스', '르꼬끄골프', '아레나수영복',
#         '캘빈클라인팬티', '빈폴레이디스 블라우스', '세덕티브', '심리스팬티', '빈폴레이디스 티셔츠',
#         '캘빈클라인언더웨어', '에잇세컨즈 여성', '로엠걸즈', '르꼬끄운동화', '나이키에어', '캘빈클라인',
#         '캘빈클라인 지갑', '르꼬끄', '르꼬끄레깅스', '폴햄', '헤지스키즈', '헤지스키즈 티셔츠', '에잇세컨드',
#         '마인브릿지', '핑골프'], dtype=object),
#  array(['후라이팬', '포크세트', '수건', '생선그릴', '생선구이오븐', '이어폰', '솔가 유산균', '이고진스텝퍼',
#         '모달이불'], dtype=object),
#  array(['이월패딩'], dtype=object),
#  array(['ggpx', '여성 베스트', '쉬폰 베스트', '베스트', '가죽베스트', '빨래바구니', '머메이드 스커트',
#         '에고이스트원피스', '에고이스트', '딘트', '밥상 접이식', 'GGPX원피스', '데님베스트',
#         '머메이드롱스커트', '나이키가방', 'GGPX'], dtype=object),
#  array(['생수', '비오템스킨'], dtype=object),
#  array(['써스데이아일랜드', '크리니크', '여성여름원피스', '전기압력밥솥', '쿠쿠전기압력밥솥', '밥솥', '여름원피스',
#         '여름 반바지', '여성원피스 쉬폰'], dtype=object),
#  array(['래쉬가드이너', '래쉬가드 이너', '세노비스', '여아 레깅스 7부', '아디다스 주니어 트레이닝', '오덴세얀테',
#         '주니어레깅스', '주니어샌들', '여아테니스스커트', '세노비스 루테인', '리퍼', '반바지레깅스 7부',
#         '아디다스 주니어', '나이키주니어레깅스', '리복키즈샌들', '테니스스커트', '빌리프 선크림', '입생로랑 바이닐',
#         '닥터지 선크림'], dtype=object),
#  array(['나이키 바지'], dtype=object),
#  array(['뉴발란스 키즈 트레이닝', '뉴발란스 키즈 냉감', '뉴발란스 키즈', '버커루', '라코스테', '테일러메이드',
#         '풋조이', '버커루 티셔츠', '키즈'], dtype=object),
#  array(['요가복세트'], dtype=object),
#  array(['크록스', '롱원피스', '섬유유연제', '에이치커넥트', '롱스커트'], dtype=object),
#  array(['밀로앤개비 베개커버', '밀로앤개비 베개', '블루독 베이비', '블루독 티셔츠', '다이치 주니어카시트'],
#        dtype=object),
#  array(['타월', '코엔자임Q10', '아이패스', '아레나 아동 수경', '여아끈런닝', '수경', '무냐무냐 끈런닝',
#         '닥스타월', '클렌징워터'], dtype=object),
#  array(['홍진경더김치'], dtype=object),
#  array(['슈에무라 스테이지', '슈에무라'], dtype=object),
#  array(['유팡', '밤부베베'], dtype=object),
#  array(['남성등산티셔츠', '티비제이 여성', '반바지', '티비제이티셔츠'], dtype=object),
#  array(['유아치약', '도시락', '닭가슴살스테이크', '아임닭도시락', '쿨매트', '에스티로더', 'mlb',
#         'mlb키즈 샌들', '유리아쥬'], dtype=object),
#  array(['드롱기 전기포트', '이동식행거', '드롱기 토스터기'], dtype=object),
#  array(['트라이엄프브라세트', '속바지', '유아발목양말', '여성속바지', '오가닉맘 내의 남아', '나이키 티셔츠 반팔',
#         '베네통원피스', '블루독바지', '핏플랍 여성샌들', '나이키 요가복', '아디다스키즈트레이닝복', '설화수로션',
#         '안다르 요가복', '나이키 티셔츠', '나이키 티셔츠 드라이핏', '오딧세이 로맨틱 2종 세트', '여아발목양말',
#         '빌리프에센스', '헤어에센스', '화이트닝 에센스', '레이스양말', '여아양말', '양말', '스케쳐스 고워크',
#         '아레나수모', '핏플랍', '안티포그', '아레나미러수경', '휴대폰방수팩', '수아팜', '아레나아동수영복',
#         '헬로카봇시계', '오가닉맘', '아레나수경', '블루독베이비 양말', '수경', '여아파자마', '숄더백',
#         '랑콤 선크림 50ml'], dtype=object),
#  array(['마담4060 팬츠', '두유', '프랑코페라로 바지', '매일두유', '연세두유', '남성바지'],
#        dtype=object),
#  array(['코트', '유닛', 'lbl'], dtype=object),
#  array(['산수시', '드끌레오', '클렌징폼'], dtype=object),
#  array(['래쉬가드 세트', '래쉬가드 세트 여성', '배럴 래쉬가드'], dtype=object),
#  array(['드라이기', '빌리프 토너', '빌리프 아쿠아밤', '빌리프 에센스', '빌리프'], dtype=object),
#  array(['스타벅스 기프티콘'], dtype=object),
#  array(['에르뎀'], dtype=object),
#  array(['여아스타킹'], dtype=object),
#  array(['비비안 브라세트', '행거', '트라이엄프브라세트', '여성속옷세트 비너스'], dtype=object),
#  array(['니나리치', '립스틱', '루이비통', '러브캣가방', '나이키반팔티', '구찌 가방', '마이클코어스 가방',
#         '여성 블라우스', '엘리자벳 슬립온', '여성 향수', '스타일베리', '아디다스 반팔티 여성', '오드 스커트',
#         '여성 핸드백', '루이비통 가방', '더블엠 가방', '오드 블라우스', '토너', '스킨', '금찌',
#         '아토팜 크림', '에블린 브라', '아토팜 탑투토워시', '바이오더마 클렌징워터', '헨어스 여성'],
#        dtype=object),
#  array(['탑텐 레깅스', '탑텐 레쉬가드'], dtype=object),
#  array(['목침', '덴텍', '신생아 바디슈트', '신생아선물', '달퐁 우주복', '신생아 선물세트 여아', '손목시계',
#         '유아내의', '아기내의'], dtype=object),
#  array(['핸드드립세트', '통굽슬리퍼', '마운틴벨리'], dtype=object),
#  array(['햇반'], dtype=object),
#  array(['라코스테 원피스'], dtype=object),
#  array(['금액권', '기프티쇼', '물티슈', '레깅스', '체험', '세제', '리빙박스', '섬유유연제', '세탁비누'],
#        dtype=object),
#  array(['디올 팩트', '베네피트 브러쉬', '단델리온 트윙클', '지오다노 티셔츠', '지오다노 여성 팬츠', '디올',
#         '팩트'], dtype=object),
#  array(['지퍼락'], dtype=object),
#  array(['난닝구 블라우스', '난닝구 스커트', '난닝구 원피스', '제니피끄', 'H', '난닝구 니트'],
#        dtype=object),
#  array(['아이시스8.0', '생수500', '생수', '세척사과'], dtype=object),
#  array(['남성팬티', '남성팬티 드로즈'], dtype=object),
#  array(['에잇세컨즈 여성 블라우스', '메디큐브', '클라리소닉 브러쉬', '위치하젤', '메이크업베이스', '스와니코코',
#         '에잇세컨즈 여성', '모공케어', '탄력에센스'], dtype=object),
#  array(['메이크업포에버 uhd', '메이크업포에버 브러쉬'], dtype=object),
#  array(['세제', '분유', '주방놀이'], dtype=object),
#  array(['책상', '학생의자'], dtype=object),
#  array(['푸마 셀렉트'], dtype=object),
#  array(['케즈'], dtype=object),
#  array(['유니참 패드'], dtype=object),
#  array(['아기선크림', '남자 티셔츠', '슬림티셔츠', '하이홈', '나인웨어', '야마토야 뉴스쿠스쿠'],
#        dtype=object),
#  array(['닥스골프남성의류', '닥스골프', '헤지스키즈'], dtype=object),
#  array(['피그먼트'], dtype=object),
#  array(['시세이도 뷰러', '여성 롱 티셔츠', '바비브라운 아이라이너', '시세이도 아이라이너', '블루독바지', '슬링백'],
#        dtype=object),
#  array(['남성린넨셔츠', '남성린넨바지', '앤듀 남성'], dtype=object),
#  array(['랑콤 미라클', '뉴발란스키즈', '나이키키즈 샌들', '빈폴키즈', '미라클', '닥스키즈', '프랜치캣',
#         '샤넬향수', '샤넬 메이크업베이스', '빈폴키즈 책가방', '랑콤', '뉴발란스', '데상트 반팔'],
#        dtype=object),
#  array(['런닝화'], dtype=object),
#  array(['파타고니아', '판타고니아'], dtype=object),
#  array(['여성단화', '흰색로퍼'], dtype=object),
#  array(['일회용 마스크', '지오다노트레이닝바지', '리빙박스', '지오다노 트레이닝', '크록스 키즈',
#         '아디다스트레이닝바지', '여자트레이닝바지', '마르조', '지오다노', '주니어롱패딩', '일룸책상'],
#        dtype=object),
#  array(['스파클생수'], dtype=object),
#  array(['블랙야크키즈 운동화'], dtype=object),
#  array(['아디다스 이큅먼트', '아디다스 운동화'], dtype=object),
#  array(['헤라 향수', '나스', '나스 쿠션'], dtype=object),
#  array(['엣코너'], dtype=object),
#  array(['유니클로', '유니클로 팬츠', '무인양품 무지', '지고트', 'k2 수지'], dtype=object),
#  array(['기저귀', '키즈 잠옷', '더블하트 젖병', '잠옷', '머미쿨쿨', '남아 잠옷', '여성잠옷', '남성지갑',
#         '프라다 키홀더', '프라다키홀더', '남자 머니클립', '보솜이', '클라란스튼살크림', '오르시떼 아동잠옷',
#         '아기이불', '잠옷세트'], dtype=object),
#  array(['아이젤', '이젤', '씨엔타', '코인코즈', '여성청바지', '롱티셔츠', '빅토리아슈즈 키즈',
#         '나이키다이나모프리', '빅토리아슈즈', '빅토리아'], dtype=object),
#  array(['알파바운스 슬리퍼'], dtype=object),
#  array(['조끼', '에르게', '은목걸이', '파우더팩트', '14k팬던트', '팬던트', '흄니트', '태창', '미장센',
#         '실버목걸이'], dtype=object),
#  array(['반지갑', '러브캣 지갑'], dtype=object),
#  array(['무료배송'], dtype=object),
#  array(['나이키슬리퍼', '나이키슬리퍼 여성'], dtype=object),
#  array(['키엘', '헤어 에센스', '키엘 로션', 'sum', '숨 세트', '트리트먼트', '숨 스킨', '숨 37',
#         '컨디셔너', '샴푸', 'ysl', 'sum:37'], dtype=object),
#  array(['레쉬가드바지', '반바지'], dtype=object),
#  array(['플레이모빌'], dtype=object),
#  array(['지오다노 머슬티'], dtype=object),
#  array(['엘프색'], dtype=object),
#  array(['슬링백', '아쿠아슈즈 여성', '디스커버리', 'MLB 모자', '썬캡', '배럴', '어린이캐리어',
#         '타미힐피거데님', '뉴발란스 키즈 바람막이', '뉴발란스 키즈', '남아 바람막이', '르쿠르제 머그',
#         '디스커버리 키즈', '디스커버리 남성티셔츠'], dtype=object),
#  array(['크리니크', '바바라', '쿠션', '언더웨어 여성', '네크리스', '고양이모래'], dtype=object),
#  array(['지비츠', '콩순이인형', '터닝메카드w'], dtype=object),
#  array(['게스 티셔츠 여성'], dtype=object),
#  array(['아베다 샴푸', '시슬리'], dtype=object),
#  array(['스마트픽 광주점'], dtype=object),
#  array(['발뮤다 전기포트', '발뮤다 토스터기'], dtype=object),
#  array(['한과', '엄마옷데드라'], dtype=object),
#  array(['코디갤러리 셔츠', '남성 남방', '파운데이션', '여름남성정장바지'], dtype=object),
#  array(['링귀걸이', '귀걸이'], dtype=object),
#  array(['쉬즈미스', '크록스 여성 샌들', '니트티셔츠', '쉬즈미스 니트', '게스 여성 청바지', '여성 반팔 니트',
#         '크록스 샌들', '크록스 이사벨라', '크록스', '파코라반베이비 원피스'], dtype=object),
#  array(['타미힐피거반팔티'], dtype=object),
#  array(['유아선스틱', '신생아내의세트'], dtype=object),
#  array(['아베다 스무드', '캘빈', '아베다', '원더브라 브라팬티세트', '더바디샵 티트리', '린스'],
#        dtype=object),
#  array(['드링크인더박스'], dtype=object),
#  array(['플라스틱아일랜드', '린넨 와이드팬츠'], dtype=object),
#  array(['빈폴'], dtype=object),
#  array(['수영복 커버업', '데상트 래쉬가드', '여아팬티', '로브 가디건', '여성래쉬가드세트', '베개', '르쿠르제',
#         '타미키즈', '블루독', '뉴발란스 키즈 티셔츠', '키즈트레이닝복세트', '데상트주니어', '발렌티노 스니커즈',
#         '엠엘비키즈', '블루독 키즈', '블루독키즈', '해지스키즈', '엠엘비키즈 샌들', '로아앤제인',
#         '알렉산더맥퀸오버솔', '밀로앤개비 베개', '텐바이텐', '헤지스키즈', '키즈이월상품', '키즈슈즈',
#         '빈폴키즈티셔츠', '타미키즈티셔츠', '키즈 레인부츠', '여아티셔츠', '블루독 세트', '여성향수',
#         '데상트키즈', '스타우브', '블루독 여아 원피스', '여아드로즈', '여아속옷', '블루독 수영복',
#         '알로봇 수영복', '남아수영복바지', '매직핸즈', '뉴발란스키즈 수영복', '향수', '냄비', '빈폴키즈 반바지',
#         '폴로키즈 남아', '키즈트레이닝세트', '갭키즈', '빈폴키즈', '버버리키즈', '웍', '헌터레인부츠',
#         '빈폴키즈신발', '폴로키즈', '블루독이월', '궁중팬', '르쿠르제냄비'], dtype=object),
#  array(['지갑', '소보제화', '쌀', '까르뜨블랑슈남성 팬츠', '여성 반팔 티셔츠', '간절기이불 차렵',
#         '올리비아데코'], dtype=object),
#  array(['버커루여성', '게스진여성', '솔브', '엘르속옷', '비욘드 바디', '왁싱', '드라이기'],
#        dtype=object),
#  array(['파우더', '빈폴티셔츠', '면티', '기본티', '시스맥스', '재단기', '구급상자', '아디다스오리지날',
#         '베네피트', '아디다스 슬리퍼', '아디다스오리지널', '아디다스 힙쌕', '아디다스모자', '노스페이스티셔츠',
#         '맥아이섀도우', '헤라파우더', '화장품정리함', '티셔츠', '아디다스가방', '런닝형브라', '노와이어브라',
#         '브래지어', '안지크', '빈폴아웃도어', '아디다스운동화', '르까프 티셔츠', '빈폴', '빈폴레이디스',
#         '린넨자켓 여성', '설화수스킨', '설화수', '키엘미스트', '설화수 아이크림', '법랑', '목욕가방',
#         '맥파우더', '정리함', '설화수기초', '나이키티셔츠', '르꼬끄티셔츠', '아디다스티셔츠', '컴퓨터책상',
#         '롱블라우스', '닥스레이디스', '브라탑', '솔가 오메가3', '인견속바지', '닥스레이디스 티셔츠', '안나수이'],
#        dtype=object),
#  array(['아디다스키즈 스탠스미스'], dtype=object),
#  array(['스티유'], dtype=object),
#  array(['디올', 'too faced', 'urban decay', '입생로랑', '맥'], dtype=object),
#  array(['구스다운', '남성구스다운', 'k2마조람', '키즈구스다운'], dtype=object),
#  array(['오랄비 칫솔', '리스테린', '샤프란'], dtype=object),
#  array(['tiss'], dtype=object),
#  array(['데님스커트', '시에로티셔츠'], dtype=object),
#  array(['데상트 반팔', '자라', '스파이더 반팔', '데상트 바지', '로즈몽', '바지', 'ZARA', '퓨마 반팔티',
#         'zara 여성', '나스 오르가즘', '맥', '라코스테', '라코스테 양말', '스파이더', '라코스테 양말 여성',
#         '자라여성'], dtype=object),
#  array(['다이나모프리 ps', '다이나모프리'], dtype=object),
#  array(['포에버21', '포에버21브라렛', '포에버21 수영복', '포에버21 비키니', '파인뷰x1000'],
#        dtype=object),
#  array(['다이슨드라이기'], dtype=object),
#  array(['쥬시쥬디', '클라이드', '온앤온', '비지트인뉴욕', '더틸버리', '올리브데올리브', '클라이드팬츠',
#         'mlb 티셔츠', '뉴발란스', '탑걸', '쥬시쥬디스커트', '쥬시쥬디팬츠', '스커트', '설화수', '탑걸팬츠',
#         '뉴발란스 샌들', '샘키즈', '쥬크', '씨씨콜렉트', 'ggpx', '닉스', '지지피엑스', '아이오페 리프트',
#         '더바디샵', 'enc팬츠', 'enc', '땀띠', '비오템크림', '에잇세컨즈', '티셔츠', '리바이스티셔츠',
#         'ggpx 가디건', '랩 LAP', '매긴', '랩', '블라우스', '가디건', '쥬시쥬디 블라우스',
#         '쥬시쥬디 팬츠', '케이블', '꾸즈', '탑걸 팬츠', 'soup', '콩콩이', '아이오페', '플라스틱아일랜드',
#         '충전', '올리브데올리브 스커트', '숲', 'LAP', '탑걸 원피스', '탑걸티셔츠', '쥬시쥬디티셔츠',
#         'LAP 스커트', '수모', '세컨플로어', '쥬시쥬디 스커트', '코벳블랑', 'lap 랩원피스', '데싱디바',
#         '리코더', '야마하 리코더', '쥬시쥬디 원피스', '페디'], dtype=object),
#  array(['여성래쉬가드', '레노마 래쉬가드 남성 세트', '래쉬가드 남성', '레노마 래쉬가드 남성'], dtype=object),
#  array(['타미힐피거여성', '나시티', '핑크시슬리 티셔츠', '키엘', '스킨', '이스트팩 백팩', '이스트팩',
#         '핑크시슬리', '체이스컬트 남성 반바지', '스판 청바지', '주니어 런닝', '오조크티셔츠', '여름 청바지 여성',
#         '타미힐피거남성'], dtype=object),
#  array(['sk2 클리어로션', '피테라에센스'], dtype=object),
#  array(['기프티콘', '슬럽티셔츠'], dtype=object),
#  array(['다이치 디가드 토들러', '나이키 토들러', '스니커즈', '아디다스키즈'], dtype=object),
#  array(['탑이슈 티셔츠', '미센스블라우스', '로즈맘', '탑텐반팔티', 'enc원피스', '예스 브라', '캐스키드슨',
#         '침대커버세트', '제습제', '크로커다일레이디', '레코브 원피스', '레이스원피스', '목살', '보노보노',
#         '조이너스원피스', '행텐여성', '행텐여성셔츠', '에이치커넥트 셔츠', '여성샌들', '아디다스반바지',
#         '보온도시락'], dtype=object),
# ...
#         '토리버치 신발', '프레쉬', '토리버치'], dtype=object),
#  array(['에어포스'], dtype=object),
#  array(['코즈니디퓨저'], dtype=object),
#  array(['나이키에어맥스2017'], dtype=object),
#  array(['나이키 에어맥스2017', '베이퍼맥스', '나이키 에어맥스 97', '에어맥스2017', '나이키 베이퍼 맥스'],
#        dtype=object),
#  array(['식기건조대', '닥스 반팔티', '스마트픽', '다이슨드라이기', '아디다스 여성 트레이닝', '포토메리온',
#         '남성 카라티셔츠', '덴비그릇', '과일포크', '락포트여성화', '포토메리온접시', '탄력크림', '루이까또즈양산',
#         '키엘', '닥스양산', '메트로시티 양산', '알라피아'], dtype=object),
#  array(['닥스'], dtype=object),
#  array(['나이스클랍', '헤라옴므'], dtype=object),
#  array(['무료배송', '덧신'], dtype=object),
#  array(['에이치커넥트여성', '베네피트', '할로윈의상', '헤지스레이디스'], dtype=object),
#  array(['미니스카프', '미니스커트', '스퍼'], dtype=object),
#  array(['수분크림'], dtype=object),
#  array(['양말', '덧신양말', '파우더 팩트', '페이크삭스', '티셔츠', '샌들'], dtype=object),
#  array(['잭니클라우스 양말', '잭니클라우스', '스톤아일랜드', '잭니클라우스양말', '크록스', '크로스',
#         '유팡젖병소독기', '버버리', '버버리 벨트', '버버리 남성'], dtype=object),
#  array(['해피프린스'], dtype=object),
#  array(['여아니삭스', '오키즈', '분리형타이즈'], dtype=object),
#  array(['방수베개커버', '쉬즈홈'], dtype=object),
#  array(['아이오페 세트', '아이오페 기초', '아이오페 기초세트'], dtype=object),
#  array(['머렐 샌들', '스포츠샌들', '남성 스포츠샌들', '캔버스백', '르까프 샌들', '여성와이드팬츠', '아동 우산',
#         '모슬린 원피스', '냉장고바지', '모슬린 엄마옷'], dtype=object),
#  array(['남자래쉬가드', '남자래쉬가드바지', '남성레쉬가드', '남성보드숏', '남자 셔츠', '남자반팔 셔츠',
#         '남자카라티셔츠', '탑텐'], dtype=object),
#  array(['크리니크 클렌징'], dtype=object),
#  array(['캣타워'], dtype=object),
#  array(['여성블라우스'], dtype=object),
#  array(['헤지스남성티', '남성 반팔티', '남성 긴팔티', '헤지스남성티셔츠 긴팔', '네파반바지'], dtype=object),
#  array(['빈'], dtype=object),
#  array(['여름로브가디건'], dtype=object),
#  array(['김나운 김치', '여성 슬립온', '더김치', '홍이장군1단계'], dtype=object),
#  array(['나시원피스'], dtype=object),
#  array(['블로퍼'], dtype=object),
#  array(['삼다수500', '생수300ml', '스파클생수', '물', '남자 운동화', '핸드믹서', '노래방 마이크',
#         '맛술', '캠핑의자', '물티슈', '포카리스웨트', '물티슈 베베숲', '쌀 20kg'], dtype=object),
#  array(['한복 속치마', '스와로브스키 볼펜', '비너스 슬립', '점프수트', '블로퍼'], dtype=object),
#  array(['abfz', '체크스커트', '숲 남방', '클러치백', '에이비에프지 스커트', '헤지스 클러치백',
#         '클러치백 여성', '숲 블라우스', '에이비에프지', 'abfz자켓'], dtype=object),
#  array(['임블리 원피스', '난닝구', '임블리 티셔츠'], dtype=object),
#  array(['후드집업', '지오다노집업', '남성 집업', '여성흰티셔츠', '남성 후드집업'], dtype=object),
#  array(['남성청바지'], dtype=object),
#  array(['온앤온', '쉬즈미스', 'ugiz 여성', 'UGIZ'], dtype=object),
#  array(['에이치커넥트', 'NBA', '후드', '정관장 에브리타임'], dtype=object),
#  array(['아디다스쪼리', 'Adidas'], dtype=object),
#  array(['뉴발란스 여성', '여성샌들', '미소페여성샌들', '잭앤질 슬립온', '타미힐피거여성', '여성키높이슬립온',
#         '남성슬립온', '여성슬립온', '플레어 치마바지', '에고이스트', '잭앤질', '치마바지'], dtype=object),
#  array(['차이슨 무선청소기', '남성면바지', '남성여름면바지', '라텍스베개커버', '베개커버', '젤리스푼 반바지',
#         '자동버블건', '메소드 핸드워시', '마우스패드', '보온물병', '보온보냉병', '핸드워시', '유아슬리퍼',
#         '남성여름양말', '남성양말'], dtype=object),
#  array(['잭니클라우스남성티셔츠', '르꼬끄가방', '헤지스남성', '유니클로티셔츠', '디스커버리남성티셔츠',
#         '버커루남성티셔츠', '어린이팬티', '남성반팔', '남성카라티셔츠', '타미남성티셔츠', '게스남성티셔츠',
#         '레노마남성티셔츠', '헤지스카라티', '시리즈 series', '버커루티셔츠', '남성티셔츠', '레노마티셔츠',
#         '블랙야크남성티셔츠', '르꼬끄남성티셔츠', '타미힐피거남성', '남성긴팔티셔츠', '헤지스티셔츠', '게스티셔츠',
#         '남성긴팔카라티셔츠', '노스페이스티셔츠', '폴로티셔츠', '남자잠옷바지'], dtype=object),
#  array(['토니버치가방'], dtype=object),
#  array(['아동모자', '노스페이스키즈', '아동복', '휠라키즈', '시리즈 코트', '아동티셔츠', '시리즈', '코트',
#         '스테파넬 코트', '트렌치코트 남성', '앤드지', '여성샌들', '세라블라썸', '오니츠카타이거', '스테파넬',
#         '텀블러', '남자코트'], dtype=object),
#  array(['소다 여성 스니커즈', '골든구스 스타터', '여성스니커즈', '발렌티노 스니커즈', '알렉산더 맥퀸 스니커즈 여성'],
#        dtype=object),
#  array(['더바디샵 선물세트'], dtype=object),
#  array(['NBA', '달고나', '케이트', '종가집김치', '올삭스', '빈폴acc', '설화수 탄력크림', '슬링백',
#         '빈폴', '빈폴남성', '젤리', '바비브라운 아이섀도우', '설화수크림', '빈폴슬링백', '변기청소',
#         '여름양말', '주니어양말', '어린이 양말'], dtype=object),
#  array(['파인프라', '종가집김치', '남자 반바지', '질경이', '세탁세제'], dtype=object),
#  array(['아이스샌드', '여아수영복', '엠엘비키즈수영복', '남자수영복세트', '남아수영복세트', '초등여아수영복',
#         '주니어여아샌들', '바비수영복', '키즈수영복', '무냐무냐 여아 원피스 잠옷', '무냐무냐내의 7부', '여아잠옷',
#         '플랩캡', '여아수영복세트', '물안경', '빈폴키즈여아', '엠엘비키즈 티셔츠', '블루테일 여아 티셔츠',
#         '초등여아샌들', '주니걸즈', '스톤헨지 목걸이', '아레나', '블루테일 여아', '여아원피스', 'been 여아'],
#        dtype=object),
#  array(['맥콜', '핸드폰 거치대', '닌텐도스위치', '라코스테', '키티', '핸드폰 링', '라코스테 신발', '삼다수',
#         '고릴라강화유리'], dtype=object),
#  array(['입생로랑 틴트', '입생로랑틴트'], dtype=object),
#  array(['래쉬가드 남자'], dtype=object),
#  array(['풀무원생수', '에르고옴니360쿨에어', '슈너글아기욕조', '설화수', '에르고 아기띠'], dtype=object),
#  array(['나스 블러셔', '블러셔', '픽서', '맥 블러셔', '메이크업 브러쉬'], dtype=object),
#  array(['오가닉맘 런닝', '클로란', '스케쳐스 슬리퍼', '쉬폰원피스', '오가닉맘', '무냐무냐 잠옷',
#         '오가닉맘 남아 잠옷', '오가닉맘 남아 내의', '카렌듈라', '르네휘테르'], dtype=object),
#  array(['스포츠 브라', '웍'], dtype=object),
#  array(['알로봇티셔츠', '빈', '엠폴햄 셔츠', '레노마키즈', '갭키즈 셔츠', '블루독티셔츠', '더아이잗컬렉션',
#         '더아이잗 블라우스', '아동티셔츠', '아놀드파마 래쉬가드', '갭키즈 원피스', '아놀드파마키즈'],
#        dtype=object),
#  array(['메이크업포에버'], dtype=object),
#  array(['티셔츠', '가디건', '바지', '여아바지', '키즈', '앤디애플', '키즈바지', '케이스'],
#        dtype=object),
#  array(['디올립글로우', '맥리듬', '럭키슈에뜨', '써스데이아일랜드 양말', '디올 립글로우', '질스튜어트 양말',
#         '양말', '헤지스 양말', '프리메라 선쿠션', '디올 립밤'], dtype=object),
#  array(['아르마니 마뜨'], dtype=object),
#  array(['입생로랑 립스틱', '입생로랑', '회전책장', '쌀독'], dtype=object),
#  array(['타미힐피거', '수분 크림'], dtype=object),
#  array(['조말론 블랙베리앤베이'], dtype=object),
#  array(['정관장 에브리타임', '홍삼원'], dtype=object),
#  array(['쥬시쥬디'], dtype=object),
#  array(['7부티', '래핑차일드', '여아블라우스'], dtype=object),
#  array(['르젠옴므'], dtype=object),
#  array(['무지 반팔티', '무지 반팔'], dtype=object),
#  array(['드팜 원피스', '티파니 티셔츠', '오즈세컨', '여성 밴딩 청바지', '반팔 원피스', '잇미샤 원피스',
#         '세컨플로어 원피스', '오즈세컨 티셔츠', '티파니 블라우스', '헤라 썬메이트', '파타고니아 티셔츠',
#         '세컨플로어 티셔츠', '세컨플로어', '잇미샤 블라우스', '여성 밴딩 바지', '돗자리', '휴대용돗자리',
#         '빅토리아앤프렌즈', '수건', '밀집모자', '앳코너', '여아 런닝', '여아 내의', '머리핀',
#         '베어파우 샌들', '타미진 가방', '래핑차일드 팬츠', '에잇세컨즈 여성', '채니봉봉', '앳코너 블라우스',
#         '칼슘 마그네슘 D', '노니 원액', '까리제 여아', '여아 티셔츠', '썬크림', '아이잗',
#         '나이스클랍 티셔츠'], dtype=object),
#  array(['빈폴남성'], dtype=object),
#  array(['비너스 팬티'], dtype=object),
#  array(['라이펀', '데상트여성', 'k2여성'], dtype=object),
#  array(['아이스 티셔츠', '한율어린쑥', '공간박스', '만년필'], dtype=object),
#  array(['알로봇 바지', '블루독', '빈', '타미힐피거여성', '크록스 키즈', '블루독 7부팬츠', '선스틱',
#         '빈 가디건', '알로봇 7부', '빈 남아', '알로봇', '빈 남아티셔츠', '노스페이스 아쿠아슈즈',
#         '록시 집업', '아쿠아슈즈'], dtype=object),
#  array(['게스신발', '체리', '게스언더웨어 여성', '나스 컨실러', '찰옥수수', '볼륨업브라', '생체리'],
#        dtype=object),
#  array(['과탄산소다', '헤지스골프여성 티셔츠', '여성골프이너', '헤지스레이디스남방', '베이킹소다'],
#        dtype=object),
#  array(['샌달펀'], dtype=object),
#  array(['뉴발란스480', '벤시몽', '플라스틱 아일랜드', '뉴발란스바지', '폴스부띠끄'], dtype=object),
#  array(['고무팩'], dtype=object),
#  array(['래스팅실크', '숨 에센스', '아베다 인바티', '아베다'], dtype=object),
#  array(['임부복'], dtype=object),
#  array(['어성초비누', '클렌징오일', '키엘크림', '온앤온', '올리브데올리브', '코오롱스포츠모자', '주크',
#         '오즈세컨', '여성등산모자', '톤업크림', '톤업선크림', '키높이슬립온', '천연비누', '화장솜', '수분크림',
#         '여름원피스', '쥬시쥬디', '디스커버리여성티셔츠', '노스페이스 여성모자'], dtype=object),
#  array(['실내화주머니', '여아 크로스백', '여아 가방'], dtype=object),
#  array(['휠라 후드집업'], dtype=object),
#  array(['탑텐 래쉬가드'], dtype=object),
#  array(['정관장', '칼하트 반팔', '홍삼'], dtype=object),
#  array(['포커스', '치마정장세트'], dtype=object),
#  array(['유리병'], dtype=object),
#  array(['애드워시', '설화수', '닥스가방', '스포츠브라', '요가바지', '남성티셔츠', '티셔츠', '상백크림',
#         '리바이스 티셔츠', '코치가방', '로봇청소기', '싹스로봇청소기', '아동티셔츠', '세탁기', '요가복세트',
#         '영양크림', '자켓', '반팔롱티'], dtype=object),
#  array(['데코라인 화장대'], dtype=object),
#  array(['디스커버리 래쉬가드', '노스페이스키즈 래쉬가드', '남성 집업 래쉬가드', '집업 래쉬가드', '남자수영복바지',
#         '래쉬가드', '남자수영바지', '디스커버리수영복'], dtype=object),
#  array(['나이키 브라탑', '나이키 래쉬가드', '랩', '톰보이티셔츠', '카이아크만 티셔츠', '미니선풍기',
#         '나이키브라탑', '수영복브라탑', '휠라 래쉬가드', '다이슨 선풍기', '가오리핏', 'nba',
#         '커밍스텝 티셔츠', '여성브랜드', '더독', '수영복브라', '랩티셔츠', '디스커버리 래쉬가드 여성',
#         'mlb 래쉬가드', '커밍스텝', '에코백', '리바이스에코백', '휠라에코백', '나이키에코백', '배변패드',
#         '톰보이', '여성 칠부 티셔츠', '브랜드', '칠부 티셔츠', '아디다스 래쉬가드', '래쉬가드 여성',
#         '노스페이스 래쉬가드 여성', '휴대용선풍기', '트레이닝바지', '죽', '나이키 트레이닝바지', '나이키바지',
#         '아디다스바지', '노스페이스 래쉬가드', '래시가드여성', '생수2리터', '삼다수2l', '생수', '생수2l',
#         '아디다스운동화', '사이다', '두유', '롯데푸드', '여성 남방', '카이아크만', '샌들 여성',
#         '카이아크만 여성', '키즈샌들', '집업래쉬가드 여성', '커버업', '스니커즈', '집업래쉬가드', '나이키운동화',
#         '쥬스', '비키니팬츠', '레노마 수영복 여성', '수영팬티', '레노마수영복'], dtype=object),
#  array(['레노마키즈', '페리미츠 남아'], dtype=object),
#  array(['정관장 홍삼정 240'], dtype=object),
#  array(['로티홈시스', '에스티로더', '베이퍼맥스'], dtype=object),
#  array(['바비브라운', '셀퓨전씨'], dtype=object),
#  array(['빌리프 모이스춰라이징밤', '락피쉬', '하루견과', '한줌견과'], dtype=object),
#  array(['아디다스 브라탑', '나이키 브라탑', '아디다스 탱크탑', '요가 상의', '아디다스 레깅스',
#         '언더아머 레깅스 여성', '나이키 레깅스', '아디다스 기능성 반팔티', '푸마레깅스', '언더아머 레깅스',
#         '요가복', '나이키 기능성 반팔', '요가복 상의'], dtype=object),
#  array(['나이키운동화'], dtype=object),
#  array(['라운드티', '폴햄반팔티', '폴햄'], dtype=object),
#  array(['아이라이너 붓펜', '라코스테 양말 여성', '라코스테 양말', '인텍스 풀장', '보행기튜브', '튜브',
#         '나이키수영복', '베스트웨이풀장', '풀장', '아벤트 노리개', '어린이튜브', '네이처러브메레'],
#        dtype=object),
#  array(['니트원피스'], dtype=object),
#  array(['헤지스키즈', '닥스키즈', '닥스키즈원피스', '랩자켓', '닥스키즈점퍼'], dtype=object),
#  array(['헨리넥', '여성 헨리넥', '봄자켓', '아동복', '에이치커넥트', '린넨 가디건', '아워큐', '가오리가디건',
#         '여름잠바', '윌튼키즈', '아워큐주니어 티셔츠', '8부 레깅스', '남아동복', 'H커넥트', '안다르 탑',
#         '안다르', '생수500', '여성 티셔츠 반팔', '닉스인쇼어862', '스퀘어넥 원피스', '여성블라우스',
#         '여성롱티', '여성롱티셔츠반팔', '썬캡', '핑크시슬리'], dtype=object),
#  array(['트레이닝 스커트', '오가닉맘 내의', '냉동식품', '여름 롱원피스', '슬리퍼', '냉동피자', '트레이닝복세트',
#         '라면', '미키 티셔츠', '블렌더', '맥포머스'], dtype=object),
#  array(['조르지오아르마니'], dtype=object),
#  array(['제이에스티나 팔찌'], dtype=object),
#  array(['루즈핏 래쉬가드', '래쉬가드 브라탑', '레노마 래쉬가드 여성'], dtype=object),
#  array(['레노마키즈'], dtype=object),
#  array(['나이키 코르테즈 클래식 레더'], dtype=object),
#  array(['나이키 여성 수영복', '티어수영복여성'], dtype=object),
#  array(['여성백팩'], dtype=object),
#  array(['앤듀 남성 셔츠', '뽀로로', '서류정리함', '해피프린스', '보넷', '화장솜', '이니스프리 화장솜',
#         '카밀핸드크림', '극세사', '3m', '파리채', '창문청소', '나무쟁반', '의자발커버', '3인용 쇼파'],
#        dtype=object),
#  array(['클라란스바디', '비오템바디', '비오템', '블랙진'], dtype=object),
#  array(['스마트픽 안산점'], dtype=object),
#  array(['아이오페'], dtype=object),
#  array(['시카크림'], dtype=object),
#  array(['입생로랑 립스틱', '입생로랑 쿠션'], dtype=object),
#  array(['버시컬러'], dtype=object),
#  array(['배럴 보드숏'], dtype=object),
#  array(['타미힐피거여성', '봄티셔츠', '스니커즈'], dtype=object),
#  array(['정관장다보록'], dtype=object),
#  array(['지오다노트레이닝바지'], dtype=object),
#  array(['물', '설화수 윤조에센스', '설화수 수분크림', '더바디샵 티트리'], dtype=object),
#  array(['롱원피스', '베네피트 아이브로우'], dtype=object),
#  array(['제이린드버그골프웨어', '파리게이츠골프', '나이키골프', '타이틀리스트', '까스텔바작골프웨어 여성',
#         '르꼬끄골프', '골프장갑 남성', '보테가베네타', '골프장갑', '여성골프바람막이', '여자팬티',
#         '파리게이츠골프 티셔츠 여성', '데상트골프', '골프웨어', '블루독', '핏플랍'], dtype=object),
#  array(['나스 쿠션'], dtype=object),
#  array(['난닝구닷컴', '난닝구스커트'], dtype=object),
#  array(['닥터브로너스'], dtype=object),
#  array(['헤라 쿠션', '오휘 쿠션', '바비브라운 쿠션', '쿠션'], dtype=object),
#  array(['자음생', '디올어딕트립글로우'], dtype=object),
#  array(['에스티로더', '르꼬끄후드집업', '립글로즈', '남성후드집업', '디스커버리후드집업'], dtype=object),
#  array(['에스티로더'], dtype=object),
#  array(['벨레다치약', '오리발', '밍크뮤', '유아치약', '나이키아동운동화', '쇼콜라외출복', '밍크뮤 상하복',
#         '유아반양말', '김밥재료 보관용기', '릴리푸리', '아디다스운동화', '아동운동화', '루빅스큐브', '세트',
#         '쇼콜라', '블루독베이비', '큐브', '백일아기옷', '퍼실', '남성내의', '지컷'], dtype=object),
#  array(['아벤느 cpi'], dtype=object),
#  array(['데쌍트', '데쌍트반팔'], dtype=object),
#  array(['쿠션솜45'], dtype=object),
#  array(['수영모자', '키즈수영모자'], dtype=object),
#  array(['비너스아르보', '속옷세트'], dtype=object),
#  array(['나이키 아동화', '뉴발란스 아동화', '아동화', '뉴발란스 키즈', '블랙야크키즈', '마크모크', '스퍼',
#         '스퍼구두', '네파 바람막이 여성', '머렐 바람막이', '머렐 티셔츠', '휠라코트디럭스'], dtype=object),
#  array(['손목시계', '헤지스반팔', '헤지스', '빈폴헨리넥', '헤지스 반팔티', '빈폴반팔', '빈폴',
#         '라코스테 헨리넥', '남성손목시계', '남자손목시계', '빈폴 헨리넥', '엘르양산', '양산', '헨리넥 반팔',
#         '아가타양산'], dtype=object),
#  array(['빈폴', '버킷햇', '폴로랄프로렌', '폴로모자', '빈폴모자'], dtype=object),
#  array(['여성팬티', '아이더여성바지', '여성면팬티', '미쟝센 퍼펙트세럼', '아이더여성', '남성점퍼 바람막이',
#         '올젠', '친환경페인트', '벽지페인트', '헤어 에센스', '르까프', '한샘가구', '르까프여성', '올젠 점퍼',
#         '브라질너트', '유기농설탕', '클렌징티슈', '화장품', '미쟝센', '아디다스남성티셔츠', '아디다스 반팔티',
#         '헤나염색', '에뛰드', '마코', '아디다스여성티셔츠', '라푸마 여성바지', '올리비아 로렌', '라푸마 여성',
#         '에뛰드하우스', '파우더팩트', '미쟝센 염색약', '비정제설탕', '베게커버', '칼슘제', '과자',
#         '자연의품격', '칼슘', '화장지', '이니스프리', '잡곡', '방충제', '보리쌀', '라면', '테이트여성',
#         '3겹 화장지', '쌀 20kg', '제습제', '물티슈', '파우더퍼프', '아몬드', '피에이티 여성', '앤섬'],
#        dtype=object),
#  array(['언더러브', '세이지스푼풀', '샤틴 원피스', '스팀', '세이지폴', '닥스 남성 지갑', '포그네넘버5',
#         '오스터', '크로커다일 레이디'], dtype=object),
#  array(['블루독 원피스', '정관장', '에브리타임로얄', '러쉬', '랑콤', '밍크뮤', '손톱영양제', '뉴발란스 키즈',
#         '오피아이', '오즈키즈 바지', '닥스키즈', '블루독베이비', '바람막이', '에뜨와', '돌반지'],
#        dtype=object),
#  array(['수유등', '정관장', '무드등', '이고르'], dtype=object),
#  array(['여성실내수영복', '수경', '카파 트레이닝 바지'], dtype=object),
#  array(['트레이닝복세트', '카라티셔츠', '게스카라티셔츠', '여름 트레이닝복세트'], dtype=object),
#  array(['아이패드 프로 10.5', '유캐슬'], dtype=object),
#  array(['어반디케이'], dtype=object),
#  array(['남성가디건'], dtype=object),
#  array(['리복 스카이스케이프', '원피스'], dtype=object),
#  array(['인피니펀', '보냉백', '팬티라이너', '유기농본팬티라이너', '아기 손수건', '아기손수건'],
#        dtype=object),
#  array(['암밴드', '맥 룩인어박스', '에어팟케이스', '맥 하이라이터', '르네휘테르', '포커스', '바비브라운',
#         '나인', '스테파넬', '아베다', '아베다 인바티'], dtype=object),
#  array(['블랙야크키즈', '블랙야크키즈아쿠아슈즈'], dtype=object),
#  array(['실바니안'], dtype=object),
#  array(['임블리', '베어파우키즈', '베어파우', '유아 샌들', '아디다스 유아 샌들'], dtype=object),
#  array(['탐스', '남성 단화', '헤지스키즈', '주니어 민소매', '보닌', '보닌구두', '주니어 나시',
#         '블랙야크키즈', '썬크림', '여아내의', '슬립온', '리바이스 주니어'], dtype=object),
#  array(['차이나카라셔츠 남성', '게스티셔츠', '게스청바지 남성'], dtype=object),
#  array(['키엘수분크림125ML'], dtype=object),
#  array(['종지', '그릇', '노래방 마이크', '공룡 메카드', '지프반팔티', '망원경', '테팔믹서기', '에어프라이어'],
#        dtype=object),
#  array(['헬렌스타인'], dtype=object),
#  array(['쿤달'], dtype=object),
#  array(['헤지스 남성', '조던 슬리퍼', '키홀더'], dtype=object),
#  array(['버킷백', '프라다 미니백', '세인트스코트가방', '린넨 원피스', '뉴발란스모자', '메트로시티 가방',
#         '아디다스모자'], dtype=object),
#  array(['양말 남성', '백화고'], dtype=object),
#  array(['고려은단 비타민', '비타민', '프렌치캣', '블루독', '티파니주니어', '오리진스', '프리메라팩'],
#        dtype=object),
#  array(['여성 티셔츠'], dtype=object),
#  array(['전기포트', '드롱기'], dtype=object),
#  array(['양산', '양산 자외선차단', '선풍기', '삼광쌀', '엘라스틴', '아몬드', 'ssd'], dtype=object),
#  array(['나이키 아동샌들', '나이키 선레이 프로텍트'], dtype=object),
#  array(['긴팔 티셔츠 여성', '타미힐피거칠드런', '옥스타', '라탄바구니', '로보킹', '블로퍼', '여드름 화장품',
#         '로션', '수납박스'], dtype=object),
#  array(['세인트제임스', '맥 버시컬러'], dtype=object),
#  array(['피지오겔', '남성슬랙스', '슬랙스'], dtype=object),
#  array(['오딧세이 로맨틱 2종 세트', '오딧세이 로맨틱', '참존화장품세트', '미쟝센 염색약', '미스트', '참존화장품',
#         '해피바스샤워코롱', '뉴트로지나'], dtype=object),
#  array(['생식'], dtype=object),
#  array(['지샥베이비지', '알람시계', '캐스키드슨'], dtype=object),
#  array(['시스템'], dtype=object),
#  array(['키즈', '크록스'], dtype=object),
#  array(['CC크림', 'AHC', '미장센'], dtype=object),
#  array(['메디테이션 요가복'], dtype=object),
#  array(['이젠벅모자', '이젠벅', '양산', '티칸', '카모마일', '탄산수', '이젠벅신발', '멀티스카프',
#         '보디가드남성팬티'], dtype=object),
#  array(['나이키 키즈 에어맥스', '여아 트렌치코트', '블루독이월', '블루독 자켓', '베베드피노', '뉴발키즈',
#         '설화수 쿠션', '나이키 에어맥스', '키즈 운동화'], dtype=object),
#  array(['남성반팔티', '박스티셔츠', '선풍기', '신일선풍기', '충전기', '핸드폰충전기'], dtype=object),
#  array(['팩', '샤프', '전통', '계피', '마스크팩', '개량한복', '청소기'], dtype=object),
#  array(['가디건', '지컷가디건', '키엘', '수딩젤', '헤지스 레이디스', '슈퍼콤마비', '핏플랍', '화애락진',
#         'vov의류', '이니스프리', '데상트'], dtype=object),
#  array(['락앤락 휴지통', '이케아', 'wmf 조리도구', '페달휴지통'], dtype=object),
#  array(['컨버스'], dtype=object),
#  array(['보냉물병파우치', '키즈바람막이'], dtype=object),
#  array(['염색약'], dtype=object),
#  array(['블루독베이비 양말', '밍크뮤 덧신', '시리즈', '시리즈 티셔츠', '그로미미 빨대컵', '더블하트 젖병',
#         '커스텀멜로우', '슈콤마보니'], dtype=object),
#  array(['골프바지'], dtype=object),
#  array(['비오템'], dtype=object),
#  array(['스틸러', '뉴발란스반바지', '아디다스 오리지널', '스틸라', '아디다스 오리지널 반바지'],
#        dtype=object),
#  array(['키엘 립밤'], dtype=object),
#  array(['잠옷', '트라이 파자마'], dtype=object),
#  array(['모르간오일', '모르칸오일', '아베다 헤어에센스', '황성주생식', '스마트픽', '뉴트리디데이 쉐이크',
#         '모로칸오일', '모로칸', '아베다', '아몬드브리즈'], dtype=object),
#  array(['빈폴레이디스', '빈폴레이디스 남방', '라코스테여성'], dtype=object),
#  array(['어린이가그린', '언더아머', '소다몬'], dtype=object),
#  array(['면원피스', '종가집 포기김치', '종가집김치', '행텐여성셔츠', '행텐여성', '배추김치'],
#        dtype=object),
#  array(['잇미샤 스커트', '잇미샤 블라우스', '여성블라우스'], dtype=object),
#  array(['테이트', '지프'], dtype=object),
#  array(['마더케이', '마더케이 일회용젖병'], dtype=object),
#  array(['여행용 캐리어', '여행용케리어'], dtype=object),
#  ...]

# %%
train_data5 = list(train.groupby('CLNT_ID')['PD_NM'].unique())
test_data5 = list(test.groupby('CLNT_ID')['PD_NM'].unique())
train_data5
# Out:
# [array(['아방세 프로믹스 핸드블렌더 HR1672/90',
#         '스판 벽걸이 에어컨커버(트라이앵글_82x27x26) 모음 - 블루가든 [블루]'], dtype=object),
#  array(['퀵실버 남성 루즈핏 래쉬가드 QS579KMT - M(100)', '칼렌듈라 딥 클렌징 포밍 페이스 워시 230ml',
#         '키엘 자외선 차단제 점보 세트',
#         '[이하늬착용]여성 비치 3pcs 래쉬가드 상하세트_RN-LS18908FC - BK / 95',
#         '홍삼정 에브리타임(10mlx30포) / 롯데백화점 본점 출고 / 정관장',
#         '[샘플 3종 증정] 핑크 라이트 톤업 쿠션 세트 (2종 중 택1) - 톤업 리필 세트 (리필2)',
#         '[7기프티쇼]저자극 투명 에센스 50ml 세트', '파워풀 비타민C 에센스 세트 (+파우치)'],
#        dtype=object),
#  array(['여성 솔리드/심플 브라팬티 5종 택1 - 01)CDABRM21RD/set / 80A/100',
#         '여성 베이직 브라 17종 택1 - 16_CBBBRM63RD / 80A',
#         '여성 베이직 팬티 17종 택1 - 14.CCCBPM91DGR / 90',
#         '205089-6OV 바야밴드 클로그 - M4W6'], dtype=object),
#  array(['[첨이첨이]8,500균일 남아아동팬티 3매입 9종중택1 - 첨이산토리니남삼각 / 75(9-10세)',
#         '[첨이첨이]남자아동팬티 CSC남아브리프05(55~75호) - 60(3-4세)'], dtype=object),
#  array(['폴리지 삭스 - 블루 / S',
#         '베스트샌들 MS4388 Malou_Color line Webbing 아이보리 외 11종 - 09)MS4384스카이 / 38',
#         '키도 애니멀 삭스 - 브라운 / M(12~24m)', '뉴 핑크 플레인 레깅스 - 핑크 / S(6~12m)',
#         '보보 삭스2 - 크림 / M(12~24m)', '스마일 레깅스 - 크림 / M(12~24m)',
#         '니삭스 클로이 - 그린 / S(6~12m)', '테팔 컴포트 주방가위',
#         '베이비 스트라이프 러플 바디수트BP8216222 - BLUE / 85',
#         '베이비 여아 화이트 블루머 5238234509001 - 24M', '수안 파일럿 - 크림 / 48(6~12m)',
#         '쥬디스 보넷3 - 베이지 / 48(6~12m)', '해피 플레인 타이즈 - 화이트 / M(12~24m)',
#         '버블 레깅스 세트 - 그레이 / M(12~24m)', '나리앙 니삭스 - 코랄 / M(12~24m)',
#         '그래픽 패스포트 아이 러브 뉴욕 프라이팬 26cm'], dtype=object),
#  array(['후레시아 3겹데코 화장지 30mx24롤'], dtype=object),
#  array(['★무료배송! 도트 리빙박스 24L (중) 1P - 오렌지'], dtype=object),
#  array(['[1+1] 탑투토 워시 300ml', '일반냉장고 B267S (254L/1등급)',
#         'MLE 로션 대용량 300ml [gift] 베스트 키트 6종'], dtype=object),
#  array(['[기프트]시어 핸드 듀오(온라인 단독 구성)',
#         '나이키 NSW 엠브로이드 클럽 반팔티 4종 택1 827021 - 나이키 NSW 엠브로이드 반팔티 / 827021-475_네이비 L(105)',
#         '퍼펙틀리 클린 멀티 액션 폼 클렌저/퓨리파잉 마스크 (150ml)',
#         'NEW 메가머쉬룸 릴리프&리얼라이언스 수딩 크림 50ml',
#         '[아디다스] 남성용 에센셜 베이스 반팔티 균일5종택1 - 05.ADIDAS_CD2816_ / M',
#         '남성 NSW CRW FLC 클럽 맨투맨 3종택1 - 01.NIKE_804340_010_ / M',
#         '볼빅 마그마 컬러 3피스 로스트볼 A+급 10알', '챔프 자마 플라이티 My Hite 83mm=25개입',
#         '에프터글로우 립 밤 오르가즘'], dtype=object),
#  array(['남성반지갑 SK4AH17KH - KHAKIE'], dtype=object),
#  array(['[아디다스] 마라톤 10 TR CNY 블랙 화이트 CM8341_신발_운동화 - 265',
#         '[마이독스] 푸르미 매직울타리 24p - 아이보리', '흰감국보송선스틱SPF50+PA++++ 17gx2'],
#        dtype=object),
#  array(['풀무원 생수 2L x 6페트'], dtype=object),
#  array(['남여공용 런닝화트리거픽YUF17N03 - BLACK(블랙) / 260',
#         'HAWKING 남성 반팔 티셔츠 YMA17203 - YELLOW(노랑) / 110(XXL)'], dtype=object),
#  array(['여성 인견 베이직나시 베이직런닝 택1 - 인견베이직나시 스킨 / 100',
#         '[EBAN] 여성 삼각 면스판 요일팬티 10칼라 택1 - 요일팬티 스카이 / L(90)',
#         '여성 면스판 세미맥시 1호 - 100'], dtype=object),
#  array(['자연이 키운 수세미배도라지 80ml*30포 - 수세미배도라지'], dtype=object),
#  array(['세붐 스트라이크 토너 - 남성 기름진 지성피부 및 모공케어/민감성 피부',
#         '기라로쉬 3단 우양산 [슬림50잔꽃60006] - 기라로쉬-SK0078-퍼플',
#         '백팩 ICHIWA S (이치와 S) KHABA27 WPW - 웜 패치워크 (W/PW)',
#         '면코랄오렌지남성드로즈 EHD5287 - 면오렌지(5287) / 95',
#         '심플블루면남성드로즈 EHD5288BU - EHD5288 / 100'], dtype=object),
#  array(['레이스 프릴 아일렛 블라우스 (AJGWB029) - 베이지(BE) / F',
#         '[모니카룸] 큐브단가라ops/원피스 - 네이비 / 프리',
#         '[비밀MD추천]프레셀 사계절 낮잠이불(디자인선택) - 후프베어'], dtype=object),
#  array(['헤링본 노라인 래쉬가드 이너 브라탑 팬티 세트 G99 - G99 실키 베이직 브라탑세트 블랙 / L(55~66)',
#         '여성 베이직 솔리드 래쉬가드 DWSW14731 - 그린 / 95'], dtype=object),
#  array(['포맨 비비 블록(50ml) - FM10'], dtype=object),
#  array(['남 옥스포드 밴드 카라 셔츠 047902 - 07 / L',
#         '남 코튼/스판 슬림핏 치노 팬츠 116904 - 87 / 33',
#         '벨티드 트렌치코트[P161MSI007] - 베이지 / 66',
#         '[지오다노]★벨트증정★ 117941 미디엄 웨이트 슬림핏 데님 - 01블랙 / 36',
#         '남 프린트 반팔 티 098501 - 04 / XL'], dtype=object),
#  array(['AST-3525 베이직 나시 후드티 - 진그레이 / L'], dtype=object),
#  array(['편안하고 시원한 인견속바지1종(9863)95~100/빅사이즈 - 베이지 / 95',
#         '+본사+한솔 참사랑 대나무 쿨매트 더블 - 더블'], dtype=object),
#  array(['남여공용 스몰로고 반팔 티셔츠[71TSD1831] - 핑크(P) / 110',
#         '팬콧 키즈 마린 스트라이프 티셔츠_PKOEURS34V - 핑크-PKOEURS34VP2 / 5T',
#         '아이시스8.0 생수 500ml*40펫', '빅로고 반팔티/유아동키즈티셔츠/NK9E82101U - 블랙 / 130',
#         '뉴욕양키스 스트라이프 반팔 티셔츠 - 블루(U) / 105', '아이시스8.0 200mlx40펫',
#         '아이시스8.0 300ml*40펫', '아이시스8.0 생수 1L*18펫'], dtype=object),
#  array(['그날엔순면 생리대 16px5팩 +사은품증정 - M_1.소형 16px5팩+마스크팩10p+샘플4p',
#         '[빠른배송]독일프리미엄 기저귀 밴드형 4단계 48매x3팩 - 밴드4단계 48매x3팩(7-13kg)',
#         '[세계 특허 유산균 배합] 드시모네 베이비드롭 2박스 + 추가 6캡슐',
#         '[세계 특허 유산균 배합] 드시모네 베이비 캡슐 2박스 + 추가 6일분'], dtype=object),
#  array(['종가집 총각김치 2.5kg', '남성 기능성 반바지 에브리데이 쇼츠 NFS6NI01 - 블랙 / 84',
#         '레이스울트라헴사각팬티EBWQ8A201BBK - 블랙 / 95',
#         '인기 아동 아쿠아슈즈 베어프리-F1SDYS001,2,3 - 2.LNV(라임) / 190',
#         '(기획특가)쿨 냉감 스카프 귀걸이 마스크 - FREE / 화이트', '다이아몬드 헤어매니큐어_140ml - 카키',
#         'EVA 무민메이든 꽃밭 60 자동 투명 장우산 MNPE-60-706 - 투명',
#         '(기획특가)펄 UV 자외선 차단 볼 마스크 - 화이트 / FREE', '종가집 깍두기 3kg',
#         '여성인견사각팬티-TTWPS004 - 화이트 / 090.',
#         '라운드 민소매 점프수트(SWWOPI20100) - 네이비(NA) / 66',
#         '종가집 포기김치2.3kg + 총각1kg',
#         '콜맨(Coleman) 정품 스크린 쉐이드 240 (아가일/라임그린)-2000017496',
#         '7L 리모컨 냉풍기 SIF-D90RKP 대용량 냉풍팬 냉풍선풍기',
#         '[바로스포츠]골프 볼주머니 NBB-18 3구용/ 골프공케이스 - 볼주머니NBB18',
#         '리제로 아이비 글리터 슬립온 - 3color - 화이트 / 6/9(250mm)',
#         '반소매 슬림핏 스트라이프셔츠 (SD8MM22HS960SGY) - 그레이 / 105',
#         '천연가죽 여성 샌들 LCWN725J27 - LCWN725J27화이트 / 230',
#         '토스터 수비토 플러스 TT2628 (넓어진 빵 투입구, 7단계 굽기조절, 해동/재가열기능, 먼지방지뚜껑)',
#         '리퍼브/에어써큘레이터 실속형/선풍기 GT-CT88AC - 화이트',
#         'NEW 2018 볼빅 VAHB-이중방풍우산 - VAHB-이중방풍우산 그린',
#         'CSC남아런닝02 남아 민소매 나시(CDCABMAC03) - 백색 / 75/9~10세',
#         'PICNIC PACK  아동용 피크닉 백 [NM2DJ05] - 핑크(PIK) / ONE SIZE',
#         '샌드박스 미니크로스 [SB-C01][J1092] - 도티앤잠뜰-J1092-엘로우',
#         '면화이트남성런닝EHR7928 - 105', '3족 케이스양말 K4SCZ606X - 네이비(NAY) / 180',
#         '블랙 배색 메쉬 슬립온 HKSO8E201BK - HKSO8E201BK / 250',
#         '라이프스타일 반소매(2) 레귤러핏 셔츠&남방 9종 택1(선물포장가능) - 선택04 / 100',
#         '일본 주방가전 레꼴뜨 샌드위치메이커 퀼트 - 베이지',
#         '아동샌들 K1SDZ5011-5012-5051-5052 - 5051 / 195'], dtype=object),
#  array(['[블루종] 페미닌 보트넥 슬림 니트_[B1801KN010A] - 아이보리 / FREE'], dtype=object),
#  array(['조개플라워원피스 (37445-400-03) - YELLOW / 100',
#         '[모니카룸] 데어드ops/원피스 - 오렌지 / FREE',
#         '여아7부가디건 (27475-200-50) - IVORY / 145',
#         '(IV)여아 7부 가디건(27475-200-50) - IV / 145'], dtype=object),
#  array(['남성 신발 썸머 슬리퍼 LCST RZ0057M18A082 - 화이트 / 270'], dtype=object),
#  array(['{17G2_18S0230}스윔보텀캡 - 블랙/11호'], dtype=object),
#  array(['NEW 이니스프리 더 미니멈 토너', '18 NEW 블루베리 리밸런싱 스킨 350mL'], dtype=object),
#  array(['[까르페티앙] 강아지 노즈워크 담요 특대형_그레이 - 선택 / 단일상품',
#         '캣모나이트 스크래쳐 - 캣모나이트 스크래쳐 브라운'], dtype=object),
#  array(['[지오다노][무료배송] 243801 코튼 져지 크루넥 3pcs 패키지 - 12(WH+GR+BK) / XL'],
#        dtype=object),
#  array(['NEW 이니스프리 자연발효 에너지 넥크림'], dtype=object),
#  array(['★한정 200개! 8/10 10:00 OPEN [L][샘플링] 쿨민트 80ml x3개'], dtype=object),
#  array(['[라이너10p+입오버1p] 화이트 울트라 날개 중형 19x3',
#         '스카티 카라 남성반팔 티셔츠 (MUNUT481) - 네이비_(M6) / 100',
#         '남 반팔 피케 폴로 018501 - 01 / S', '핀덴스킨베베 모이스춰 로션 300ml',
#         '데일리 트레이닝복 후드집업 (4color) TRM211 - 네이비 / L',
#         '부드러운 면 요일팬티 5종 jpt 5205 (p57c) - 90',
#         '[라이너10p+입오버1p] 데일리 라이너 롱 40x3',
#         '공용 코튼 져지 크루넥 3PCS 패키지 243801 - 03 / S',
#         '여름로퍼 우븐슈즈 여름슬립온 여자로퍼 천단화 BR323a - BR323블랙 / 250',
#         '홍삼정 에브리타임(10mlx30포) / 롯데백화점 본점 출고 / 정관장',
#         '[커스텀에이블]헨리넥 린넨티셔츠_[C1807TS146B] - 카키 / FREE',
#         '남성_허리 밴드 숏 슬랙스팬츠(PHY2PH1022) - CCH / 34(86)',
#         '[N]딥클린 클렌징 오일 200ml x2개',
#         '[김나운더키친] 서울식 생 아삭 포기김치 10kg / 국내산 - 포기김치10kg',
#         '미셀라 솔루션 클렌징 워터 500ml', '3겹데코 순백 27m *(30)롤(EC) *2팩(블루)',
#         '웰메이드 인디안 여름 캐주얼 배색 반팔 카라티셔츠 MITASTM3201 - 베이지 / 95',
#         '한우한마리곰탕600g×3팩+특미갈비도가니탕700g×2팩+[목우촌]한우머리고기수육120g×2팩',
#         '[어반프랑] 헬렌 나그랑 린넨 원피스 - 베이지 / FREE'], dtype=object),
#  array(['남성_잔세로 스트라이프 슬럽셔츠 H172H201 - 라이트블루 / 110'], dtype=object),
#  array(['DULTON 5단서랍장 100-135 SAX', 'T60 시리즈 T603FW EGA 인테리어의자 - 오렌지'],
#        dtype=object),
#  array(['[4BT]비기너 스페셜 세트', '더 화이트 디콕션 - 얼티미트 브라이트닝 크림 50ml',
#         '[7SB]화이트디콕션 브라이트닝 에센스 50ml 세트', '[5BT]UV프로텍터 멀티선스크린 30ml 세트',
#         '울트라 라이트 데일리 유브이 디펜스 톤 업 크림',
#         '[8기프티쇼]울트라 훼이셜 크림 점보 125ml 세트 - 점보세트'], dtype=object),
#  array(['스와들 스트랩 속싸개 (색상선택)/속싸개/겉싸개 - 핑크 솔리드(S)',
#         '포그내 넘버5 플러스 올인원아기띠(무소음 허리벨트)-데님그레이'], dtype=object),
#  array(['[M]쉬어 피니시 프레스드 파우더 (11g) - #2 써니 베이지'], dtype=object),
#  array(['스탠스미스 컴포트 CQ2632 G - CQ2632_WHITE / 225',
#         '[미니멜리사] CAMPANA ZIG ZAG 캄파나 지그재그4종 (MSK182CAM011-MD) - 골드글리터 / 170mm',
#         '클래식 클로그 키즈 8종 디자인 선택 - 오션_204536-456 / 180'], dtype=object),
#  array(['여성 순면 팬티 5종 택1 BTWP9031 - 화이트 / 95',
#         '트라이엄프 여성 슬로기 면 팬티TS7674T - 연핑크 / 100',
#         '(트라이)(여삼각)순면 여성맥시팬티 3매입-110까지 - 백색-85',
#         '밴딩반바지[AFS3GP58E] - 네이비(NAVY) / FREE(M)'], dtype=object),
#  array(['아레나 여아동 일반 원피스 수영복 AUSPG01NVY - NVY / 080'], dtype=object),
#  array(['기본티_RGRA72301C - 핑크 / 100',
#         '여아 해지배색 다이마루ST 원피스 (R1721O607_11) - 140',
#         '여성용 키높이 5.5CM 웨지힐 4종  SCS7601WD SCS6102WD - 밴딩네이비(7602WD21) / 230',
#         '기본반팔티셔츠 RGRA72301C - 아이보리 / 130', '기본FG티_RGLA81101C - 그레이 / 110',
#         '비비라인 세트 95032-1 - 블랙 / 130'], dtype=object),
#  array(['노와이어 인견 메쉬 브라 gbr 5456 - BE / 90B'], dtype=object),
#  array(['여 부츠컷 크롭 슬랙스 418903 - 66 / 29',
#         '휴어 삼중직 스판 벽걸이 에어컨커버(트라이앵글) - 그린_89x27x26',
#         '리스 삼중직 스판 에어컨커버 - 36x27x195',
#         '보트넥 와이드 트임 티셔츠 (GIHTS753F) - 그레이 / F',
#         '스퀘어넥 체크 블라우스 (S88BL20) - 네이비 / F', '부직포 선풍기커버(팬형) 모음 - 디어가든 [블루]',
#         '[지오다노] 418905 여 롱 와이드 슬랙스 - 10베이지체크 / 28'], dtype=object),
#  array(['[데상트] 남성 PRO RUN 마라토너 프로 러너용 경량 반바지 (S8221RHP21) - RPBL_RPBL(R.PurpleBlue) / 85',
#         '[데상트] 남성 SUMMER RUN 스트레치 니트 5부 반바지 (S8211RKH21) - RNVY_RNVY(Running-Navy) / 85'],
#        dtype=object),
#  array(['[하마비즈] 비즈 16종 패키지', '[하마비즈] 비즈 투명보드 - 큰동그라미'], dtype=object),
#  array(['라텍스밴드-옐로우(120x15x0.3mm) 튜빙밴드 근력밴드 탄력밴드 스트레칭밴드 - 라텍스밴드-옐로우(120x15x0.3mm)'],
#        dtype=object),
#  array(['[제이손] 라면 전용 진공젓가락 & 국물스푼(RN2)'], dtype=object),
#  array(['크록스공식 남여공용 CROCBAND II SLIDE 4종 택1(18SS204108) - 01_NAVY_PEPPER(Z4CC) / M6W8(250)',
#         '[나이키] 런 스위프트 908989-001 - 280', '여름 마 롱 자켓(BBFB500A) - 네이비 / 66',
#         '난닝구 럽디오 브이넥린넨원피스 - 베이지(beige)-FREE',
#         '잭앤질 국내산 핫셀러 베스트 샌들 9종택일 - J7209_핑크(낮은굽) / 235'], dtype=object),
#  array(['여아 5부 우븐 팬츠(DOM11PS63M_PK) - 150',
#         '배색 요꼬 카라 티셔츠(DOM11TP61M_WT) - 120',
#         '여아 5부 우븐 팬츠(DOM11PS63M_NV) - 120',
#         '3.5 부 져지 치마바지(DOM11SA64M_NV) - 140',
#         '하우스체크 3.5부 팬츠(DOM12PS65M_BG) - 140',
#         '남성 블랙 마이크로 깅엄 체크 팬츠 (BJ7221B095) - 검정색 / 078',
#         '남성 화이트 두잉 경량 팬츠 (BJ8321B061) - 흰색 / 080',
#         '화이트 3부 팬츠(DOM44PS72M_WT) - 130',
#         '여아 BASIC R넥 티셔츠(DOM11TR63M_WT) - 165'], dtype=object),
#  array(['듀얼(쿨&웜) 낮잠이불-로라 /정상가 128,000원 - 로라',
#         '유아 사계절 린넨 이불(디자인선택) /정상가 44,000원 - 루시의 하늘비행'], dtype=object),
#  array(['풀무원 생수 2L x 6페트'], dtype=object),
#  array(['[자일로스] 무불소 어린이 안심 치약 딸기/사과향 60g X 1세트 - 어린이치약 무불소 1P / 사과'],
#        dtype=object),
#  array(['AQUA TITAN CAP KMA17C15 - 블랙 / M(58)'], dtype=object),
#  array(['우븐절개숏팬츠 183g3481(기존가59900) - [1051703765]블랙/175',
#         '주니어/성인 아쿠아슈즈 워터슈즈 멀티 4종 택1 - 블랙 / 250', '주니어앵무새여래쉬가드세트 - 블랙M'],
#        dtype=object),
#  array(['16년 S/S 흡습,속건성이 좋은 남성 슬럽 반팔 라운드 티 - NFT7UH0 - IVO(아이보리) / 110(XXL)',
#         'NYT7UH19 남여공용 컬러 돔 티셔츠 - ORG(오렌지) / 110(XX)',
#         'NYT7UI01 린덴 라운드 티 - NAV(네이비) / 105(XL)',
#         'NT7TJ02 눕시 긴팔 라운드티 - BLK(블랙) / 110(XXL)',
#         'NT7TI51 베이직 로고 긴팔 라운드티 - BLK(블랙) / 100(L)',
#         'NYT7UI01린덴라운드티 - DKG(다크그린) / S'], dtype=object),
#  array(['[M] 바이오 세컨덤 라이트 감마 1매', '[M] 바이오 세컨덤 클리어 알파 1매',
#         '(24종택1) 여름을 시원하게 SUMMER 반소매 모음전 - 02번 / 100'], dtype=object),
#  array(['시카비오 포마드 크림 40ml  휴식크림'], dtype=object),
#  array(['여성사이바져지배색패딩L174DW951P06 - 85'], dtype=object),
#  array(['남여공용 NYY 레터링 포인트 기본 반팔티셔츠 31TSCL831 - 선택03_화이트 / 110'],
#        dtype=object),
#  array(['BECKY/베키백 숄더+크로스백 세트/10007916'], dtype=object),
#  array(['유니_햇츠온X디즈니 콜라보레이션 미키마우스 귀요미 스냅백(MICSNH0303BK) - 블랙 / FREE',
#         '남여공용 MICKEY MOUSE 패션모자 310(MICFAH0310) - 블랙 / FREE',
#         '아디다스 슈퍼스타 파운데이션 C77124 - 290'], dtype=object),
#  array(['스무드 인퓨전 내츄럴리 스트레이트(150ml)'], dtype=object),
#  array(['까르니꼬 클레식 이태리 천연 대리석 인테리어 테이블_CL171'], dtype=object),
#  array(['T184MTS246W_여성 자수 포인트 슬림핏 티셔츠 - 오프화이트 / WM',
#         '[여성]레이어드 슬립원피스(T184MOP241W) - 민트 / M'], dtype=object),
#  array(['쥬쥬 아쿠아슈즈 [J1121][K0634] - 쥬쥬-K0634 / 150',
#         '(헌트키즈) 솔리드 반팔티셔츠_HKRP6A5002 - 레드/90',
#         '부드럽고 맛있는 닭가슴살 11종 (100g,120g,130g,150g*1팩) - 2.부드러운 훈제 닭가슴살',
#         '18SS 유아 아동내의 순면 무형광 슬러브 실내복 7부1차 토마토RD - 130호(7~8세)',
#         '리본 프릴 블루머(아이스크림) - 블루 / L(130)[258320003]',
#         '오끼오 아동 7부내의세트(17SS)-택1 [무냐무냐 자매브랜드] - 오끼오플로랄7부세트 / 60',
#         '[동물원] 동글버니 5부 쟈가드 상하세트 - 140(9~10세)',
#         '★특가★여름 여아 잠옷 3종택1★ - 02.쏘핫큐트실내복 / 화이트105',
#         '어린이용 일반 Regular 스노클링 마스크 - 블루 XS',
#         '2018SS 아동 여아 3부 레이온 파자마 (2종 택1) - 1.CSC여3부파01 / 75호',
#         '18SS 유아 아동내의 순면 무형광 슬러브 실내복 7부2차 토마토PK - 90호(24개월)',
#         '위드 식탁의자_2개입(3종/택1) - C형 그레이(C)',
#         '도담이 100매 10팩 캡형 도톰한 물티슈 평량 50g - 100매 10팩 캡형',
#         '펫더맨 오리고기 치즈버거100g',
#         '[ZAXY]동물캐릭터 키즈 샌들 ATSO8E713 - 핫핑크(P3) / 22(125-130)',
#         '[1+1]퓨리나 알포 리틀프렌즈 치아건강 닭고기맛 2.6KG 2개+새감바 30g 증정'], dtype=object),
#  array(['캐닝머그2조세트'], dtype=object),
#  array(['아이키커 총30포/1박스 (사과 10포, 오렌지10포, 포도10포) - 정관장아이키커',
#         '[백화점배송/백화점AS] 오토메틱 남성 메탈 FC-306S4S6B2'], dtype=object),
#  array(['먼지없는 고양이모래 매직카펫 LowTrack 7kg (굵은입자)',
#         '우먼스 베네시 듀오 울트라 슬라이드  819717-010 (9840612) - 230',
#         '먼지없는 고양이모래 매직카펫 Classic 7kg (중간입자)'], dtype=object),
#  array(['[무료배송/한달분량] 스파클 생수 2리터×6병(6팩) - 총36병 / 대리점배송 (배송가능지역 확인必)'],
#        dtype=object),
#  array(['오직 유기농 노니즙 1박스 100포',
#         '892764 나이키우먼스레가시91골프캡 골프모자 2018신형 여성용 - [892764-471] 썬더블루'],
#        dtype=object),
#  array(['0.045mm미세모 42만모 모공브러쉬 大 (65%할인) / 세안 클렌저 클렌징 저자극 부드러운 블랙헤드 각질케어 - 멀티 모공브러쉬 大'],
#        dtype=object),
#  array(['턴어라운드 엑셀러레이티드 리뉴얼 세럼 (30ml)', '디자이닝 아이브로우 N (F) 세트 - EX-5',
#         '진징 아이크림'], dtype=object),
#  array(['TS-러브볼륨스커트 - 레드 / 130',
#         '18FW 오가닉 유아 아동내의 순면 무형광 30수 9부1차 실내복 세트 6종 택1 - 18FW슈퍼히어로30수9부상하 / 110호(5세)'],
#        dtype=object),
#  array(['여성 오리지날스 다트디테일 쇼츠(YI5D6960) - 미디엄블루 / 28'], dtype=object),
#  array(['레몬 버베나 바디 워시', 'MLE 포밍 바스 280ml', '면 누디팬티 - 연핑크 / XL',
#         '[보리보리/삐삐롱]삐삐롱 코랄판타지 여롱드로즈 1매/아동팬티/아동속옷 - 여드로즈/65호',
#         '[보리보리/삐삐롱]삐삐롱 스노우플라워 여롱드로즈 1매/아동팬티/속옷 - 여드로즈/60호',
#         '[보리보리/삐삐롱]삐삐롱 크림코코 여숏드로즈 1매/아동팬티/아동속옷 - 여드로즈/65호',
#         '노와이어 브라 - 코코아 / 85AB', '[JB]공주샴푸 500ml -액티브 키즈 샤이니 샴푸',
#         '페이스 크림 35ml'], dtype=object),
#  array(['남성_어반슬림핏 사이드밴딩 슬랙스팬츠 (PHY1PP1033) - NV / 86(34)',
#         '여성 하프 밀라노 숏가디건(10160-140-211-34) - 오프화이트(021) / 95(M)',
#         '어딕트 립 글로우 핑크 (3.5g)', '진주 장식 펀칭 물결 넥 가디건 (ENCK81301Z) - 베이지 / F',
#         'CRYSTALITE 여행가방 4종 - PURPLE', '디올 어딕트 립 글로우 라즈베리'], dtype=object),
#  array(['아이패스 H(50ml X 30포) / 롯데백화점 본점 출고 / 정관장', '아이패스 M(50ml X 30포)'],
#        dtype=object),
#  array(['블랙 나야나 티셔츠 (BI8342U045) - 검정색 / 155',
#         '아기물티슈 화이트 캡형 74매X20팩 WC20 - 화이트 캡형_74매X20팩',
#         '아기물티슈 화이트 캡형 74매X10팩 WC10 - 화이트 캡형_74매X10팩',
#         '클래식 체크 핸드폰 가방 (2종 택1) - 짙은분홍 / F', '아이시스8.0 200mlx80펫',
#         '우먼스 드라이 쇼츠  895864-010 - 075', '매치업 숏슬리브 폴로 886508-010 - 090'],
#        dtype=object),
#  array(['[노트북 그램] 터치스크린 14Z980-TA5IK (i5-8250U 3.4GHz / 8GB / SSD 512GB / Full HD / Win 10)',
#         '[BF][코랄크러쉬입고!] 리퀴드아이섀도(+멀티블록브러쉬+뷰러) - 집시.'], dtype=object),
#  array(['V랩텐셀수유브라_MB18RAB01_2COLOR - 아이보리 / 2XL'], dtype=object),
#  array(['[제주]삼다수 500ml*20 - 제주 삼다수 500ml*20',
#         '[제주]삼다수 2L*6 - 제주삼다수 2L*6EA', '하프슬리브카라니트 (J11PNT169) - 네이비 / FF',
#         '에이머 원형접시 2P세트 JAPAN', '제주삼다수 2L x 12펫',
#         '양면브이넥니트 (J11PNT179) - 브라운 / FF', '5부소매골지니트 (J11PNT173) - 블랙 / FF',
#         '이지펀칭가디건 (J11PCD055) - 아이보리 / FF',
#         '브이넥타이니트 (J11PNT170) - 아이보리 / FF',
#         '레이스 가디건 OBNB503A - WHITE / FREE', '에이머 혼밥세트 Pasta Ver. JAPAN',
#         '[오가게/매그제이]린넨스커트팬츠 (J11PPT178) - 카키/FF',
#         '린넨슬릿티셔츠 (J11PTT111) - 블랙 / FF',
#         '펀칭셔링블라우스 (J11PBL114) - 아이보리 / FF',
#         '배색카라니트 (J12WNT011) - 브라운 / FF'], dtype=object),
#  array(['포커스 W2 1600 옷장세트 A형 - 오크화이트', '해븐 수납헤드 트리플 서랍침대SS(본넬) - 워시'],
#        dtype=object),
#  array(['국내산 골드체인 블로퍼(JA8141) - 핑크 / 245',
#         '[예스비] Y 레이스 집업점퍼 BA5U5WGJ200_270 - VIOLET / 66',
#         '여름 노카라 스트링 집업 점퍼_TWWJPH60020_PI - 핑크/66',
#         '여성 홈웨어 세트 스트라이프 (4color) - MSWS312세트-블루FREE',
#         '남성 로고포인트 트레이닝 팬츠 DMTP65731 - 네이비[NY] / 30',
#         '아디다스 ADIDAS 아디다스 남성 클라이마칠 폴로티 S93913 골프의류 골프용품 GB Golf Climachill Polo - S93913 네이비 / S',
#         '[하프클럽/CCUTTI]장미자수 여름점퍼(C82JPM001) - 화이트|WH|/FF|FREE|',
#         '언더아머 스포츠스타일 피케 트랙팬츠 (1313201-002) - 1313201-002_블랙 / LG',
#         '헤지스남성 OUTS7BH52G2 컬러배색 면 반팔티셔츠 - 105'], dtype=object),
#  array(['[4BT]뉴메로10 에센스75ml 세트 - 기본',
#         '데님 서스팬더 원피스 MIWOW8636J - L/INDIGO / S',
#         '(공식 판매)오떼르말 300ml(1+1)_AN08-2', '루즈핏 하와이안 로브가디건[D2840] - 아이보리'],
#        dtype=object),
#  array(['에어워크서프 남성래쉬가드 타슬란보드숏 모음 /비치트렁크/레쉬가드/래시가드 - 03.LAWe0902_BK / 100',
#         '나이키 에이스 로고 탱크 슬리브리스 화이트 779234-102 - S'], dtype=object),
#  array(['갤럭시탭A 8.0 2017 (SM-T380/T385)태블릿 어린이안전 에바폼케이스 - 갤럭시탭A 8.0 2017 에바폼케이스(+터치펜) / 블루',
#         '스키니 팬티라이너 20p x4팩 - 스키니 일반라이너 20p x4팩 +샘플4p',
#         '[CLRID.n] 클라이드 남성 데님팬츠 CDBDP203M062 - CDBDP203M062 / 032'],
#        dtype=object),
#  array(['뉴컴퍼터블 진드기차단 요솜 120X210 - 화이트', '뉴컴퍼터블 진드기차단 요솜 150X210 - 화이트'],
#        dtype=object),
#  array(['모노톤 바스켓 15L_(아이보리/그레이/다크블루) (INP311M) - 다크블루',
#         '★일주일특가! 이동식 5단 트롤리_아이보리 (HPO732)/기저귀정리함',
#         '모노톤 바스켓 30L_(아이보리/그레이/다크블루) (INP312M) - 다크블루',
#         'INPLUS스토리박스INP311,312공용캡(Natural) (INP313)'], dtype=object),
#  array(['[당일배송] 2018 NEW UV플랩캡/캠핑햇 13종 택 1 - 10.캠핑햇_GREEN / XL',
#         '스카치 테이프(583-3/3M)', '[129590]다람쥐 학용가위(연두/138mm/niceday)',
#         'NEW DS-DU7781 디즈니 아동 미키/미니 수영모자 - 핫핑크', 'PLUS수정테이프(WH-605/5X6)',
#         '선글라스 스트랩 6컬러 - 블랙 / S(38cm)', '디즈니 정품 미키 도날드덕 파우치2종 택1 - 레드',
#         '[센터배송]유아동 UV 선글라스 제이반즈 12종 택1 - 07.플라이어_BROWNLPD',
#         'PLUS수정테이프리필(WH-605R-2P/2개)',
#         '[129600]마술토끼 학용가위(핑크/136mm/niceday)'], dtype=object),
#  array(['[클렌징티슈 증정]순딩자차 크리미 선쿠션 SPF40 PA+++_GBKG8105 - 없음/20393120/',
#         '[7기프티쇼]자외선 차단제 점보 세트', '톡톡 페이셜 선팩트 15g'], dtype=object),
#  array(['F/W 비지니스 긴소매 슬림핏과 일반핏 셔츠 모음전(사은품증정) - 37 / 105'], dtype=object),
#  array(['아디다스 남성 Corp CL Polo M 반팔카라티셔츠-B30905 - 2XL',
#         '세련된 스트라이프 셔츠 블라우스 (GI6N0BL69) - (77)레드 / FF',
#         '[아디다스] 남성용 에스트로 15 JSY 반팔티 S16150 - S'], dtype=object),
#  array(['우먼스 액티브웨어 레깅스 OZMP-00106 - [OZMP-00106] 에어쿨링 블랙/6 (66반 ~ 77)',
#         '우먼스 액티브웨어 코튼모달 티셔츠 OMIT-00101 - [OMIT-00101] 화이트/F (Free)'],
#        dtype=object),
#  array(['[8상품권]매트 벨벳 스킨 블러링 파우더 파운데이션 세트 - Y305',
#         '볼드 팁 피케셔츠Block Tipped Pique Shirt AFPM1834525-102 - XL(110)',
#         '맨 릴랙싱UV프로텍터(50ml)'], dtype=object),
#  array(['워싱진 10부(연청) TJ81101C - 라이트 인디고 / 130',
#         '[핑크시슬리]썸머스트라이프 반바지 - 블랙 Black / F'], dtype=object),
#  array(['[크로커다일레이디] 스트라이프 긴팔 블라우스_CL7MBL139 - IV / 090',
#         '2018SS 주니어 남아 런닝 모음 (9종 택1) - 7.CSC남런닝09 / 90호',
#         '플로랄 스트라이프 블라우스(CL8MBL107) - 블루 / 100',
#         '남자아동런닝 CSC남아런닝01(80~90호) - 80(11-12세)'], dtype=object),
#  array(['티엠포 레전드 VII 아카데미 HG  AO9880-006 - 280'], dtype=object),
#  array(['[#텐텐] 간편접이식 캠핑용 와이드형 4인 폴딩테이블(우드무늬)',
#         '패스트캠프 원터치텐트 메가스위트 착탈익스텐션 - 그레이+보냉백'], dtype=object),
#  array(['가방 플레밍 미듐백 12159765 659 크로스백 - ONE SIZE',
#         '남성 소프트 멜란지 디테일 헨리넥 티셔츠 AMMR3TW9067A 401 - LT BLUE / S',
#         '남성 헨리넥 레글런 티셔츠 AMMR3TW9208A 800 - ORNG / XL'], dtype=object),
#  array(['밴딩우븐숏팬츠 (27415-413-51) - ORANGE / 130',
#         'BR26TS05PK 여아 핑크 롱 반팔 티셔츠 - PK(핑크) / 165',
#         '베이직5부데님팬츠 (27315-414-54) - BLUE / 110',
#         'IV프릴드롭티셔츠(T73KAT070-W2) - 120'], dtype=object),
#  array(['로얄캐닌 라이트(LIGHT)3.5kg+습식파우치 1개 랜덤 증정',
#         '기내용캐리어 20인치 여행가방 MCP29900 - 네이비'], dtype=object),
#  array(['헤지스남성 OUTS7BH13G2 컬러블록 면 반팔카라티셔츠 - 100',
#         '부엉이티셔츠 BATS10741 - 그린 / 44(66)'], dtype=object),
#  array(['트윙클 암막 아일렛 중형커튼 (2장) - 핑크', '문중 총각김치 5kg / 무료배송 - 문중 총각김치 5kg'],
#        dtype=object),
#  array(['핑크 발렌타인_삼각 팬티 세트[EBBR622011EBBR622111EBWP622011] - 핑크 / 75B / 90'],
#        dtype=object),
#  array(['세련된 스트라이프 셔츠 블라우스(GI6N0BL79,GI4N0BL56) - (41)스카이 / FF',
#         '심플 베이직핏 원피스  VOBOASM5121 - 43(그린) / 100', '(기획)리치 포밍 클렌저 세트'],
#        dtype=object),
#  array(['아레나 망사 가방(AUAAB06) 세로형 수영가방 - 로이'], dtype=object),
#  array(['배트 슈혼 구두주걱/25cm 아크릴 구두칼/헤라'], dtype=object),
#  array(['백팩 CHALLENGER [PASTEL BEIGE C]',
#         '그레이 음각로고패턴 가죽 카드지갑 WIHO7F009G2 - WIHO7F009G2 / 선택사항참조'],
#        dtype=object),
#  array(['[가이타이너 빙수기증정!] 통째로 원액기 WSJ-972K'], dtype=object),
#  array(['단독 어린쑥 수분진정 크림 50ml', '산들박하 트러블 젤크림 100ml'], dtype=object),
#  array(['go! 내추럴 캣 치킨 7.26kg'], dtype=object),
#  array(['여성 캐쥬얼/심플 브라팬티 6종 택1 - 11)EPB3672/Set / 75B/90',
#         '컨트롤 에이 센스티브 선 프로텍터 40ml (ctrl-A Sensitive Sun Protector)'],
#        dtype=object),
#  array(['안티 포어 블랙헤드 클리어 키트 10회분'], dtype=object),
#  array(['[오가게/비엘르]라이드 체크 원피스 - 옐로우/FREE', '이츠웰 맛김치 1kg',
#         '[오가게/비엘르]첵스 원피스 - 블랙/FREE', '[오가게/비엘르]시슬라운 랩원피스 - 네이비/FREE',
#         'KLINGSBO 사이드테이블 201.615.58',
#         '배색데님스커트[AFS2EE01C] - 네이비(NAVY) / 55',
#         '일본 정품 히로사 규조토 발매트(대) L 사이즈 3종 택1 욕실매트 집들이 선물 - 핑크 - L',
#         '이츠웰 총각김치 1kg'], dtype=object),
#  array(['EnC 배색 라운드네크 스트라이프 니트풀오버 ENKT82403N - NV-네이비 / FREE',
#         '히로인 메이크 롱앤컬 마스카라EX - 롱앤컬(K117ON)',
#         '블랙 로고 가죽 반지갑 HJWA8E918BK - HJWA8E918BK / 선택사항참조'], dtype=object),
#  array(['[지오다노] 028910 기본 테리 크루넥 풀오버 - 08 레드 / L',
#         '[지오다노][무료배송] 243801 코튼 져지 크루넥 3pcs 패키지 - 12(WH+GR+BK) / XL',
#         '하이브리드 후디 AJ6353-100 - 110',
#         '[지오다노] 028601 저지 크루넥 솔리드 긴팔 티 - 06스카이블루 / XL',
#         '남 기본 테리 크루넥 풀오버 028910 - 01 / XL',
#         '헤지스남성 HZSH7D405N2 카키 체크 면 긴팔캐주얼셔츠 - 105',
#         '미즈노 운동화 런닝화 맥시마이저 시리즈 7종중 택 1 - 06. MZ-K1GA180010-00 / 290',
#         '남성용 캘린더 메탈시계 SUR243', '[지오다노] 378950 여 초경량 크루넥 숏자켓 - 10 차콜 / XS'],
#        dtype=object),
#  array(['리오 델 뉴송 우드슬랩 통원목 4인용 식탁세트 1400 A - 투톤', '위도우 의자(1+1)/A TYPE'],
#        dtype=object),
#  array(['에어팟 케이스 고리형 키링 행 - 러블리 핑크', '에어팟 실리콘 이어후크 (6 color) - 야광블루',
#         '에어팟 방수 고리형 케이스 / 철가루 방지 - 레드'], dtype=object),
#  array(['베이블레이드 B-105 초Z 제트 아킬레스.11.Xt',
#         '나시 티셔츠/K2RSZ106X.107X - WHI / 100',
#         'NEW 올인원 3-Way 수압상승 절수 샤워기-블루',
#         '나시 티셔츠/K2RSZ106X.107X - WHI / 120', '베이블레이드 B-104 초Z 위닝발키리',
#         'B-88[툴] 베이런처LR / 베이블레이드 버스트갓 좌우회전 - (영실업) B-88(툴) 베이런처LR',
#         'BR23TS02CG 남아 도형프린트 티셔츠 - CG(차콜그레이) / 100',
#         '디자인방문모기장100×210cm/현관모기장/자석모기장/일체형자석/방충망 - 디자인방문모기장(싱어송)100',
#         '프리미엄 과탄산소다 대용량 5kg', 'BR25TS07GY 나뭇잎 나염 그레이 티셔츠 - GY(그레이) / 120',
#         '베이직민소매티셔츠 QATS37731 - 멜란지 / 155',
#         '[3801049][아모스]1200 물풀 120ml/ 액체괴물풀/낱개 - [3050181]단일상품',
#         '홍백작 - 홍백작 (40mlx30포)'], dtype=object),
#  array(['실버 포맨(50정)+실버 포우먼(50정) 세트'], dtype=object),
#  array(['[E]뚜쉬 에끌라 르 쿠션 - B20',
#         '조던 키즈 DL 쇼트팬츠 반팔 상하세트 NNM11QST90 - 레드(RE) / 3T(2-3세)',
#         '여성 NEW XY ZIP UP 록시 짚업 래쉬가드 R821RS333 - MLJ / 95(M)'],
#        dtype=object),
#  array(['남성_허리밴딩 면5부 팬츠(PHX2PH1062) - BL / 74(28)',
#         '메가 버섯 수딩 트리트먼트 로션 200ml', '남성 반팔 티셔츠 (FILA_U2HTX101M_GY_) - 95',
#         '남성면３２수트윌스판쿨드라이５부팬츠,HPHP3161 - WH / 30'], dtype=object),
#  array(['나이키 베네시 듀오 울트라 슬라이드 819717-010 - 블랙화이트 / 290',
#         '우먼스 베네시 듀오 울트라 슬라이드(슬리퍼)[나이키/819717010] - 220'], dtype=object),
#  array(['트릿 미 텐더 퀵 수딩 세럼 30ml'], dtype=object),
#  array(['아디다스 요가매트 4mm - 블랙', '스툴의자-심플 - 아이보리', '빌리책장-3단 - 블랙'],
#        dtype=object),
#  array(['(8월)안티/옥시+ 클렌징 오일 450ml 세트',
#         '프로 테일러 파운데이션 비 글로우 30ml - 바닐라_611121303', '크로스액션 프로-엑스퍼트(35모)x5개',
#         '기라로쉬 큐브 타올(1매) - 보라'], dtype=object),
#  array(['울트라 훼이셜 크림 50ml 세트', '쿨링 수분 젤크림 점보 세트'], dtype=object),
#  array(['체리라즈베리반소세트PT310388SET - 80', '퍼실 하이진 1.8L(타입선택) - 일반',
#         '옴므 에센스 인 스킨 125ml', 'ME by 린넨 버튼 롱 원피스 (MIWWH8721L) - BROWN / M',
#         '남자아동런닝 CSC남아런닝01(60~75호) - 75(9-10세)',
#         '베이비 여아 플래드 드레스 원피스 5238240501061 - 18M',
#         '[크록스] 리나 도르세이 샌들 204361-488 - CRO-204361-488_240',
#         '오끼오 아동 3부내의세트(17SS)-택1 [무냐무냐 자매브랜드] - 오끼오빈티지플라잉3부세트 / 60',
#         '[EWG업그레이드 성분ㅣ한국한정판] 사노산 밸런스플러스 바스앤샴푸 400ml',
#         '정품 가정용 USB 일반충전기 2A / EP-TA12K - (EP-TA12KWKUG) 화이트',
#         '[오랄비]스테이지스 어린이용 칫솔(단계선택/색상랜덤) - 3단계-카즈',
#         '[첨이첨이]남자아동런닝 CSC남아런닝02(80~90호) - 85(13-14세)',
#         '꽁뜨린마린원피스 - 흰색 / 100',
#         '베이비 여아 아이스크림 러플소매 바디수트 5238243572001 - 24M',
#         '베이비 여아 레몬 바디수트 5238243537051 - 6M',
#         '아디다스 주니어 캡틴토이 K CM7639 CM7640 (2종택1) 아동샌들 - CM7639 블루 / 180',
#         '베이비 여아 자수 민소매 원피스 5238240611064 - 24M',
#         '[스파오] 여성 FG라글란반팔티셔츠-SPRA536G98 - 카키 / XS.',
#         '아동 듀크라글란티셔츠(CBG2TS402S) - 블루 / 110',
#         '헤지스남성 HZSH7B482B1 면 버튼 다운 카라 캐주얼 셔츠 - 100',
#         '5부 스판 면바지 _OHTH824B01 - 그린 / 150'], dtype=object),
#  array(['[오가게/톰앤래빗]프렌체크자켓 /자켓/체크자켓/기본자켓/하프자켓 - 그레이/L',
#         '[오가게/톰앤래빗]마약스키니팬츠 /컬러스키니/면바지/데일리팬츠/스판바지 - 네이비/M'], dtype=object),
#  array(['[E][9월 임직원몰][정가165,000원]아로마 리페어 샴푸&컨디셔너 대용량 세트',
#         '[E][9월 임직원몰][정가76,000원]아로마 리페어 샴푸 950ml'], dtype=object),
#  array(['마법보정팬티 1+1 - 마법보정팬티 블랙 / S',
#         '여신브라 - 여신브라 바이올렛 / 105(90B.90C.95A)'], dtype=object),
#  array(['리미티드 립 컬렉션 세트 - 리미티드 립 컬렉션'], dtype=object),
#  array(['여성 베이직 밴딩 브라팬티 4종 택1 - 01)CDBBRM51NY/set / 80B/90'], dtype=object),
#  array(['남성 겨울용 반집업 티셔츠 AMW16231EDM - 베이지 / 105',
#         '가을/겨울 여성용 등산기능성 짚업스타일 P3XP3티셔츠-2 - BLACK(검정색) / 100',
#         '★겨울선오픈★ 패딩/다운조끼 4종 균일가 - 03_GFAK7312C01 / 100',
#         '남성 경량 구스다운베스트FHMWCVW143P - 네이비(NY) / 100'], dtype=object),
#  array(['트위스티드 비치모자/SH775-6 - 검정', '[핑크시슬리] 미앤유 브이넥 롱Tee - 아이보리Ivory_XL',
#         'P5102 줄무늬 주름 슬림 롱스카프 - 와인 / free',
#         '[핑크시슬리]파인애플 단가라Tee - 화이트 White / F',
#         '[핑크시슬리] 미키포켓D 롱박스Tee - 화이트White_F',
#         '여성 빈티지 컷팅 팬츠(T162PT680P) - 블랙 / 71', '미니 차차틴트 (4ml)',
#         '믹스매치 벙거지/JS004 - 베이지', '[핑크시슬리]썸머 쿨링 3type 원피스 - 네이비플라워패턴 / F'],
#        dtype=object),
#  array(['FU3부레깅스(화이트_메란지_차콜_블랙) - 차콜 / 15',
#         '[크록스]성인 바야(10126外)택일 - ▶10126-200초콜렛 / M5/W7',
#         '키즈 남/여 런닝&케미솔&팬티 4종택1 - 3.남)남아삼각 / 80'], dtype=object),
#  array(['라이프 중식도 2종 세트 중식도+클리버(HK38590-001) - 라이프 중식도 2종 세트(중식도+클리버)'],
#        dtype=object),
#  array(['무한타올 기라로쉬 베어40 - 백색',
#         '[마이독스] 램버트케이 샴푸(베이비파우다/해충제거/약용/오드밀)/애견/강아지/애완/개/샴푸/린스/미용/위 - 오트밀 소다'],
#        dtype=object),
#  array(['[bn507] 스노클링세트 - BN-507 아쿠아',
#         '[신제품] 디올스킨포에버 익스트림컨트롤퍼펙트 매트파우더메이크업(리필) - 020 라이트 베이지 (리필)',
#         '아이폰SE 네오플랜 재질 열쇠홀더 제공 스포츠 암밴드[심플] - 핑크',
#         '35cm 좌석용 선풍기 DF-14AG 일반선풍기 안방선풍기 [신일AS가능]',
#         '엑스트라 오디네리 오일 마스크 250g', '공식판매처 센카 퍼펙트 휩 N 120g 2개',
#         '남성 냉감 팔토시 (X1PMETM41) - 화이트 / M', '에브리데이 아쿠아 선크림 50mlx2',
#         '프레시팝 샴푸/컨디셔너 500ML 3개 (옵션) - 20 유칼립투스 두피 컨디셔너 500ml 3개'],
#        dtype=object),
#  array(['[HONG SHOT] 홍샷 파워래스팅 파운데이션 30ml×2 + 파워래스팅 컨실팩트 + 파워래스팅 벨벳틴트 (3종  ... - 21호 일반피부',
#         '샴푸2개+트리트먼트1개+바디워시1개 세트(+1 추가 랜덤 증정) - 07.잉글리시로즈',
#         '[오가게/엔비룩]캐쥬얼버튼원피스 - 베이지/FREE', '[#텐텐]패치가 찰싹 데님 클러치_3005750 - 무지개',
#         '1+1 방수 매트리스커버 SS+Q/진드기차단/침대커버'], dtype=object),
#  array(['★★ ★화애락진(70ml*30포) - 화애락진',
#         '헤지스남성 OUTS7BH34N2 라인배색 면 반팔카라티셔츠 - 100',
#         '여성 노와이어 브라팬티 6종 택1 - 02)TWB0329/Set / 75A/90',
#         '여아 세일러 플레어 원피스[71OP57831] - 화이트(W) / 145',
#         'YC-79003 심플로고모자 라파클럽 아동모자 - 브라운',
#         '오슬로 노트북 파우치 15.4/15.6인치[사은품증정] - 레티나15.4인치-그레이',
#         '봄여름 브라팬티SET 5종택1 TWB0464TWH0464SK_5 - 0465(네이비) / 75A / 95',
#         '솔리드쿠션빵빵브라팬티셋트 5종택1[TWB0467TWH0467-5] - 95 / 80B / 3.TWB0466TWH0466PK'],
#        dtype=object),
#  array(['단독 NEW 에어쿠션 본품 15g + 리필 15g + 퍼프 2개 - 커버 13'], dtype=object),
#  array(['별밤 반짝이 플랫 - 190', '데일리 키즈 프로바이오틱스 1통 (30일분)',
#         '페이퍼자수 티셔츠 - S 5호 노랑', '데일리키즈 유산균 프로바이오틱스 2통 (60일분)+추가 2일분',
#         '샌들힐 Ivy K200398-005 - EU38(240-245mm)', '페이퍼자수 반바지 - M 7호 노랑',
#         '블랙리본 블라우스 - XS 5호',
#         'BS27TS02CG,BS27PT01CG 남아 의류 세트 - CG(차콜그레이) / 175',
#         '러뷰 티셔츠 - M 9호 회색',
#         '우먼 피하 집업 래쉬가드 블랙/블랙 플라워 (BW5WRGT012D19SM) - 단일색상 / Small',
#         '베이직 긴팔티셔츠 - XS 5호 노랑', '(MG)그래픽나시상하SET(184A9-640-04) - MG / 155'],
#        dtype=object),
#  array(['[정기배송 홈서비스 6개월] 트레비 (플레인) 500mlx10펫'], dtype=object),
#  array(['바야 키즈 6종 디자인 선택 - 페퍼레드_10190-6EN / 210',
#         '이정섭의 본가김치8kg+석박지2kg(총10kg)'], dtype=object),
#  array(['여 크루넥 프린트 반팔 티 398504 - 07 / M'], dtype=object),
#  array(['여성 스트라이프 7부 V셔츠 (070-120-414) - 644(핑크) / M(004)',
#         '여성 3칼라 등프린트 롱셔츠 (30070-121-405-30 ) - 303(블루) / S(003)',
#         '여성 스트라이프 가슴프린팅 티셔츠 (070-131-409) - 244(네이비) / M(004)'],
#        dtype=object),
#  array(['홍삼정 에브리타임(10mlx30포) / 롯데백화점 본점 출고 / 정관장',
#         '★코드제로 핸디스틱 A9 청소기 A958SA (판타지실버/스마트인버터모터) - 있음'], dtype=object),
#  array(['순수 저자극 허브 달팽이 스킨로션 / 천연 순한 기초화장품 저자극 유수분밸런스 수분공급 보습 촉촉한 - 02_허브 달팽이 로션',
#         '센시티브 스킨 안티 더스트 클렌징폼 100ml'], dtype=object),
#  array(['밤부은하수 손발싸개세트_여름용', '미니미 손발싸개세트_여름용'], dtype=object),
#  array(['다시 돌아온 앵콜 브라팬티 15종택1 EPB2308EPH3308-15 - 5.EPB2339(SK) / 85B/90',
#         '엘르이너웨어 핑크아웃밴드 여성면팬티 EPP0145 - 95'], dtype=object),
#  array(['트윙클 토즈 SK0GL17X111 - 170(121번)'], dtype=object),
#  array(['[탐나나]서프 뒷트임나시티 - 블랙 / FREE(44~66)',
#         '[WOMENS ORIGINALS] 트레포일 탱크 4종 {CE5580SERIES} - CE5583(핑크+화이트) / L(100)',
#         '브라운 패밀리 칫솔걸이 - 단품',
#         '[화랑고무] 잘지워지는 지우개 G371(45*21*9mm) - [2304100]단품',
#         '[실버] 에브리데이 심플 팔찌[폭스타일] - Navy',
#         '남여공용 스누피 에코백38010-0031 - 아이보리 / Free (넓이43cm 높이40cm)',
#         '[아디다스/단독] 클라이마쿨 드로즈 7종 - 7MYZSH04/00 / 100',
#         'Wonderbra 에센셜 브라팬티 2종 12스타일 택1 WBLT2_SELECT12 - 02. WBW8E17_T / 80A(95)',
#         '원 숄더 플라운스 티셔츠 - IVORY / Medium [063]',
#         '남성 타미로고 플레이스 홀더 벨트 TJMS1ABE73A0 - 화이트(N00) / 85',
#         '여성 스니커즈 양말 택1 - 11.섬머단가라 / 핑크', '바이오 민소매 티셔츠 (YD5TSQ362) - 아이보리',
#         'a컷팅 데님 팬츠 (A-18012201) - 중청 / M',
#         '[정품]남여공용 멕시코66슬립온 211717030 (W/RB) 0143 - 화이트&블루&레드 / 245',
#         '마일드 나이트타임 튜브형 치약 200g x 4개 + 마일드 20g 1개',
#         '플랫일자팬츠 (A-18021901) - 검정 / S'], dtype=object),
#  array(['여성 5부 해지 밴딩 팬츠 - 블루(21) / 66(26)',
#         '포멀 베이직 숏기장 팬츠 (GI4A0SL33) - (47)네이비 / 55',
#         '남여공용 밴딩 면 반바지 KA8U4-UPH090 - 베이지 / 32'], dtype=object),
#  array(['남녀공용 스니커즈 볼트 로우 CS_M6017CV_WH - 화이트 / 270',
#         '남녀공용 스니커즈 볼트 로우 CS_M6017CV_WG - 화이트 / 250',
#         '질레트 프로쉴드 옐로우 면도기+면도날(4입)+센서티브폼+휴대용 / 무료배송 - 질레트 프로쉴드기획세트'],
#        dtype=object),
#  array(['린넨 혼방 반소매 긴소매 BEST 셔츠 19종 택1 - 선택04 / 110'], dtype=object),
#  array(['칼렌듈라 허벌 엑스트렉트 토너 500ml', '[감사의달] 자외선 차단제 점보 세트'], dtype=object),
#  array(['[선물포장]오가닉 애착인형 아기양 치치  - 아기양치치',
#         '납작머리 관리 전문베개 지오필로우 M사이즈 - M사이즈(머리둘레 41Cm 이상) / 옐로우스타',
#         '[선물포장]오가닉 애착인형 몽실이  - 브라운st(BS)',
#         '[한정기획특가★] 변신범퍼침대 특대형_월드스타 160 (아이보리) - 월드스타 특대형 160 (아이보리)'],
#        dtype=object),
#  array(['[기프팅] 싱글레귤러콘'], dtype=object),
#  array(['[전품목 9,900원] 폴란드 그릇 비자(WIZA) 균일가전 - 01.공기 3종 택1 / 01-03.이베이스(171-153)',
#         '[14,900원 균일가] 폴란드 그릇 자크라디(Zaklady) 특가찬스 - 10.서포트 / 10-01.블루플라워/1517',
#         '[전품목 12,900원] 폴란드 그릇 비자(WIZA) 균일가전 - 04.스몰오발디시 5종 택1 / 04-03.마리아/222-165'],
#        dtype=object),
#  array(['(PK)후드패딩베스트(28A75-131-03) - PK / 145',
#         'Sneakers_RANION RK631 - Lavender / 250'], dtype=object),
#  array(['[스테디셀러] 1+1 베개솜 6종 균일가! - 메밀베개 1+1(45x25)_네이비',
#         '트라이탄 푸고 바디링 / 부품,아기,유아,빨대컵,텀블러,시피컵,보온병,보틀,물병,스텐,세척솔,젖병솔 - [트라이탄 푸고]바디링(핑크)'],
#        dtype=object),
#  array(['여성 스트라이프 원피스 LCST EF258E-18B001 - 036'], dtype=object),
#  array(['크록스공식 여성 LEIGH ANN ANKLE STRAP LEATHER 2종택1(18SS204732) - 01_HAZELNUT(Z28G) / W7(240)',
#         '[촉촉미백]아쿠아볼릭 하이드로-휩 크림 세트 - 없음'], dtype=object),
#  array(['텐더케어 소프트 슬리커 브러쉬 M'], dtype=object),
#  array(['듀오 아이섀도우 생 폴 드 방스',
#         '(SM) 헤리티지 스니커즈 운동화 디스럽터 2 Triple Black (FS1HTA1078X_BBK) - FS1HTA1078X_BBK / 250',
#         '아디다스 아딜렛 샤워 B42212 - 그레이화이트 / 250',
#         '(SM) 헤리티지 스니커즈 운동화 디스럽터 2 에나멜 (FS1HTZ3077X_BLK) - FS1HTZ3077X_BLK / 220',
#         '(10월)탄력크림 세트', '피사 남성 블랙 레귤러핏 RFSO8E126 - BK(블랙) / 041(265mm)',
#         '(SM) 헤리티지 스니커즈 운동화 디스럽터 2 (FS1HTZ3075X_EPK) - FS1HTZ3075X_EPK / 245',
#         '에어맥스 90 울트라 2.0 에센셜  875695-101 - 260',
#         '나이키 아쿠아 삭 360(885105-001)_검/흰 - 220',
#         '스탠스미스 ADIDAS STAN SMITH (AQ0439) - 225', '에그 레미디 팩샴푸+헤어팩',
#         '구프 프루프 브로우 펜슬 (#슈퍼 이지 눈썹 펜슬) - 05 (딥)',
#         '(SM)헤리티지운동화 디스럽터 2 핑크플라밍고 (FS1HTZ3074X WPK) - FS1HTZ3074X WPK / 230',
#         '남여공용 로얄 컴플리트 2LCS CN7428 - 230',
#         'Sidewall Check 슬립온 VN0A38F7RA7 - 그린 / 265',
#         '아디다스 아딜렛 샌달 2.0 W (B27998) - B27998_민트 / 225',
#         '아디다스 프로피어 CQ2542 - 245', '아딜렛 샌들 2.0 (AC8583) - 265',
#         '포토-에이지 30 앰플 (올-인-원 3초앰플)', '패치워크 클래식 슬립온 VN0A38F7Q9H1 - 260',
#         '타임머신 핑크- 갈바닉 이온 마사지기/뷰티디바이스/얼굴마사지기구/데콜테/림프마사지/피부관리기/피부',
#         '(공용) 디스럽터 2 운동화 7종 - 05_FS1HTA1077X_BLK / 225',
#         '(SM) 레터링 라운드 백팩 FS3BPA5303F_BLK - BLK(블랙)', '(10월)자음 기초2종 세트',
#         '여성 아딜렛 CF 스트라이프 슬리퍼(B43528) - 235', '아쿠아 삭 360 885105-001 - 290'],
#        dtype=object),
#  array(['베이쥬 포인트V넥 티셔츠 #19617 - white / L',
#         '시크폭스 베이비노 브이넥티셔츠 - charcoal / FREE',
#         '(마뜨로즈 재입고)루즈언리미티드 슈프림 마뜨 립스틱 - OR570',
#         '[난닝구]키메르 브이넥티 - 카키(khaki)-FREE',
#         '마요_요가복 필라테스복 9600원 균일가 상하의 모음전 - 03_매쉬나시 / 오렌지S',
#         '난닝구 팔레트 브이넥반팔티 - 다홍(cherry red)-FREE',
#         '여성용 스키니 화이트 팬츠 바지(B165Z0504M) - 화이트(00) / 24(62)'], dtype=object),
#  array(['트로피칼 체리모야 코롱 30ML', '바워리 크로스바디 인 퀼팅 앤 리벳 28480 OLCHK',
#         '2018 가을 컬러 컬렉션 쿼드 아이섀도우 - 모하비'], dtype=object),
#  array(['[지온골프] 지온 튼튼하고 클럽헤드 보호 플라스틱 고무티(30p) 6팩 - 롱롱6팩',
#         '캘러웨이 정품 뉴 클래식 양피 여성 골프장갑 양손1세트 - 화이트-네이비 / 18호[양손1세트]',
#         '루쥬 뷔르 꾸뛰르 베르니 아 레브르 - 370', '여성 린넨 셔츠 LCST CF6704-18B001 - 034',
#         '내추럴 플러스 선스틱 20g (SPF50+/PA++++)',
#         'UA Links Visor 2.0 여성용 골프바이저(1306282) - 화이트(100)',
#         '[7기프티쇼](리필)르 쿠션 엉크르 드 뽀 SPF23 PA++ 14g - 25',
#         '르 쿠션 엉크르 드 뽀 SPF23 PA++ - 5', '스페셜 클렌징 젤 250ml',
#         '공식판매 DMT 페이셜 크림 150ml - 페이셜 크림 150ml',
#         '클리어리 코렉티브 다크 스팟 솔루션 100ml', '베르니 아 레브르 팝 워터(워터 틴트) - 216',
#         '도담이 100매 10팩 리필형 토톰한 아기 물티슈', '나그랑면티셔츠(AC2TS5190) - 블랙 / FREE',
#         '셀럽 린넨 통바지 M182PSL502 - [1051432893]블랙/fr', '접착형 드라이기 거치대 - 그린',
#         '데일리 밴딩 슬랙스 M172YSL601 - 블랙 / 66', '대용량 에트투스 바오밥 트리트먼트 헤어팩 1000ml',
#         '[미스터펑]1초만에 배수구 펑! 미스터펑! 탄산실린더 10개',
#         '썬 자수 반팔티 M182PTS504 - [1050576420]화이트/fr',
#         '볼륨소매 자수 원피스 M172NOP401 - [1044778816]다크베이지/55', 'RGB 캠핑백 - 유즈백'],
#        dtype=object),
#  array(['[공식]스위스런 아쿠아슈즈 성인/아동/키즈/커플/가족신발 20종 택1 - 선택16.오렌지 / 255',
#         '커브 리빙박스 (특대) 2P - 다크그레이', '[레노마] 여성 비치웨어 4PCS 래쉬가드 상하세트 - 90'],
#        dtype=object),
#  array(['[10빅딜]극광 CC 크림 30g세트'], dtype=object),
#  array(['299  진주 프릴 샌들 _EDWC82558E - 블랙 / 190',
#         '샤리본 포인트 또각 샌들_CKWN82504G - 핑크 / 200',
#         '여아 3부 면 스판 컬러 팬츠 (PPP0M441GS) - 화이트 / 140',
#         '아동 LA 칠부 티셔츠 - LA 칠부 티셔츠 / 핫핑크5호',
#         '펜타 나그랑 티셔츠(73TS556) - 블루 / 140',
#         '[순천모다] 5부 베이직 래글런 티 - 레드 / 15호 ◈85017827◈',
#         '반짝이샌들(JSSS1650GD) - GD / 220',
#         '여아면마3부팬츠-T7MT9P21 - (17D2_18S0392) 라이트블루 / 110',
#         '(여아)모티브데님바지_AHM3GPT8003_BL - 블루 / 140'], dtype=object),
#  array(['[한정판] 뿌드르 아 레브르 - 415 로쏘 파르테놉',
#         '비클리프 브라운 위드 실린더힐 샌들B9102 6cm - 베이지 / 225',
#         'R8413 크로쉐 미들웨지 - 베이지 / 245',
#         '[OUR] 자수 레터링 티셔츠 ATTS8B345 - WT(화이트) / S(55)',
#         '레터링장식 루즈핏 후드 티셔츠 ATTS8A309 - O2(오렌지) / M(66)',
#         '디올스킨 포에버 컴팩트 파운데이션 스폰지', '데님 데미지 핫 팬츠 ATPA8B312 - 라이트블루 / S(55)',
#         '캡춰 토탈 컴팩트 트리플 코렉팅 파우더 메이크업 리필 SPF 20-PA+++ (11g) - 012 포슬린',
#         '[가을룩 한정 출시]디올쇼 온 스테이지 라이너 워터프루프 - 861 매트 레드'], dtype=object),
#  array(['활기력세트 30병'], dtype=object),
#  array(['핸드크림 본품 1+1 - 프레쉬 / 허벌', '에센셜 모이스춰 샴푸 350ml', '에센셜 모이스춰 워시 500ml',
#         '[무료배송/한달분량] 스파클 생수 2리터×6병(6팩) - 총36병 / 대리점배송 (배송가능지역 확인必)',
#         '[방송히트] 남영비비안 스킨핏3차 아쿠아X윙 노와이어세트 13종 - 85C/100'], dtype=object),
#  array(['공식판매 DMT 인텐시브 페이셜 크림 100ml', '엑스퍼트 컬러 아이 북 모노 S - S502 레드달리아'],
#        dtype=object),
#  array(['남성 스판 트레이닝 반바지 E-BAND 5부  ( MMKUP102 ) - C/GREY(15) / 065',
#         '1218OP234 신축성이 우수한 남성용 7부 반바지 - 네이비 / 95',
#         '남성 쿨라이트 7부 팬츠 JHPOM18212NYX - 네이비 / 95',
#         '울트라 라이트2 쇼츠 LOMUH498 - 블랙 / 070'], dtype=object),
#  array(['몬데인 여성시계 MSE.26110.LB', '몬데인 남성시계 MSE.40210.LB'], dtype=object),
#  array(['인견 노와이어 탑브라 lbr 1246 - 스킨 / 95A',
#         '쿨 메쉬 노와이어 몰드브라 br1683 - 소프트브라운 / 90A',
#         '자수메쉬포인트블라우스 CF04BR0750 - 라이트블루 / 66',
#         '나염 손수건 16종 택 1 - 선택(13)_DKU1403 연핑크(16)',
#         '심플노카라재킷C62J221 - 그레이 / 77(98)',
#         '남녀 손수건 26종 택 1 - 선택(26)_DKT1411 블루(73)',
#         '[VV올리비아] 레이어 포인트 롱 티셔츠 VVCALQS2321_01 - 화이트 / 100',
#         '언발란스 배색 입체 장식 티셔츠 VOCALQS2241_53 - 블루 / 95',
#         '글로시 프린트 민소매 티셔츠 VOBANRM3411 - 23(오렌지) / 105',
#         '멋스러운점퍼재킷C62Y157 - 77 / 엘로',
#         '베이직 슬림핏 그라데이션 5부 팬츠 VOCMPRM5161 - 53(블루) / 70',
#         '셔링블라우스SW21BL030 - 올리브 / 66',
#         '자수 장식 스트라이프 티셔츠 VOCALRS2311_23 - 오렌지 / 90', '미니 누디팬티 - 블랙 / XL',
#         '리스트 여름 플리츠 큐롯 숏 팬츠_TWWSPH60060_DG - 다크그레이 / 66',
#         '깔끔한원피스C62O221 - 네이비 / 55(90)'], dtype=object),
#  array(['여 테리 크롭 후드 풀오버 328925 - 02 / M', '포티샤 두피&모근강화 샴푸 600ml 세트_10빅',
#         '[지오다노] 418920 여 스트레이트 테리팬츠 - 09 블랙 / M', '럭스 립칼라 - 러시안 돌'],
#        dtype=object),
#  array(['드라이 마일러 숏슬리브 탑 932500-100 - 085',
#         '나이키 우먼스 나이키 RADIATE 토트 가방/BA5527-010/토트백/스포츠백/여행가방 - BA5527-010 블랙 / FREE',
#         '아디다스 오션 엘리먼츠 빅 쇼퍼 (여성용) CF5492 - 000',
#         '나이키 우먼스 프로 하이퍼쿨 타이츠 팬츠/830587-010/트레이닝/레깅스/바지/츄리닝/스포츠/헬스 - 830587-010 블랙 / 80XL',
#         '스포츠웨어 숏슬리브 티 버비아지  848698-100 - 090',
#         '여성 프로 하이퍼쿨 타이츠(889646-010) - 80[65표기]',
#         '[ 아디다스 D11005/D11006/D11007 ] 아디다스숄더백/쇼퍼/쇼핑백/신발가방 - 레드(D11006)'],
#        dtype=object),
#  array(['팔찌 279hmbr', '캔버스 토트백 미니 3727 5종 택 1 - 머스타드'], dtype=object),
#  array(['[-] 미니동물베개(커버+매쉬or마이크로솜)세트-디자인선택 /정상가47,000원 - 미니딜런(공룡)',
#         '동물베개(커버+매쉬or마이크로솜)세트-디자인선택 /정상가77,000 - 클레오(여우) / 마이크로실버 베개솜'],
#        dtype=object),
#  array(['멀티탭2구 1.5M 일반접지/2구멀티탭/멀티탭2구/일반멀티탭/일반2구 - 일반접지_1.5M',
#         '엑토 소프트마우스패드 MP-25 /엑토마우스패드/젤마우스패드//레이저마우스패드/정전기방지용 - 그레이',
#         '엑토 스테이블 모바일스탠드 MST-11 /스마트폰거치대/테블릿PC거치대 - 블랙',
#         '락앤락 패턴 보냉백 20L_네이비/그레이 (HPO8002) - 그레이',
#         '글라스락 밀폐용기 실속형 6조묶음 (원400*3개, 정490*3개)'], dtype=object),
#  array(['라이노 원피스(EGOPIE92) - 멜란지그레이 / 66',
#         '클레샤 원피스(EGOPIE93) - 네이비프린트 / 66'], dtype=object),
#  array(['디스트레스드 데님 팬츠_SSDLG51020 - 블랙 / 66',
#         '꽃문양쉬폰원피스MSBCWO4840_ - 아이보리(IV) / 66',
#         '면싱글 슬럽넥 랍빠 배색 티셔츠 JRTS221C - 카키(KH) / 90', '주니어민소매오버롤 - 블루 / 17호',
#         '[하프클럽/비키]비키 슬림라인 반팔 라운드 풀오버 (TPUCI9903) - IV/90',
#         '크록스 크록밴드 12종 샌들/아쿠아슈즈 - 06.11016-22Y / M10W12(280)',
#         '리스트 내추럴 워싱 컷오프 데님 숏팬츠_TSMSPI20020_BL - 블루 / 66',
#         '여름침구 시원한 쿨엠보 리플 패드 (SS) 10컬러 - 쿨엠보 패드[SS] / CE09_라이트블루',
#         '5color 시어서커 여름침대패드 퀸/Q 프린트 리플소재 - 애슐리-블루',
#         '플라워 자수 니트 EJ1KL168 - 코랄(CL) / FREE',
#         '헤지스남성 WHSH7B131B1 컬러블록 린넨 긴팔캐주얼셔츠 - 110',
#         '쉬즈미스 데일리 스트레이트 팬츠_SWWSLH10020 - 다크네이비 / 55',
#         '균일가 펌프스/슬링백/토오픈外 14종 택1 - 02.Eldora_JLMP006_Black_5 / 235',
#         '스페셜 에디션 웍 28cm', '7227360605 - 아이보리 / 66', '[L]쿨민트 250ml x5개',
#         '세인트스코트 뉴욕 버킷백 NNV7701 네이비 - FREE',
#         '[JJ지고트] 페미닌 프릴 블라우스 GH7A0BL21 - 600(IVORY) / 66', '[L]쿨민트 250ml',
#         '헤지스남성 HZTS8A261G2 면혼방 후드티셔츠 - 110',
#         '멀티 키즈 스페이스 스트라이프 롱슬리브_PKOEARL21U - 네이비-PKOEARL21UN8 / 9T',
#         '플라워 프릴 타이 블라우스 ITI3ZBL970 - 크림 / 44',
#         '페미닌한루즈핏팬츠(N182XSA002) - 66 / 네이비',
#         '아디다스 우먼스 ATH 3S 우븐 쇼트 (BI4526) - BI4526_검흰 / 080',
#         '니오르7부청바지_A162G3181BJ - 네이비29 / 135',
#         '[엘르세트양말][선물포장/쇼핑백동봉]포인트탑일 반목 3족세트_11874-3'], dtype=object),
#  array(['[지니킴] Andrea_JKOS018 - White_10 / 250',
#         '하이드라-에센셜 인텐시브 바이 페이즈 세럼 50ml - 80023630',
#         '퓨리케어360 공기청정기 AS181DAW 58㎡',
#         '[8/7예약][S] 더블웨어 골드라벨 쿠션 (+리필 정품 증정) - 1C1 쿨본',
#         '인칸토 참 우먼 (EDT) 30ml',
#         '면 혼방 로고 클러치백 TUMS3AAE33D0 - 멀티네이비(B87) / FREE',
#         '올아워 파운데이션 SPF20/ PA+++ - B20 아이보리'], dtype=object),
#  array(['유니 미니삼각 자수 반팔 티셔츠(NI2K6441) - 화이트 / 90(S)',
#         '남성 미니 ▽자수 반팔티셔츠(MI2K9411) - 베이지 / 90(S)',
#         '남성 오리지날 ▽ 반팔티셔츠(MI2K9405) - 블랙 / 90(S)'], dtype=object),
#  array(['여성 튤립 3부 팬츠 WH2WSPH842 - 네이비 / 32', '커튼봉 에스닉화이트 25mm 10자',
#         '[보리보리/리바이스키즈]T BEAR TS - NAVY/90',
#         '픽스 앤 픽스 톤업 프라이머 SPF33/PA++ -04호 애프리콧 /화사한 아침 메이크업',
#         '단독 NEW 에어쿠션 리필15g + 퍼프 - 내추럴 21C',
#         '1 W‘S RECOVERY EX S/S R/TEE [NST7UI37] 여성용 리커버리 EX 라운드티 - 퍼피레드 / 100(XL)[88]'],
#        dtype=object),
#  array(['2016년 S/S 후드 일체형의 홑겹 솔리드 바람막이 자켓 [BK오스자켓] - FRENCH BLUE / 165',
#         '남여 간절기용 바람막이 자켓 5217OJ210211 - OJ212(남.블루) / S(90)',
#         '남성 트레블 홑겹 방풍자켓 1MMJKS405 - 카키색 / 95'], dtype=object),
#  array(['실버스트라이프원피스 QAOP17831 - 네이비 / 155',
#         '[보리보리/휠라키즈]휠라시코2.0운동화(FK1SIA1051XFK1SIA1052XFK1SIA1053X) - 화이트 210@21',
#         '후드 웨이스트팩 BA4272-067 - FREE', '후드 웨이스트팩  BA4272-067 - FREE',
#         '2017 신상품 쿠기 여아동 수영복 KG-K619 하의 단품 - 70',
#         '[크록스] 성인 바야 균일 8종 (10126-410外) - 06.CROCS_10126_4O5_ / 270'],
#        dtype=object),
#  array(['Q54DKP2200 베이지 플라워 치랭스 - 베이지 / 105',
#         '[보리보리/헬로키티]헬로키티프릴배색 티셔츠 KDA3T07IP - 인핑크/130',
#         '[보리보리/미네뜨]코코도트샤원피스(핑크) - pink/130',
#         '갭키즈 토들러 여아 애니멀 페이스 레깅스 5227434611081 - 그레이 / 24M'], dtype=object),
#  array(['기름종이(탁상용)'], dtype=object),
#  array(['홍삼톤 마일드(50ml*60포)/백화점 상품',
#         '여성 솔리드 슬럽 브이넥 반팔티MSY2TS2012 - BK(블랙) / 95',
#         '여성 베이직 코튼 모달 브이넥 반팔티셔츠MSY2TS2902 - MGR(멜란지그레이) / 90',
#         '여성 라운지 레이온 반바지 (MSX2UH2001) - BKP / 76(30)',
#         '여성 민소매2종 택1MSX2TL2003,2004 - 선택02_OWT(오프화이트) / 90'], dtype=object),
#  array(['[임블리]레이스플라워 치마바지 - 화이트 / S',
#         '유기농 타히티 노니주스 2병 - 유기농 타히티 노니주스 946ml×2병'], dtype=object),
#  array(['[무료배송] D(남/여)99% 벗겨지지 않는 밀착더블밴드 무지 페이크삭스 3족세트 - (여)화이트(3족)'],
#        dtype=object),
#  array(['18SS 레반트모던 반팔티 (9863 88) - L',
#         '핑크 가먼트 다잉 5부 팬츠 (BC8425C20X) - 분홍색 / 080',
#         '남여공용 쿨필드 돔 햇 야구모자(32CPH6811-50W) - 화이트 / FREE(55~61)',
#         'H86 코리아 캡 AO0821-010 - FREE'], dtype=object),
#  array(['[손상모발케어SET]아로마 리페어 샴푸 500ml 세트 - 세트'], dtype=object),
#  array(['실키선스틱 15g 1+1 (2018)', '슈퍼 액티브 에어리 썬스틱 15g 1+1'], dtype=object),
#  array(['[9빅딜]클리어로션 160ml 듀오 세트', '모짜렐라 핫도그(치즈&소시지) 20입 세트',
#         '[C]수율미스트 세트 - 세트', '4cm 국내산 글리터 벨크로 샌들(J7205) - 블랙 / 235',
#         '여성샌들 BBB491OR - 235'], dtype=object),
#  array(['클리어리 코렉티브 다크 스팟 솔루션 100ml'], dtype=object),
#  array(['퀵실버 아동 래쉬가드 QS621YBT - 7', '퀵실버 아동 워터레깅스 QS606LBB - 10'],
#        dtype=object),
#  array(['ANF유기농 6free 플러스 소고기 5.6kg'], dtype=object),
#  array(['뉴케어 미니 구수한맛 아셉틱(150ml*30팩) / 무료배송 - 뉴케어 미니 구수한맛 아셉틱'],
#        dtype=object),
#  array(['[Thursday Island]여성 플라워 숏 팬츠(T164MPT237W) - NV2 / 70(M)',
#         'A128 유니크한 디자인의 린넨 체크블라우스/루즈핏블라우스/버튼블라우스/5부소매블라우스 - 블랙(BLACK) / FREE',
#         '남.여공용 캐주얼 스트레치 5부 팬츠 (AI2WL591) - 화이트 / 32', '인텐시브 클리어 부스터35ml',
#         'V넥 플라워 패턴 원피스 (LU2178OP824P) - 그린 / F',
#         '[ELOQ]여성 비대칭 슬릿 롱 슬리브리스(B164MSL351W) - MI2 / FREE'], dtype=object),
#  array(['플럼 사각세제통', '플럼 대국자', '플럼 도자기주걱', '플럼 절구통'], dtype=object),
#  array(['[for women] 메탈 버클 퍼 부츠 (데나) 1667302601001 - 블랙 / 8',
#         '[for women] 크리스탈 버튼 부츠 (이리나) 1667302568001 - 블랙 / 7',
#         '[for women] 스트라이프 리본 장식 부츠 (베일리 보우 스트라이프) 1667302587000 - 블랙 / 6',
#         '[for women] 베일리 보우 부츠 1666302576000 - 라이트 네이비 / 6',
#         '타투 커버 쿠션 [핑크에디션] 14g - 시크릿키 타투 커버 쿠션 [핑크에디션]/23호 내추럴베이지',
#         '여우털폼폼이A라인코트SRHAL2650 - NA(네이비) / 66',
#         '★BEST★ Gby고세 천연고트스킨 부띠 베이직 G0116023S(4color)7cm - 블랙 / 250',
#         '[for women] 끈 장식 폼폼 부츠 (브리타) 1667302518000 - 블랙 / 8',
#         '이월상품/여성화/앵클부츠/플랫폼/퍼부츠 GB36.084 _2컬 - 57 (블랙) / 255 (5½)',
#         'BK0006 00M001S 50TA 여성 하이탑 스니커즈 - 단일품목 / 40',
#         '폭스롱베스트 SRVEL2721 - GY(그레이) / 55',
#         '[for women] 끈 장식 폼폼 부츠 (브리타) 1667302520000 - 카멜 / 8',
#         'WOOL TWEED JACKET - GRAY / M ◈79715416◈',
#         '하이드라비오 에센스 로션 (수분 미백 부스터)200ml',
#         '뽀글이 재킷 (SA4CTF069) - 1(FREE) / 아이보리(IV)',
#         '[for women] 새틴 레이스업 부츠 (팔라) 1667302622001 - 블랙 / 7',
#         '뒤트임 롱 니트티셔츠(DP385120/블루) - 블루 / 66 ◈56303515◈',
#         '귀요미파스텔짚업가디건 TRCCY2930 - 민트 / 55', '제니 탑커버 컨실러 - 3호 미디움베이지',
#         '[오가게/러비더빅]히그팝 티셔츠 - 블랙/FREE', '전자렌지전용 사각그릴구이팬s3 - 그릴구이팬s3',
#         '폴란드95 구스다운 이불 싱글S.SS 1000 순면 속통 한파용 laselene',
#         '이자벨 마랑 윌라 웨지 스니커즈 WILA BK0026 02AN ANTHRACITE [IMS003] - 35',
#         '머스크렛배색코트(DA4-HC6960) - 네이비 / 66 ◈63156002◈',
#         '벨먼 내추럴 스파 쿨링 바디 마사지 롤러젤 140ml',
#         '[한파용] 폴란드산 구스다운 이불 싱글(S) 솜털97% 900g/순면100% 80수/알러지-x',
#         '러플이 예쁜 라그랑 원피스GHC8OP825F - 046(레드) / M(66)',
#         '양털 라운드 넥 숏 FAR JK (SD4LTF106) - 다크그린(DN) / 1(FREE)',
#         '헝가리90 구스다운 차렵이불 듀오 싱글S.SS 1000 한파 알러지케어',
#         '라운드넥 데님 원피스 (ENOW83702Z) - 블루 / F',
#         '[한파용] 헝가리산 구스이불 싱글(S) 솜털90% 900g/순면100% 60수/알러지-x',
#         '[오가게/러비더빅]웰컴스 티셔츠 - 네이비/FREE',
#         '보니스팍스 PNC02 스프라이프 포켓 티셔츠 W12TS170 [1861891] - 그레이 / FREE ◈88375738◈',
#         '보니스팍스 PNC02 배색 티셔츠 732TS530 [1870615] - 그레이 / FREE ◈88377465◈',
#         '보니스팍스 PNC02 스커트형 배기 팬츠 W12SL280 [1862300] - 챠콜 / FREE ◈88375893◈',
#         '랩베기체크팬츠 BW21SL160 - 블랙 / 55', '프린트언발셔츠 BW22BL290 - 블랙 / FREE',
#         '기하학프린트티셔츠 BW22KP040 - 블루 / FREE', '허리스모킹패턴셔츠 BW22BL250 - 블랙 / 66',
#         '케쥬얼 야상 점퍼 Y173C702 - 블랙(11) / FREE',
#         '루즈핏 뽀글이 코트 Y174C708 - 베이지(04) / FREE',
#         '플라워 프린팅 시스루니트 Y173C901 - 그레이(13) / FREE',
#         '풍기인견 스칸디콜렉션 스키니브이라인 소파패드 4인 - 스키니브이',
#         '양수웍+알루미늄찜기+유리뚜껑28cm(CN5934)', 'V라인 헨리넥 나시 GN-3N09 - 화이트 / Size2',
#         '[보슈아]숙녀-Sms얼굴코르셋/얼굴교정밴드/V라인[9862] - 얼굴코르셋', '[본사직영] 립 컨디셔너',
#         '심플패턴 모던 롱 니트가디건(DP380090/베이지) - 베이지 / 55 ◈55136430◈',
#         '잭앤질 8cm 토끼털 앵클부츠(J54-4998) - 블랙 / 230',
#         '8cm 토끼털 앵클부츠(J74-4998) - 블랙 / 225',
#         '금장 버클 V라인 블라우스_VUDBL14 - (45)네이비 / FFF',
#         '[먼싱웨어] [18SS 신상]여성 브이라인 중형마스크 (M8222ACM02) - BLCK_BLACK / FR'],
#        dtype=object),
#  array(['[9상품권]윤조에센스 90ml대용량 세트 - 세트.', '[G]자음 기초2종 기획세트(+상품권1만원증정) - 세트/'],
#        dtype=object),
#  array(['코모도스퀘어 베이지 춘하 코튼 치노팬츠 9317212903 - 82 / 필수선택 ◈84720672◈'],
#        dtype=object),
#  array(['시루콧토 우루우루 화장솜 40매×5박스+추가증정4매(총204매)'], dtype=object),
#  array(['NEW 스마트백 미디움 2P(HSS605)',
#         '미국산 스너글 고농축 블루스파클 섬유유연제 4.96L - 스너글고농축_블루스파클4.96L x1개'],
#        dtype=object),
#  array(['헤지스남성 HZTS8B832E1 스트라이프 면 반팔티셔츠 - 095',
#         '스튜디오 드 땅뜨 리퀴드 에어 - 02호 아이보리',
#         '여성 스트라이프 원피스EF090E-18A_3컬러 - 선2)PQ8(블루) / 034(90)',
#         '헤지스남성 HZTS8B053N2 [윔블던] 스트라이프 면혼방 반팔티셔츠 - 105',
#         '스카이스케이프 하모니 M45742 - 240', '눈썹수정칼(2pcs)',
#         '헤지스남성 HZTS7B441G2 면 패턴 스트라이프 반팔 티셔츠 - 095'], dtype=object),
#  array(['솔리드 블랙버드 티 [CW2336 CW2339] - CW2336(화이트) / XL',
#         '여성 리뉴얼 7차 MOVE CELL 풀세트 브라팬티 14종+패드 AFYBFH11 - AFYBFH11 / 80B',
#         '[1808MS]퍼펙트 선 파우더 1호 기획 세트',
#         '뉴발란스 UNI 빅로고 반팔티 NBNE721013(4종택1)남여반팔티 - NBNE721013-19블랙 / 90',
#         '[데상트] 남녀공용 그래픽 by 이기준 반팔티셔츠 (S8223HTS50) - BLK0_(BLK0)BLACK / 100'],
#        dtype=object),
#  array(['작은꽃 번아웃 망사 양산 MCP-1115 - 네이비',
#         '편한 여성컴포트 정장샌들 8B96 4CM 흑색블루 2색택1 - 블루 / 245'], dtype=object),
#  array(['[모니카룸] 먼데이롱t/티셔츠 - 아이', '[모니카룸] 몰디set/세트 - 핑크 / FREE',
#         '[모니카룸] 쿨옵set/세트_M - 카키 / FREE', '[모니카룸] 보헤ops/원피스 - 네이비 / FREE',
#         '[모니카룸] 지짐체크ops/원피스 - 보라 / FREE',
#         '[모니카룸] 럭키set (1+1)세트_M - 네이비 / 핑크',
#         '[모니카룸] 루이배색ops/원피스_M - 옐로우 / FREE',
#         '여성 비치 3pcs 집업 썬탑 레깅스팬츠 상하세트_RN-LS18907 - MG / 95',
#         '[모니카룸] 디테일ops/원피스 - 블랙 / FREE'], dtype=object),
#  array(['1+1 방수 매트리스커버 SS+Q/진드기차단/침대커버', '[세이프레스트] 프리미엄 매트리스커버 SS'],
#        dtype=object),
#  array(['[alaroo]버클멜빵줄무늬투피스 - 화이트스트라이프 / M ◈88584676◈'], dtype=object),
#  array(['L826009 블로퍼 Shield(2cm) - 블랙/2cm / 255',
#         '플랫할인 LF9047 Cozy slim square 브라운 - 브라운 / 230', '이지스탠드 우산꽂이 - 블랙'],
#        dtype=object),
#  array(['프랜치댄디 카라티셔츠 CMM1GQTS51OR [여름] - OR / 150[9817993-5]',
#         '유니크 스트라이프 민소매셔츠 CMM2GQSH51BL [여름] - BL / 120[9709962-2]'],
#        dtype=object),
#  array(['여성 이미서블 컷아웃 NESS8057-678 - 32_NESS805767832'], dtype=object),
#  array(['주름 플라워 MF04OP100 - 핑크 / 프리', '박스 롱 데님 점퍼 MF04JP501 - 블루 / 프리'],
#        dtype=object),
#  array(['여성 사각팬티 QD3565 985 SET - M',
#         '빅플라워 프린트 남성파자마 LSMES324 - 324 BU / 105(XL)'], dtype=object),
#  array(['A,B컵 데일리 베이직 브라팬티 10종 택1 - 10.(RSET780)핑크 / 75A-90',
#         '베스트셀러 베이직 팬티 8스타일 택1 - 05.(SNPTS339A)라이트브라운 / 90', '더 퍼스트 올가노니',
#         '강아지별겉싸개 (46W70-AAB-01) - NAVY / FREE',
#         '휘슬러 1845오리지널 압력솥세트(4.5L)+ 1845오리지널 2.5L 압력솥 바디+ 메탈킵스 3종+ 스텐주걱+    ... - 단일상품',
#         '라푸마 여성 멜란지 아웃도어 미들 양말 4족 세트 LESS7G851BK - 240',
#         '이지워시 썬스틱 2개세트 (15gx2)', '헤리티지 86 스크립트 캡 AO8104-133 - FREE',
#         'A컵 노와이어 볼륨업 누디브라팬티 세트 10스타일 택1 - 05.(RSET700)브라운 / 85A-100',
#         '[올리비에스클로젯]린넨 통 8부팬츠_[O1805PT055B] - 베이지 / FREE',
#         '난닝구 랠리 라운드티 - 블랙(black)-Free',
#         '[#텐텐]  1+1 쿠폰할인/무료배송  쿨 밴딩 스판 슬랙스 (~XL) - 베이지 / 베이지 / XL(31~32인치)',
#         'NN2PJ07 화이트라벨 두잉 크로스 백 S - PIK(핑크) / ONE',
#         '스포츠웨어 헤리티지 86 JDI 캡 925415-010 - FREE'], dtype=object),
#  array(['카렌듈라 스틱밤 15g', '[릿첼] ND 이유스푼세트(케이스포함)',
#         '그로미미 빨대솔 / 빨대브러쉬,세척솔,젖병솔,젖병브러쉬,젖꼭지솔,빨대컵,텀블러,보온병,젖병,빨대리필 - 그로미미 빨대솔',
#         '★1+1 이벤트★[선물포장]오가닉 애착인형 착한코코+아기코코 set',
# ...
#         '퍼실 하이진 1.8L x 4개 - 일반', '(NY)해지고래우주복(38312-600-01) - 90',
#         '장안사 반장양말 [우아레스][H0268] - 장안사-H0268-핑크-4',
#         'ARENA 아레나 이태리 수입오리발 AOAAF01 - BLU / 42-43(260-265mm)',
#         '장안사 반장양말 [헤라레스][H0266] - 장안사-H0266-핑크-3',
#         '[보리보리/릴리푸리]레모나티셔츠(화이트) - 화이트/120호', '샤치마레깅스(화이트) - 130호',
#         '(BL)캐릭터해지캡모자(38112-800-01) - 46(46cm)', '아이큐 웨이브 큐브(3x3)',
#         '남성기본런닝 TMRSB01T - 100', '프리프리스 겨울왕국 지니 도트 아동 덧신 - 핑크 / 170'],
#        dtype=object),
#  array(['CPI 스킨리커버리 크림 50ml(1+1/2)_AN85-3', '홈쇼핑방송 스테비아 스위트 파우더 200g'],
#        dtype=object),
#  array(['아카이브 스피릿 포인트 터프 볼륨 반팔 티셔츠 - AYLW_AYLWYELLOW / 100',
#         '뉴발란스 남성 야구로고 반팔 티셔츠 NBNE726091 - 20_레드 / 100L'], dtype=object),
#  array(['[속통] 고급 쿠션솜(45x45) - 45x45', '순면 인테리어쿠션 마이리틀러버 45x45cm - B타입'],
#        dtype=object),
#  array(['PCC-004 팝덕 아동/주니어 플랩캡 수영모 비치웨어 수모 UV차단 - PCC_004 / 팝덕_라임'],
#        dtype=object),
#  array(['브라팬티세트 6스타일 택1 - 06.(RSET661)브라운 / 80B-95',
#         '브라팬티 TV방송상품 풀패키지 16종 세트 - 선택02)프라미스 3차 패키지 / 75C/90'],
#        dtype=object),
#  array(['가볍고 활동성이 좋은 기본형 운동화 [아이콘] - BLACK / 200mm',
#         '펌프스할인 JF7036 베이지 외 18종 택 1 - 06)LS7024베이지 / 240',
#         '남여 여름용 시원한 반팔티셔츠 5217NT225 - NT267(여.블랙) / S(90)'], dtype=object),
#  array(['[하프클럽/아디다스]아디다스 남성 테니스 코트 클라이마라이트 반바지-BP8138 - 사이즈/2XL',
#         '헤지스남성 HZTS8B901WT 피즈패치 면 반팔티셔츠 - 120',
#         '헤지스남성 HZTS8B901P2 피즈패치 면 반팔티셔츠 - 100',
#         '18SS 네이비 딜라이트 리넨 헨리넥 티셔츠BC8342A23R - 남색 / 100',
#         '헤지스남성 HZTS8B908U1 퍼피패치 면 반팔티셔츠 - 100',
#         'HZTS7B405G2 Air-cool Cotton 퍼피 패치 반팔 티셔츠 - 100',
#         '헤지스남성 HZTS8B908B2 퍼피패치 면 반팔티셔츠 - 090',
#         '헤지스남성 HZTS8B901Y2 피즈패치 면 반팔티셔츠 - 120',
#         '남성시계 FS5151 파슬코리아 전국 백화점 A/S가능', '접이식 양산-스코티 러브(AG1817) - 블랙',
#         '헤지스남성 HZTS8B901B1 피즈패치 면 반팔티셔츠 - 100'], dtype=object),
#  array(['스카이 블루 클래식 체크 셔츠 (BF8464U03Q_) - 100(77)',
#         '[빈폴멘] [SLIM] Unisex 블랙 베이직 스트라이프 셔츠 (BC8764A185) - 검정색 / 110',
#         '챙모자 LEHE7E101 - 네이비 / 60'], dtype=object),
#  array(['[하프클럽/마코](여성)프린팅 배색 반팔 티셔츠 4MFW0TR90 - 10|화이트|/90',
#         '1217TR553 기능성 AERODRY 소재를 사용한 심플한 디자인의 긴팔 여성 라운드 - 차콜그레이 / 100',
#         '70파이 극세사 면분첩 - 보니비노 70파이 극세사 면분첩',
#         '피카 붙박이장 2400~2500 화이트 하이글로시_행거형',
#         '한샘 샘베딩 스테디 옷장세트 320cm(높이194cm) 선반형 8종 - G형/ 피치화이트 콤비+화이트몸통(G)',
#         '[#텐텐] 완태 브라질너트 500g x3봉 (총1.5kg) - 브라질너트(페루산)500g*3봉',
#         '초경량 바람막이 점퍼ZPY2JJ1501 - 라이크카키(LKH) / 105',
#         '구운아몬드 400g 4봉 총 1.6kg / 아몬드 견과 견과류 볶은아몬드 무염아몬드 볶음아몬드',
#         '[산과들에] 페루산 완태 브라질너트 500g+500g (총1kg) - 브라질너트(페루산)500g*2봉',
#         '칼슘 마그네슘 아연 비타민D 3개월분 x 2병',
#         'NEW그루 프리미엄 화이트 27M 30롤x3팩(3개, 총90롤)/화장지/휴지/롤티슈 - 그루 프리미엄 화이트 27M 30롤x3',
#         '[테이트] 여성 패턴 레깅스 KA4W0WKX050610 - KA4W0WKX050610 / FREE',
#         '브라 단품 10종 택1 - 10.(1HN5454)아네타 / 85A',
#         '[EBAN] 여성 삼각 면스판 요일팬티 10칼라 택1 - 01.베이지 / 95(XL)',
#         '카리노 윈드 베스트 (여성용) 7341401 - 화이트(100) / 90',
#         '갤럭시 노트3 전용 호환배터리 3200mAh',
#         '1217IT553 AQUA-X 냉감 기능성 원사의 자외선 차단기능이 우수한 여성 티셔츠 - 화이트 / 90',
#         '구운 아몬드 400g 1개사면 1개 더 견과류 슈퍼푸드 아몬드外 균일가 택1 - 호두 400g+400g',
#         '헬로버블 염색약 1+1 (옵션) - 21 7N 모카라떼 브라운 + 5BR 딥브로드로즈',
#         '베이직 지퍼 디테일 쿨 팬츠  MVYDLRM3141 - 34(베이지) / 76'], dtype=object),
#  array(['냉장고 반팔원피스 7종 택1 - 반팔원피스_B06_FREE',
#         '이유식마스터 6종(스파츌라+파우치 증정) 이유식용기/이유식기/세이지스푼풀 - 네온&핑크 / 연블루1P / 베이비블루 / 민트',
#         'DBWA7F203BK 블랙 로고 가죽 반지갑',
#         '헤지스남성 WHTS7B113E2 컬러배색 린넨혼방 반팔카라티셔츠 - 100',
#         'DCWA7E421네이비 체크 배색 3단 장지갑',
#         '볼 메이슨자 스무디 믹서기 BLSTMM-BRD-071 레드/미니믹서기/볼 메이슨/볼자/과일주스 - BLSTMM-BRD-071',
#         '은은한 프린트 패턴의 반팔 쉬폰원피스 (CL8MOP103) - 네이비 / 95(66)'], dtype=object),
#  array(['벨리타 니트 원피스 (07L124047) - 3Y(110)',
#         '홍삼정 에브리타임(10mlx30포) / 롯데백화점 본점 출고 / 정관장', '크리미 캔디 - 버블 바',
#         '[30％] 컬러엔비&프로스파큐티클오일투고 2종세트+푸셔 증정 - 03.Pink to Envy-투명핑크',
#         'PK),캐릭터STRIPE원피스,[47312-400-0100] - PK / 85',
#         '빵떡데님 아동배기팬츠 - 데님(블루) / 100', '블루 스카이스 앤드 플러피 화이트 클라우즈 - 버블 바',
#         '[4.4만▶3.5만] 손톱강화제+리무버 2종 세트',
#         'Angelo Natale Pororo 목걸이 (JJK1N07AN318SC340) - 각인_선택안함',
#         '순금 천사날개 돌반지 3.75g'], dtype=object),
#  array(['홍삼정 240g 롯데백화점 본점 출고 / 정관장',
#         '[이고르] 이고르 젤리슈즈 IGOR BONDI 8컬러 - 08.화이트블루 / EU34(216mm)'],
#        dtype=object),
#  array(['여성 실내수영복 풀세트 EUPSO05S500 - DGY(다크그레이) / 095',
#         '여성용 시원한 여름 7부 트레이닝 KJFH281FO - 블랙 / 65(S)'], dtype=object),
#  array(['[게스][18SS] MI2K9407 남 무테 발포 반팔 티셔츠 - MI2K9407 MGY / S',
#         '3404 남성 후드집업 래쉬가드 세트1_LBSUMRZ303BK - 팬츠-LDU7MRP951NG / L-L',
#         '[게스][18SS] YI2K9407 BLK 여 무테 발포 반팔 - YI2K9407 BLK / XS'],
#        dtype=object),
#  array(['아이패드 프로 10.5 2017  후면 외부보호필름(무광2매)[젠피엠]',
#         '[어반] 화이트 여성 뱀부 쇼트 팬츠 (BO7325C011) - 흰색 / 073',
#         '길라잡이 아이패드 프로 10.5 외부보호필름 (2매입)'], dtype=object),
#  array(['2017 NEW 메이크업 세팅 스프레이 트래블 30ml'], dtype=object),
#  array(['라드 롱 숄 가디건_LI8SCA04 - LI8SCA04.블랙 / XL'], dtype=object),
#  array(['스카이스케이프 하모니 M45742 - 255'], dtype=object),
#  array(['인피니펀 2종세트 롤링크랩 퍼니망치', '인피니펀 호랑이전화기(16545) 아기 멜로디 전화기',
#         '[쏘피] 바디피트 유기농 순면 팬티라이너 롱 40P×3팩(총120P)',
#         '[쏘피] 한결 팬티라이너 롱 40P×3팩(총120P)', '에브리데이 도톰 라운드 티셔츠 T171 - 남색 S',
#         '무형광 오가닉 거즈 유아스카프(아기손수건 겸용)_클라우드 - 단일품목',
#         '무형광 오가닉 거즈 유아스카프(아기손수건 겸용)_발레리나핑크 - 단일품목',
#         '스퀘어동물나염손수건(10장) - 스퀘어동물나염손수건_10매입',
#         '달퐁패밀리엠보손수건_10매입 유아 아기 - 달퐁패밀리엠보손수건_10매입 블루',
#         '무형광 오가닉 거즈 유아스카프(아기손수건 겸용)_레몬에이드 - 단일품목',
#         '소프트 코튼 손수건 세트(10장) /디자인선택 - 비글SET'], dtype=object),
#  array(['에어팟 케이스 고리형 키링 행 - 러블리 핑크', '프렙 프라임 트랜스페어런트 피니싱 파우더/프레스드',
#         '하이스카이 스마트폰 암밴드 - 하이스카이 스마트폰 암밴드/블랙', '아이래쉬 컬러(뷰러) 정품 고무리필 증정 세트',
#         '포티샤 두피&모근강화 샴푸 1200ml 세트_10빅',
#         '[샘플 3종 증정] 핑크 라이트 톤업 쿠션 세트 (2종 중 택1) - 톤업 리필 세트 (리필2)',
#         '플라워 레이스 미디 스커트 ITI3ZSK950 - 크림 / 66', '[6월]인바티 어드밴스드 헤어 세트',
#         '프렙+프라임 하이라이터 - 미디엄',
#         '[가죽 립케이스 증정] 엑스트라 립 틴트 듀오 세트 (택2) - 베어 팝시클 / 베어 핑크',
#         '[올데이 파운데이션] 스킨 롱웨어 웨이트리스 파운데이션 SPF 15 PA++ - 웜 포슬린(0.5)'],
#        dtype=object),
#  array(['17 S/S BK케이지키즈/아동아쿠아슈즈/(CITY) - 블랙 / 190',
#         '야외활동 햇빛차단에 효과적인 서플렉스 햇 아동 모자 [BK테라햇] - RED / 054'], dtype=object),
#  array(['[이디](소인권)  조식 1인 뷔페권', '[이디] 조식 1인 뷔페권'], dtype=object),
#  array(['[임블리]블루플라워 뷔스티에원피스 - 화이트 / FREE', '[임블리]레깅스같은 맘블리제깅스 - 블랙 / M',
#         '[임블리]러브미모어 후드롱원피스 - 퍼플 / FREE',
#         '나이키 선레이 어드저스트4 TD 아동샌들 3종 택일 - 386519-011 / (160/10C)'],
#        dtype=object),
#  array(['천연소가죽 러너창 포인트 배색 스니커즈 INDN168BK - BLACK / 255',
#         '유니READY폴리민소매티셔츠JB2MTT442UL - 그린(GN) / 15(165)',
#         '점보 브라이트닝 업 선 80ml+(증정) 미스트 50ml+필링 젤 10g',
#         '치노셜린7부내의세트핑크 AT3103P1P7 - 75', '체리콕여아내의PT110384 - 핑크 / 90',
#         '유니 메쉬배색 민소매 SETJB2MTT491UL - 11(145) / 다크블루(DB)'], dtype=object),
#  array(['남성 블럭스트라이프 차이나셔츠(30111-020-001-30) - 022(그레이 / M(004)',
#         '남여커플 게스 반팔티(MI2K9405外 11종 택1) - 선택05_GEN / XL(M)'], dtype=object),
#  array(['베이비 크림 포 훼이스 앤드 바디(200ml)', '[10상품권]울트라 훼이셜 크림 점보_키엘 러브스 코리아 세트'],
#        dtype=object),
#  array(['어린이 키높이 운동엔 메버릭 스카이콩콩 - 레드',
#         '[블랙마틴싯봉] 패션 브랜드 시계 BKL1526L 백화점A/S가능 - 피치_P_RP',
#         '[손오공 공룡메카드 타이니소어 크로노 니쿠스 미크로 - 타이니소어_미크로',
#         '티블루-키즈노래방마이크K3 (색상랜덤)',
#         'Francois Wallet (GAXP112_46) - GAXP112_46 / 001',
#         '[바로배송] HUDORA 독일 명품 킥보드 휴도라 빅휠 STYLE 230 - 블랙',
#         '[아방세 에어프라이어 HD9240/90] (대용량 에어프라이어, 초대형 3L)',
#         '正品 미니 단망경 7X18 스마트폰확대경 망원경 휴대용망원경 야구장 뮤지컬망원경 미니단망경'], dtype=object),
#  array(['헤지스남성 OUTS7BH41N3 스트라이프 면 반팔티셔츠 - 095'], dtype=object),
#  array(['샴푸워시 세트 - 01.베이비파우더'], dtype=object),
#  array(['엔비에이 남녀공용 NBA 메쉬 배색 반팔 후드 N182TH103P - 화이트/XL / 필수선택 ◈86650965◈',
#         '헤지스남성 OUTS7BH34N2 라인배색 면 반팔카라티셔츠 - 100'], dtype=object),
#  array(['[유니코] 17S/S 여성 트라이앵글 메탈 스몰 토드숄더백 (1BA838_NZV_F0770_V_OOO_17S) - 분홍베이지색',
#         '여성장지갑 에나벨_MC410075 - 네이비', '남여공용 로고베이스볼캡2(NBGD8SM101) - 화이트(WH)'],
#        dtype=object),
#  array(['정품 신사숙녀양말 2족선물세트 균일가 17종 택1 - 06.18374 남녀 혼합 2족 커플양말 2족세트'],
#        dtype=object),
#  array(['◆ 비타민C 365골드 96정(1캔)+쇼핑백 1개/롯데닷컴전용상품',
#         '[본사직영] 고려은단 비타민c 1000 (1080mg*180정/6개월분)', '오리지널 스킨 마스크 100ml',
#         '(기획)씨드 앤 스프라우트 에너지 마스크 로터스 세트'], dtype=object),
#  array(['V넥 트임 소매 레이스 블라우스 LI4BL619 - WT(화이트) / FREE',
#         '요크 수술 에스닉 블라우스, LH7BL658 - 화이트(WH) / FREE'], dtype=object),
#  array(['여성 체인 디테일 플랫 로퍼 GEMONA (AD18S110508049_AD62) - 8',
#         '여성 체인 디테일 플랫 로퍼 GEMONA (AD18S110508049_AD97) - 8'], dtype=object),
#  array(['코롱EDT 120ML', '[공식정품] D&G 라이트블루 오 인텐스 뿌르 옴므 EDP 100ml (선물포장가능)',
#         '[공식수입] 프레쉬 핑크 50ml + 퍼퓸케이스', '맨 인 블랙 (EDP) 100ml',
#         '[무료선물포장가능] 불가리 아쿠아 뿌르옴므 마린 EDT 100ml', '잔느 100ml + 미니어처',
#         '[정품] CA드림즈 핑크(여) 오드퍼퓸100ml',
#         '[공식정품] 불가리 골데아 우먼 EDP 25ml (선물포장가능)',
#         '[공식정품] 이세이미야케 로디세이 EDP 25ml (선물포장가능)', '데이지 10주년 EDT 50ml',
#         '[공식정품] 캘빈클라인 이터너티 포맨 50ml (선물포장가능)', '안나수이 라비드 보헴 EDT 75ml',
#         '안나수이 라비드보헴 50ml', '스타워커 EDT 75ml', '안나수이 플라잇오브팬시 50ml',
#         '인칸토 참 오드뚜왈렛 30ml', '인칸토 뉴블룸 EDT 30ml', '인칸토 아미티 EDT 30ml',
#         '로디세이 퓨어 EDT 50ml', '인칸토 샤인 오드뚜왈렛 30ml', '울트라 바이올렛 맨 (EDT) 100ml',
#         '비바라쥬시 수크레 EDP 50ML', '에로스 뿌르팜므 30ml',
#         '[공식정품] 불가리 아쿠아 뿌르옴므 EDT 100ml (선물포장가능)',
#         '[무료선물포장가능] 불가리 아쿠아 아틀란틱 옴므 EDT 100ml',
#         '[하프클럽/Burberry Perfume]버버리 위크앤드 포맨 100ml - 버버리 위크앤드 포맨 100ml/ETC',
#         '레스 벨 드 니나 루나 블로썸 (EDT) 80ml', '엠블럼 EDT 100ml',
#         '브리트 쉬어 포 우먼 오드뚜왈렛 50ml', '벤츠 맨 100ml + 퍼퓸케이스', '블로썸 60ml + 퍼퓸케이스',
#         '[무료선물포장가능]랑방 잔느 EDP 100ml'], dtype=object),
#  array(['NZS96I14키즈 네오 벤트 - BLU / 190'], dtype=object),
#  array(['무료배송 엘라모 파인애플 반팔티셔츠 남녀공용 빅사이즈 ~4XL 세탁변형 최소화한 덤블가공 - 다크그레이 / M',
#         '단독 맨 올데이 퍼펙트 올인원 120ml',
#         '아디다스 셀우드/코트벤티지 스니커즈 운동화 3종 택일 - BB8694 / 225',
#         '[CC]에센셜 모이스처라이저 125ml x2개', '트랜디한체크자켓(N174XSF101) - 블랙(BK) / 66',
#         '베이직 실내화 2.5cm (95053/95055/95057) - 95055_핑크 / L(240-245)',
#         '[CC]에센셜 훼이셜 포밍 클렌저 150ml x2개'], dtype=object),
#  array(['[세인트제임스][프랑스] GUILDO R / OUESSANT R (0RZ) NEIGE/ANIS (Z3SSH5TS001.KH) - 카키 / T3'],
#        dtype=object),
#  array(['(5월)UV 미스트쿠션 커버 리필 SPF50+/PA+++ 세트 - 17호 커버',
#         '남성화 신상품 균일가 14 종 택 1 - 04.AJM850FG10_BLACK / 255',
#         '헤지스남성 HZTS8B052N2 [윔블던] 라인배색 면혼방 반팔티셔츠 - 100',
#         'ADIDAS Forta Swim I  AC8148 블루 아디다스 키즈 샌들 - AC8148 블루 / 150',
#         '공식판매 DMT 페이셜 크림 150ml - 페이셜 크림 150ml'], dtype=object),
#  array(['디에이지 레드-애디션 2종 세트 3개 +증정(탄력크림50ml 3개, 아이크림25ml 3개) - 레드-애디션 2종 세트 3개 +수분크림3개 +증정',
#         '디에이지 레드-애디션 2종 세트 /스킨토너130ml+에멀전130ml +여행용 콘트롤크림15g - 레드-애디션 2종 세트 1개 +증정',
#         '단독 로맨틱 2종세트', '단독 로맨틱 2종 기획세트'], dtype=object),
#  array(['[이롬황성주]1일1생식 12주 + 쉐이커'], dtype=object),
#  array(['트레일링 로즈 폴디드 짚 월렛 내츄럴 710459', '햄스테드 로즈 포켓 크로스바디 더스티 그린 719339'],
#        dtype=object),
#  array(['캔버스 스판 9부 팬츠 HSPA8B211 - 화이트 / 70(66)'], dtype=object),
#  array(['[크록스]성인 크록밴드(11016外)택일/샌들/아쿠아슈즈 - 06.CROCS_11016_001_ / 290',
#         '체크 메쉬 MIX R넥 반팔 티셔츠(DOM12TR38M_NV) - 110',
#         '냉감 슬림핏 5부 팬츠/유아동반바지/NK9V82102U - 네이비 / 130'], dtype=object),
#  array(['[LOVE]옴므 CC크림 SPF35/PA++ 세트 - 1호 내추럴 베이지',
#         'CC 크림 코렉션 컴플리트 수퍼 액티브 SPF 50 30ml - 20 배쥬',
#         '퍼펙트 세럼 70ml 1+1 (옵션) - 05. 퍼펙트리치세럼+퍼펙트세럼(증정)'], dtype=object),
#  array(['요가복 CA6066 네이비 브라탑 필라테스복 트레이닝복 - S (44-55)',
#         '요가복 CA6066 레드 브라탑 필라테스복 트레이닝복 - S (44-55)'], dtype=object),
#  array(['Y 여성 COLLANTES 블럭 장갑-BC28132_414 - PALE PINK / 00M',
#         'Y 여성 CANUT  단목 양말-BB27301_199 - BLACK / 230',
#         'Y 여성 KUNST GRAPHIC 2 반팔 티셔츠-BA45371_401 - L.PINK / 090',
#         '★자외선 차단★[1+1] 무료배송! 붙이는 셀프 블라인드 화이트 전월세 최적화! No 설치도구! - 셀프 1+1 화이트 240',
#         '자외선/미세먼지 차단★ 1+1 다용도 붙이는 셀프 블라인드 90x190 화이트 - 셀프 190 2장',
#         'Y 여성 ELLCOY 장갑-BA28105_800 - BLUE / 00S',
#         'Y 여성 COLLANTES 블럭 장갑-BC28132_199 - BLACK / 00S',
#         'Y 남성 WELKOM 벨콤 슈즈-BAA7602_808 - AQUA / 275',
#         '절개형 팔토시 2MMXXX5906 - 코랄 / M', '내추럴 휀스 스탠드 1200 버닝[타카쇼]',
#         'Y 여성 VIENTO 양말-BC28332_820 - NAVY / 230',
#         'Y 공용 KLASSE 클라세-BCC7611_199 - BLACK / 245',
#         'Y 여성 TOPES 숏 양말-BC28303_101 - OFF WHITE / 230',
#         'Y 여성 SALBER 반팔 티셔츠-BA45334_700 - GREEN / 095',
#         'Y 여성 TOPES 숏 양말-BC28303_931 - CHARCOAL.GREY / 230',
#         'Y 여성 CANUT  단목 양말-BB27301_816 - SKYBLUE / 230',
#         '장갑형 팔토시 2MMXXX5905 - 블랙 / M',
#         'Y 남성 VIENTO 양말-BC18332_931 - CHARCOAL.GREY / 260',
#         'Y 남성 VIENTO 양말-BC18332_820 - NAVY / 260',
#         '뉴드라이존 팔토시 2MMXXX5904 - 블루 / L',
#         'Y 여성 CABURNI 양말-BC28302_199 - BLACK / 230',
#         'Y 남성 VIENTO 양말-BC18332_100 - WHITE / 260',
#         '[제임스딘] 블루 스트라이프 아웃밴드 드로즈-JDMDTW01 - 세피아 / 100.',
#         'Y 여성 KATARINE 장갑-BA28107_199 - BLACK / 00M',
#         'Y 공용 UWE 우베 머플러-BAG7706_820 - NAVY / 000'], dtype=object),
#  array(['[9상품권]탄력크림 세트 - 세트.', '[16]퍼펙팅쿠션 세트 - 11호'], dtype=object),
#  array(['[크루클린] 인기 베이직 상품 8종 균일가! - 08 TRS053 화이트 / XL',
#         '5핀 2.1A 가정용 충전기 SK-TCA210 - 블랙', '35cm 스탠드형 선풍기 QSF-K100',
#         'CRESCENT IMAGINATION 01_BLCT (반팔박스티) - BLACK / M ◈71239707◈'],
#        dtype=object),
#  array(['북유럽 헤링본 순면 욕실  발매트 (42x67cm) - 헤링본 발매트_베이지',
#         '[국민속옷 트라이] 남자 베이직 민소매 런닝 5매 - 100', '[스펙트럼] 플라워 타올링',
#         '슈퍼싸이킹 주니어 청소기 K73SG [택배상품](샤이니실버/트윈 싸이클론)'], dtype=object),
#  array(['자수 스트라이프 면 7부티셔츠 HSTS8B754 - 네이비 / 85(55)',
#         '슈퍼스케이트 (FFSO8G025) - SV(실버) / 40(240)',
#         '칼렌듈라 딥 클렌징 포밍 페이스 워시 230ml',
#         '[MD추천] 다이아몬드코팅 포셀후라이팬 듀오세트 A형(팬20cm,팬24cm)',
#         '까사로퍼 (FFSO8G021) - GD(메탈릭골드) / 60(260)',
#         '화애락진(70ml*30포) /백화점 상품 - 화애락진_',
#         '루즈핏 숏 가디건 (7157350101) - 네이비46 / FREE',
#         '우먼스 에픽 리액트 플라이니트  AQ0070-007 - 230'], dtype=object),
#  array(['어반ST 미니티슈커버', '딥브이브라팬티세트[TWB0126/TWH0126] - 스킨 / 75B / 100',
#         'FL 뷰티폴 디너포크 핑크골드 - DT-1087GP-DF',
#         'FL 뷰티폴 디너나이프 핑크골드 - DT-1087GP-DK',
#         '하비라이프 페달휴지통 3L 아이보리(THB312IV)', '모던내추럴 웜그레이 미니티슈커버',
#         '뷰티폴 커트러리 디너라인 단품 4종택1(핑크골드) - 디너포크 핑크골드', '어반도트 미니티슈커버'],
#        dtype=object),
#  array(['공용베이직 스니커즈 MSY5AS3001 - WT(화이트) / 265',
#         '공용 레이스업 스니커즈MSY5AS3003 - WT / 265'], dtype=object),
#  array(['[호핑백]물통가방_네이쳐_6종중택1 - 그린몽키',
#         '남아 여아 바람막이 4종택1 - 100 / BS15JP02BU(블루)'], dtype=object),
#  array(['[임부복닷컴]햅번 슬랍 77 88까지 여름 롱티 - 화이트 / F(55~88)',
#         '헬로버블 염색약 1+1 (옵션) - 21 7N 모카라떼 브라운 + 5BR 딥브로드로즈',
#         '포린스 아로마 캡슐 향기톡톡 섬유유연제 2Lx3개 - 바이올렛 2Lx3개'], dtype=object),
#  array(['리프래빗끈소내의[MAM5EE38] - 110',
#         '에디슨 뽀로로/패티 입체 스텐 젓가락 1단계 (오른손용) - 패티 입체 스텐젓가락',
#         '요물 빨대 교체용 실리콘 빨대리필2p/젖병호환가능 - 교체용 빨대리필(1단계)',
#         '프렌즈 흘림방지 양손빨대컵투 유아 어린이 에디슨 - 프렌즈양손빨대컵투[사자]',
#         '3M스카치다용도테이프리필550 12x30M/3M스카치테이프/3M테이프 - 1개입',
#         '3M매직테이프리필 810R-3 12mmX18M 알뜰팩/세이빙팩/3M테이프 - 810R-3 12mm알뜰팩',
#         '피스여아끈소내의[MAM5EE21] - 80'], dtype=object),
#  array(['앙드레김골프 남성 기모 긴팔티 - 06_AB7DMTS356_블랙 / 110',
#         '앙드레김골프 남성 패딩점퍼 - 01_AB7DMJP807_브라운 / 105',
#         '앙드레김 남성/여성 기모바지 패딩바지 8종 - 05_AB6DMPT008_DGY / 88'], dtype=object),
#  array(['[롯데단독 특별전]아쿠아수르스 에센스 스킨 400ml 세트(택1) - 중복합성'], dtype=object),
#  array(['올 인 원 컬러 코렉팅 팔레트(+페이스블렌더+금손원스텝브러쉬)',
#         '[Womens Originals] 3 ST 쇼츠 2종{DH4422SERIES} - DH3199(핑크) / M(95)'],
#        dtype=object),
#  array(['립밤 #1 (튜브15ml)',
#         '2016FW 아동 총판 양면 내의 (6종 택1) - 16FC총여아양면내의02 / 70호',
#         '링플라워 여세트 후라이스 어린이내복_(55~80호) - 60호'], dtype=object),
#  array(['[C] 블러쉬 바 키트', '남여긴팔샤무즈파자마 TWJSC11TMJSC11 - 남성TMJSC11(그레이)-105'],
#        dtype=object),
#  array(['라이트 엘리먼츠 스무딩 플루이드 (100ml)', '[이롬황성주]1일1생식 8주 + 쉐이커'], dtype=object),
#  array(['여성 체크 셔츠 LCST CF501E-18ATUC - 034',
#         '여성 하운드투스 린넨 셔츠 LCST CF906E-18BQ1Y - 034'], dtype=object),
#  array(['[동아제약] 어린이가그린 딸기향 380ml x 1개', '[동아제약] 어린이가그린 사과향 380ml x 1개',
#         '[센터배송]제이반즈 듀얼 선글라스 - 블랙핫핑크'], dtype=object),
#  array(['균일가 로맨틱 원피스 16종 택1 SACI2H05 - 02.FAEI2612_네이비 / FREE',
#         '종가집 포기김치 8kg (4kg+4kg) - 8kg',
#         '여성스트라이프7부 셔츠10170-120-408-26 - 스카이블루(211) / S'], dtype=object),
#  array(['린넨 날개 티(AJ2CT549) - 아이보리(IV) / FREE',
#         '단추 포인트 H 라인 스커트 ITI5ZSK960 - 그린 / 66'], dtype=object),
#  array(['[#텐텐]  여성 반팔 티셔츠 균일가50종 - 05_FBAG5824D30 / 90',
#         '여성 넥변형 반팔 티셔츠-GBZG5813C40 - NAVY / 85',
#         '여성 러플 소매 그래픽 티셔츠-GBAG5858DB0 - MGREY / 85'], dtype=object),
#  array(['마더케이 블록 젖꼭지 케이스 리필', '마더케이 블록 젖꼭지 케이스'], dtype=object),
#  array(['헤지스남성 OUTS7BH41N3 스트라이프 면 반팔티셔츠 - 095',
#         '남여공용 지퍼 언발 보강 슬링백 힙색 크로스백 가방(N185AB032P) - 블랙 / FREE(18*31)',
#         '남여공용 빅로고 나시티(NBNG82M113) - 화이트(WH) / 105(XL)'], dtype=object),
#  ...]

# %%
train_data6 = list(train.groupby('CLNT_ID')['CLAC2_NM'].unique())
test_data6 = list(test.groupby('CLNT_ID')['CLAC2_NM'].unique())
train_data6
# Out:
# [array(['주방가전', '수예소품'], dtype=object),
#  array(['수영/물놀이', '스킨케어', '선케어', '홍삼/인삼가공식품', '메이크업'], dtype=object),
#  array(['여성속옷', '여성스포츠화'], dtype=object),
#  array(['유아동속옷'], dtype=object),
#  array(['유아동양말류', '여성화', '조리도구', '유아의류전신', '모자', '조리기구'], dtype=object),
#  array(['화장지/티슈'], dtype=object),
#  array(['정리용품'], dtype=object),
#  array(['유아스킨/바디케어', '냉장/냉동고'], dtype=object),
#  array(['핸드/풋케어', '남성일반스포츠의류', '스킨케어', '골프', '메이크업'], dtype=object),
#  array(['남성지갑'], dtype=object),
#  array(['남성스포츠화', '애견용품', '선케어'], dtype=object),
#  array(['생수'], dtype=object),
#  array(['여성일반스포츠의류', '남성일반스포츠의류'], dtype=object),
#  array(['여성속옷'], dtype=object),
#  array(['건강진액'], dtype=object),
#  array(['남성케어', '우산/양산류', '스포츠잡화', '남성속옷'], dtype=object),
#  array(['여성의류상의', '여성의류전신', '유아동침구'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['남성의류상의', '남성의류하의', '여성의류아우터'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['여성속옷', '냉방가전'], dtype=object),
#  array(['유아의류상의', '여아의류상의', '생수'], dtype=object),
#  array(['여성위생용품', '유아위생용품', '영양제'], dtype=object),
#  array(['포장반찬', '남성등산/아웃도어의류', '여성속옷', '유아동스포츠화', '골프', '헤어케어', '우산/양산류',
#         '여성의류전신', '캠핑', '냉방가전', '여성화', '남성의류상의', '주방가전', '유아동속옷', '등산',
#         '여성가방', '남성속옷', '유아동양말류'], dtype=object),
#  array(['여성의류상의'], dtype=object),
#  array(['유아의류하의', '여성의류전신', '여아의류상의'], dtype=object),
#  array(['여성스포츠화'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['애견용품', '고양이용품'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['구강케어'], dtype=object),
#  array(['여성위생용품', '남성등산/아웃도어의류', '남성의류상의', '유아스킨/바디케어', '남성의류아우터', '여성속옷',
#         '여성화', '홍삼/인삼가공식품', '여성의류상의', '남성의류하의', '스킨케어', '포장반찬', '화장지/티슈',
#         '냉동간편식', '여성의류전신'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['수납가구', '사무용/학생용가구'], dtype=object),
#  array(['스킨케어', '선케어'], dtype=object),
#  array(['수유/이유용품', '유아발육용품'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['여성일반스포츠의류', '유아동스포츠화', '유아동화'], dtype=object),
#  array(['여성속옷', '여성의류하의'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['여아의류상의', '유아의류전신', '여성일반스포츠의류'], dtype=object),
#  array(['여성속옷'], dtype=object),
#  array(['남성의류하의', '수예소품', '여성의류상의'], dtype=object),
#  array(['남성일반스포츠의류'], dtype=object),
#  array(['교육완구'], dtype=object),
#  array(['피트니스'], dtype=object),
#  array(['그릇/식기'], dtype=object),
#  array(['수영/물놀이', '남성스포츠화', '여성의류아우터', '여성의류전신', '여성화'], dtype=object),
#  array(['유아의류하의', '여아의류상의', '남성골프의류'], dtype=object),
#  array(['유아동침구'], dtype=object),
#  array(['생수'], dtype=object),
#  array(['유아위생용품'], dtype=object),
#  array(['스포츠잡화'], dtype=object),
#  array(['수영/물놀이', '유아동화'], dtype=object),
#  array(['남성등산/아웃도어의류', '남성일반스포츠의류'], dtype=object),
#  array(['스킨케어', '남성의류상의'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['여성골프의류'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['여성가방'], dtype=object),
#  array(['모자', '유아동화'], dtype=object),
#  array(['헤어케어'], dtype=object),
#  array(['거실가구'], dtype=object),
#  array(['여성의류상의', '여성의류전신'], dtype=object),
#  array(['유아동화', '여아의류상의', '닭고기류', '유아동속옷', '남아의류상의', '수영/물놀이', '홈웨어',
#         '주방가구', '유아위생용품', '애견용품', '여성화'], dtype=object),
#  array(['밀폐/보관용기'], dtype=object),
#  array(['홍삼/인삼가공식품', '시계'], dtype=object),
#  array(['고양이용품', '남성스포츠화'], dtype=object),
#  array(['생수'], dtype=object),
#  array(['건강진액', '골프'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['스킨케어', '메이크업'], dtype=object),
#  array(['유아의류하의', '유아동속옷'], dtype=object),
#  array(['남성의류하의'], dtype=object),
#  array(['바디케어', '유아위생용품', '여성속옷', '유아동속옷', '헤어케어', '유아스킨/바디케어'],
#        dtype=object),
#  array(['남성의류하의', '남성의류상의', '메이크업', '여성의류상의', '여행용가방류'], dtype=object),
#  array(['기능성음료'], dtype=object),
#  array(['유아의류상의', '유아위생용품', '캐쥬얼가방', '생수', '여성일반스포츠의류', '남성일반스포츠의류'],
#        dtype=object),
#  array(['컴퓨터/노트북', '메이크업'], dtype=object),
#  array(['여성속옷'], dtype=object),
#  array(['생수', '여성의류상의', '그릇/식기', '여성의류하의'], dtype=object),
#  array(['침실가구'], dtype=object),
#  array(['여성화', '여성의류아우터', '홈웨어', '남성등산/아웃도어의류', '남성골프의류', '여성의류상의',
#         '남성일반스포츠의류', '남성의류상의'], dtype=object),
#  array(['스킨케어', '여성의류전신', '여성의류상의'], dtype=object),
#  array(['수영/물놀이', '남성일반스포츠의류'], dtype=object),
#  array(['모바일액세서리', '여성위생용품', '남성의류하의'], dtype=object),
#  array(['성인침구'], dtype=object),
#  array(['정리용품'], dtype=object),
#  array(['모자', '일반문구/사무용품', '수영/물놀이', '필기도구', '안경/선글라스', '여성가방'],
#        dtype=object),
#  array(['유아스킨/바디케어', '선케어'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['남성일반스포츠의류', '여성의류상의'], dtype=object),
#  array(['여성일반스포츠의류'], dtype=object),
#  array(['메이크업', '남성의류상의', '선케어'], dtype=object),
#  array(['유아의류하의', '여성의류하의'], dtype=object),
#  array(['여성의류상의', '유아동속옷'], dtype=object),
#  array(['여성화'], dtype=object),
#  array(['캠핑'], dtype=object),
#  array(['여성가방', '남성의류상의'], dtype=object),
#  array(['여아의류하의', '여아의류상의', '남아의류하의'], dtype=object),
#  array(['고양이용품', '여행용가방류'], dtype=object),
#  array(['남성의류상의', '여성의류상의'], dtype=object),
#  array(['커튼/블라인드류', '포장반찬'], dtype=object),
#  array(['여성속옷'], dtype=object),
#  array(['여성의류상의', '여성의류전신', '스킨케어'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['여성화'], dtype=object),
#  array(['캐쥬얼가방', '여성지갑'], dtype=object),
#  array(['주방가전'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['고양이용품'], dtype=object),
#  array(['여성속옷', '선케어'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['여성의류전신', '포장반찬', '사무용/학생용가구', '여성의류하의', '욕실용품'], dtype=object),
#  array(['여성의류상의', '메이크업', '남성지갑'], dtype=object),
#  array(['남성의류상의', '남성일반스포츠의류', '남성스포츠화', '시계', '남성의류아우터'], dtype=object),
#  array(['주방가구'], dtype=object),
#  array(['모바일액세서리'], dtype=object),
#  array(['남아완구', '유아의류상의', '욕실용품', '캠핑', '세탁세제', '일반문구/사무용품', '기능성음료'],
#        dtype=object),
#  array(['영양제'], dtype=object),
#  array(['메이크업', '유아의류전신', '수영/물놀이'], dtype=object),
#  array(['남성의류하의', '스킨케어', '남성일반스포츠의류'], dtype=object),
#  array(['남성스포츠화'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['피트니스', '거실가구', '사무용/학생용가구'], dtype=object),
#  array(['스킨케어', '메이크업', '구강케어', '욕실용품'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['유아동속옷', '세탁세제', '남성케어', '여성의류전신', '유아의류상의', '수영/물놀이', '유아위생용품',
#         '모바일액세서리', '유아의류전신', '유아동스포츠화', '남성의류상의', '남아의류하의'], dtype=object),
#  array(['여성의류아우터', '여성의류하의'], dtype=object),
#  array(['헤어케어'], dtype=object),
#  array(['여성속옷'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['여성속옷'], dtype=object),
#  array(['남성등산/아웃도어의류', '여성등산/아웃도어의류', '남성의류상의'], dtype=object),
#  array(['모자', '여성의류상의', '패션액세서리', '남성의류하의', '메이크업', '여성의류전신'], dtype=object),
#  array(['여아의류하의', '남성스포츠화', '유아동속옷'], dtype=object),
#  array(['조리도구'], dtype=object),
#  array(['욕실용품', '애견용품'], dtype=object),
#  array(['수영/물놀이', '메이크업', '일반문구/사무용품', '냉방가전', '헤어케어', '스킨케어', '골프', '선케어'],
#        dtype=object),
#  array(['스킨케어', '헤어케어', '여성의류전신', '일반문구/사무용품', '성인침구'], dtype=object),
#  array(['홍삼/인삼가공식품', '남성의류상의', '여성속옷', '유아의류전신', '모자', '컴퓨터주변기기'],
#        dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['유아동화', '영양제', '여아의류상의', '여성화', '여아의류하의', '남아의류세트', '수영/물놀이'],
#        dtype=object),
#  array(['생수'], dtype=object),
#  array(['유아동화', '포장반찬'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['홍삼/인삼가공식품', '청소기'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['유아동양말류'], dtype=object),
#  array(['여성속옷'], dtype=object),
#  array(['유아동스포츠화'], dtype=object),
#  array(['여성의류상의', '여성일반스포츠의류', '구강케어', '필기도구', '일반문구/사무용품', '여성가방', '남성속옷',
#         '여성속옷', '남성지갑', '여성양말류', '여성의류하의', '여성스포츠화'], dtype=object),
#  array(['남성의류하의', '여성의류하의'], dtype=object),
#  array(['여성스포츠화', '미용소품'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['스킨케어', '선케어'], dtype=object),
#  array(['여아완구', '유아동침구', '유아안전용품'], dtype=object),
#  array(['모바일상품권'], dtype=object),
#  array(['그릇/식기'], dtype=object),
#  array(['여아의류상의', '여성화'], dtype=object),
#  array(['성인침구', '수유/이유용품'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['수영/물놀이', '스킨케어'], dtype=object),
#  array(['애견용품'], dtype=object),
#  array(['메이크업', '여성스포츠화', '남성스포츠화', '스킨케어', '남성화', '여성일반스포츠의류', '헤어케어',
#         '이미용가전', '스포츠잡화', '여성화'], dtype=object),
#  array(['여성의류상의', '메이크업', '피트니스', '남성의류하의'], dtype=object),
#  array(['향수', '여성가방', '메이크업'], dtype=object),
#  array(['골프', '메이크업', '남성의류상의', '선케어', '스킨케어', '유아스킨/바디케어', '유아위생용품',
#         '여성의류상의', '여성의류하의', '정리용품', '헤어케어', '욕실용품', '여성의류전신', '주방정리용품/소모품'],
#        dtype=object),
#  array(['수영/물놀이', '정리용품'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['유아동스포츠화', '여아의류하의', '남아의류상의', '여아의류상의'], dtype=object),
#  array(['메이크업', '여성화', '여성의류상의', '미용소품', '여성의류하의'], dtype=object),
#  array(['홍삼/인삼가공식품'], dtype=object),
#  array(['핸드/풋케어', '유아위생용품', '생수', '여성속옷'], dtype=object),
#  array(['유아스킨/바디케어', '메이크업'], dtype=object),
#  array(['남성등산/아웃도어의류', '남성일반스포츠의류'], dtype=object),
#  array(['시계'], dtype=object),
#  array(['여성속옷', '여성의류상의', '패션액세서리', '여성의류아우터', '여성의류하의', '여성의류전신'],
#        dtype=object),
#  array(['남성의류상의', '헤어케어', '남성의류하의', '메이크업'], dtype=object),
#  array(['여성일반스포츠의류', '스포츠잡화'], dtype=object),
#  array(['보석', '남성가방'], dtype=object),
#  array(['유아동침구'], dtype=object),
#  array(['일반문구/사무용품', '모바일액세서리', '주방정리용품/소모품', '밀폐/보관용기'], dtype=object),
#  array(['여성의류전신'], dtype=object),
#  array(['여성의류하의', '여성의류전신', '여성의류상의', '여아의류하의', '남성스포츠화', '성인침구', '남성의류상의',
#         '여성화', '조리기구', '구강케어', '여성가방', '여아의류상의', '여성일반스포츠의류', '남성양말류'],
#        dtype=object),
#  array(['여성화', '스킨케어', '공기청정/가습/제습', '메이크업', '향수', '여성가방'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['여성등산/아웃도어의류', '커튼/블라인드류', '여아의류상의', '메이크업'], dtype=object),
#  array(['여아의류아우터', '남성등산/아웃도어의류'], dtype=object),
#  array(['유아의류전신', '유아동화', '스포츠잡화', '수영/물놀이'], dtype=object),
#  array(['유아의류하의', '여아의류상의'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['홍삼/인삼가공식품', '남성의류상의', '남성의류하의'], dtype=object),
#  array(['여성의류하의', '건강진액'], dtype=object),
#  array(['여성양말류'], dtype=object),
#  array(['남성의류상의', '남성의류하의', '모자', '스포츠잡화'], dtype=object),
#  array(['헤어케어'], dtype=object),
#  array(['유아스킨/바디케어', '선케어'], dtype=object),
#  array(['스킨케어', '냉동간편식', '여성화'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['애견용품'], dtype=object),
#  array(['영양제'], dtype=object),
#  array(['남성의류하의', '여성의류상의', '여성의류하의', '스킨케어', '여성의류전신', '남성의류상의'],
#        dtype=object),
#  array(['주방정리용품/소모품', '조리도구'], dtype=object),
#  array(['여성화', '메이크업', '여성의류아우터', '여성의류상의', '스킨케어', '조리도구', '성인침구', '바디케어',
#         '여성의류전신', '여성의류하의', '수예소품', '조리기구', '남성의류상의', '여성속옷', '핸드/풋케어',
#         '골프'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['남성의류하의'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['정리용품', '세탁세제'], dtype=object),
#  array(['남성의류상의', '메이크업', '여성의류전신', '여성스포츠화', '미용소품'], dtype=object),
#  array(['남성일반스포츠의류', '여성속옷', '선케어'], dtype=object),
#  array(['우산/양산류', '여성화'], dtype=object),
#  array(['여성의류상의', '여성의류전신', '여성의류하의', '수영/물놀이'], dtype=object),
#  array(['성인침구'], dtype=object),
#  array(['여성의류전신'], dtype=object),
#  array(['여성화', '정리용품'], dtype=object),
#  array(['남아의류상의', '여아의류상의'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['여성의류전신', '여성의류아우터'], dtype=object),
#  array(['여성속옷', '남성속옷'], dtype=object),
#  array(['여성속옷', '건강진액', '수유/이유용품', '조리도구', '등산', '유아스킨/바디케어', '스포츠잡화',
#         '여성의류하의', '여성의류상의'], dtype=object),
#  array(['유아스킨/바디케어', '수유/이유용품', '여아완구', '조리도구', '모바일상품권'], dtype=object),
#  array(['스킨케어', '메이크업'], dtype=object),
#  array(['우산/양산류', '메이크업', '남성속옷', '남성스포츠화', '남성가방', '모바일액세서리', '스킨케어'],
#        dtype=object),
#  array(['여성화'], dtype=object),
#  array(['스킨케어', '남성케어'], dtype=object),
#  array(['여성의류상의', '여성가방', '여아의류상의', '유아의류전신', '성인침구', '여성화', '일반문구/사무용품',
#         '주방가전', '수예소품', '메이크업'], dtype=object),
#  array(['커튼/블라인드류'], dtype=object),
#  array(['여성양말류'], dtype=object),
#  array(['여성가방', '메이크업'], dtype=object),
#  array(['핸드/풋케어', '여성의류하의', '스킨케어', '남성의류상의', '조리기구', '거실가구', '여성속옷',
#         '건강보조식품', '여성의류상의', '남성의류하의', '영양제', '남성화', '여성스포츠화', '여성의류전신',
#         '일반문구/사무용품', '생수', '청소기', '메이크업', '바디케어', '남성케어', '여성화', '밀폐/보관용기',
#         '캐쥬얼가방', '주방정리용품/소모품', '욕실용품', '여성가방', '여성의류아우터', '모자', '여행용가방류',
#         '보석', '조리도구', '컴퓨터주변기기', '등산', '선케어', '남성일반스포츠의류', '정리용품', '유아동가구',
#         '애견용품'], dtype=object),
#  array(['여성스포츠화'], dtype=object),
#  array(['여성의류하의', '이미용가전'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['여성가방'], dtype=object),
#  array(['남아의류상의', '남성의류상의', '유아의류상의', '유아동화'], dtype=object),
#  array(['모자', '수영/물놀이'], dtype=object),
#  array(['모바일상품권'], dtype=object),
#  array(['메이크업', '핸드/풋케어', '남성스포츠화', '여성스포츠화'], dtype=object),
#  array(['유아동침구', '유아동속옷', '성인침구', '세탁세제', '수유/이유용품', '유아동양말류', '유아동스포츠화',
#         '유아동화', '유아의류상의', '유아의류하의'], dtype=object),
#  array(['메이크업', '미용소품', '컴퓨터주변기기', '정리용품'], dtype=object),
#  array(['주방가전', '조리도구'], dtype=object),
#  array(['그릇/식기'], dtype=object),
#  array(['미용소품', '여성의류상의', '메이크업'], dtype=object),
#  array(['컴퓨터주변기기', '메이크업'], dtype=object),
#  array(['메이크업', '영양제', '모바일액세서리'], dtype=object),
#  array(['여성스포츠화', '남성가방'], dtype=object),
#  array(['시계', '유아동양말류', '수유/이유용품', '여성의류전신', '유아의류전신', '여성의류상의'],
#        dtype=object),
#  array(['메이크업', '스킨케어', '미용소품', '화장지/티슈'], dtype=object),
#  array(['남성의류하의', '남아완구', '메이크업', '컴퓨터주변기기', '인라인/스케이트보드/킥보드', '향수', '남성화'],
#        dtype=object),
#  array(['우산/양산류'], dtype=object),
#  array(['여성화', '유아동화'], dtype=object),
#  array(['여성일반스포츠의류'], dtype=object),
#  array(['미용소품'], dtype=object),
#  array(['유아의류상의', '남아의류하의', '여성가방', '유아동속옷'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['모바일상품권'], dtype=object),
#  array(['여성의류아우터', '남성의류하의'], dtype=object),
#  array(['메이크업', '남성일반스포츠의류', '여성의류하의', '여성의류상의', '스포츠잡화', '남성스포츠화',
#         '남성의류아우터', '남성의류상의', '여성화', '골프', '남성의류하의', '여성가방'], dtype=object),
#  array(['여성화'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['남성일반스포츠의류', '남성의류상의', '남성스포츠화'], dtype=object),
#  array(['여아의류상의', '유아의류하의', '유아동화'], dtype=object),
#  array(['남성일반스포츠의류'], dtype=object),
#  array(['생수'], dtype=object),
#  array(['여성화'], dtype=object),
#  array(['여성양말류', '포장반찬', '냉방가전'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['남성의류하의', '남성일반스포츠의류', '메이크업'], dtype=object),
#  array(['메이크업', '미용소품'], dtype=object),
#  array(['여성의류상의', '남성의류상의', '유아의류하의', '수유/이유용품'], dtype=object),
#  array(['욕실용품'], dtype=object),
#  array(['미용소품'], dtype=object),
#  array(['주방가전'], dtype=object),
#  array(['남성골프의류', '골프', '여성속옷', '스킨케어', '메이크업'], dtype=object),
#  array(['여성의류상의'], dtype=object),
#  array(['남성스포츠화'], dtype=object),
#  array(['향수'], dtype=object),
#  array(['여성일반스포츠의류', '정리용품', '여성화', '여성의류상의', '영양제', '여성의류전신', '여성의류아우터',
#         '남성일반스포츠의류'], dtype=object),
#  array(['일반문구/사무용품', '애견용품'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['남아의류상의'], dtype=object),
#  array(['여성속옷'], dtype=object),
#  array(['구강케어'], dtype=object),
#  array(['모바일액세서리'], dtype=object),
#  array(['메이크업', '스킨케어'], dtype=object),
#  array(['여성의류하의', '남성스포츠화', '여성의류상의', '수영/물놀이'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['여성화', '여성의류상의'], dtype=object),
#  array(['일반문구/사무용품'], dtype=object),
#  array(['유아의류하의'], dtype=object),
#  array(['여성일반스포츠의류'], dtype=object),
#  array(['수영/물놀이', '유아발육용품', '여성가방'], dtype=object),
#  array(['패션액세서리', '컴퓨터/노트북', '메이크업'], dtype=object),
#  array(['성인침구'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['골프', '남성의류상의', '여성화', '여성의류상의', '여성스포츠화', '남성스포츠화'], dtype=object),
#  array(['남성의류상의', '유아동속옷'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['스킨케어', '남성의류하의', '애견용품', '헤어케어', '메이크업'], dtype=object),
#  array(['남성의류하의', '애견용품'], dtype=object),
#  array(['남성케어'], dtype=object),
#  array(['모바일상품권'], dtype=object),
#  array(['유아의류하의', '바디케어', '수영/물놀이', '여성화', '주방정리용품/소모품', '일반문구/사무용품',
#         '수납가구', '남성의류상의', '여성의류상의', '남성의류하의', '여성속옷', '조리도구', '여성스포츠화',
#         '두유', '미용소품', '우산/양산류', '여행용가방류', '밀폐/보관용기', '정리용품'], dtype=object),
#  array(['두유', '여성스포츠화', '여성의류상의', '유아동화', '여성화', '여성속옷'], dtype=object),
#  array(['남성의류아우터'], dtype=object),
#  array(['여성의류하의', '여성의류전신', '여성의류상의', '유아의류상의', '남성의류상의'], dtype=object),
#  array(['여성의류상의'], dtype=object),
#  array(['남성의류아우터'], dtype=object),
#  array(['여성의류전신', '남성의류상의', '여성의류상의', '유아의류하의', '보석', '여아의류상의', '여성의류아우터',
#         '여성스포츠화', '유아의류전신', '여아의류아우터', '여성속옷', '견과류'], dtype=object),
#  array(['두유', '메이크업'], dtype=object),
#  array(['캠핑', '고양이용품'], dtype=object),
#  array(['스킨케어', '메이크업'], dtype=object),
#  array(['메이크업', '여성의류상의'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['남성일반스포츠의류', '여성스포츠화', '여성의류상의'], dtype=object),
#  array(['여성의류전신'], dtype=object),
#  array(['여성의류전신', '수영/물놀이'], dtype=object),
#  array(['여성일반스포츠의류', '남성일반스포츠의류', '수유/이유용품'], dtype=object),
#  array(['여성가방', '수영/물놀이', '컴퓨터주변기기'], dtype=object),
#  array(['여성속옷', '유아의류상의', '바디케어', '유아동스포츠화'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['유아동속옷', '유아동양말류'], dtype=object),
#  array(['남성의류하의', '홍삼/인삼가공식품'], dtype=object),
#  array(['애견용품'], dtype=object),
#  array(['유아의류전신'], dtype=object),
#  array(['남성스포츠화'], dtype=object),
#  array(['유아스킨/바디케어'], dtype=object),
#  array(['성인침구', '헤어케어', '메이크업', '거실가구', '바디케어'], dtype=object),
#  array(['남성등산/아웃도어의류'], dtype=object),
#  array(['여성화', '스킨케어'], dtype=object),
#  array(['메이크업', '모바일액세서리', '여성화'], dtype=object),
#  array(['냉동간편식'], dtype=object),
#  array(['정리용품', '조리도구', '바디케어'], dtype=object),
#  array(['유아위생용품', '애견용품'], dtype=object),
#  array(['유아동화', '등산', '조리기구', '유아동스포츠화'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['유아동스포츠화'], dtype=object),
#  array(['밀폐/보관용기'], dtype=object),
#  array(['헤어케어', '미용소품'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['여성일반스포츠의류', '남성의류상의', '유아의류상의', '남성의류아우터', '남성속옷', '스포츠잡화', '모자'],
#        dtype=object),
#  array(['남성의류상의', '피트니스', '남성의류하의', '여성가방', '여성일반스포츠의류', '남성가방', '수영/물놀이'],
#        dtype=object),
#  array(['생수'], dtype=object),
#  array(['여성의류전신', '여성의류상의'], dtype=object),
#  array(['홍삼/인삼가공식품'], dtype=object),
#  array(['메이크업', '헤어케어', '컴퓨터주변기기', '바디케어', '조리기구', '홍삼/인삼가공식품', '스킨케어',
#         '미용소품', '청소기'], dtype=object),
#  array(['여성속옷'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['여성속옷', '남성속옷', '여성의류전신', '여성의류상의', '스킨케어', '남성의류상의'], dtype=object),
#  array(['스킨케어', '그릇/식기'], dtype=object),
#  array(['남성화', '여성화'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['성인침구', '스킨케어', '헤어케어', '유아동침구', '미용소품', '메이크업', '세탁세제', '남성의류상의',
#         '여성의류아우터', '여성속옷', '영양제'], dtype=object),
#  array(['남성의류상의', '여성속옷', '유아동속옷', '애견용품', '남성의류하의'], dtype=object),
#  array(['메이크업', '스킨케어'], dtype=object),
#  array(['여성의류전신', '여성등산/아웃도어의류'], dtype=object),
#  array(['여성의류하의', '그릇/식기', '여성의류전신', '일반문구/사무용품', '남성의류상의', '남성화',
#         '여성의류상의', '여성화'], dtype=object),
#  array(['모자', '여성의류상의', '애견용품'], dtype=object),
#  array(['유아의류상의'], dtype=object),
#  array(['홈웨어'], dtype=object),
#  array(['유아동속옷', '여성의류아우터'], dtype=object),
#  array(['스킨케어', '바디케어'], dtype=object),
#  array(['성인침구'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['우산/양산류'], dtype=object),
#  array(['남성스포츠화'], dtype=object),
#  array(['주방가전', '캠핑'], dtype=object),
#  array(['캠핑'], dtype=object),
#  array(['스킨케어', '메이크업', '선케어', '남성스포츠화', '바디케어', '조리도구'], dtype=object),
#  array(['여성등산/아웃도어의류'], dtype=object),
#  array(['남성골프의류', '캐쥬얼가방', '컴퓨터주변기기', '주방정리용품/소모품', '유아동화', '남성등산/아웃도어의류',
#         '남성의류상의', '자동차음향/가전기기', '컴퓨터/노트북'], dtype=object),
#  array(['조리도구', '남성스포츠화', '그릇/식기', '애견용품', '남성속옷', '남성의류하의', '남성의류상의',
#         '여성화'], dtype=object),
#  array(['영양제'], dtype=object),
#  array(['유아의류상의', '유아동스포츠화'], dtype=object),
#  array(['여성의류상의', '수영/물놀이', '홈웨어', '영양제', '이미용가전', '남성의류아우터', '메이크업',
#         '여성속옷', '여성의류하의', '욕실용품', '냉방가전', '컴퓨터주변기기', '모바일액세서리'],
#        dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['남성케어'], dtype=object),
#  array(['남성의류상의', '여성의류아우터'], dtype=object),
#  array(['여성속옷', '수영/물놀이', '홈웨어', '여성일반스포츠의류', '유아동화', '유아스킨/바디케어'],
#        dtype=object),
#  array(['여성의류상의'], dtype=object),
#  array(['남성일반스포츠의류', '여성일반스포츠의류', '수영/물놀이', '남성의류상의'], dtype=object),
#  array(['스킨케어', '헤어케어'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['여성의류상의', '주방정리용품/소모품', '남성의류상의', '선케어', '영양제', '스킨케어', '애견용품'],
#        dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['냉동간편식'], dtype=object),
#  array(['남성일반스포츠의류', '여행용가방류'], dtype=object),
#  array(['여성의류하의'], dtype=object),
#  array(['남성일반스포츠의류'], dtype=object),
#  array(['고양이용품'], dtype=object),
#  array(['남아의류하의', '남아의류상의', '여아의류상의'], dtype=object),
#  array(['남아의류하의', '남아의류세트', '유아의류상의', '스킨케어', '애견용품', '조리도구', '유아위생용품',
#         '남아의류상의', '세탁세제', '여성화', '일반문구/사무용품'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['여성의류전신'], dtype=object),
#  array(['여성의류전신'], dtype=object),
#  array(['여성의류상의', '욕실용품', '포장반찬', '수납가구', '침실가구', '정리용품', '메이크업', '남성의류하의',
#         '안경/선글라스', '여성골프의류', '건강진액', '생수', '주방가전', '여성의류하의', '모바일액세서리',
#         '영양제'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['수유/이유용품'], dtype=object),
#  array(['남아의류세트', '유아동일반스포츠의류', '남아의류상의', '남아의류하의'], dtype=object),
#  array(['남성의류상의', '남성의류하의'], dtype=object),
#  array(['여아의류상의', '여성화', '남아의류하의'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['성인침구'], dtype=object),
#  array(['남성등산/아웃도어의류'], dtype=object),
#  array(['남성스포츠화', '스포츠잡화'], dtype=object),
#  array(['여성일반스포츠의류'], dtype=object),
#  array(['메이크업', '수영/물놀이'], dtype=object),
#  array(['여성속옷', '남성케어'], dtype=object),
#  array(['여성가방'], dtype=object),
#  array(['여성의류상의', '여성의류하의'], dtype=object),
#  array(['여성의류상의', '여성의류하의', '여성의류전신', '여아의류상의'], dtype=object),
#  array(['고양이용품', '스킨케어'], dtype=object),
#  array(['유아동스포츠화', '메이크업', '여성화', '여성가방'], dtype=object),
#  array(['사무용/학생용가구'], dtype=object),
#  array(['유아동양말류'], dtype=object),
#  array(['냉방가전', '영양제', '냉장/냉동고'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['유아동스포츠화'], dtype=object),
#  array(['커튼/블라인드류'], dtype=object),
#  array(['여성등산/아웃도어의류', '생수', '스킨케어'], dtype=object),
#  array(['모자'], dtype=object),
#  array(['홍삼/인삼가공식품', '성인침구', '모바일액세서리', '여성속옷', '남성의류상의', '헤어케어', '국산과일'],
#        dtype=object),
#  array(['건강보조식품'], dtype=object),
#  array(['유아의류하의', '여아의류하의'], dtype=object),
#  array(['메이크업', '스킨케어', '헤어케어', '바디케어'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['여성위생용품', '바디케어'], dtype=object),
#  array(['패션액세서리', '홍삼/인삼가공식품', '여성스포츠화', '골프'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['남성일반스포츠의류'], dtype=object),
#  array(['여성의류상의', '남성의류상의', '여성화'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['건강진액'], dtype=object),
#  array(['여아의류상의', '유아의류하의'], dtype=object),
#  array(['미용소품', '모바일액세서리', '남성케어', '메이크업'], dtype=object),
#  array(['주방가전', '성인침구'], dtype=object),
#  array(['남아의류상의', '유아동일반스포츠의류'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['여성의류상의', '여성의류아우터'], dtype=object),
#  array(['보석', '남성골프의류', '여성스포츠화'], dtype=object),
#  array(['피트니스', '수영/물놀이', '남성의류상의'], dtype=object),
#  array(['여성의류하의'], dtype=object),
#  array(['여성의류상의', '메이크업'], dtype=object),
#  array(['남성의류상의', '여성의류아우터', '여성의류전신', '여성의류하의', '건강진액'], dtype=object),
#  array(['남성의류하의'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['스포츠잡화', '조리기구'], dtype=object),
#  array(['여성스포츠화', '여성의류전신'], dtype=object),
#  array(['우산/양산류', '세탁세제'], dtype=object),
#  array(['남성등산/아웃도어의류', '남성의류하의'], dtype=object),
#  array(['거실가구'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['여성의류상의'], dtype=object),
#  array(['여성의류상의', '여성의류아우터', '여성의류하의', '스킨케어', '여성속옷', '유아동속옷', '유아동화'],
#        dtype=object),
#  array(['보석'], dtype=object),
#  array(['스킨케어', '주방정리용품/소모품'], dtype=object),
#  array(['화장지/티슈', '선케어', '세탁세제', '청소기', '유아스킨/바디케어', '향수'], dtype=object),
#  array(['일반문구/사무용품'], dtype=object),
#  array(['패션액세서리', '메이크업'], dtype=object),
#  array(['여성양말류'], dtype=object),
#  array(['여성가방'], dtype=object),
#  array(['남성의류하의', '남성속옷', '여아의류하의', '보석', '남성의류상의', '여성화', '여성가방',
#         '여성의류상의', '여성속옷', '수영/물놀이', '여성골프의류', '남성스포츠화', '유아의류하의', '유아의류상의'],
#        dtype=object),
#  array(['욕실용품', '조리기구', '영양제', '피트니스'], dtype=object),
#  array(['여성화', '여성등산/아웃도어의류'], dtype=object),
#  array(['여성의류전신', '여성의류상의', '정리용품', '성인침구', '영양제', '스포츠잡화', '메이크업', '주방가구'],
#        dtype=object),
#  array(['생수', '스킨케어'], dtype=object),
#  array(['스킨케어', '여성의류전신', '주방가전'], dtype=object),
#  array(['여성속옷', '영양제', '유아동스포츠화', '그릇/식기', '여아의류상의', '선케어', '남아의류세트',
#         '메이크업'], dtype=object),
#  array(['남성일반스포츠의류'], dtype=object),
#  array(['남아의류세트', '남아의류하의', '남성의류상의', '골프', '남성일반스포츠의류', '유아의류전신',
#         '유아의류상의'], dtype=object),
#  array(['여성양말류'], dtype=object),
#  array(['남성스포츠화', '세탁세제'], dtype=object),
#  array(['여아완구', '남아의류상의', '유아동침구', '유아안전용품'], dtype=object),
#  array(['욕실용품', '유아동속옷', '유아위생용품', '여아의류상의', '조리기구', '기능성음료', '유아의류전신'],
#        dtype=object),
#  array(['포장반찬'], dtype=object),
#  array(['남성케어'], dtype=object),
#  array(['수유/이유용품', '유아위생용품'], dtype=object),
#  array(['남성의류상의', '남성의류하의', '남성등산/아웃도어의류'], dtype=object),
#  array(['유아위생용품', '냉동간편식', '유아스킨/바디케어', '냉방가전', '메이크업', '유아동스포츠화'],
#        dtype=object),
#  array(['수납가구'], dtype=object),
#  array(['여성속옷', '유아동속옷', '여성일반스포츠의류', '유아의류전신', '유아동화', '수영/물놀이',
#         '유아동일반스포츠의류', '여성양말류', '피트니스', '유아동양말류', '헤어케어', '스킨케어', '모바일액세서리',
#         '남아완구', '일반문구/사무용품', '수유/이유용품', '홈웨어'], dtype=object),
#  array(['여성의류하의', '두유', '남성의류하의'], dtype=object),
#  array(['여성의류아우터', '여성의류상의'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['이미용가전', '스킨케어'], dtype=object),
#  array(['모바일상품권'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['유아동양말류', '여아의류상의'], dtype=object),
#  array(['여성속옷', '정리용품', '수납가구'], dtype=object),
#  array(['메이크업', '향수', '여성의류상의', '여성의류하의', '유아위생용품', '남성의류상의'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['헤어케어', '일반문구/사무용품', '여성양말류', '스킨케어', '유아의류전신', '유아동속옷'],
#        dtype=object),
#  array(['보석', '남성의류하의', '여성화'], dtype=object),
#  array(['두유'], dtype=object),
#  array(['여성의류아우터'], dtype=object),
#  array(['모바일상품권', '화장지/티슈', '정리용품'], dtype=object),
#  array(['메이크업', '남성의류상의'], dtype=object),
#  array(['주방정리용품/소모품'], dtype=object),
#  array(['여성의류상의', '스킨케어'], dtype=object),
#  array(['생수'], dtype=object),
#  array(['남성속옷'], dtype=object),
#  array(['남성의류아우터', '스킨케어', '남성의류상의'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['세탁세제', '주방가전', '여아완구'], dtype=object),
#  array(['사무용/학생용가구'], dtype=object),
#  array(['여성스포츠화'], dtype=object),
#  array(['여성스포츠화'], dtype=object),
#  array(['고양이용품'], dtype=object),
#  array(['남성의류상의', '수유/이유용품', '유아동가구'], dtype=object),
#  array(['골프', '남성골프의류', '유아의류전신'], dtype=object),
#  array(['여성의류하의'], dtype=object),
#  array(['메이크업', '남성스포츠화', '미용소품', '남아의류하의', '남성의류상의', '여성의류상의'],
#        dtype=object),
#  array(['남성의류상의', '남성의류하의'], dtype=object),
#  array(['향수', '유아의류전신', '유아동스포츠화', '남아의류하의', '메이크업', '남성의류상의', '유아의류상의',
#         '스킨케어', '남아의류세트', '캐쥬얼가방', '남성일반스포츠의류'], dtype=object),
#  array(['여성스포츠화'], dtype=object),
#  array(['남성일반스포츠의류'], dtype=object),
#  array(['여성화', '여성의류전신'], dtype=object),
#  array(['일반문구/사무용품', '남성의류하의', '정리용품', '유아동화', '메이크업', '유아동가구'],
#        dtype=object),
#  array(['생수'], dtype=object),
#  array(['유아동화'], dtype=object),
#  array(['스킨케어', '여성속옷', '컴퓨터주변기기'], dtype=object),
#  array(['향수', '메이크업'], dtype=object),
#  array(['여성의류하의'], dtype=object),
#  array(['유아동양말류', '수유/이유용품', '여성의류상의', '여성의류하의', '수영/물놀이', '모자', '여성의류아우터',
#         '여성등산/아웃도어의류'], dtype=object),
#  array(['유아위생용품', '홈웨어', '수유/이유용품'], dtype=object),
#  array(['여성의류상의', '유아동스포츠화'], dtype=object),
#  array(['수영/물놀이', '남성스포츠화'], dtype=object),
#  array(['보석', '여성의류상의', '패션액세서리', '여성의류하의', '여성의류전신', '헤어케어'], dtype=object),
#  array(['여성지갑'], dtype=object),
#  array(['교육완구'], dtype=object),
#  array(['여성스포츠화'], dtype=object),
#  array(['스킨케어', '헤어케어', '메이크업'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['교육완구'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['여성의류하의', '여성의류전신'], dtype=object),
#  array(['수영/물놀이', '등산', '남성의류상의', '유아동일반스포츠의류', '그릇/식기', '남아의류상의', '모자'],
#        dtype=object),
#  array(['메이크업', '여성화', '여성속옷', '고양이용품'], dtype=object),
#  array(['유아위생용품', '유아동화', '수유/이유용품', '여아완구', '건강보조식품'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['헤어케어', '메이크업'], dtype=object),
#  array(['선케어', '미용소품'], dtype=object),
#  array(['주방가전'], dtype=object),
#  array(['냉동간편식', '여성의류하의'], dtype=object),
#  array(['남성의류상의', '메이크업', '남성의류하의'], dtype=object),
#  array(['여성의류상의'], dtype=object),
#  array(['남성의류상의', '남성스포츠화', '여성의류상의', '유아동스포츠화', '유아의류상의'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['유아스킨/바디케어', '유아동속옷'], dtype=object),
#  array(['남성속옷', '헤어케어', '스킨케어'], dtype=object),
#  array(['수유/이유용품'], dtype=object),
#  array(['여성의류하의'], dtype=object),
#  array(['여성등산/아웃도어의류'], dtype=object),
#  array(['수영/물놀이', '성인침구', '유아동일반스포츠의류', '유아동스포츠화', '유아동화', '유아동침구',
#         '유아의류상의', '유아동속옷', '남아의류하의', '조리기구', '향수'], dtype=object),
#  array(['여성화', '남성의류하의', '남성의류상의', '성인침구'], dtype=object),
#  array(['바디케어', '남성의류상의', '남성의류하의', '여성화', '이미용가전'], dtype=object),
#  array(['메이크업', '남성의류상의', '남성일반스포츠의류', '여성일반스포츠의류', '성인침구', '스포츠잡화',
#         '남성등산/아웃도어의류', '여성속옷', '여성의류상의', '여성등산/아웃도어의류', '남성스포츠화', '스킨케어',
#         '일반문구/사무용품', '수영/물놀이', '영양제'], dtype=object),
#  array(['유아동스포츠화'], dtype=object),
#  array(['여성화'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['남성등산/아웃도어의류'], dtype=object),
#  array(['구강케어', '세탁세제'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['여성의류하의', '여성의류상의'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['유아동스포츠화'], dtype=object),
#  array(['여성의류하의', '자동차음향/가전기기'], dtype=object),
#  array(['이미용가전'], dtype=object),
#  array(['여성의류하의', '여성의류아우터', '남성의류상의', '여성의류상의', '메이크업', '미용소품', '스킨케어',
#         '유아스킨/바디케어', '여성의류전신', '수영/물놀이', '여아완구', '보석', '유아위생용품'],
#        dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['주방정리용품/소모품', '남성의류상의', '스킨케어', '스포츠잡화', '남성속옷', '여성의류상의'],
#        dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['모바일상품권', '여성의류상의'], dtype=object),
#  array(['유아동화'], dtype=object),
#  array(['여성의류상의', '여성의류하의', '남성의류상의', '여성의류전신', '여성속옷', '보석', '여성화',
#         '성인침구', '밀폐/보관용기'], dtype=object),
#  array(['메이크업', '유아스킨/바디케어', '수유/이유용품', '유아위생용품', '스킨케어', '고양이용품', '냉동간편식',
#         '남성의류하의', '건강진액', '남성의류상의', '유아동속옷'], dtype=object),
#  array(['여성화'], dtype=object),
#  array(['남성의류상의', '향수', '남성등산/아웃도어의류', '안경/선글라스'], dtype=object),
#  array(['여성스포츠화', '남아의류상의'], dtype=object),
#  array(['남성의류상의', '여성의류전신', '여성의류하의'], dtype=object),
#  array(['수유/이유용품', '유아발육용품'], dtype=object),
#  array(['여성의류전신', '수영/물놀이', '보석', '여성화', '남성지갑'], dtype=object),
#  array(['남성스포츠화'], dtype=object),
#  array(['남성스포츠화'], dtype=object),
#  array(['수영/물놀이', '남아의류세트'], dtype=object),
#  array(['남아의류하의', '스킨케어', '유아의류상의', '남성케어'], dtype=object),
#  array(['유아의류상의'], dtype=object),
#  array(['유아스킨/바디케어'], dtype=object),
#  array(['스킨케어', '선케어', '여성화'], dtype=object),
#  array(['여성의류상의', '여성의류하의'], dtype=object),
#  array(['남성일반스포츠의류'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['유아동화', '여아의류상의', '유아의류전신', '유아의류상의', '모자'], dtype=object),
#  array(['여성의류전신', '남성의류상의', '메이크업', '여성의류하의', '스킨케어', '건강진액'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['남성의류상의', '여성속옷'], dtype=object),
#  array(['여성의류하의', '여성의류아우터', '남성골프의류', '여성골프의류', '여성의류상의', '여성의류전신'],
#        dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['수영/물놀이', '여성화', '유아동화', '모자'], dtype=object),
#  array(['향수'], dtype=object),
#  array(['스킨케어', '냉방가전'], dtype=object),
#  array(['남성의류상의', '여성화', '여성속옷', '국산과일', '메이크업', '포장반찬', '남성의류하의', '성인침구',
#         '유아의류상의', '그릇/식기', '여아의류하의', '세탁기', '여성의류하의'], dtype=object),
#  array(['선케어', '여성속옷', '스킨케어'], dtype=object),
#  array(['헤어케어', '모바일상품권'], dtype=object),
#  array(['피트니스'], dtype=object),
#  array(['애견용품', '여성의류상의', '여성의류하의'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['여성양말류', '여성화'], dtype=object),
#  array(['여성의류전신', '여성지갑'], dtype=object),
#  array(['건강보조식품', '건강진액', '생수'], dtype=object),
#  array(['여성속옷'], dtype=object),
#  array(['스킨케어', '메이크업', '바디케어', '여성의류상의'], dtype=object),
#  array(['헤어케어'], dtype=object),
#  array(['조리도구'], dtype=object),
#  array(['여성속옷'], dtype=object),
#  array(['구강케어', '여성양말류', '남성케어', '기능성음료', '유아위생용품', '남성의류상의', '유아동양말류'],
#        dtype=object),
#  array(['유아동스포츠화', '남성의류하의'], dtype=object),
#  array(['보석', '여성화'], dtype=object),
#  array(['남성의류상의', '여성의류상의'], dtype=object),
#  array(['메이크업', '스킨케어'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['여성속옷'], dtype=object),
#  array(['일반문구/사무용품', '유아동속옷', '유아동양말류', '성인침구', '수예소품', '남아의류상의', '기능성음료',
#         '여아의류상의', '컴퓨터주변기기', '조리도구'], dtype=object),
#  array(['여성속옷'], dtype=object),
#  array(['유아의류상의', '남아의류하의'], dtype=object),
#  array(['헤어케어'], dtype=object),
#  array(['남성스포츠화'], dtype=object),
#  array(['세탁세제'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['남성의류상의', '남성일반스포츠의류'], dtype=object),
#  array(['수영/물놀이', '생수'], dtype=object),
#  array(['남아의류세트'], dtype=object),
#  array(['여성일반스포츠의류', '메이크업', '여성지갑', '여성의류상의', '남성의류상의'], dtype=object),
#  array(['남성케어', '스킨케어', '수영/물놀이', '냉방가전'], dtype=object),
#  array(['남성의류상의', '여성의류전신'], dtype=object),
#  array(['여아의류상의', '여성양말류', '그릇/식기', '스킨케어', '메이크업', '유아동속옷', '남성의류상의',
#         '유아의류하의'], dtype=object),
#  array(['남성양말류', '밀폐/보관용기'], dtype=object),
#  array(['구강케어', '여아의류상의'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['남성지갑'], dtype=object),
#  array(['여성의류상의'], dtype=object),
#  array(['수영/물놀이', '남성의류하의', '남성의류상의'], dtype=object),
#  array(['여성화'], dtype=object),
#  array(['여성의류전신', '등산', '여성스포츠화', '스킨케어', '골프', '여성화'], dtype=object),
#  array(['수예소품'], dtype=object),
#  array(['여성의류상의', '메이크업', '스킨케어', '미용소품'], dtype=object),
#  array(['유아의류전신', '여아의류상의'], dtype=object),
#  array(['유아동화', '여아의류하의', '여아의류상의'], dtype=object),
#  array(['홍삼/인삼가공식품', '생수'], dtype=object),
#  array(['헤어케어'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['스포츠잡화', '남성케어', '우산/양산류', '여성의류상의', '수영/물놀이', '여성의류하의', '여성의류전신',
#         '유아스킨/바디케어'], dtype=object),
#  array(['스킨케어', '수영/물놀이', '남성스포츠화', '남성케어'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['유아동침구', '유아동일반스포츠의류', '여성의류하의', '여성의류전신'], dtype=object),
#  array(['여성가방', '여성속옷'], dtype=object),
#  array(['견과류', '여성의류상의'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['여성의류하의'], dtype=object),
#  array(['여성일반스포츠의류'], dtype=object),
#  array(['메이크업', '스킨케어', '남성케어'], dtype=object),
#  array(['여아의류하의', '모자'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['남성골프의류'], dtype=object),
#  array(['바디케어'], dtype=object),
#  array(['남성골프의류', '남성일반스포츠의류', '여성일반스포츠의류', '남성등산/아웃도어의류', '남성의류아우터'],
#        dtype=object),
#  array(['수영/물놀이', '우산/양산류', '스킨케어'], dtype=object),
#  array(['남성스포츠화', '남성의류하의', '이미용가전'], dtype=object),
#  array(['수영/물놀이', '애견용품'], dtype=object),
#  array(['유아의류하의', '남아완구', '바디케어', '필기도구', '교육완구', '여아의류상의', '유아위생용품',
#         '일반문구/사무용품'], dtype=object),
#  array(['여성일반스포츠의류', '여성화'], dtype=object),
#  array(['스킨케어', '선케어', '바디케어'], dtype=object),
#  array(['유아동화'], dtype=object),
#  array(['향수', '메이크업'], dtype=object),
#  array(['여성의류상의', '필기도구', '남아의류세트', '남성의류상의', '영양제', '여아의류상의', '교육완구',
#         '유아의류상의', '유아동일반스포츠의류', '패션액세서리', '그릇/식기', '여아의류하의', '남성지갑',
#         '여성스포츠화'], dtype=object),
#  array(['모바일기기'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['수영/물놀이', '남성등산/아웃도어의류', '등산'], dtype=object),
#  array(['여성지갑', '남성속옷', '남성일반스포츠의류'], dtype=object),
#  array(['바디케어'], dtype=object),
#  array(['남아의류세트', '유아동일반스포츠의류', '남아의류상의', '남성일반스포츠의류', '유아동화', '남성가방'],
#        dtype=object),
#  array(['유아동스포츠화', '남아의류세트', '유아동화', '수영/물놀이', '유아의류상의'], dtype=object),
#  array(['남성의류상의', '여성골프의류', '남아의류하의'], dtype=object),
#  array(['남성의류상의', '모자', '남성일반스포츠의류', '여성가방'], dtype=object),
#  array(['유아의류하의', '남성의류상의', '여아의류하의', '여성의류하의', '남성의류하의'], dtype=object),
#  array(['주방가전'], dtype=object),
#  array(['영양제', '홍삼/인삼가공식품'], dtype=object),
#  array(['여성의류상의'], dtype=object),
#  array(['보석'], dtype=object),
#  array(['유아의류하의', '여성의류하의', '여아의류상의', '여성의류상의', '여성속옷'], dtype=object),
#  array(['여성속옷', '여성화'], dtype=object),
#  array(['그릇/식기'], dtype=object),
#  array(['메이크업', '조리도구', '안경/선글라스', '밀폐/보관용기', '여성화', '건강보조식품', '여성속옷',
#         '우산/양산류'], dtype=object),
#  array(['남성의류하의'], dtype=object),
#  array(['수영/물놀이', '유아의류하의', '여아의류상의', '남성등산/아웃도어의류', '여성등산/아웃도어의류'],
#        dtype=object),
#  array(['여성지갑', '여성의류상의'], dtype=object),
#  array(['유아스킨/바디케어'], dtype=object),
#  array(['여성의류하의'], dtype=object),
#  array(['스킨케어', '건강보조식품', '선케어', '바디케어', '영양제', '메이크업'], dtype=object),
#  array(['유아동속옷', '수유/이유용품'], dtype=object),
#  array(['구강케어'], dtype=object),
#  array(['생수', '화장지/티슈'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['남성일반스포츠의류', '골프'], dtype=object),
#  array(['여성의류전신', '여성화', '여성일반스포츠의류', '여성의류아우터', '여성의류상의', '여성양말류',
#         '남성의류하의', '바디케어', '여성의류하의', '남성의류상의', '견과류', '피트니스', '스킨케어',
#         '패션액세서리', '우산/양산류', '그릇/식기'], dtype=object),
#  array(['유아동속옷', '유아동화'], dtype=object),
#  array(['남성의류하의'], dtype=object),
#  array(['스포츠잡화', '유아동일반스포츠의류', '유아의류전신', '유아의류하의', '여아의류상의', '여성골프의류',
#         '유아동스포츠화'], dtype=object),
#  array(['여성의류상의'], dtype=object),
#  array(['여성의류상의', '영양제'], dtype=object),
#  array(['유아위생용품', '기능성음료'], dtype=object),
#  array(['스킨케어', '유아스킨/바디케어'], dtype=object),
#  array(['남성의류하의', '바디케어'], dtype=object),
#  array(['영양제', '유아의류전신'], dtype=object),
#  array(['스킨케어', '메이크업'], dtype=object),
#  array(['수유/이유용품'], dtype=object),
#  array(['여성일반스포츠의류', '여성스포츠화'], dtype=object),
#  array(['모바일상품권'], dtype=object),
#  array(['여성위생용품', '여성의류전신'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['수유/이유용품'], dtype=object),
#  array(['유아동속옷'], dtype=object),
#  array(['모자', '여성골프의류', '여성의류상의', '여성속옷', '여성양말류', '골프', '여성의류아우터',
#         '일반문구/사무용품', '생수', '여성화', '여성의류하의', '남성가방', '남성일반스포츠의류', '메이크업',
#         '수영/물놀이', '스킨케어', '홍삼/인삼가공식품', '여성의류전신', '여성가방'], dtype=object),
#  array(['홈웨어', '유아의류상의', '여성양말류'], dtype=object),
#  array(['남성케어'], dtype=object),
#  array(['닭고기류'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['메이크업', '스킨케어'], dtype=object),
#  array(['유아동침구'], dtype=object),
#  array(['스킨케어', '여아의류상의', '남성의류상의', '미용소품'], dtype=object),
#  array(['유아동속옷', '남성스포츠화'], dtype=object),
#  array(['남성스포츠화'], dtype=object),
#  array(['시계', '헤어케어'], dtype=object),
#  array(['홍삼/인삼가공식품', '남성스포츠화', '여아의류하의'], dtype=object),
#  array(['유아의류아우터', '유아의류상의', '남아의류하의'], dtype=object),
#  array(['모자'], dtype=object),
#  array(['유아의류전신', '남아의류세트', '유아의류상의', '여아의류상의'], dtype=object),
#  array(['여성일반스포츠의류'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['유아의류하의'], dtype=object),
#  array(['여성등산/아웃도어의류'], dtype=object),
#  array(['여성속옷'], dtype=object),
#  array(['여성가방', '스킨케어', '여성속옷', '여성스포츠화', '메이크업'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['남성의류상의', '여성일반스포츠의류', '스포츠잡화', '여성화', '남성의류아우터', '여성의류하의',
#         '여성의류상의'], dtype=object),
#  array(['여성의류상의', '세탁세제', '여성의류전신', '여성의류하의'], dtype=object),
#  array(['남성의류상의', '핸드/풋케어'], dtype=object),
#  array(['수영/물놀이', '메이크업', '욕실용품'], dtype=object),
#  array(['여성의류아우터', '남성의류상의', '향수', '여성의류하의', '필기도구'], dtype=object),
#  array(['메이크업', '안경/선글라스', '헤어케어', '패션액세서리'], dtype=object),
#  array(['남성스포츠화', '유아발육용품', '남성케어'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['남성의류상의', '남성의류하의', '시계', '남성일반스포츠의류'], dtype=object),
#  array(['여성의류하의', '여성스포츠화'], dtype=object),
#  array(['기능성음료'], dtype=object),
#  array(['유아의류상의', '스킨케어'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['보석'], dtype=object),
#  array(['여성화', '여성의류하의', '남성의류상의', '여성지갑', '남성의류하의'], dtype=object),
#  array(['여성의류하의'], dtype=object),
#  array(['영양제', '남성속옷', '여성스포츠화'], dtype=object),
#  array(['모바일액세서리'], dtype=object),
#  array(['남성일반스포츠의류'], dtype=object),
#  array(['여성의류전신'], dtype=object),
#  array(['스킨케어', '여성화', '시계', '골프', '여성의류상의', '메이크업', '우산/양산류', '안경/선글라스',
#         '여성의류아우터', '남성케어', '여성의류하의', '여성가방', '헤어케어', '유아동화'], dtype=object),
#  array(['메이크업', '패션액세서리', '유아동양말류'], dtype=object),
#  array(['여성화', '여성의류상의', '남성일반스포츠의류', '그릇/식기', '조리도구', '여성지갑', '여성골프의류',
#         '여성의류전신'], dtype=object),
#  array(['여성지갑'], dtype=object),
#  array(['수유/이유용품', '유아동스포츠화', '유아동화'], dtype=object),
#  array(['유아동화', '여아의류상의', '유아의류상의', '여아의류하의'], dtype=object),
#  array(['남성스포츠화'], dtype=object),
#  array(['여아완구'], dtype=object),
#  array(['남아완구'], dtype=object),
#  array(['여성속옷'], dtype=object),
#  array(['남성의류상의', '스킨케어'], dtype=object),
#  array(['여성속옷', '여성스포츠화'], dtype=object),
#  array(['스킨케어', '향수', '화장지/티슈', '남성속옷', '바디케어'], dtype=object),
#  array(['향수', '바디케어', '핸드/풋케어'], dtype=object),
#  array(['수영/물놀이', '유아동화', '주방가전'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['냉동간편식'], dtype=object),
#  array(['두유'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['스킨케어', '유아동스포츠화', '여성화', '여성의류상의', '여성의류전신', '유아동화', '여성의류하의'],
#        dtype=object),
#  array(['유아동화'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['여성스포츠화', '남성스포츠화'], dtype=object),
#  array(['남성스포츠화'], dtype=object),
#  array(['그릇/식기', '여성일반스포츠의류', '이미용가전', '남성의류상의', '여성화', '향수', '남성의류하의',
#         '남성일반스포츠의류', '스킨케어', '우산/양산류', '바디케어'], dtype=object),
#  array(['골프'], dtype=object),
#  array(['여성의류하의', '남성케어', '스킨케어'], dtype=object),
#  array(['여성속옷', '여성양말류'], dtype=object),
#  array(['남성의류상의', '메이크업', '여성의류하의'], dtype=object),
#  array(['여성의류하의', '여성화'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['여성스포츠화', '여성양말류'], dtype=object),
#  array(['골프', '수영/물놀이', '남성일반스포츠의류', '수유/이유용품'], dtype=object),
#  array(['모자'], dtype=object),
#  array(['유아동양말류'], dtype=object),
#  array(['성인침구'], dtype=object),
#  array(['여성의류상의', '스킨케어'], dtype=object),
#  array(['등산', '성인침구', '여성의류상의'], dtype=object),
#  array(['여성의류전신', '수영/물놀이', '남성의류상의'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['고양이용품'], dtype=object),
#  array(['여성의류상의'], dtype=object),
#  array(['남성의류상의', '남성등산/아웃도어의류'], dtype=object),
#  array(['여성의류상의'], dtype=object),
#  array(['수유/이유용품'], dtype=object),
#  array(['포장반찬', '여성화'], dtype=object),
#  array(['바디케어', '핸드/풋케어', '헤어케어'], dtype=object),
#  array(['여성화'], dtype=object),
#  array(['생수', '여성스포츠화', '주방가전', '남성속옷', '캠핑', '밀폐/보관용기', '유아위생용품'],
#        dtype=object),
#  array(['패션액세서리', '스킨케어', '홈웨어'], dtype=object),
#  array(['여성의류하의', '여성의류상의'], dtype=object),
#  array(['여성의류상의', '여성의류전신'], dtype=object),
#  array(['남성의류아우터', '남성의류상의'], dtype=object),
#  array(['남성의류하의'], dtype=object),
#  array(['여성의류아우터'], dtype=object),
#  array(['여성의류상의', '홍삼/인삼가공식품'], dtype=object),
#  array(['남성스포츠화'], dtype=object),
#  array(['여성화', '여성의류전신'], dtype=object),
#  array(['성인침구', '남성의류하의', '유아의류하의', '남아완구', '남아의류하의', '바디케어', '컴퓨터주변기기',
#         '밀폐/보관용기', '핸드/풋케어', '유아동화', '남성양말류'], dtype=object),
#  array(['유아동속옷', '남성의류상의', '남성등산/아웃도어의류', '홈웨어'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['유아의류상의', '여성의류아우터', '남아의류하의', '남성의류상의', '여성화', '모자', '남성스포츠화',
#         '밀폐/보관용기', '남아의류세트'], dtype=object),
#  array(['여성화'], dtype=object),
#  array(['바디케어'], dtype=object),
#  array(['메이크업', '밀폐/보관용기', '여성양말류', '스킨케어', '바디케어', '컴퓨터주변기기', '보석',
#         '유아의류상의', '유아동양말류'], dtype=object),
#  array(['구강케어', '포장반찬', '남성의류하의', '애견용품', '세탁세제'], dtype=object),
#  array(['수영/물놀이', '여아의류상의', '유아동속옷', '유아동화', '유아의류하의', '여아의류하의', '모바일액세서리',
#         '여성의류상의', '유아의류상의'], dtype=object),
#  array(['생수', '모바일액세서리', '남성의류상의', '일반문구/사무용품'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['생수', '유아발육용품', '스킨케어'], dtype=object),
#  array(['메이크업', '스킨케어'], dtype=object),
#  array(['유아동속옷', '헤어케어', '유아동양말류', '여성의류전신', '스킨케어'], dtype=object),
#  array(['여성일반스포츠의류', '조리기구'], dtype=object),
#  array(['유아의류상의', '유아동양말류', '남성의류상의', '여아의류상의'], dtype=object),
#  array(['미용소품', '메이크업'], dtype=object),
#  array(['남성의류상의', '여성화', '유아동일반스포츠의류', '유아의류하의', '여아의류아우터', '캠핑', '유아의류전신',
#         '유아동화', '밀폐/보관용기', '여성의류하의'], dtype=object),
#  array(['스킨케어', '메이크업'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['메이크업', '유아동화', '유아동스포츠화', '패션액세서리', '조리기구'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['여성스포츠화', '남아의류세트', '향수'], dtype=object),
#  array(['홍삼/인삼가공식품'], dtype=object),
#  array(['여성의류하의'], dtype=object),
#  array(['여아의류상의', '남아의류상의'], dtype=object),
#  array(['남성의류아우터'], dtype=object),
#  array(['여성양말류'], dtype=object),
#  array(['여성화', '남성등산/아웃도어의류', '컴퓨터주변기기', '여아의류상의', '스킨케어', '여성의류하의',
#         '피트니스', '유아의류하의', '캠핑', '욕실용품', '모자', '여성의류상의', '여아의류하의', '유아의류전신',
#         '여성가방', '메이크업', '영양제', '남아의류하의', '유아동속옷', '여성속옷', '유아동스포츠화',
#         '남성의류상의', '여성양말류'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['여성속옷'], dtype=object),
#  array(['스킨케어', '여성일반스포츠의류'], dtype=object),
#  array(['여성일반스포츠의류', '미용소품', '여성가방', '필기도구'], dtype=object),
#  array(['남아의류하의', '미용소품', '여성화', '유아의류상의', '유아의류하의', '남아의류상의'],
#        dtype=object),
#  array(['여성의류상의', '메이크업', '여성속옷'], dtype=object),
#  array(['세탁세제', '여성골프의류'], dtype=object),
#  array(['유아동스포츠화'], dtype=object),
#  array(['여성의류하의', '여성의류전신'], dtype=object),
#  array(['스킨케어', '미용소품'], dtype=object),
#  array(['스킨케어', '메이크업', '헤어케어'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['스킨케어', '여성의류전신', '여성화', '미용소품', '메이크업', '여성등산/아웃도어의류', '스포츠잡화',
#         '여성의류상의'], dtype=object),
#  array(['캐쥬얼가방'], dtype=object),
#  array(['남성일반스포츠의류', '스포츠잡화'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['남성스포츠화', '여성속옷'], dtype=object),
#  array(['여성의류상의', '여성의류하의', '여성의류전신'], dtype=object),
#  array(['밀폐/보관용기'], dtype=object),
#  array(['청소기', '스킨케어', '여성의류상의', '여성등산/아웃도어의류'], dtype=object),
#  array(['침실가구'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['일반문구/사무용품', '여성골프의류', '여성의류상의', '애견용품', '여성등산/아웃도어의류', '여성가방',
#         '남성일반스포츠의류', '영양제', '여성일반스포츠의류', '수영/물놀이', '남성등산/아웃도어의류', '생수',
#         '두유', '남성의류상의', '여성화'], dtype=object),
#  array(['유아의류상의'], dtype=object),
#  array(['홍삼/인삼가공식품'], dtype=object),
#  array(['주방정리용품/소모품', '스킨케어', '여성스포츠화', '홍삼/인삼가공식품', '정리용품'], dtype=object),
#  array(['메이크업', '선케어'], dtype=object),
#  array(['여성화', '견과류'], dtype=object),
#  array(['여성일반스포츠의류'], dtype=object),
#  array(['남성스포츠화'], dtype=object),
#  array(['남성의류상의', '여성속옷'], dtype=object),
#  array(['스포츠잡화', '패션액세서리', '수유/이유용품', '유아동스포츠화', '유아위생용품'], dtype=object),
#  array(['향수'], dtype=object),
#  array(['남아의류하의', '여아의류아우터', '유아의류상의', '유아의류아우터'], dtype=object),
#  array(['여성의류상의', '남성의류상의', '남아의류상의', '여아의류상의', '여성의류하의', '생수', '남아의류세트',
#         '피트니스', '수영/물놀이', '화장지/티슈', '남성스포츠화', '스포츠잡화', '여성일반스포츠의류', '바디케어'],
#        dtype=object),
#  array(['생수', '교육완구'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['바디케어'], dtype=object),
#  array(['수영/물놀이', '남성일반스포츠의류'], dtype=object),
#  array(['유아의류하의', '여아의류상의'], dtype=object),
#  array(['남성스포츠화', '여성스포츠화'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['캐쥬얼가방'], dtype=object),
#  array(['남성의류상의', '교육완구', '유아발육용품', '유아동양말류', '남성의류하의', '핸드/풋케어', '유아의류상의',
#         '미용소품', '캠핑', '모자', '조리도구', '거실가구', '유아위생용품', '유아의류전신'],
#        dtype=object),
#  array(['보석', '남아의류하의'], dtype=object),
#  array(['여성골프의류'], dtype=object),
#  array(['남성케어'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['메이크업', '스킨케어'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['여성의류상의'], dtype=object),
#  array(['홍삼/인삼가공식품'], dtype=object),
#  array(['남성의류하의'], dtype=object),
#  array(['스킨케어', '생수'], dtype=object),
#  array(['밀폐/보관용기', '여성의류전신', '메이크업'], dtype=object),
#  array(['골프', '향수', '남성골프의류', '여성속옷', '여성일반스포츠의류', '여성골프의류', '수영/물놀이',
#         '여성스포츠화'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['스킨케어', '메이크업'], dtype=object),
#  array(['남성속옷', '메이크업', '유아의류상의', '유아동화', '남아의류하의', '유아동양말류'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['유아위생용품', '여성의류상의', '세탁세제', '유아의류전신', '유아동양말류', '수영/물놀이', '여아의류상의',
#         '여아의류하의', '모자', '교육완구', '남성속옷', '유아동화'], dtype=object),
#  array(['스킨케어', '영양제'], dtype=object),
#  array(['남성일반스포츠의류'], dtype=object),
#  array(['수예소품'], dtype=object),
#  array(['수영/물놀이'], dtype=object),
#  array(['여성속옷'], dtype=object),
#  array(['유아동화', '여성화', '남성등산/아웃도어의류'], dtype=object),
#  array(['남성일반스포츠의류', '남성의류상의', '시계', '우산/양산류'], dtype=object),
#  array(['여성의류상의', '남성의류상의', '스포츠잡화'], dtype=object),
#  array(['여성골프의류', '여성일반스포츠의류', '유아스킨/바디케어', '침실가구', '견과류', '남성의류아우터',
#         '영양제', '화장지/티슈', '여성양말류', '여성속옷', '여성등산/아웃도어의류', '모바일액세서리', '헤어케어',
#         '여성의류하의'], dtype=object),
#  array(['홈웨어', '수유/이유용품', '남성지갑', '남성의류상의', '여성지갑', '주방가전', '여성의류전신'],
#        dtype=object),
#  array(['유아의류상의', '홍삼/인삼가공식품', '바디케어', '메이크업', '유아의류하의', '보석'],
#        dtype=object),
#  array(['홍삼/인삼가공식품', '유아동스포츠화'], dtype=object),
#  array(['수영/물놀이', '여성일반스포츠의류'], dtype=object),
#  array(['남성의류상의', '수영/물놀이'], dtype=object),
#  array(['일반문구/사무용품', '여성등산/아웃도어의류', '모바일액세서리'], dtype=object),
#  array(['메이크업'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['여성스포츠화'], dtype=object),
#  array(['유아발육용품', '여성위생용품', '유아의류상의', '수유/이유용품'], dtype=object),
#  array(['모바일액세서리', '메이크업', '미용소품', '헤어케어', '여성의류하의'], dtype=object),
#  array(['유아동스포츠화', '모자'], dtype=object),
#  array(['모바일상품권'], dtype=object),
#  array(['여성의류전신', '여성의류하의', '유아동스포츠화'], dtype=object),
#  array(['남성화', '남아의류상의', '선케어', '유아동속옷', '남아의류세트'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['바디케어', '스킨케어'], dtype=object),
#  array(['인라인/스케이트보드/킥보드', '시계', '남아완구', '교육완구', '여성지갑', '주방가전', '등산'],
#        dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['헤어케어'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['여성가방', '여성지갑', '스포츠잡화'], dtype=object),
#  array(['여성양말류'], dtype=object),
#  array(['영양제', '스킨케어'], dtype=object),
#  array(['여성의류상의'], dtype=object),
#  array(['여성화'], dtype=object),
#  array(['향수'], dtype=object),
#  array(['유아동스포츠화'], dtype=object),
#  array(['남성의류상의', '남성케어', '남성스포츠화', '스킨케어', '여성의류아우터', '여성화'], dtype=object),
#  array(['여성의류상의'], dtype=object),
#  array(['메이크업', '남성화', '남성의류상의', '유아동스포츠화', '유아스킨/바디케어'], dtype=object),
#  array(['스킨케어', '남성케어'], dtype=object),
#  array(['두유'], dtype=object),
#  array(['여성지갑', '여성가방'], dtype=object),
#  array(['여성의류하의'], dtype=object),
#  array(['수영/물놀이', '유아의류상의', '남아의류하의'], dtype=object),
#  array(['남성케어', '스킨케어', '헤어케어'], dtype=object),
#  array(['피트니스'], dtype=object),
#  array(['등산', '여성등산/아웃도어의류', '커튼/블라인드류', '일반문구/사무용품', '남성속옷', '스포츠잡화'],
#        dtype=object),
#  array(['스킨케어', '메이크업'], dtype=object),
#  array(['남성의류상의', '모바일액세서리', '냉방가전'], dtype=object),
#  array(['욕실용품', '남성속옷', '정리용품', '청소기'], dtype=object),
#  array(['여성의류상의', '여성화', '스킨케어', '조리기구', '홍삼/인삼가공식품', '여성스포츠화'],
#        dtype=object),
#  array(['수예소품', '여성속옷', '그릇/식기', '정리용품'], dtype=object),
#  array(['여성화'], dtype=object),
#  array(['캐쥬얼가방', '유아의류아우터'], dtype=object),
#  array(['여성의류상의', '헤어케어', '세탁세제'], dtype=object),
#  array(['유아동속옷', '수유/이유용품', '일반문구/사무용품'], dtype=object),
#  array(['남성골프의류'], dtype=object),
#  array(['스킨케어'], dtype=object),
#  array(['메이크업', '여성일반스포츠의류'], dtype=object),
#  array(['메이크업', '유아동속옷'], dtype=object),
#  array(['메이크업', '홈웨어'], dtype=object),
#  array(['헤어케어', '두유'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['구강케어', '안경/선글라스'], dtype=object),
#  array(['여성의류전신', '포장반찬', '남성의류상의'], dtype=object),
#  array(['여성의류상의', '여성의류하의'], dtype=object),
#  array(['남성의류상의'], dtype=object),
#  array(['수유/이유용품'], dtype=object),
#  array(['남성의류상의', '여성가방', '남성일반스포츠의류'], dtype=object),
#  ...]

# %%
train['PD_C'] = train['PD_C'].astype(str)
test['PD_C'] = test['PD_C'].astype(str)

# %%
train_data7 = list(train.groupby('CLNT_ID')['PD_C'].unique())
test_data7 = list(test.groupby('CLNT_ID')['PD_C'].unique())
train_data7
# Out:
# [array(['578845', '788068'], dtype=object),
#  array(['180447', '731145', '216947', '491876', '1965', '457181', '190233',
#         '236174'], dtype=object),
#  array(['248358', '506359', '506337', '554217'], dtype=object),
#  array(['436275', '578537'], dtype=object),
#  array(['536257', '141349', '535684', '75955', '29069', '41283', '489942',
#         '760527', '233182', '178471', '64916', '535442', '535601', '64933',
#         '72185', '102618'], dtype=object),
#  array(['809170'], dtype=object),
#  array(['837392'], dtype=object),
#  array(['765673', '660999', '804'], dtype=object),
#  array(['375713', '133407', '742158', '742089', '484590', '641183',
#         '68947', '842488', '225207'], dtype=object),
#  array(['682061'], dtype=object),
#  array(['569802', '832202', '221420'], dtype=object),
#  array(['826313'], dtype=object),
#  array(['276275', '140325'], dtype=object),
#  array(['694453', '811116', '585440'], dtype=object),
#  array(['700995'], dtype=object),
#  array(['7893', '733585', '185099', '722909', '611777'], dtype=object),
#  array(['425921', '499940', '549195'], dtype=object),
#  array(['220714', '218301'], dtype=object),
#  array(['626454'], dtype=object),
#  array(['473112', '739681', '746888', '657620', '478990'], dtype=object),
#  array(['676622'], dtype=object),
#  array(['685372', '186166'], dtype=object),
#  array(['455026', '454153', '839324', '523581', '397797', '594883',
#         '836917', '689380'], dtype=object),
#  array(['714091', '554220', '255735', '255805'], dtype=object),
#  array(['841644', '530357', '550764', '217166', '207163', '783266',
#         '733465', '310728', '841642', '634905', '111788', '798665',
#         '740039', '155106', '793821', '498418', '265906', '717107',
#         '789521', '209960', '369827', '412912', '352717', '772781',
#         '664328', '520714', '448099', '315356', '621557', '242314'],
#        dtype=object),
#  array(['577673'], dtype=object),
#  array(['332489', '221077', '339653', '360023'], dtype=object),
#  array(['164956'], dtype=object),
#  array(['217672'], dtype=object),
#  array(['825162', '210784'], dtype=object),
#  array(['657088', '807682'], dtype=object),
#  array(['812803'], dtype=object),
#  array(['782362'], dtype=object),
#  array(['624221'], dtype=object),
#  array(['750564', '427373', '159530', '600643', '659195', '5609', '809732',
#         '744190', '314843', '1965', '117061', '72033', '6353', '500350',
#         '651086', '777470', '261331', '406787', '151256'], dtype=object),
#  array(['323680'], dtype=object),
#  array(['696708', '818129'], dtype=object),
#  array(['377510', '736885', '107273', '274604', '149519', '119734'],
#        dtype=object),
#  array(['814520', '418525'], dtype=object),
#  array(['742656'], dtype=object),
#  array(['176758', '193137', '448598'], dtype=object),
#  array(['665779', '222', '812291', '199507'], dtype=object),
#  array(['595905'], dtype=object),
#  array(['431974', '480855', '234515', '417612', '589529', '635789'],
#        dtype=object),
#  array(['402421'], dtype=object),
#  array(['21386', '59919', '59915', '45864', '42760', '788073', '24286'],
#        dtype=object),
#  array(['237980', '279738'], dtype=object),
#  array(['830988', '831995'], dtype=object),
#  array(['657509'], dtype=object),
#  array(['599806'], dtype=object),
#  array(['520208', '678491', '328975', '225011', '704761'], dtype=object),
#  array(['331305', '236745', '331313', '331315', '325462', '754008',
#         '525734', '316297', '234321'], dtype=object),
#  array(['552345', '809795'], dtype=object),
#  array(['826313'], dtype=object),
#  array(['656134'], dtype=object),
#  array(['482240'], dtype=object),
#  array(['224538', '190919', '264638'], dtype=object),
#  array(['705025', '526416', '488965', '353082', '484753', '673029'],
#        dtype=object),
#  array(['668377', '668381', '203849'], dtype=object),
#  array(['847487'], dtype=object),
#  array(['624244'], dtype=object),
#  array(['130018'], dtype=object),
#  array(['391390'], dtype=object),
#  array(['305827', '439597', '844427'], dtype=object),
#  array(['742356'], dtype=object),
#  array(['614387'], dtype=object),
#  array(['347882', '417009'], dtype=object),
#  array(['703034', '684955', '833340', '484185', '384940', '741257',
#         '524284', '230466', '425801', '248687', '465628', '528909',
#         '843603', '801330', '188144', '823839'], dtype=object),
#  array(['672920'], dtype=object),
#  array(['248047', '838123'], dtype=object),
#  array(['773995', '464972', '773992'], dtype=object),
#  array(['846851'], dtype=object),
#  array(['469740', '580208'], dtype=object),
#  array(['778734'], dtype=object),
#  array(['667897', '522054', '742108'], dtype=object),
#  array(['89333', '40972'], dtype=object),
#  array(['214597'], dtype=object),
#  array(['835321', '627769', '771557', '17101', '17095', '17100', '179067',
#         '695935', '836099'], dtype=object),
#  array(['564962', '432361', '742269', '497067', '835143', '590408'],
#        dtype=object),
#  array(['1967', '1974'], dtype=object),
#  array(['415723', '789560', '789582', '273953', '588278', '218470',
#         '164930'], dtype=object),
#  array(['539083', '128079'], dtype=object),
#  array(['182425'], dtype=object),
#  array(['803165', '804957', '350387', '590047', '661770', '337522',
#         '337517', '350336', '340910', '98359', '589994', '215829',
#         '220490', '199326', '70943'], dtype=object),
#  array(['783193', '776237'], dtype=object),
#  array(['481452', '648696', '308641', '379286', '548654', '634550',
#         '298844', '584080', '525226'], dtype=object),
#  array(['377512', '132566', '835090', '345871'], dtype=object),
#  array(['793807', '214124'], dtype=object),
#  array(['589276', '786274', '798040'], dtype=object),
#  array(['840782', '827708'], dtype=object),
#  array(['556576', '556736', '556575', '786573'], dtype=object),
#  array(['839528', '787263', '774268', '793173', '787900', '795003',
#         '240984', '839518', '787901', '774271'], dtype=object),
#  array(['511275', '190234', '732222'], dtype=object),
#  array(['687109'], dtype=object),
#  array(['715428', '282505', '484979'], dtype=object),
#  array(['24736', '75417'], dtype=object),
#  array(['91765', '220251', '737516'], dtype=object),
#  array(['419017', '246686'], dtype=object),
#  array(['365338', '475039', '146717', '542723'], dtype=object),
#  array(['70388'], dtype=object),
#  array(['369894', '710881'], dtype=object),
#  array(['363761', '540267', '607801'], dtype=object),
#  array(['339928', '231953', '433158', '405531'], dtype=object),
#  array(['9622', '362816'], dtype=object),
#  array(['346349', '647567'], dtype=object),
#  array(['820596', '702687'], dtype=object),
#  array(['765348'], dtype=object),
#  array(['430918', '384838', '699485'], dtype=object),
#  array(['700083'], dtype=object),
#  array(['454775'], dtype=object),
#  array(['694510', '106165'], dtype=object),
#  array(['835536'], dtype=object),
#  array(['724248', '477852'], dtype=object),
#  array(['763182'], dtype=object),
#  array(['427529', '1555'], dtype=object),
#  array(['3627'], dtype=object),
#  array(['138127', '499565', '189112', '55505', '818150', '402455',
#         '226541', '499571'], dtype=object),
#  array(['398276', '751647', '422559'], dtype=object),
#  array(['62544', '812803', '20778', '80953', '54442', '616222', '398777',
#         '166466', '43168'], dtype=object),
#  array(['164222', '608512'], dtype=object),
#  array(['692709', '667520', '528952'], dtype=object),
#  array(['233088', '685637', '844451', '325784', '233093', '586706',
#         '232364', '808125', '610038', '231869', '471376', '116151',
#         '835793'], dtype=object),
#  array(['224479'], dtype=object),
#  array(['350816', '467676', '593242'], dtype=object),
#  array(['92054', '695295', '106313', '261184'], dtype=object),
#  array(['457338', '392975'], dtype=object),
#  array(['187406'], dtype=object),
#  array(['818235', '788184', '547987'], dtype=object),
#  array(['90726', '587688', '813725', '831581'], dtype=object),
#  array(['119440', '82412'], dtype=object),
#  array(['467056', '801428', '737381', '153479', '542721', '237334',
#         '723410', '732165', '654287', '817724', '606643', '461583',
#         '337679', '178427', '183546', '301060', '179311', '564444',
#         '369907', '704429', '466095'], dtype=object),
#  array(['576935', '648484'], dtype=object),
#  array(['26786', '26781'], dtype=object),
#  array(['170172', '783315'], dtype=object),
#  array(['325027'], dtype=object),
#  array(['427578'], dtype=object),
#  array(['92959', '39798', '10617', '22503'], dtype=object),
#  array(['746106', '448458', '662207', '338225', '358308', '339641',
#         '686956', '746637', '274520'], dtype=object),
#  array(['396880', '805342', '721493'], dtype=object),
#  array(['621954'], dtype=object),
#  array(['743591', '163986'], dtype=object),
#  array(['771158', '685591', '805287', '795994', '219950', '613327',
#         '143001', '221502', '686598'], dtype=object),
#  array(['77784', '70824', '44083', '62448', '831368'], dtype=object),
#  array(['571977', '346353', '427398', '239291', '802617', '1991', '319558',
#         '470374'], dtype=object),
#  array(['802533'], dtype=object),
#  array(['355423', '612430', '285225', '612192', '101236', '285226',
#         '514632', '225375', '397026', '451206', '361266', '180640'],
#        dtype=object),
#  array(['796170'], dtype=object),
#  array(['448112', '707723'], dtype=object),
#  array(['463914'], dtype=object),
#  array(['318514', '678593', '721593'], dtype=object),
#  array(['1965', '134109'], dtype=object),
#  array(['782256', '807086'], dtype=object),
#  array(['484066', '484021'], dtype=object),
#  array(['278269', '730248'], dtype=object),
#  array(['549163'], dtype=object),
#  array(['228969', '290962', '451855', '579504', '813584', '531745',
#         '84088', '538938', '673948', '339654', '637249', '236205',
#         '565534', '751437', '462370', '524623'], dtype=object),
#  array(['131621', '166295', '146757'], dtype=object),
#  array(['37591', '37589', '228819'], dtype=object),
#  array(['157438'], dtype=object),
#  array(['737833', '331291'], dtype=object),
#  array(['845920', '766109', '847340', '95376'], dtype=object),
#  array(['283474'], dtype=object),
#  array(['484910', '464142', '484914'], dtype=object),
#  array(['21527', '139318'], dtype=object),
#  array(['68262', '744813'], dtype=object),
#  array(['304719'], dtype=object),
#  array(['455203', '382491'], dtype=object),
#  array(['462218'], dtype=object),
#  array(['812355', '602936', '177621', '633165', '737465', '439241',
#         '638834', '745992', '100581', '600886', '295538', '737019',
#         '649639', '433922', '348994', '325866', '503810', '168943',
#         '793984', '288716', '398993', '602742', '185590', '737456',
#         '185451', '179794'], dtype=object),
#  array(['633205', '507445', '737108', '492100', '489573', '426460',
#         '643719'], dtype=object),
#  array(['381421', '498898', '86035'], dtype=object),
#  array(['8044', '584546', '737770', '457825', '514057', '351544', '189859',
#         '737744', '757621', '812389', '731144', '737753', '807229',
#         '296651', '273453', '588188', '248898', '813189', '838160',
#         '373139', '423749', '775255'], dtype=object),
#  array(['802474', '2574', '701460'], dtype=object),
#  array(['731231'], dtype=object),
#  array(['385727', '405952', '358419', '516983', '666218', '396146',
#         '333489', '462824', '286237'], dtype=object),
#  array(['587449', '803232', '143555', '263449', '141498', '741797',
#         '175170', '742014', '156769'], dtype=object),
#  array(['1959'], dtype=object),
#  array(['130354', '818172', '818170', '846851', '333607'], dtype=object),
#  array(['826962', '737200'], dtype=object),
#  array(['125314', '405643', '363078', '222557'], dtype=object),
#  array(['675999', '680819'], dtype=object),
#  array(['8781', '701610', '496043', '421603', '197538', '332857', '574687',
#         '574728', '347557', '196508', '303129', '127472', '563385',
#         '771558', '349862', '710755'], dtype=object),
#  array(['27493', '134810', '59137', '742702'], dtype=object),
#  array(['482531', '339054', '142758', '668157', '699665', '518765', '7010'],
#        dtype=object),
#  array(['792983', '637455'], dtype=object),
#  array(['812091', '736142'], dtype=object),
#  array(['5671', '763472', '791368', '719827', '800276'], dtype=object),
#  array(['156818', '156821'], dtype=object),
#  array(['678668', '334785', '62002', '379743', '63194', '279649', '174418',
#         '799721', '673660', '158936', '147650', '550249', '523074',
#         '732025', '268104', '653293', '255244', '232737', '689564',
#         '343289', '64438', '496201', '295663', '729276', '449614',
#         '810725'], dtype=object),
#  array(['681618', '513766', '688070', '470469', '824246', '98085',
#         '674014'], dtype=object),
#  array(['352123', '467361', '290426'], dtype=object),
#  array(['77621', '8143', '357620', '671211', '807545', '104938'],
#        dtype=object),
#  array(['446901', '462910', '450004'], dtype=object),
#  array(['456907', '539982', '594892', '684241', '705211', '547370'],
#        dtype=object),
#  array(['38078', '661752', '18096', '34901'], dtype=object),
#  array(['243436'], dtype=object),
#  array(['666769', '106113', '337126', '132486', '221243'], dtype=object),
#  array(['150551', '109616'], dtype=object),
#  array(['669572'], dtype=object),
#  array(['411683', '274759', '302954', '591447'], dtype=object),
#  array(['46814'], dtype=object),
#  array(['83872', '224211'], dtype=object),
#  array(['492664', '679395', '73461', '706836', '125551'], dtype=object),
#  array(['731144'], dtype=object),
#  array(['601039', '600923'], dtype=object),
#  array(['134168'], dtype=object),
#  array(['456811'], dtype=object),
#  array(['366070', '335108', '226114', '846665', '91249', '340190'],
#        dtype=object),
#  array(['780899', '489294', '489616', '780898'], dtype=object),
#  array(['31803', '32543', '32539', '32546', '305699', '155435', '787614',
#         '31880', '604488', '43292', '140109', '31871', '450598', '791897',
#         '784275', '32541', '95079', '14957', '747812', '23085', '699048',
#         '405748', '847121', '440300', '183258', '810085', '394172',
#         '27852', '447552', '133610', '810083', '23082', '191422', '191427',
#         '191424', '212054', '154999', '222951', '101612', '638673',
#         '578512', '643030', '259725', '679889', '108585', '115889',
#         '113999', '95077', '825163', '625310', '352237', '525279'],
#        dtype=object),
#  array(['58764', '50185'], dtype=object),
#  array(['428396'], dtype=object),
#  array(['631492'], dtype=object),
#  array(['814295', '747182'], dtype=object),
#  array(['343507', '735510', '561804', '343675', '527221', '365009',
#         '727523'], dtype=object),
#  array(['255857', '354836', '83748', '359218', '295051'], dtype=object),
#  array(['465400', '317252'], dtype=object),
#  array(['338161', '349436', '120008', '155128', '111253', '128018',
#         '149651', '391579', '85339'], dtype=object),
#  array(['831368', '2310'], dtype=object),
#  array(['178122'], dtype=object),
#  array(['67884', '615582', '726154'], dtype=object),
#  array(['719174', '733764'], dtype=object),
#  array(['134830'], dtype=object),
#  array(['463058', '463062'], dtype=object),
#  array(['655621', '750374'], dtype=object),
#  array(['260824', '125584', '469647', '444736', '53376', '724836',
#         '432644', '128837', '535774', '286948', '570870', '201175',
#         '352958', '128829'], dtype=object),
#  array(['785097', '7514', '835836', '8460', '801491', '754998', '390491',
#         '716500'], dtype=object),
#  array(['605825', '574707', '742651', '530833', '737665'], dtype=object),
#  array(['481765', '742654', '671328', '201595', '722733', '642112',
#         '647750', '742311', '742625', '737808', '190230', '112365'],
#        dtype=object),
#  array(['195072', '195071'], dtype=object),
#  array(['689788', '334695', '167536'], dtype=object),
#  array(['671828', '563784', '27708', '350247', '72324', '72394', '840047',
#         '33795', '2376', '772365', '802906', '19558'], dtype=object),
#  array(['253332'], dtype=object),
#  array(['669572'], dtype=object),
#  array(['547977', '742747'], dtype=object),
#  array(['677214', '840541', '826939', '346356', '320963', '690246',
#         '567651', '514547', '193356', '377673', '526080', '350581',
#         '536810', '709293', '710074', '326193', '677217', '730706',
#         '654997', '763454', '313387', '5197', '812280', '118621', '835',
#         '538088', '48019', '677215', '212710', '203160', '481045',
#         '458353', '632139', '295137', '844453', '302856', '783315',
#         '244483', '538085', '9991', '465895', '599577', '306153', '711099',
#         '708629', '522966', '519305', '615196', '732686', '214623',
#         '340033', '319700', '176347', '800677', '780332', '314861',
#         '369556', '635162', '193330', '411599', '567130', '512500',
#         '261348', '812984', '536819', '380199', '513837', '710075',
#         '795494', '7919', '244456', '634289', '787094', '337116', '321766',
#         '773522', '624444', '779529', '596828', '559355', '526019',
#         '732663', '464236', '338636'], dtype=object),
#  array(['390670'], dtype=object),
#  array(['487681', '780657', '806886'], dtype=object),
#  array(['47331'], dtype=object),
#  array(['560320'], dtype=object),
#  array(['300444', '343728', '342029', '330569', '464926'], dtype=object),
#  array(['839528', '698132'], dtype=object),
#  array(['819930'], dtype=object),
#  array(['742675', '558770', '573209', '218089', '280620', '398449'],
#        dtype=object),
#  array(['373717', '730164', '568249', '373715', '673573', '756642',
#         '488729', '328879', '180785', '501288', '388029', '764815',
#         '347549', '508919', '351551', '332462', '547333', '504025',
#         '446860'], dtype=object),
#  array(['607270', '620700', '170193', '757101', '781476', '789994'],
#        dtype=object),
#  array(['8712', '794131'], dtype=object),
#  array(['196737'], dtype=object),
#  array(['748439', '659177', '334444'], dtype=object),
#  array(['646611', '623754'], dtype=object),
#  array(['382490', '682433', '692709', '329116'], dtype=object),
#  array(['664264', '637455'], dtype=object),
#  array(['669356', '501302', '800235', '416128', '800234', '417907',
#         '501293', '745879', '342625', '501300', '517729'], dtype=object),
#  array(['61223', '731932', '86037', '781829', '86035', '748332', '651254',
#         '85473', '748418', '777472', '242021', '199107', '642112',
#         '408434', '116052', '457196', '111179', '748417', '588468',
#         '100456', '472175', '54319', '149862', '140404', '651255', '68873',
#         '742211', '813954', '329115', '248174', '401577'], dtype=object),
#  array(['233516', '345333', '658747', '310169', '782749', '274127',
#         '310183', '550522', '778833', '214104'], dtype=object),
#  array(['199973'], dtype=object),
#  array(['303182', '447899'], dtype=object),
#  array(['69354', '662962'], dtype=object),
#  array(['748431'], dtype=object),
#  array(['221505', '323498', '354274', '324214', '421369', '342777'],
#        dtype=object),
#  array(['692330', '209785'], dtype=object),
#  array(['206999'], dtype=object),
#  array(['484247', '729558'], dtype=object),
#  array(['762919', '486575', '654395', '361887', '478954', '296080',
#         '526005', '460093', '398394', '209761', '130655', '233317',
#         '785174', '261858', '492331', '315806', '485835'], dtype=object),
#  array(['211730'], dtype=object),
#  array(['134854', '298304'], dtype=object),
#  array(['460111', '356720', '626244'], dtype=object),
#  array(['72324', '37121', '40284', '84272'], dtype=object),
#  array(['388399'], dtype=object),
#  array(['654875', '149042', '828359', '826313'], dtype=object),
#  array(['100191', '231136', '338631', '535124'], dtype=object),
#  array(['90129', '9321', '786107', '268003', '305572'], dtype=object),
#  array(['737501'], dtype=object),
#  array(['520788'], dtype=object),
#  array(['287294'], dtype=object),
#  array(['526080', '381532', '329120', '329116'], dtype=object),
#  array(['737610', '723629', '737633'], dtype=object),
#  array(['22888', '26708', '34771', '85639', '79237', '34786'], dtype=object),
#  array(['804859', '804848'], dtype=object),
#  array(['822715'], dtype=object),
#  array(['549462'], dtype=object),
#  array(['344055', '832785', '431212', '161270', '296741', '145757',
#         '218637', '761641'], dtype=object),
#  array(['532576', '706853', '651457'], dtype=object),
#  array(['595176'], dtype=object),
#  array(['58204', '820814'], dtype=object),
#  array(['380823', '370344', '719043', '172169', '342333', '340607',
#         '173184', '653904', '498988', '561653'], dtype=object),
#  array(['772585', '573575'], dtype=object),
#  array(['714385', '703429'], dtype=object),
#  array(['83084'], dtype=object),
#  array(['480780'], dtype=object),
#  array(['4039', '777584'], dtype=object),
#  array(['732309'], dtype=object),
#  array(['692264', '699485'], dtype=object),
#  array(['394322', '328001', '542582', '305528', '728189', '146706',
#         '376829'], dtype=object),
#  array(['564187'], dtype=object),
#  array(['38937'], dtype=object),
#  array(['620347', '140108', '631697'], dtype=object),
#  array(['434465'], dtype=object),
#  array(['85392'], dtype=object),
#  array(['332768'], dtype=object),
#  array(['740103', '227561', '821485'], dtype=object),
#  array(['52200', '253053', '737108'], dtype=object),
#  array(['695718'], dtype=object),
#  array(['616065'], dtype=object),
#  array(['509734', '517166', '209301', '147127', '243148', '549379',
#         '587203', '655538', '278203', '587933', '719118'], dtype=object),
#  array(['665172', '543383', '593323', '527417', '527414'], dtype=object),
#  array(['566761', '469364', '471249'], dtype=object),
#  array(['33767', '35462', '725199', '58598', '712691'], dtype=object),
#  array(['117350', '774586'], dtype=object),
#  array(['794349'], dtype=object),
#  array(['616778'], dtype=object),
#  array(['89651', '772615', '748783', '397479', '595640', '619393',
#         '781396', '325910', '209150', '421254', '258529', '777692',
#         '372511', '637761', '811545', '837913', '346613', '637481',
#         '834792', '834062', '779229', '728742', '322691', '398058',
#         '791314', '5715', '752478', '550924', '575573', '729461', '783315'],
#        dtype=object),
#  array(['190492', '834790', '544357', '437941', '804661', '321344',
#         '750547', '256318'], dtype=object),
#  array(['533075'], dtype=object),
#  array(['207469', '232674', '316100', '266155', '426394', '332674',
#         '275698'], dtype=object),
#  array(['599216'], dtype=object),
#  array(['634129', '634094'], dtype=object),
#  array(['73560', '32677', '87817', '589836', '391199', '573768', '33685',
#         '60991', '19349', '589865', '60893', '198390', '589863', '251373',
#         '589766', '16864', '50355', '493178', '127566', '557954', '492772',
#         '9266', '60992'], dtype=object),
#  array(['706814', '706843', '296735'], dtype=object),
#  array(['775246', '9622'], dtype=object),
#  array(['695943', '810835', '546345'], dtype=object),
#  array(['475300', '437941'], dtype=object),
#  array(['128397', '737456'], dtype=object),
#  array(['779990', '631958', '354576'], dtype=object),
#  array(['296225'], dtype=object),
#  array(['209545', '131136'], dtype=object),
#  array(['325416', '359651', '835842'], dtype=object),
#  array(['78275', '334977', '329126'], dtype=object),
#  array(['159824', '29420', '686841', '840502', '33392'], dtype=object),
#  array(['674957', '471349'], dtype=object),
#  array(['478898', '750823'], dtype=object),
#  array(['196452', '836070'], dtype=object),
#  array(['707882'], dtype=object),
#  array(['138486'], dtype=object),
#  array(['583827'], dtype=object),
#  array(['752641'], dtype=object),
#  array(['636196', '817403', '8136', '748308', '774865', '152657'],
#        dtype=object),
#  array(['184319'], dtype=object),
#  array(['29858', '38634'], dtype=object),
#  array(['748308', '748332', '692709', '537270'], dtype=object),
#  array(['751506', '403838'], dtype=object),
#  array(['787075', '718869', '91008'], dtype=object),
#  array(['463588', '554251'], dtype=object),
#  array(['354615', '221405', '140316', '89073', '806639', '140318'],
#        dtype=object),
#  array(['9070', '9071'], dtype=object),
#  array(['609903'], dtype=object),
#  array(['831503'], dtype=object),
#  array(['742384', '742372'], dtype=object),
#  array(['725745'], dtype=object),
#  array(['467380', '364525', '706040', '665172', '384665', '605233',
#         '479834', '364524', '739126', '746731', '693430'], dtype=object),
#  array(['494618', '738176', '666890', '480979', '784985', '515355',
#         '502580', '576462', '380980', '467378', '369167', '428011',
#         '540155', '239363', '675473', '340610', '321042'], dtype=object),
#  array(['836917'], dtype=object),
#  array(['91575', '523778'], dtype=object),
#  array(['4044'], dtype=object),
#  array(['637487', '720388', '690460', '575557', '560007', '176908',
#         '805827', '572858', '826446', '745701', '808872', '742372',
#         '207259'], dtype=object),
#  array(['76173'], dtype=object),
#  array(['379918', '401396', '387935'], dtype=object),
#  array(['530661', '768597', '234901', '83379', '121121', '515175',
#         '255258', '486281', '404507', '334660', '119609', '331076'],
#        dtype=object),
#  array(['737807', '331297', '672351'], dtype=object),
#  array(['685987', '322107'], dtype=object),
#  array(['590415'], dtype=object),
#  array(['598144', '737460', '67321', '707121', '817471', '737060',
#         '425438', '194385', '137428', '410378', '437823', '327959',
#         '284063', '737510', '668429', '817857'], dtype=object),
#  array(['269403', '752425', '478899', '612633', '824520', '297291',
#         '325685', '824530'], dtype=object),
#  array(['71716', '63695'], dtype=object),
#  array(['192287', '240830', '341707'], dtype=object),
#  array(['814056', '715521', '485201', '527956', '491433', '265086',
#         '417600', '373447', '394732', '782342', '330861', '286973',
#         '467024'], dtype=object),
#  array(['539427', '139816', '750758'], dtype=object),
#  array(['34822', '45518', '51395'], dtype=object),
#  array(['768024'], dtype=object),
#  array(['451799', '696647'], dtype=object),
#  array(['630358', '635169', '838753'], dtype=object),
#  array(['797566'], dtype=object),
#  array(['42043', '63605'], dtype=object),
#  array(['359452'], dtype=object),
#  array(['350307'], dtype=object),
#  array(['372518', '802485'], dtype=object),
#  array(['710881'], dtype=object),
#  array(['737317', '586166', '713274', '493275', '515188', '702032'],
#        dtype=object),
#  array(['147899', '147964'], dtype=object),
#  array(['745816', '754791', '5156', '5488', '608450', '49913', '219427',
#         '788726', '697097', '592740'], dtype=object),
#  array(['630113', '2369', '835617', '835622', '367606', '804050', '593432',
#         '615661', '254318', '247379', '375553', '626791', '348825'],
#        dtype=object),
#  array(['630259'], dtype=object),
#  array(['171529', '445136', '195492'], dtype=object),
#  array(['556834', '795952', '541586', '330712', '188737', '5641', '409679',
#         '513843', '730248', '684902', '177577', '714463', '728759',
#         '813539', '602153', '815373', '507388'], dtype=object),
#  array(['396365', '206869'], dtype=object),
#  array(['737561', '647394'], dtype=object),
#  array(['685830', '669180', '342467', '669226', '446748'], dtype=object),
#  array(['832006', '475677', '460145', '146606', '585078', '154956',
#         '448598', '795460'], dtype=object),
#  array(['525102'], dtype=object),
#  array(['525858', '155697', '228709', '147751', '729276'], dtype=object),
#  array(['752445', '397862', '752446'], dtype=object),
#  array(['408434'], dtype=object),
#  array(['396804', '753201', '153865', '753202', '660269', '320658',
#         '785665', '765101', '753197', '753198'], dtype=object),
#  array(['215217', '391581', '358750', '273452'], dtype=object),
#  array(['829819'], dtype=object),
#  array(['484245', '326691', '249989', '536430'], dtype=object),
#  array(['262451'], dtype=object),
#  array(['17621'], dtype=object),
#  array(['285664'], dtype=object),
#  array(['306182', '586545', '589812', '49636', '118489', '118485',
#         '529150', '76761', '822652', '55103', '3019', '118499', '118501'],
#        dtype=object),
#  array(['86247', '82425', '118054', '577307', '523110', '523111', '537149',
#         '818422', '463792', '463795', '75991', '262061', '85927', '525201',
#         '416012', '61947', '66450', '775002', '85847', '775015'],
#        dtype=object),
#  array(['630735'], dtype=object),
#  array(['543799', '400825'], dtype=object),
#  array(['304912'], dtype=object),
#  array(['609280', '286373', '798670', '846819', '831424', '833672',
#         '302850', '356872', '662158', '320367', '75613', '829032',
#         '599943', '298569', '796398', '156525', '573414', '152024',
#         '651577', '816716', '831242', '379154', '794329', '194847',
#         '668429'], dtype=object),
#  array(['39091'], dtype=object),
#  array(['672358', '303278'], dtype=object),
#  array(['775659'], dtype=object),
#  array(['551017', '446800', '467286', '422009', '421962', '422021',
#         '456942', '489562', '501173', '795918', '542563'], dtype=object),
#  array(['128679', '102826', '74132', '123731'], dtype=object),
#  array(['762132', '466509', '524695'], dtype=object),
#  array(['369831'], dtype=object),
#  array(['768404'], dtype=object),
#  array(['147945', '148333'], dtype=object),
#  array(['389541', '759720', '559495'], dtype=object),
#  array(['182990'], dtype=object),
#  array(['84275', '421926'], dtype=object),
#  array(['836402', '737561'], dtype=object),
#  array(['359923'], dtype=object),
#  array(['177990', '476425'], dtype=object),
#  array(['328758', '464636', '409999', '260336'], dtype=object),
#  array(['751722', '737666', '621025'], dtype=object),
#  array(['242157', '836060', '282819', '481753'], dtype=object),
#  array(['817433'], dtype=object),
#  array(['536144', '536259', '416127', '501293', '535763', '517726'],
#        dtype=object),
#  array(['717243', '181932', '370168'], dtype=object),
#  array(['64089', '677362', '64087', '742807', '12641'], dtype=object),
#  array(['543826', '344628'], dtype=object),
#  array(['3508', '3493', '3492'], dtype=object),
#  array(['353292', '803165', '508574', '737456'], dtype=object),
#  array(['839528'], dtype=object),
#  array(['829122', '392634', '760793', '129606', '1950', '156320', '379351',
#         '760779', '760794', '6651', '781953', '718416', '442335', '1965'],
#        dtype=object),
#  array(['755337'], dtype=object),
#  array(['42669', '42639'], dtype=object),
#  array(['149863', '336136', '225207', '275880', '556590', '185431'],
#        dtype=object),
#  array(['198487', '306816'], dtype=object),
#  array(['403224', '573207'], dtype=object),
#  array(['466036', '596661', '538544', '802915', '549292'], dtype=object),
#  array(['726123', '726122'], dtype=object),
#  array(['418300'], dtype=object),
#  array(['40813', '528167', '53818', '474940'], dtype=object),
#  array(['741796'], dtype=object),
#  array(['641675'], dtype=object),
#  array(['513396', '375912'], dtype=object),
#  array(['818741', '768976', '89965', '569523'], dtype=object),
#  array(['814651', '767797', '606439'], dtype=object),
#  array(['566215', '373010', '742924'], dtype=object),
#  array(['534349', '379850', '379892'], dtype=object),
#  array(['331005', '577714', '194230'], dtype=object),
#  array(['809288', '835556', '71372', '20812'], dtype=object),
#  array(['807286', '420614', '446863', '526659', '771348', '491989',
#         '795248'], dtype=object),
#  array(['341489'], dtype=object),
#  array(['106880', '283543', '129191', '511512'], dtype=object),
#  array(['702959', '342004', '53684', '81629', '325220', '66577', '685829',
#         '749517'], dtype=object),
#  array(['183531', '274552', '100756'], dtype=object),
#  array(['274332', '142314'], dtype=object),
#  array(['546845', '836458'], dtype=object),
#  array(['664249', '192287', '656640'], dtype=object),
#  array(['405394', '640153'], dtype=object),
#  array(['546781', '666970', '546782'], dtype=object),
#  array(['837871'], dtype=object),
#  array(['200666'], dtype=object),
#  array(['89242'], dtype=object),
#  array(['471689', '137386', '305442', '572972', '154112', '586876',
#         '572973', '272751', '404249', '586040', '549871', '476652',
#         '114002', '404263', '600200', '583812', '117700', '172159',
#         '114725', '534475'], dtype=object),
#  array(['295887', '792001'], dtype=object),
#  array(['838481', '734124', '836362', '829268'], dtype=object),
#  array(['777476', '678514', '641034', '600523', '623488', '824411',
#         '574431'], dtype=object),
#  array(['173642', '174089'], dtype=object),
#  array(['42909', '742269', '35379'], dtype=object),
#  array(['339597', '339233'], dtype=object),
#  array(['760166'], dtype=object),
#  array(['325946', '446523', '535431', '660804', '250363', '424467',
#         '186803', '527662', '99083', '677042', '315609', '575046',
#         '346483', '640711', '178171', '59685', '125699', '520111',
#         '326093', '69756', '75027', '663430', '673073', '462132', '487768',
#         '396691', '527991', '356906', '449133', '104994', '297231',
#         '540394', '608147', '262103', '334538', '334559', '608275',
#         '503703', '432482', '412060'], dtype=object),
#  array(['581756', '114316', '842924', '186310'], dtype=object),
#  array(['407577', '566728'], dtype=object),
#  array(['234438', '362937', '120662', '159279', '826272', '251110',
#         '206998', '676797', '215069', '551269', '607879', '768107'],
#        dtype=object),
#  array(['828359', '227789'], dtype=object),
#  array(['741828', '742621', '158831', '323067', '413296', '824640',
#         '325598', '741768'], dtype=object),
#  array(['179606', '330468', '219398', '84219', '330712', '269251', '84217',
#         '92273', '75865', '336799', '373246', '373255', '241895', '737746',
#         '341626'], dtype=object),
#  array(['592380'], dtype=object),
#  array(['532678', '452652', '589957', '688477', '538878', '554407',
#         '553732', '685104', '692050', '477547', '145023', '214573',
#         '507856'], dtype=object),
#  array(['544489'], dtype=object),
#  array(['119239', '233291'], dtype=object),
#  array(['740322', '432277', '824968', '835097'], dtype=object),
#  array(['401674', '232956', '830280', '405195', '714652', '391876',
#         '835805', '405274'], dtype=object),
#  array(['840560'], dtype=object),
#  array(['58255'], dtype=object),
#  array(['602182', '758937'], dtype=object),
#  array(['334684', '418360', '204052', '796983', '379644', '720404'],
#        dtype=object),
#  array(['710466', '671629', '517697', '153792', '775498', '432644',
#         '725890', '742656', '279423', '153790'], dtype=object),
#  array(['6162'], dtype=object),
#  array(['427431', '427398', '406877', '691659', '354363', '382751',
#         '491879', '110327', '588072', '556119', '644290', '421334',
#         '724134', '742385', '736908', '779224', '482514', '385925',
#         '220929', '6674', '691130', '526050', '469472', '641561', '565035',
#         '783255', '594912', '182560', '799952', '275555', '891', '275554',
#         '346793'], dtype=object),
#  array(['387882', '706814', '176075'], dtype=object),
#  array(['260235', '81976'], dtype=object),
#  array(['764159', '764158'], dtype=object),
#  array(['509122', '509124'], dtype=object),
#  array(['752439', '274600', '108959', '167538'], dtype=object),
#  array(['616778'], dtype=object),
#  array(['329118'], dtype=object),
#  array(['610743', '54976', '70976', '64517'], dtype=object),
#  array(['182179', '821579', '787187'], dtype=object),
#  array(['753126', '820744', '230443', '132757', '525171', '380283', '6368',
#         '502830', '411546'], dtype=object),
#  array(['387519'], dtype=object),
#  array(['781953', '591035', '584380', '836872', '562474', '544961'],
#        dtype=object),
#  array(['619579', '452635', '271874', '271780'], dtype=object),
#  array(['706924'], dtype=object),
#  array(['207006'], dtype=object),
#  array(['614414', '692187', '756308'], dtype=object),
#  array(['592258', '540803', '164063', '446863', '475305'], dtype=object),
#  array(['843037', '843031'], dtype=object),
#  array(['602467', '33449'], dtype=object),
#  array(['776660', '833281', '8551'], dtype=object),
#  array(['334661'], dtype=object),
#  array(['473179', '634547', '105508'], dtype=object),
#  array(['489003'], dtype=object),
#  array(['772512', '831767', '482101', '639480', '831745', '638927',
#         '847506', '604632', '502346', '725077', '454878', '233291',
#         '831750', '694765', '7505', '719898', '596499', '525409', '553769',
#         '610046', '823265'], dtype=object),
#  array(['5874', '3378'], dtype=object),
#  array(['69761'], dtype=object),
#  array(['741295'], dtype=object),
#  array(['344695', '81962', '665189', '720742'], dtype=object),
#  array(['812803', '755884', '775662', '207179'], dtype=object),
#  array(['746418', '565313', '744816', '79819'], dtype=object),
#  array(['382453'], dtype=object),
#  array(['401574', '205674', '704131', '742658', '742680', '500722',
#         '697951', '423307'], dtype=object),
#  array(['144286', '204052'], dtype=object),
#  array(['697501', '337020', '241470', '488102', '373008', '497931',
#         '461158', '452652', '377325', '51086', '406717', '373867',
#         '222942', '507768', '61508', '426586', '525216', '509545',
#         '507767', '435925', '543929', '386549', '690828'], dtype=object),
#  array(['463725'], dtype=object),
#  array(['33431'], dtype=object),
#  array(['659458', '503354'], dtype=object),
#  array(['525499', '106427', '826265', '448341', '531159', '651560'],
#        dtype=object),
#  array(['819210'], dtype=object),
#  array(['217011'], dtype=object),
#  array(['759584', '170615', '767364'], dtype=object),
#  array(['144127', '672266'], dtype=object),
#  array(['450199', '653503'], dtype=object),
#  array(['451074', '718304', '649559', '483585', '535766', '756482',
#         '450596', '285357', '278062', '246442', '375324', '478993'],
#        dtype=object),
#  array(['781587', '495392', '795324', '304584'], dtype=object),
#  array(['78519', '206401', '44886', '785729'], dtype=object),
#  array(['808912', '747055'], dtype=object),
#  array(['400090', '658397', '570683', '746561', '834546', '767626',
#         '600869', '584192', '215964', '155429', '217439', '98122'],
#        dtype=object),
#  array(['626351'], dtype=object),
#  array(['841906'], dtype=object),
#  array(['126819', '126821'], dtype=object),
#  array(['382388', '737779', '737552', '175021'], dtype=object),
#  array(['123007'], dtype=object),
#  array(['412272', '412273'], dtype=object),
#  array(['167157', '659479', '312849'], dtype=object),
#  array(['388424', '218187'], dtype=object),
#  array(['302720', '580968', '64891', '413125', '79329', '290830', '522838',
#         '833940', '522616', '413390', '10149'], dtype=object),
#  array(['513843', '112403', '474525', '827197', '367573'], dtype=object),
#  array(['726405', '448598', '554713', '785752', '698673', '1106'],
#        dtype=object),
#  array(['490371'], dtype=object),
#  array(['58234', '607867'], dtype=object),
#  array(['406987', '742701'], dtype=object),
#  array(['583557'], dtype=object),
#  array(['59350', '28963'], dtype=object),
#  array(['616811', '734786', '810258', '314501'], dtype=object),
#  array(['152307', '139177'], dtype=object),
#  array(['292388', '279631', '367321', '701496', '463549', '430666'],
#        dtype=object),
#  array(['196446'], dtype=object),
#  array(['732070', '732222', '584639'], dtype=object),
#  array(['836906', '742345', '666512', '742475', '601092', '771616'],
#        dtype=object),
#  array(['824888'], dtype=object),
#  array(['271951', '87906'], dtype=object),
#  array(['624294'], dtype=object),
#  array(['715039', '647172', '761061', '662588', '244354', '494059',
#         '413440', '415711', '415723', '806391', '188804', '159003',
#         '112560', '188730', '367089', '825689', '822487'], dtype=object),
#  array(['492069', '283660', '163375', '447222', '474802', '700681'],
#        dtype=object),
#  array(['720405', '340627', '695915', '388869', '722379', '408424',
#         '331016', '695985', '331545', '659240', '826955'], dtype=object),
#  array(['748332', '690686', '307867', '398869', '808157', '168942',
#         '367742', '8738', '719117', '430952', '706659', '469598', '168320',
#         '737452', '677771', '533655', '737460', '390395', '808160',
#         '728126', '309316', '130963', '128688', '406807', '304571',
#         '841919', '737666'], dtype=object),
#  array(['719799'], dtype=object),
#  array(['27728'], dtype=object),
#  array(['408437', '19558', '334446', '399507', '13325', '775418'],
#        dtype=object),
#  array(['200231'], dtype=object),
#  array(['736471', '624221', '641019'], dtype=object),
#  array(['274252', '761753'], dtype=object),
#  array(['793223', '267556'], dtype=object),
#  array(['813954'], dtype=object),
#  array(['73090', '198691'], dtype=object),
#  array(['294817', '537726'], dtype=object),
#  array(['573665'], dtype=object),
#  array(['726623', '443034', '70663', '393343', '333392', '447369',
#         '123889', '205784', '463431', '80271', '661432', '87799', '737510',
#         '380255', '79693', '264724', '413825', '79095', '157109', '151463',
#         '90042', '450258', '840543', '349053', '120534', '398798',
#         '687794', '376083', '601296', '321530', '446815', '187713',
#         '785874', '289495', '157879', '144945', '118396', '397990',
#         '154028', '368517', '398381', '412309', '49047', '838139'],
#        dtype=object),
#  array(['533416', '792369', '491876'], dtype=object),
#  array(['595711', '172178', '737821', '623730', '812694', '46035'],
#        dtype=object),
#  array(['652772', '733305'], dtype=object),
#  array(['616610', '678265'], dtype=object),
#  array(['477018', '461557'], dtype=object),
#  array(['468351', '224716', '670961', '214156', '659385', '401651',
#         '344358', '522146', '206399', '289883', '293626', '402834',
#         '102261', '130960', '380998', '814960', '50113', '224262',
#         '253711', '632314'], dtype=object),
#  array(['814541', '380341', '554713', '726395', '119441', '505145',
#         '748308', '438339', '380229', '565451', '127282', '268607',
#         '225207', '825881', '775156', '215584', '207156'], dtype=object),
#  array(['48583'], dtype=object),
#  array(['720331', '685468', '644941', '759410', '688343', '646796',
#         '311824', '679480'], dtype=object),
#  array(['741295', '266340'], dtype=object),
#  array(['48927', '18833', '172627', '106236'], dtype=object),
#  array(['788097', '787124'], dtype=object),
#  array(['114018', '169691', '169689', '608892', '433276', '416288'],
#        dtype=object),
#  array(['584061'], dtype=object),
#  array(['450506', '541095'], dtype=object),
#  array(['482122', '462617'], dtype=object),
#  array(['170663', '216948', '155623', '737832', '236986'], dtype=object),
#  array(['360026', '339321'], dtype=object),
#  array(['810664'], dtype=object),
#  array(['614306', '326382', '176526', '681637', '784745', '614318'],
#        dtype=object),
#  array(['239574', '175974'], dtype=object),
#  array(['756398'], dtype=object),
#  array(['121192'], dtype=object),
#  array(['806391', '277959', '170029', '723588', '396476', '523581',
#         '295844', '372317', '349636', '442702', '139639'], dtype=object),
#  array(['681998', '366386', '737401', '366372', '252126', '712719',
#         '712716', '651550', '366371', '830701', '553311', '321835',
#         '505288', '122763', '346393', '750739'], dtype=object),
#  array(['632865', '209409'], dtype=object),
#  array(['52713', '125584'], dtype=object),
#  array(['383701', '406535', '647721', '491946', '371459', '453103',
#         '647714', '491947', '388755'], dtype=object),
#  array(['736941', '741838', '578905'], dtype=object),
#  array(['213369', '159928', '266127', '681442', '275538', '836929',
#         '715169', '730161', '840589', '388300'], dtype=object),
#  array(['567939'], dtype=object),
#  array(['352396', '296439'], dtype=object),
#  array(['382581', '212398', '260398', '555909', '737613', '334671',
#         '513426', '180255', '331144', '803965', '415711', '213554',
#         '260406', '698997', '619722', '689189', '567219', '307939',
#         '331145'], dtype=object),
#  array(['119442', '361422', '530369', '217676'], dtype=object),
#  array(['740701', '613353'], dtype=object),
#  array(['500923', '65021'], dtype=object),
#  array(['731916', '338114', '225484'], dtype=object),
#  array(['186440', '180341'], dtype=object),
#  array(['669553', '725534'], dtype=object),
#  array(['11107', '671727'], dtype=object),
#  array(['295372', '841245', '820961'], dtype=object),
#  array(['350443'], dtype=object),
#  array(['603982', '458135', '241306', '72071', '235815', '736992', '88670',
#         '112194'], dtype=object),
#  array(['572859'], dtype=object),
#  array(['633215'], dtype=object),
#  array(['839525', '157677'], dtype=object),
#  array(['827095', '844010', '195006', '737381', '1955', '195007', '461',
#         '746779', '169416', '350015', '680176', '350833'], dtype=object),
#  array(['242943', '146923'], dtype=object),
#  array(['800020', '325783'], dtype=object),
#  array(['502669', '447213', '436312', '583281', '270292', '383441'],
#        dtype=object),
#  array(['623754', '742158'], dtype=object),
#  array(['368706', '394089'], dtype=object),
#  array(['4563', '833913'], dtype=object),
#  array(['729238', '481601', '723113', '840145', '596511', '247740',
#         '474160', '514249', '472537', '234957', '478479', '816993',
#         '694312', '481602', '827755', '384886'], dtype=object),
#  array(['526475'], dtype=object),
#  array(['523581', '455026', '461083'], dtype=object),
#  array(['363867', '363897'], dtype=object),
#  array(['351716'], dtype=object),
#  array(['838158'], dtype=object),
#  array(['632041', '829464', '829465'], dtype=object),
#  array(['509352', '507634', '490334'], dtype=object),
#  array(['543787', '836919'], dtype=object),
#  array(['318365'], dtype=object),
#  array(['176790', '189867', '516465', '683823', '132259', '61405',
#         '221523', '681716', '737765'], dtype=object),
#  array(['760885', '737808', '737386', '714067', '725891'], dtype=object),
#  array(['48932', '49037'], dtype=object),
#  array(['499782', '643581', '277244', '643582', '425793', '836872',
#         '802533', '100399', '393351', '425703', '418772', '320828',
#         '544088', '425786', '415508', '415509'], dtype=object),
#  array(['565282', '496203'], dtype=object),
#  array(['839435', '725996'], dtype=object),
#  array(['681467'], dtype=object),
#  array(['351307'], dtype=object),
#  array(['425873'], dtype=object),
#  array(['176815', '220714', '689924', '176799', '691085'], dtype=object),
#  array(['48587'], dtype=object),
#  array(['132872', '540468', '89035', '613328', '9547', '706837', '613333',
#         '736886', '274605', '377511'], dtype=object),
#  array(['812521'], dtype=object),
#  array(['157281', '709536', '407783', '802803', '715693'], dtype=object),
#  array(['374008', '50947', '472142'], dtype=object),
#  array(['54207', '21838', '68905', '34241', '63006', '518664'],
#        dtype=object),
#  array(['1965', '826313'], dtype=object),
#  array(['678199'], dtype=object),
#  array(['200172'], dtype=object),
#  array(['528674', '169416', '321092', '315279', '843248', '306206',
#         '452408', '833623', '510979', '372501', '761532'], dtype=object),
#  array(['737715', '89097', '530019', '441831'], dtype=object),
#  array(['674855', '814540'], dtype=object),
#  array(['687872', '673967'], dtype=object),
#  array(['768900', '482023', '249023', '24863'], dtype=object),
#  array(['527795', '665801', '689902'], dtype=object),
#  array(['454888', '337052'], dtype=object),
#  array(['748308'], dtype=object),
#  array(['206308'], dtype=object),
#  array(['362726', '182889'], dtype=object),
#  array(['58257', '737484', '43323'], dtype=object),
#  array(['394214', '364229'], dtype=object),
#  array(['574250', '156968'], dtype=object),
#  array(['283553'], dtype=object),
#  array(['453881', '454219'], dtype=object),
#  array(['749136', '709466', '709469', '335960', '338236', '749137'],
#        dtype=object),
#  array(['168517', '339898', '181187', '169343', '462165'], dtype=object),
#  array(['283154', '246102', '727190'], dtype=object),
#  array(['288226', '576394', '267086', '683978'], dtype=object),
#  array(['145803', '572397', '667196', '4995', '555559', '251891', '760568',
#         '338493', '716329', '817388', '222257'], dtype=object),
#  array(['339816', '337968', '284350'], dtype=object),
#  array(['689789', '737348', '18822'], dtype=object),
#  array(['450909'], dtype=object),
#  array(['645920', '19963', '658747'], dtype=object),
#  array(['407755', '673531', '447339', '447222', '636939', '625438',
#         '625436', '248115', '671290', '785290', '523579', '417338',
#         '529635', '788121', '768775', '7112', '474761', '5165'],
#        dtype=object),
#  array(['565569'], dtype=object),
#  array(['656353'], dtype=object),
#  array(['215217', '593200', '210248', '215214', '379518'], dtype=object),
#  array(['582907', '780404', '501509'], dtype=object),
#  array(['558411'], dtype=object),
# ...
#  array(['4568'], dtype=object),
#  array(['402502'], dtype=object),
#  array(['425127'], dtype=object),
#  array(['635907', '840456', '659890', '784200', '497009', '169544',
#         '180707', '814540', '369539', '544713', '674014', '776994',
#         '577973', '737734', '358239', '799906', '217763', '842072',
#         '765697', '723352', '797984'], dtype=object),
#  array(['499585', '529651', '654419', '529426', '529421', '317061',
#         '528835', '528820'], dtype=object),
#  array(['357268', '396820', '214542', '236036', '243289', '263', '770840',
#         '637416', '335160', '218966', '462670', '199409', '214089'],
#        dtype=object),
#  array(['624133'], dtype=object),
#  array(['318702', '366379', '267222', '371364'], dtype=object),
#  array(['130094', '74594', '569938', '675899', '580354', '63073', '653942'],
#        dtype=object),
#  array(['465381'], dtype=object),
#  array(['571318', '572701'], dtype=object),
#  array(['562234'], dtype=object),
#  array(['118107'], dtype=object),
#  array(['486277', '486283', '343507', '88163'], dtype=object),
#  array(['535774', '718536', '826044', '305870', '260824', '289742'],
#        dtype=object),
#  array(['697058', '697059', '842984', '801724', '516463', '671362',
#         '780404', '9091', '821376', '575567', '606389', '836231'],
#        dtype=object),
#  array(['824362', '188430', '807342'], dtype=object),
#  array(['328310', '386163', '549885'], dtype=object),
#  array(['802533'], dtype=object),
#  array(['277327', '277309', '277311'], dtype=object),
#  array(['706926'], dtype=object),
#  array(['209785'], dtype=object),
#  array(['462019', '719799', '519491', '377678', '389443', '423262',
#         '314079', '280257', '260879', '577138'], dtype=object),
#  array(['237066'], dtype=object),
#  array(['629140'], dtype=object),
#  array(['768593', '689149'], dtype=object),
#  array(['689149'], dtype=object),
#  array(['99329', '729276', '573665', '282391', '712944', '334626',
#         '537321', '554508', '449943', '818594', '216948', '737792',
#         '737835', '260437', '719687', '350344', '153151', '233312',
#         '561941'], dtype=object),
#  array(['718468', '841112', '842540'], dtype=object),
#  array(['173212', '737391', '508674', '173213'], dtype=object),
#  array(['247015', '669553'], dtype=object),
#  array(['49012', '737005', '12378', '807545'], dtype=object),
#  array(['214647', '656606', '827933'], dtype=object),
#  array(['498701'], dtype=object),
#  array(['741295', '807689'], dtype=object),
#  array(['743326', '520212', '489439', '617557', '8737', '327709'],
#        dtype=object),
#  array(['536465'], dtype=object),
#  array(['478479', '845627', '478484'], dtype=object),
#  array(['188713'], dtype=object),
#  array(['159432', '266681', '228845'], dtype=object),
#  array(['355584', '828958', '354880'], dtype=object),
#  array(['198496', '799225', '533412', '220710', '287119', '233404',
#         '225538', '165193'], dtype=object),
#  array(['513844'], dtype=object),
#  array(['751722'], dtype=object),
#  array(['695270'], dtype=object),
#  array(['583883', '460529', '710376', '391685', '179167'], dtype=object),
#  array(['381981'], dtype=object),
#  array(['714818'], dtype=object),
#  array(['500350', '818446', '840633'], dtype=object),
#  array(['188430', '336084', '318', '418093', '801241', '418091'],
#        dtype=object),
#  array(['472128'], dtype=object),
#  array(['803165', '784207', '846272', '375530', '647879', '741193',
#         '686321', '827830', '843603'], dtype=object),
#  array(['764921', '358285', '835480'], dtype=object),
#  array(['135235', '76982'], dtype=object),
#  array(['218629', '210647'], dtype=object),
#  array(['11620', '556963'], dtype=object),
#  array(['567462', '470462'], dtype=object),
#  array(['358343', '661630'], dtype=object),
#  array(['325285', '1965'], dtype=object),
#  array(['336897'], dtype=object),
#  array(['499484', '325743', '499250', '721806'], dtype=object),
#  array(['447557', '699944', '261241', '398559', '432056', '639939',
#         '847324', '845144', '350238', '537908', '289542', '788112',
#         '720066', '350132', '422797'], dtype=object),
#  array(['592586', '697786', '346344', '593908', '427072', '309923',
#         '32524'], dtype=object),
#  array(['358305'], dtype=object),
#  array(['195054', '207172', '351482', '443950', '489822', '295246',
#         '744407', '781823', '630651', '241516', '349239', '796948'],
#        dtype=object),
#  array(['752736'], dtype=object),
#  array(['654410'], dtype=object),
#  array(['182854', '437998', '522054', '675851', '679147', '679139',
#         '58765', '677536', '549361', '740052', '667255', '522352',
#         '195037', '522134', '513245', '82288', '671942', '621541'],
#        dtype=object),
#  array(['704849', '841648', '418360', '246102', '264892', '553769'],
#        dtype=object),
#  array(['391610', '533188', '245824', '464284', '731761', '317112',
#         '543879', '245822', '433512', '245789', '680327', '245782',
#         '357052', '430124', '822002', '177536', '266155'], dtype=object),
#  array(['678285', '595884', '70378', '593371'], dtype=object),
#  array(['737770'], dtype=object),
#  array(['271488'], dtype=object),
#  array(['828357', '721021', '139603'], dtype=object),
#  array(['475303', '580144'], dtype=object),
#  array(['688666', '789663', '610735', '585930', '688735', '768838',
#         '429498', '737833', '845223', '768830', '446762', '585913'],
#        dtype=object),
#  array(['382798', '102615', '710124'], dtype=object),
#  array(['703653', '450351', '430229', '277961', '349220'], dtype=object),
#  array(['109486', '116052'], dtype=object),
#  array(['237377', '761692', '133455', '203266', '50564', '27218', '611658',
#         '600970', '60459', '72394', '558808', '178493', '791922', '30371',
#         '16364'], dtype=object),
#  array(['313686', '281344', '22924'], dtype=object),
#  array(['107592'], dtype=object),
#  array(['737752', '531882', '737749', '27548', '267888', '727580', '19558',
#         '566731'], dtype=object),
#  array(['209785'], dtype=object),
#  array(['83899', '43336', '553877'], dtype=object),
#  array(['755981'], dtype=object),
#  array(['580945'], dtype=object),
#  array(['627422', '57501', '573768', '68910', '589834', '68908', '65984',
#         '57498', '67257', '627421', '67228'], dtype=object),
#  array(['594219'], dtype=object),
#  array(['788108'], dtype=object),
#  array(['256587', '485846', '604492', '345977', '325662', '228397',
#         '564463', '236047', '495790', '676512', '820761', '161084',
#         '502141', '432007', '267464', '525813', '511512', '551504',
#         '752387', '315954', '300626', '721493', '781943', '199317',
#         '714973', '298079', '325295', '749241', '218638', '544479'],
#        dtype=object),
#  array(['596605', '646399'], dtype=object),
#  array(['61926', '61932'], dtype=object),
#  array(['418129', '124170'], dtype=object),
#  array(['467379', '320134', '656818', '157830'], dtype=object),
#  array(['504219', '755174', '537115', '481107', '473859', '450424',
#         '341861', '557848', '550780', '126822', '534080', '402237',
#         '404872'], dtype=object),
#  array(['683818', '814540', '524011', '737770', '488790'], dtype=object),
#  array(['610046', '34113', '703605', '442123'], dtype=object),
#  array(['716670'], dtype=object),
#  array(['333289', '299524'], dtype=object),
#  array(['718470', '7075'], dtype=object),
#  array(['278202', '274571', '572857'], dtype=object),
#  array(['571990'], dtype=object),
#  array(['731141', '769214', '4627', '252203', '254529', '571185', '574079',
#         '282643', '147925', '585364', '276077', '334574'], dtype=object),
#  array(['772092', '210984'], dtype=object),
#  array(['59006', '75766'], dtype=object),
#  array(['67342'], dtype=object),
#  array(['803516', '535773'], dtype=object),
#  array(['544851', '563135', '749183', '561735', '563084'], dtype=object),
#  array(['14764', '831509'], dtype=object),
#  array(['363930', '492725', '405756', '485142', '477799', '469921'],
#        dtype=object),
#  array(['115959'], dtype=object),
#  array(['148363'], dtype=object),
#  array(['215956', '278987', '272549', '274341', '421640', '824530',
#         '432147', '510208', '604722', '599005', '527647', '509803',
#         '846418', '278408', '760525', '584833', '642935', '296168',
#         '295838', '661770', '9718', '214357', '514106', '279001', '381142',
#         '9328', '599040', '361892', '685606', '824518'], dtype=object),
#  array(['705974', '256254', '256209'], dtype=object),
#  array(['718416'], dtype=object),
#  array(['599053', '102138', '321587', '1950', '598894'], dtype=object),
#  array(['574718', '499008'], dtype=object),
#  array(['189754', '233836', '16522'], dtype=object),
#  array(['361594', '587544'], dtype=object),
#  array(['579381'], dtype=object),
#  array(['370191', '663430', '114548', '44008', '479790', '703143',
#         '172635', '48880', '115739'], dtype=object),
#  array(['184094', '241717', '462343', '500859', '500880', '462348',
#         '500840', '8420', '237196', '772803'], dtype=object),
#  array(['820814'], dtype=object),
#  array(['195959', '23020', '47684', '17785'], dtype=object),
#  array(['151919', '410565', '183941', '512778', '416714', '512875',
#         '453835', '259362', '235944', '257745', '144804', '654969',
#         '811213', '341690', '398116', '556385', '556439', '450083',
#         '304918', '734857', '512782', '473424', '197061', '328758',
#         '274178', '790454', '616266', '502633', '674651', '341992',
#         '390834', '469867', '106716', '297617', '322989', '649578',
#         '473432', '379350', '838861', '236250', '159972', '341098'],
#        dtype=object),
#  array(['830097', '812863'], dtype=object),
#  array(['736933', '127282'], dtype=object),
#  array(['822272'], dtype=object),
#  array(['686143', '353351', '112630', '801689'], dtype=object),
#  array(['481017', '480294', '480414'], dtype=object),
#  array(['699471', '767537'], dtype=object),
#  array(['298476'], dtype=object),
#  array(['805122'], dtype=object),
#  array(['373597', '9304', '167054', '535611', '11739', '380430', '681102',
#         '536125', '650785', '831942', '29067', '847042', '685773',
#         '634299', '29075'], dtype=object),
#  array(['651605', '532079', '108873'], dtype=object),
#  array(['750900'], dtype=object),
#  array(['314733', '794349'], dtype=object),
#  array(['810666'], dtype=object),
#  array(['737743', '742323'], dtype=object),
#  array(['809194'], dtype=object),
#  array(['686142', '302720'], dtype=object),
#  array(['766995', '781529'], dtype=object),
#  array(['77362'], dtype=object),
#  array(['714988', '506867', '367548'], dtype=object),
#  array(['161208', '526537', '803165', '837751'], dtype=object),
#  array(['799898', '249913', '284144'], dtype=object),
#  array(['746473', '729586', '745297', '719455', '754511', '677241',
#         '836390', '494402', '565137', '729585', '397112', '413101',
#         '551610', '426539', '428241', '241764'], dtype=object),
#  array(['674855'], dtype=object),
#  array(['87104'], dtype=object),
#  array(['776417'], dtype=object),
#  array(['302575', '457181'], dtype=object),
#  array(['492730', '741792'], dtype=object),
#  array(['350814', '736211', '66450', '221967', '428326', '62125'],
#        dtype=object),
#  array(['733305'], dtype=object),
#  array(['5632', '710125', '672454', '801420', '434018', '845627', '5381',
#         '845629', '382974', '281252', '525481', '667109', '774659',
#         '570911'], dtype=object),
#  array(['505231', '668574'], dtype=object),
#  array(['435791', '420841'], dtype=object),
#  array(['802497', '622745'], dtype=object),
#  array(['281379'], dtype=object),
#  array(['538650', '692780'], dtype=object),
#  array(['653462', '755284', '459966'], dtype=object),
#  array(['270094', '486277', '486278', '176211', '486260', '727545',
#         '486263', '486276', '751265', '274969', '486283'], dtype=object),
#  array(['78759', '104725', '437761'], dtype=object),
#  array(['258653', '489708', '708875', '795990', '816666', '466159',
#         '449945', '632323', '759967', '799045', '519589', '625869',
#         '279148', '754856', '733094', '7089', '489717', '809108', '809620',
#         '303185'], dtype=object),
#  array(['242656', '584210', '669285', '147674', '757225', '806734',
#         '159817'], dtype=object),
#  array(['490701', '1965', '558391', '728033', '477136', '529355', '558411',
#         '753589', '602302', '675644'], dtype=object),
#  array(['718416', '431523'], dtype=object),
#  array(['527231', '127672'], dtype=object),
#  array(['489730', '174464', '201506'], dtype=object),
#  array(['629371', '732199', '586969'], dtype=object),
#  array(['755014'], dtype=object),
#  array(['486451'], dtype=object),
#  array(['573047'], dtype=object),
#  array(['617176', '778644', '770105', '777588', '594307', '703513',
#         '703522', '665747', '790849', '703520', '785161'], dtype=object),
#  array(['692709', '743808', '521600', '704131', '416656', '457181',
#         '428483', '230335', '744308', '495099', '574718'], dtype=object),
#  array(['196608', '144853'], dtype=object),
#  array(['403274', '403263'], dtype=object),
#  array(['330376', '236675', '358294', '698475'], dtype=object),
#  array(['706647', '141216', '443011', '258799', '528092', '247158'],
#        dtype=object),
#  array(['479829', '122053'], dtype=object),
#  array(['737548', '19178'], dtype=object),
#  array(['645096', '549376', '595309', '472318', '738454', '286701',
#         '619453', '842735'], dtype=object),
#  array(['485891'], dtype=object),
#  array(['50824'], dtype=object),
#  array(['327807', '346353'], dtype=object),
#  array(['748033', '678194', '384404'], dtype=object),
#  array(['419492'], dtype=object),
#  array(['624940', '712821', '741885', '514210'], dtype=object),
#  array(['363998', '669728'], dtype=object),
#  array(['401575', '401571'], dtype=object),
#  array(['407110', '208074', '584713', '810170', '696400', '777424',
#         '718485', '490135', '496185', '225170', '686245', '564568',
#         '134278', '213692', '134305', '6792', '3122', '3127', '333672',
#         '2881', '820651', '411668', '823138', '696403', '696017', '257479',
#         '684830', '213691', '1170', '780220', '768469', '41709'],
#        dtype=object),
#  array(['214842'], dtype=object),
#  array(['235561', '794349', '809314', '784934', '68058', '488312', '7483'],
#        dtype=object),
#  array(['467812'], dtype=object),
#  array(['621088', '511309', '343702', '256446', '812389'], dtype=object),
#  array(['544521', '545604', '817143', '740443'], dtype=object),
#  array(['715109'], dtype=object),
#  array(['174812', '235159'], dtype=object),
#  array(['304142'], dtype=object),
#  array(['714067', '193461', '461083'], dtype=object),
#  array(['554990', '769724', '824990'], dtype=object),
#  array(['69024', '69028'], dtype=object),
#  array(['479495', '479536', '442916', '773618', '521535', '479515',
#         '479496', '482708', '220308', '757579', '479541', '482694',
#         '479551', '442936', '479550', '479535', '220309', '479516',
#         '479517', '220310', '479552', '479518', '617177', '479512',
#         '450887'], dtype=object),
#  array(['58765', '183572'], dtype=object),
#  array(['495890', '755969', '729048', '408784'], dtype=object),
#  array(['412925', '1259', '800320', '656704'], dtype=object),
#  array(['429278', '322491', '731145', '774120', '322485', '805827',
#         '285063', '316500'], dtype=object),
#  array(['618077', '80799', '538284', '538269', '780415', '618081',
#         '610874', '618076'], dtype=object),
#  array(['164626', '86660'], dtype=object),
#  array(['736412', '346531'], dtype=object),
#  array(['300787', '809620', '807319'], dtype=object),
#  array(['688432', '832687', '710255', '601282', '836169', '770725',
#         '688875'], dtype=object),
#  array(['581445', '581455', '578369'], dtype=object),
#  array(['227789'], dtype=object),
#  array(['603604', '163441'], dtype=object),
#  array(['737824', '781710', '828915'], dtype=object),
#  array(['479877', '543566'], dtype=object),
#  array(['742503', '715121'], dtype=object),
#  array(['558852', '474475'], dtype=object),
#  array(['805526', '805524', '562636'], dtype=object),
#  array(['261565', '150890', '309009'], dtype=object),
#  array(['160793', '221545'], dtype=object),
#  array(['387935', '741516', '698866'], dtype=object),
#  array(['199078', '199076'], dtype=object),
#  array(['485891', '543523', '343253'], dtype=object),
#  ...]

# %%
import random
def oversample(x, n):
    lst = []
    for i in x:
        tmp = []
        for j in range(n):
          random.shuffle(i)
          tmp += list(i)
        lst.append(tmp)
    return lst

# %%
w2v_input = oversample(train_data, 10)

# %%
w2v_input2 = oversample(train_data2, 10)

# %%
w2v_input3 = oversample(train_data3, 10)

# %%
w2v_input4 = oversample(train_data4, 10)

# %%
w2v_input5 = oversample(train_data5, 10)

# %%
w2v_input6 = oversample(train_data6, 10)

# %%
w2v_input7 = oversample(train_data7, 10)

# %%
from gensim.models import word2vec

w2v = word2vec.Word2Vec(sentences = w2v_input,
                        size = 60, #단어 벡터의 크기
                        window = 3, #주변단어개수
                        min_count = 1, #전체 문서에 등장한 최소 개수
                        sg = 1).wv # sg : Training algorithm: 1 for skip-gram; otherwise CBOW.

# %%
w2v_2 = word2vec.Word2Vec(sentences = w2v_input2,
                        size = 60, #단어 벡터의 크기
                        window = 3, #주변단어개수
                        min_count = 1, #전체 문서에 등장한 최소 개수
                        sg = 1).wv

# %%
w2v_3 = word2vec.Word2Vec(sentences = w2v_input3,
                        size = 60, #단어 벡터의 크기
                        window = 3, #주변단어개수
                        min_count = 1, #전체 문서에 등장한 최소 개수
                        sg = 1).wv

# %%
w2v_4 = word2vec.Word2Vec(sentences = w2v_input4,
                        size = 60, #단어 벡터의 크기
                        window = 3, #주변단어개수
                        min_count = 1, #전체 문서에 등장한 최소 개수
                        sg = 1).wv

# %%
w2v_5 = word2vec.Word2Vec(sentences = w2v_input5,
                        size = 60, #단어 벡터의 크기
                        window = 3, #주변단어개수
                        min_count = 1, #전체 문서에 등장한 최소 개수
                        sg = 1).wv

# %%
w2v_6 = word2vec.Word2Vec(sentences = w2v_input6,
                        size = 60, #단어 벡터의 크기
                        window = 3, #주변단어개수
                        min_count = 1, #전체 문서에 등장한 최소 개수
                        sg = 1).wv

# %%
w2v_7 = word2vec.Word2Vec(sentences = w2v_input7,
                        size = 60, #단어 벡터의 크기
                        window = 3, #주변단어개수
                        min_count = 1, #전체 문서에 등장한 최소 개수
                        sg = 1).wv

# %%
train_mean_vector = []
from tqdm import tqdm
for words in tqdm(train_data):
        tmp = np.zeros(60)             # 다음 customer ID에 대한 vector를 계삲하기 전 0으로 초기화
        cnt = 0
        for word in words:
            try:
                tmp += w2v[word]
                cnt += 1
            except:
                pass
        tmp /= cnt                      # customer ID 에 있는 아이템 갯수로 전체 벡터를 mean해줌  
        train_mean_vector.append(tmp)
        
train_mean_vector = np.array(train_mean_vector)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 150000/150000 [00:02<00:00, 72024.58it/s]

# %%
train_mean_vector_2 = []
from tqdm import tqdm
for words in tqdm(train_data2):
        tmp = np.zeros(60)             # 다음 customer ID에 대한 vector를 계삲하기 전 0으로 초기화
        cnt = 0
        for word in words:
            try:
                tmp += w2v_2[word]
                cnt += 1
            except:
                pass
        tmp /= cnt                      # customer ID 에 있는 아이템 갯수로 전체 벡터를 mean해줌  
        train_mean_vector_2.append(tmp)
        
train_mean_vector_2 = np.array(train_mean_vector_2)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 150000/150000 [00:02<00:00, 53905.99it/s]

# %%
train_mean_vector_3 = []
from tqdm import tqdm
for words in tqdm(train_data3):
        tmp = np.zeros(60)             # 다음 customer ID에 대한 vector를 계삲하기 전 0으로 초기화
        cnt = 0
        for word in words:
            try:
                tmp += w2v_3[word]
                cnt += 1
            except:
                pass
        tmp /= cnt                      # customer ID 에 있는 아이템 갯수로 전체 벡터를 mean해줌  
        train_mean_vector_3.append(tmp)
        
train_mean_vector_3 = np.array(train_mean_vector_3)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 150000/150000 [00:02<00:00, 72101.02it/s]

# %%
train_mean_vector_4 = []
from tqdm import tqdm
for words in tqdm(train_data4):
        tmp = np.zeros(60)             # 다음 customer ID에 대한 vector를 계삲하기 전 0으로 초기화
        cnt = 0
        for word in words:
            try:
                tmp += w2v_4[word]
                cnt += 1
            except:
                pass
        tmp /= cnt                      # customer ID 에 있는 아이템 갯수로 전체 벡터를 mean해줌  
        train_mean_vector_4.append(tmp)
        
train_mean_vector_4 = np.array(train_mean_vector_4)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 150000/150000 [00:03<00:00, 47495.84it/s]

# %%
train_mean_vector_5 = []
from tqdm import tqdm
for words in tqdm(train_data5):
        tmp = np.zeros(60)             # 다음 customer ID에 대한 vector를 계삲하기 전 0으로 초기화
        cnt = 0
        for word in words:
            try:
                tmp += w2v_5[word]
                cnt += 1
            except:
                pass
        tmp /= cnt                      # customer ID 에 있는 아이템 갯수로 전체 벡터를 mean해줌  
        train_mean_vector_5.append(tmp)
        
train_mean_vector_5 = np.array(train_mean_vector_5)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 150000/150000 [00:02<00:00, 53807.31it/s]

# %%
train_mean_vector_6 = []
from tqdm import tqdm
for words in tqdm(train_data6):
        tmp = np.zeros(60)             # 다음 customer ID에 대한 vector를 계삲하기 전 0으로 초기화
        cnt = 0
        for word in words:
            try:
                tmp += w2v_6[word]
                cnt += 1
            except:
                pass
        tmp /= cnt                      # customer ID 에 있는 아이템 갯수로 전체 벡터를 mean해줌  
        train_mean_vector_6.append(tmp)
        
train_mean_vector_6 = np.array(train_mean_vector_6)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 150000/150000 [00:01<00:00, 77799.93it/s]

# %%
train_mean_vector_7 = []
from tqdm import tqdm
for words in tqdm(train_data7):
        tmp = np.zeros(60)             # 다음 customer ID에 대한 vector를 계삲하기 전 0으로 초기화
        cnt = 0
        for word in words:
            try:
                tmp += w2v_7[word]
                cnt += 1
            except:
                pass
        tmp /= cnt                      # customer ID 에 있는 아이템 갯수로 전체 벡터를 mean해줌  
        train_mean_vector_7.append(tmp)
        
train_mean_vector_7 = np.array(train_mean_vector_7)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 150000/150000 [00:02<00:00, 51486.47it/s]

# %%
test_mean_vector = []

for words in tqdm(test_data):
        tmp = np.zeros(60)
        cnt = 0
        for word in words:
            try:
                tmp += w2v[word]
                cnt += 1
            except:
                pass
        tmp /= cnt
        test_mean_vector.append(tmp)
test_mean_vector = np.array(test_mean_vector)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 113104/113104 [00:01<00:00, 74654.54it/s]

# %%
test_mean_vector_2 = []

for words in tqdm(test_data2):
        tmp = np.zeros(60)
        cnt = 0
        for word in words:
            try:
                tmp += w2v_2[word]
                cnt += 1
            except:
                pass
        tmp /= cnt
        test_mean_vector_2.append(tmp)
test_mean_vector_2 = np.array(test_mean_vector_2)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 113104/113104 [00:01<00:00, 61374.06it/s]

# %%
test_mean_vector_3 = []

for words in tqdm(test_data3):
        tmp = np.zeros(60)
        cnt = 0
        for word in words:
            try:
                tmp += w2v_3[word]
                cnt += 1
            except:
                pass
        tmp /= cnt
        test_mean_vector_3.append(tmp)
test_mean_vector_3 = np.array(test_mean_vector_3)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 113104/113104 [00:01<00:00, 66778.15it/s]

# %%
test_mean_vector_4 = []

for words in tqdm(test_data4):
        tmp = np.zeros(60)
        cnt = 0
        for word in words:
            try:
                tmp += w2v_4[word]
                cnt += 1
            except:
                pass
        tmp /= cnt
        test_mean_vector_4.append(tmp)
test_mean_vector_4 = np.array(test_mean_vector_4)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 113104/113104 [00:02<00:00, 46214.79it/s]

# %%
test_mean_vector_5 = []

for words in tqdm(test_data5):
        tmp = np.zeros(60)
        cnt = 0
        for word in words:
            try:
                tmp += w2v_5[word]
                cnt += 1
            except:
                pass
        tmp /= cnt
        test_mean_vector_5.append(tmp)
test_mean_vector_5 = np.array(test_mean_vector_5)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 113104/113104 [00:02<00:00, 54762.01it/s]

# %%
test_mean_vector_6 = []

for words in tqdm(test_data6):
        tmp = np.zeros(60)
        cnt = 0
        for word in words:
            try:
                tmp += w2v_6[word]
                cnt += 1
            except:
                pass
        tmp /= cnt
        test_mean_vector_6.append(tmp)
test_mean_vector_6 = np.array(test_mean_vector_6)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 113104/113104 [00:01<00:00, 79129.81it/s]

# %%
test_mean_vector_7 = []

for words in tqdm(test_data7):
        tmp = np.zeros(60)
        cnt = 0
        for word in words:
            try:
                tmp += w2v_7[word]
                cnt += 1
            except:
                pass
        tmp /= cnt
        test_mean_vector_7.append(tmp)
test_mean_vector_7 = np.array(test_mean_vector_7)
# Out:
# 100%|███████████████████████████████████████████████████████████████████████| 113104/113104 [00:01<00:00, 57075.43it/s]

# %%
pd.DataFrame(train_mean_vector).isna().sum().sum()
# Out:
# 0

# %%
pd.DataFrame(test_mean_vector).isna().sum().sum()
# Out:
# 0

# %%
pd.DataFrame(train_mean_vector_2).isna().sum().sum()
# Out:
# 0

# %%
pd.DataFrame(test_mean_vector_2).isna().sum().sum()
# Out:
# 385980

# %%
pd.DataFrame(train_mean_vector_3).isna().sum().sum()
# Out:
# 0

# %%
pd.DataFrame(test_mean_vector_3).isna().sum().sum()
# Out:
# 10740

# %%
pd.DataFrame(train_mean_vector_4).isna().sum().sum()
# Out:
# 0

# %%
pd.DataFrame(test_mean_vector_4).isna().sum().sum()
# Out:
# 37140

# %%
pd.DataFrame(train_mean_vector_5).isna().sum().sum()
# Out:
# 0

# %%
pd.DataFrame(test_mean_vector_5).isna().sum().sum()
# Out:
# 623040

# %%
pd.DataFrame(train_mean_vector_6).isna().sum().sum()
# Out:
# 0

# %%
pd.DataFrame(test_mean_vector_6).isna().sum().sum()
# Out:
# 0

# %%
pd.DataFrame(train_mean_vector_7).isna().sum().sum()
# Out:
# 0

# %%
pd.DataFrame(test_mean_vector_7).isna().sum().sum()
# Out:
# 649740

# %%
train_mean_vector = pd.DataFrame(train_mean_vector)
train_mean_vector.columns = train_mean_vector.columns.astype(str) + '_CLAC3_NM'
data_v = pd.concat([data_sc_oh, train_mean_vector], axis=1)

test_mean_vector = pd.DataFrame(test_mean_vector)
test_mean_vector.index = data_te_sc_oh.index
test_mean_vector.columns = test_mean_vector.columns.astype(str) + '_CLAC3_NM'
data_te_v = pd.concat([data_te_sc_oh, test_mean_vector], axis=1)

# %%
train_mean_vector_2 = pd.DataFrame(train_mean_vector_2)
train_mean_vector_2.columns = train_mean_vector_2.columns.astype(str) + '_PD_ADD_NM'
data_v = pd.concat([data_v, train_mean_vector_2], axis=1)

test_mean_vector_2 = pd.DataFrame(test_mean_vector_2)
test_mean_vector_2.index = data_te_v.index
test_mean_vector_2.columns = test_mean_vector_2.columns.astype(str) + '_PD_ADD_NM'
data_te_v = pd.concat([data_te_v, test_mean_vector_2], axis=1)

# %%
train_mean_vector_3 = pd.DataFrame(train_mean_vector_3)
train_mean_vector_3.columns = train_mean_vector_3.columns.astype(str) + '_PD_BRA_NM'
data_v = pd.concat([data_v, train_mean_vector_3], axis=1)

test_mean_vector_3 = pd.DataFrame(test_mean_vector_3)
test_mean_vector_3.index = data_te_v.index
test_mean_vector_3.columns = test_mean_vector_3.columns.astype(str) + '_PD_BRA_NM'
data_te_v = pd.concat([data_te_v, test_mean_vector_3], axis=1)

# %%
train_mean_vector_4 = pd.DataFrame(train_mean_vector_4)
train_mean_vector_4.columns = train_mean_vector_4.columns.astype(str) + '_KWD_NM'
data_v = pd.concat([data_v, train_mean_vector_4], axis=1)

test_mean_vector_4 = pd.DataFrame(test_mean_vector_4)
test_mean_vector_4.index = data_te_v.index
test_mean_vector_4.columns = test_mean_vector_4.columns.astype(str) + '_KWD_NM'
data_te_v = pd.concat([data_te_v, test_mean_vector_4], axis=1)

# %%
train_mean_vector_5 = pd.DataFrame(train_mean_vector_5)
train_mean_vector_5.columns = train_mean_vector_5.columns.astype(str) + '_PD_NM'
data_v = pd.concat([data_v, train_mean_vector_5], axis=1)

test_mean_vector_5 = pd.DataFrame(test_mean_vector_5)
test_mean_vector_5.index = data_te_v.index
test_mean_vector_5.columns = test_mean_vector_5.columns.astype(str) + '_PD_NM'
data_te_v = pd.concat([data_te_v, test_mean_vector_5], axis=1)

# %%
train_mean_vector_6 = pd.DataFrame(train_mean_vector_6)
train_mean_vector_6.columns = train_mean_vector_6.columns.astype(str) + '_CLAC2_NM'
data_v = pd.concat([data_v, train_mean_vector_6], axis=1)

test_mean_vector_6 = pd.DataFrame(test_mean_vector_6)
test_mean_vector_6.index = data_te_v.index
test_mean_vector_6.columns = test_mean_vector_6.columns.astype(str) + '_CLAC2_NM'
data_te_v = pd.concat([data_te_v, test_mean_vector_6], axis=1)

# %%
train_mean_vector_7 = pd.DataFrame(train_mean_vector_7)
train_mean_vector_7.columns = train_mean_vector_7.columns.astype(str) + '_PD_C'
data_v = pd.concat([data_v, train_mean_vector_7], axis=1)

test_mean_vector_7 = pd.DataFrame(test_mean_vector_7)
test_mean_vector_7.index = data_te_v.index
test_mean_vector_7.columns = test_mean_vector_7.columns.astype(str) + '_PD_C'
data_te_v = pd.concat([data_te_v, test_mean_vector_7], axis=1)

# %%
data_v = data_v.replace([np.inf, -np.inf], 0)
data_te_v = data_te_v.replace([np.inf, -np.inf], 0)

# %% [markdown]
# # modeling

# %%
X_train = data_v
X_test = data_te_v

# %%
X_train = X_train.fillna(0)
X_test = X_test.fillna(0)

# %%
X_train = X_train.drop(columns = ['CLNT_ID'])
X_test = X_test.drop(columns = ['CLNT_ID'])

y_train = pd.read_csv('y_train.csv').LABEL
display(y_train)
# Out:
# 0         F20
# 1         F30
# 2         F20
# 3         F30
# 4         F30
#          ...
# 149995    F30
# 149996    F30
# 149997    F30
# 149998    F30
# 149999    F30
# Name: LABEL, Length: 150000, dtype: object

# %%
X_train.shape, X_test.shape, y_train.shape
# Out:
# ((150000, 458), (113104, 458), (150000,))

# %% [markdown]
# # cat

# %%
from sklearn.model_selection import StratifiedKFold
from catboost import CatBoostClassifier, Pool
from sklearn.metrics import log_loss

# %%
X_train.shape, X_test.shape, y_train.shape
# Out:
# ((150000, 458), (113104, 458), (150000,))

# %%
cust_te = test.groupby('CLNT_ID')['SESS_ID'].agg([('count', 'count')]).reset_index().CLNT_ID

# %%
cb = CatBoostClassifier(iterations=10000, learning_rate=0.01, eval_metric='MultiClass', silent=True, loss_function='MultiClass', random_state=0)

# %%
ll_list = []
cb_pred = np.zeros((X_test.shape[0], 6))

folds = StratifiedKFold(n_splits=10, random_state=0, shuffle=True)
for train_idx, val_idx in folds.split(X_train, y_train):
    
    train_x = X_train.iloc[train_idx]
    train_y = y_train[train_idx]
    val_x = X_train.iloc[val_idx]
    val_y = y_train[val_idx]
    train_data = Pool(data=train_x, label=train_y)
    val_data = Pool(data=val_x, label=val_y)
    
    cb.fit(train_data, eval_set=val_data, early_stopping_rounds=1000, use_best_model=True, verbose=2000)
    best = cb.best_iteration_
    pred = cb.predict_proba(val_x, ntree_end = best)
    
    ll = log_loss(val_y, pred)
    ll_list.append(ll)
    print(f'FOLD log_loss = {ll}')
    
    sub_pred = cb.predict_proba(X_test, ntree_end = best)[:, ] / 10
    cb_pred += sub_pred
print(f'\n{cb.__class__.__name__} log_loss_score = {np.mean(ll_list)}')

# %%
pred = cb_pred

# %%
result = pd.concat([cust_te, pred], axis=1)
result.columns = ['CLNT_ID','F20','F30','F40','M20','M30','M40']
result
result.to_csv('11.23_kyu_cattune.csv',index=False)
